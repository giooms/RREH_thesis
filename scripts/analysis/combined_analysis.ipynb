# %% [markdown]
# # Triple Analysis
# ## Offshore and Onshore wind, 3 Hydro plants, wave and no production in Belgium

# %%
from datetime import datetime

def is_leap_year(year):
    """Determine whether a year is a leap year."""
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

def sum_hours_over_years(start_year, end_year):
    """Calculate the sum of hours from start_year to end_year, inclusive."""
    total_hours = 0
    for year in range(start_year, end_year + 1):
        if is_leap_year(year):
            total_hours += 366 * 24  # Leap year has 366 days
        else:
            total_hours += 365 * 24  # Non-leap year has 365 days
    return total_hours

# Now, we will iterate over the years from 2015 to 2019 as per the requirement.
start_year = 2015
end_year = 2019
yearly_hours = {}

# Calculating the sum of hours for each range starting from 2015
for year in range(start_year, end_year + 1):
    yearly_hours[f"{start_year}-{year}"] = sum_hours_over_years(start_year, year)

yearly_hours
# Out:
# {'2015-2015': 8760,
#  '2015-2016': 17544,
#  '2015-2017': 26304,
#  '2015-2018': 35064,
#  '2015-2019': 43824}

# %%
from gboml import GbomlGraph

timehorizon = 17544


gboml_model = GbomlGraph(timehorizon=timehorizon)
nodes, edges, param = gboml_model.import_all_nodes_and_edges("../../models/combined/greenland_combined.gboml")
gboml_model.add_global_parameters(param)
gboml_model.add_nodes_in_model(*nodes)
gboml_model.add_hyperedges_in_model(*edges)
gboml_model.build_model()
solution, obj, status, solver_info, constr_info, _ = gboml_model.solve_gurobi(opt_file="gurobi.txt")
print("Solved")
# Out:
# Check variables of node LIQUEFIED_METHANE_CARRIERS_GR : --- 0.0009999275207519531 seconds ---
# Check variables of node LIQUEFIED_METHANE_STORAGE_HUB_GR : --- 0.0 seconds ---
# Check variables of node METHANE_LIQUEFACTION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node METHANATION_PLANTS_GR : --- 0.0010001659393310547 seconds ---
# Check variables of node WATER_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node CARBON_DIOXIDE_STORAGE_GR : --- 0.0009999275207519531 seconds ---
# Check variables of node HYDROGEN_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node DIRECT_AIR_CAPTURE_PLANTS_GR : --- 0.0006871223449707031 seconds ---
# Check variables of node DESALINATION_PLANTS_GR : --- 0.00018906593322753906 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node HVDC_GR : --- 0.0 seconds ---
# Check variables of node BATTERY_STORAGE_GR : --- 0.0010454654693603516 seconds ---
# Check variables of node WAVE_PLANT_GR : --- 0.002512216567993164 seconds ---
# Check variables of node HYDRO_PLANT_05h_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_BASIN_05h_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_PLANT_03j_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_BASIN_03j_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_PLANT_03h_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_BASIN_03h_GR : --- 0.0 seconds ---
# Check variables of node ON_WIND_PLANTS_GR : --- 0.0009958744049072266 seconds ---
# Check variables of node OFF_WIND_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node ENERGY_DEMAND_BE : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_STORAGE_DESTINATION : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_REGASIFICATION : --- 0.0 seconds ---
# Check hyperlink COASTAL_CARBON_DIOXIDE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_LIQUEFIED_METHANE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_METHANE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_WATER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_HYDROGEN_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_POWER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink INLAND_POWER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_05h : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_03j : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_03h : --- 0.0 seconds ---
# Check hyperlink DESTINATION_LIQUEFIED_METHANE_BALANCE : --- 0.0 seconds ---
# Warning : Hyperedge constraint using variables from a single node at line 41
# Check hyperlink DESTINATION_METHANE_BALANCE : --- 0.0 seconds ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-12-03
#
# Reading Gurobi options from file gurobi.opt
# Set parameter Method to value 2
# Set parameter BarHomogeneous to value 1
# Set parameter Crossover to value 0
#
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 7735HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2736890 rows, 1122844 columns and 5182053 nonzeros
# Model fingerprint: 0x17d7228d
# Variable types: 1105299 continuous, 17545 integer (17544 binary)
# Coefficient statistics:
#   Matrix range     [5e-05, 1e+04]
#   Objective range  [2e-04, 3e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-03, 6e+04]
# Presolve removed 2019662 rows and 669839 columns (presolve time = 6s) ...
# Presolve removed 2047389 rows and 682270 columns (presolve time = 10s) ...
# Presolve removed 2124991 rows and 717630 columns
# Presolve time: 12.42s
# Presolved: 611899 rows, 405214 columns, 1858702 nonzeros
# Variable types: 405213 continuous, 1 integer (0 binary)
# Root barrier log...
#
# Ordering time: 0.13s
#
# Barrier statistics:
#  Dense cols : 23
#  AA' NZ     : 1.827e+06
#  Factor NZ  : 9.498e+06 (roughly 500 MB of memory)
#  Factor Ops : 1.783e+08 (less than 1 second per iteration)
#  Threads    : 7
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.59202937e+05 -1.45877094e+09  2.70e+02 1.88e-02  3.03e+03    16s
#    1   3.03156790e+05 -2.89814996e+08  1.40e+02 4.46e+00  6.89e+02    16s
#    2   2.62930416e+05 -6.62800734e+07  1.31e+02 9.25e-01  2.38e+02    17s
#    3   1.91697448e+05 -2.74848986e+07  7.51e+01 2.33e+00  1.17e+02    17s
#    4   1.55445994e+05 -8.16992553e+06  4.92e+01 1.12e-01  5.55e+01    17s
#    5   1.11854897e+05 -4.75697680e+06  1.74e+01 6.33e+01  2.24e+01    18s
#    6   9.69453524e+04 -3.08954090e+06  9.80e+00 2.90e+01  1.33e+01    18s
#    7   9.16478670e+04 -1.50712423e+06  7.93e+00 1.10e+01  8.16e+00    18s
#    8   7.71448218e+04 -7.11600594e+05  4.46e+00 9.05e+00  3.99e+00    19s
#    9   5.32355730e+04 -2.92838828e+05  1.87e+00 4.64e+00  1.45e+00    19s
#   10   1.86807765e+04 -9.42541152e+04  4.38e-01 1.78e+00  3.01e-01    20s
#   11   8.36300908e+03 -4.63949856e+04  1.25e-01 8.93e-01  9.64e-02    20s
#   12   5.81551151e+03 -2.57439504e+04  6.74e-02 5.11e-01  4.97e-02    20s
#   13   4.46398109e+03 -1.48575461e+04  4.11e-02 3.02e-01  2.88e-02    21s
#   14   4.08811421e+03 -9.65824699e+03  3.41e-02 2.52e-01  2.01e-02    21s
#   15   3.96694158e+03 -5.88594659e+03  3.22e-02 1.59e-01  1.42e-02    21s
#   16   3.63079185e+03 -4.01914148e+03  2.63e-02 1.37e-01  1.08e-02    22s
#   17   2.90967554e+03 -4.76526963e+02  1.34e-02 4.64e-02  4.63e-03    22s
#   18   2.66623494e+03  8.41361289e+02  9.42e-03 2.87e-02  2.42e-03    23s
#   19   2.57806005e+03  1.20298182e+03  8.05e-03 2.13e-02  1.80e-03    23s
#   20   2.43144824e+03  1.43795024e+03  5.71e-03 1.65e-02  1.29e-03    23s
#   21   2.37284697e+03  1.59758838e+03  4.78e-03 1.22e-02  1.00e-03    24s
#   22   2.29414030e+03  1.79212933e+03  3.59e-03 6.87e-03  6.38e-04    24s
#   23   2.20567815e+03  1.88897067e+03  2.23e-03 4.38e-03  4.00e-04    25s
#   24   2.16288598e+03  1.99324798e+03  1.56e-03 1.90e-03  2.09e-04    25s
#   25   2.13453894e+03  2.01491139e+03  1.11e-03 1.28e-03  1.47e-04    26s
#   26   2.11289420e+03  2.03955841e+03  7.36e-04 5.47e-04  8.94e-05    26s
#   27   2.09938860e+03  2.04844138e+03  5.12e-04 3.77e-04  6.21e-05    26s
#   28   2.09634093e+03  2.05242777e+03  4.59e-04 3.08e-04  5.34e-05    27s
#   29   2.09162411e+03  2.05631271e+03  3.78e-04 2.40e-04  4.28e-05    27s
#   30   2.08781711e+03  2.05851789e+03  3.12e-04 2.02e-04  3.55e-05    27s
#   31   2.08304299e+03  2.06079712e+03  2.30e-04 1.64e-04  2.70e-05    28s
#   32   2.08064232e+03  2.06355609e+03  1.89e-04 1.10e-04  2.07e-05    28s
#   33   2.07819180e+03  2.06411820e+03  1.47e-04 9.89e-05  1.71e-05    29s
#   34   2.07668441e+03  2.06577482e+03  1.21e-04 7.01e-05  1.32e-05    29s
#   35   2.07580264e+03  2.06666631e+03  1.05e-04 5.19e-05  1.10e-05    30s
#   36   2.07454792e+03  2.06753177e+03  8.38e-05 3.54e-05  8.43e-06    30s
#   37   2.07324808e+03  2.06851939e+03  6.15e-05 1.67e-05  5.64e-06    31s
#   38   2.07269576e+03  2.06897906e+03  5.19e-05 9.65e-06  4.40e-06    31s
#   39   2.07218525e+03  2.06907227e+03  4.33e-05 8.91e-06  3.68e-06    32s
#   40   2.07134942e+03  2.06947306e+03  2.87e-05 4.25e-06  2.20e-06    32s
#   41   2.07088572e+03  2.06952247e+03  2.05e-05 3.53e-06  1.60e-06    33s
#   42   2.07071893e+03  2.06955671e+03  1.75e-05 2.96e-06  1.36e-06    34s
#   43   2.07040901e+03  2.06962003e+03  1.18e-05 2.23e-06  9.25e-07    34s
#   44   2.07024442e+03  2.06969836e+03  8.83e-06 7.65e-07  6.37e-07    35s
#   45   2.07018258e+03  2.06971324e+03  7.67e-06 5.22e-07  5.47e-07    35s
#   46   2.07002583e+03  2.06974078e+03  4.66e-06 3.08e-07  3.32e-07    36s
#   47   2.06993804e+03  2.06976994e+03  2.94e-06 1.07e-06  1.95e-07    36s
#   48   2.06992124e+03  2.06977955e+03  2.61e-06 8.83e-07  1.64e-07    37s
#   49   2.06989078e+03  2.06978333e+03  3.38e-06 2.56e-06  1.26e-07    38s
#   50   2.06981837e+03  2.06978977e+03  9.13e-07 1.39e-06  3.35e-08    38s
#   51   2.06980205e+03  2.06979153e+03  3.47e-07 3.01e-07  1.23e-08    38s
#   52   2.06979557e+03  2.06979188e+03  1.23e-07 1.17e-07  4.32e-09    39s
#   53   2.06979530e+03  2.06979191e+03  4.31e-07 1.08e-07  3.98e-09    40s
#   54   2.06979491e+03  2.06979210e+03  3.87e-07 4.61e-08  3.30e-09    40s
#   55   2.06979368e+03  2.06979214e+03  2.03e-07 3.47e-08  1.83e-09    41s
#   56   2.06979316e+03  2.06979219e+03  1.29e-07 2.93e-08  1.15e-09    42s
#   57   2.06979310e+03  2.06979220e+03  2.52e-07 2.66e-08  1.07e-09    42s
#   58   2.06979289e+03  2.06979220e+03  1.89e-07 4.35e-07  8.17e-10    43s
#   59   2.06979282e+03  2.06979221e+03  1.68e-07 4.59e-07  7.31e-10    43s
#   60   2.06979280e+03  2.06979221e+03  2.78e-07 5.86e-07  7.07e-10    44s
#   61   2.06979278e+03  2.06979221e+03  4.19e-07 6.35e-07  6.68e-10    44s
#   62   2.06979275e+03  2.06979222e+03  5.43e-07 4.82e-07  6.32e-10    45s
#   63   2.06979273e+03  2.06979222e+03  5.25e-07 6.13e-07  6.10e-10    46s
#   64   2.06979271e+03  2.06979223e+03  4.93e-07 4.28e-07  5.74e-10    46s
#   65   2.06979271e+03  2.06979223e+03  5.31e-07 4.27e-07  5.74e-10    47s
#   66   2.06979269e+03  2.06979223e+03  5.12e-07 1.26e-07  5.50e-10    48s
#   67   2.06979269e+03  2.06979223e+03  5.13e-07 1.16e-07  5.51e-10    48s
#   68   2.06979267e+03  2.06979223e+03  4.89e-07 4.05e-07  5.26e-10    49s
#   69   2.06979267e+03  2.06979223e+03  1.21e-06 4.02e-07  5.26e-10    49s
#   70   2.06979265e+03  2.06979223e+03  1.16e-06 6.68e-07  5.05e-10    50s
#   71   2.06979265e+03  2.06979223e+03  1.16e-06 6.67e-07  5.05e-10    51s
#   72   2.06979261e+03  2.06979224e+03  1.04e-06 1.23e-06  4.51e-10    51s
#   73   2.06979261e+03  2.06979224e+03  1.04e-06 1.20e-06  4.49e-10    52s
#   74   2.06979261e+03  2.06979224e+03  1.03e-06 1.21e-06  4.47e-10    53s
#   75   2.06979261e+03  2.06979224e+03  1.03e-06 1.21e-06  4.47e-10    53s
#   76   2.06979260e+03  2.06979224e+03  1.01e-06 9.90e-07  4.37e-10    54s
#   77   2.06979260e+03  2.06979224e+03  1.01e-06 9.88e-07  4.36e-10    55s
#   78   2.06979258e+03  2.06979224e+03  9.52e-07 1.01e-06  4.12e-10    55s
#   79   2.06979258e+03  2.06979224e+03  9.51e-07 1.00e-06  4.12e-10    56s
#   80   2.06979258e+03  2.06979224e+03  9.51e-07 1.00e-06  4.11e-10    57s
#   81   2.06979258e+03  2.06979224e+03  9.51e-07 1.00e-06  4.11e-10    57s
#   82   2.06979258e+03  2.06979224e+03  9.50e-07 1.00e-06  4.11e-10    58s
#
# Barrier solved model in 82 iterations and 57.98 seconds (56.26 work units)
# Optimal objective 2.06979273e+03
#
#
# Root crossover log...
#
#   149949 DPushes remaining with DInf 0.0000000e+00                59s
#    65630 DPushes remaining with DInf 0.0000000e+00                60s
#    26637 DPushes remaining with DInf 0.0000000e+00                65s
#    21297 DPushes remaining with DInf 0.0000000e+00                71s
#    19301 DPushes remaining with DInf 0.0000000e+00                76s
#    17231 DPushes remaining with DInf 0.0000000e+00                84s
#    16833 DPushes remaining with DInf 0.0000000e+00                89s
#    16435 DPushes remaining with DInf 0.0000000e+00                94s
#    16037 DPushes remaining with DInf 0.0000000e+00               100s
#    15639 DPushes remaining with DInf 0.0000000e+00               105s
#    15241 DPushes remaining with DInf 0.0000000e+00               110s
#    14445 DPushes remaining with DInf 0.0000000e+00               118s
#    14047 DPushes remaining with DInf 0.0000000e+00               122s
#    13649 DPushes remaining with DInf 0.0000000e+00               126s
#    12853 DPushes remaining with DInf 0.0000000e+00               133s
#    12455 DPushes remaining with DInf 0.0000000e+00               137s
#    12057 DPushes remaining with DInf 0.0000000e+00               140s
#    11261 DPushes remaining with DInf 0.0000000e+00               148s
#    10863 DPushes remaining with DInf 0.0000000e+00               152s
#    10465 DPushes remaining with DInf 0.0000000e+00               156s
#     9669 DPushes remaining with DInf 0.0000000e+00               163s
#     8873 DPushes remaining with DInf 0.0000000e+00               166s
#     7679 DPushes remaining with DInf 0.0000000e+00               170s
#     6485 DPushes remaining with DInf 0.0000000e+00               175s
#     5689 DPushes remaining with DInf 0.0000000e+00               182s
#     5291 DPushes remaining with DInf 0.0000000e+00               186s
#     4495 DPushes remaining with DInf 0.0000000e+00               192s
#     4097 DPushes remaining with DInf 0.0000000e+00               196s
#     3301 DPushes remaining with DInf 0.0000000e+00               203s
#     2903 DPushes remaining with DInf 0.0000000e+00               207s
#     2505 DPushes remaining with DInf 0.0000000e+00               210s
#     1709 DPushes remaining with DInf 0.0000000e+00               217s
#     1311 DPushes remaining with DInf 0.0000000e+00               220s
#      515 DPushes remaining with DInf 0.0000000e+00               226s
#        0 DPushes remaining with DInf 0.0000000e+00               229s
#
#    86584 PPushes remaining with PInf 7.1727809e-03               229s
#    63247 PPushes remaining with PInf 8.4701888e+02               233s
#    53296 PPushes remaining with PInf 8.4701393e+02               238s
#    23801 PPushes remaining with PInf 3.5238834e+02               241s
#    10767 PPushes remaining with PInf 3.5237044e+02               245s
#     8379 PPushes remaining with PInf 3.5237044e+02               250s
#     5991 PPushes remaining with PInf 3.5237044e+02               255s
#     3603 PPushes remaining with PInf 3.5237030e+02               260s
#      694 PPushes remaining with PInf 3.5237030e+02               266s
#        0 PPushes remaining with PInf 3.5237030e+02               267s
#
#   Push phase complete: Pinf 3.5237030e+02, Dinf 1.1972737e+02    268s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   138103    2.0697923e+03   0.000000e+00   1.197274e+02    268s
#   138501    2.0697923e+03   0.000000e+00   1.125502e+01    272s
#   139046    2.0697923e+03   3.544882e+02   0.000000e+00    276s
#   139299    2.0697923e+03   0.000000e+00   0.000000e+00    280s
#   139299    2.0697923e+03   0.000000e+00   0.000000e+00    281s
#
# Root relaxation: objective 2.069792e+03, 139299 iterations, 266.54 seconds (777.92 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2069.79227    0    1          - 2069.79227      -     -  280s
#      0     0 2069.79227    0    1          - 2069.79227      -     -  339s
# H    0     0                    2069.7922753 2069.79227  0.00%     -  345s
#
# Explored 1 nodes (139299 simplex iterations) in 345.41 seconds (978.38 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2069.79
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.069792275286e+03, best bound 2.069792273228e+03, gap 0.0000%
# Solved

# %%
import json

gathered_data = gboml_model.turn_solution_to_dictionary(solver_info, status, solution, obj, constr_info)
print("Json done")
with open(f'../../models/combined/results/RREH.json', "w") as fp:json.dump(gathered_data, fp, indent=4)
# Out:
# Json done

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
class MakeMeReadable:
    def __init__(self, d):
        self.d = d
    
    def __dir__(self):
        return self.d.keys()
    
    def __getattr__(self, v):
        try:
            out = self.d[v]
            if isinstance(out, dict):
                return MakeMeReadable(out)
            return out
        except:
            return getattr(self.d, v)
        
    def __str__(self):
        return str(self.d)
    
    def __repr__(self):
        return repr(self.d)

# %%
dico = {}
with open('../../models/combined/results/RREH.json', 'r') as f:
    dico = json.load(f)
            
d = MakeMeReadable(dico)
    
if isinstance(dico, dict):
    print('The data is a dictionary')
else:
    print('The data is not a dictionary')
# Out:
# The data is a dictionary

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(18, 15), constrained_layout=True)
ylim = (-0.1, 0.1)
axs = axs.flatten()
def plot_balance(ax, data, title):
    ax.plot(data)
    ax.set_ylim(ylim)
    ax.set_title(title)
    
# GR_CO2 Balance
co2_storage_gr_in = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.carbon_dioxide_in.values)
co2_storage_gr_out = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.carbon_dioxide_out.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.carbon_dioxide.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.carbon_dioxide.values)
co2_balance_gr = dac_gr + co2_storage_gr_out - co2_storage_gr_in - methanation_gr

plot_balance(axs[0], co2_balance_gr, 'GR_CO2 Balance')

# GR_LCH4 Balance
lch4_carriers_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_CARRIERS_GR.variables.liquefied_methane_in.values)
lch4_storage_gr_in = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_in.values)
lch4_storage_gr_out = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_out.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.liquefied_methane.values)
lch4_balance_gr = ch4_liquefaction_gr + lch4_storage_gr_out - lch4_storage_gr_in - lch4_carriers_gr

plot_balance(axs[1], lch4_balance_gr, 'GR_LCH4 Balance')

# Check BE_CH4 Balance
conversion_factor = d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.conversion_factor
demand_CH4 = np.array(d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.demand)
lch4_regasification_be = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.methane.values)
ch4_balance_be = conversion_factor * lch4_regasification_be - 10 * demand_CH4[:timehorizon]

plot_balance(axs[2], ch4_balance_be, 'BE_CH4 Balance')


# Check BE_LCH4 Balance
lch4_carriers_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_CARRIERS_GR.variables.liquefied_methane_out.values)
lch4_storage_dest_in = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_in.values)
lch4_storage_dest_out = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_out.values)
lch4_regasification_be = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.liquefied_methane.values)
lch4_balance_be = lch4_carriers_gr + lch4_storage_dest_out - lch4_storage_dest_in - lch4_regasification_be

plot_balance(axs[3], lch4_balance_be, 'BE_LCH4 Balance')


# Check GR_INLAND CH4 Balance
off_wind_gr = np.array(d.solution.elements.OFF_WIND_PLANTS_GR.variables.electricity.values)
on_wind_gr = np.array(d.solution.elements.ON_WIND_PLANTS_GR.variables.electricity.values)
battery_storage_gr_out = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_out.values)
battery_storage_gr_in = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_in.values)
hvdc_gr_in = np.array(d.solution.elements.HVDC_GR.variables.electricity_in.values)
hydro_03h_gr = np.array(d.solution.elements.HYDRO_PLANT_03h_GR.variables.electricity.values)
hydro_03j_gr = np.array(d.solution.elements.HYDRO_PLANT_03j_GR.variables.electricity.values)
hydro_05h_gr = np.array(d.solution.elements.HYDRO_PLANT_05h_GR.variables.electricity.values)
wave_gr = np.array(d.solution.elements.WAVE_PLANT_GR.variables.electricity.values)

power_balance_gr = off_wind_gr + on_wind_gr + hydro_03h_gr + hydro_03j_gr + hydro_05h_gr + wave_gr + battery_storage_gr_out - battery_storage_gr_in - hvdc_gr_in

plot_balance(axs[4], power_balance_gr, 'GR_Inland CH4 Balance')


# Check GR_Coastal Power Balance
hvdc_gr_out = np.array(d.solution.elements.HVDC_GR.variables.electricity_out.values)
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.electricity.values)
h2_storage_gr = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.electricity.values)
desalination_gr = np.array(d.solution.elements.DESALINATION_PLANTS_GR.variables.electricity.values)
h2o_storage_gr = np.array(d.solution.elements.WATER_STORAGE_GR.variables.electricity.values)
co2_storage_gr = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.electricity.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.electricity.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.electricity.values)
power_balance_gr = hvdc_gr_out - electrolysis_gr - h2_storage_gr - desalination_gr - h2o_storage_gr - co2_storage_gr - ch4_liquefaction_gr - dac_gr 

plot_balance(axs[5], power_balance_gr, 'GR_Coastal Power Balance')


# Check GR_Coastal H2 Balance
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.hydrogen.values)
h2_storage_gr_out = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_out.values)
h2_storage_gr_in = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_in.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.hydrogen.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.hydrogen.values)
h2_balance_gr = electrolysis_gr + h2_storage_gr_out - h2_storage_gr_in - methanation_gr - dac_gr

plot_balance(axs[6], h2_balance_gr, 'GR_Coastal H2 Balance')


# Check GR_Coastal H2O Balance
desalination_gr = np.array(d.solution.elements.DESALINATION_PLANTS_GR.variables.water.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.water.values)
h2o_storage_gr_out = np.array(d.solution.elements.WATER_STORAGE_GR.variables.water_out.values)
h2o_storage_gr_in = np.array(d.solution.elements.WATER_STORAGE_GR.variables.water_in.values)
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.water.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.water.values)
h20_balance_gr = desalination_gr + methanation_gr + h2o_storage_gr_out - h2o_storage_gr_in - electrolysis_gr - dac_gr

plot_balance(axs[7], h20_balance_gr, 'GR_Coastal H2O Balance')

# Check GR_Coastal CH4 Balance
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.methane.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.liquefied_methane.values)
ch4_balance_gr = methanation_gr - ch4_liquefaction_gr

plot_balance(axs[8], ch4_balance_gr, 'GR_Coastal CH4 Balance')

plt.show()

print()

# %%
ls_nodes = list(d.model.nodes.keys())

print(ls_nodes)
# Out:
# ['LIQUEFIED_METHANE_CARRIERS_GR', 'LIQUEFIED_METHANE_STORAGE_HUB_GR', 'METHANE_LIQUEFACTION_PLANTS_GR', 'METHANATION_PLANTS_GR', 'WATER_STORAGE_GR', 'CARBON_DIOXIDE_STORAGE_GR', 'HYDROGEN_STORAGE_GR', 'DIRECT_AIR_CAPTURE_PLANTS_GR', 'DESALINATION_PLANTS_GR', 'ELECTROLYSIS_PLANTS_GR', 'HVDC_GR', 'BATTERY_STORAGE_GR', 'WAVE_PLANT_GR', 'HYDRO_PLANT_05h_GR', 'HYDRO_BASIN_05h_GR', 'HYDRO_PLANT_03j_GR', 'HYDRO_BASIN_03j_GR', 'HYDRO_PLANT_03h_GR', 'HYDRO_BASIN_03h_GR', 'ON_WIND_PLANTS_GR', 'OFF_WIND_PLANTS_GR', 'ENERGY_DEMAND_BE', 'LIQUEFIED_METHANE_STORAGE_DESTINATION', 'LIQUEFIED_METHANE_REGASIFICATION']

# %%
def cost_rreh(ls:list):
    if len(ls) == 0:
        return 0.0

    cost = 0

    for ele in ls:
        # print(f"{ele = }")
        # print(dico["solution"]["elements"][ele]["objectives"])
        try:
            cost += np.sum(dico["solution"]["elements"][ele]["objectives"]["unnamed"])
        except:
            for e in dico["solution"]["elements"][ele]["objectives"]["named"].values():
                # print(f"{e = }")
                cost += e
        # print(f"{cost = }")
    
    return cost

# %%
import re 

excluded_hydro_basins = [node for node in ls_nodes if re.match(r'HYDRO_BASIN_[\w]+_GR$', node)]

try:
    GR_nodes = [node for node in ls_nodes if node.endswith("_GR") and node not in excluded_hydro_basins]
except:
    GR_nodes = []
BE_nodes = list(map(lambda string: string if string[-3:] == "_BE" or string in ["PCCC_CCGT", "PCCC", "CO2_EXPORT", "LIQUEFIED_METHANE_STORAGE_DESTINATION","LIQUEFIED_METHANE_REGASIFICATION"] else None, ls_nodes))

try:
    GR_nodes = list(filter(lambda x: x not in [None, "PCCC", "PROD_CO2", "CO2_EXPORT"], GR_nodes))
except:
    GR_nodes = []
BE_nodes = list(filter(lambda x: x not in [None, "PROD_CO2"], BE_nodes))

cost_GR = cost_rreh(GR_nodes)
cost_BE = cost_rreh(BE_nodes)


print(f"GR {cost_GR = }")
print(f"BE {cost_BE = }")


obj_cost = d.solution.objective
tot_cost = np.sum([cost_GR, cost_BE])

abs_diff = np.abs(d.solution.objective - np.sum([cost_GR, cost_BE]))
print(f"{obj_cost = }")
print(f"{tot_cost = }")
print(abs_diff < 0.1)
# Out:
# GR cost_GR = 2051.764752896909
# BE cost_BE = 18.027522389570443
# obj_cost = 2069.792275287234
# tot_cost = 2069.7922752864797
# True

# %%
# Initialize a dictionary to hold individual capacities
plant_capacities = {}

# Store wind capacities individually and add them to the total capacity
plant_capacities['wind_onshore_gr'] = d.solution.elements.ON_WIND_PLANTS_GR.variables.capacity.values[0]
plant_capacities['wind_off_gr'] = d.solution.elements.OFF_WIND_PLANTS_GR.variables.capacity.values[0]

wave_n_units = d.solution.elements.WAVE_PLANT_GR.variables.num_units.values[0]
wave_RP = d.model.nodes.WAVE_PLANT_GR.parameters.unit_rated_power[0]
plant_capacities['wave_off_gr'] = wave_RP * wave_n_units

# Dynamically identify HYDRO_PLANT capacities and store them
for element_name in ls_nodes:
    if re.match(r'HYDRO_PLANT_\w+_GR$', element_name):
        # Extract capacity and store it in the dictionary
        plant_capacities[element_name] = dico["solution"]["elements"][element_name]["variables"]["capacity"]["values"][0]

# Compute the total installed capacity by summing all individual capacities
total_installed_capacity = sum(plant_capacities.values())

# %%
# Doesn't install on/offshore wind turbines if 1,7GW of Hydro

import matplotlib.pyplot as plt
import numpy as np

# Print installed capacities
for plant, capacity in plant_capacities.items():
    plant_type = "hydro" if "HYDRO_PLANT" in plant else "onshore" if "onshore" in plant else "offshore" if "wind_off" in plant else "wave"
    print(f"Installed capacity of {plant_type} = {capacity:.3f} GW")

# Calculate the total installed capacity
total_installed_capacity = sum(plant_capacities.values())

print(f"\nTotal installed capacity = {total_installed_capacity:.3f} GW")

# Calculate total hydro capacity by summing all hydro plant capacities
total_hydro_capacity = sum(capacity for plant, capacity in plant_capacities.items() if "HYDRO_PLANT" in plant)

# Data for the first plot
categories = ['Onshore Wind', 'Offshore Wind', 'Wave', 'Total Hydro']
capacities = [
    plant_capacities.get('wind_onshore_gr', 0),
    plant_capacities.get('wind_off_gr', 0),
    plant_capacities.get('wave_off_gr', 0),
    total_hydro_capacity
]

### Plot 1: Combined Wind and Total Hydro Capacities
plt.figure(figsize=(10, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(categories)))
plt.bar(categories, capacities, color=colors)
plt.ylabel('Installed Capacity (GW)')
plt.title('On-Offshore Wind and Total Hydro Capacities')
# Annotate each bar with its capacity
for i, v in enumerate(capacities):
    plt.text(i, v, f"{v:.3f}", ha='center', va='bottom')
plt.tight_layout()
plt.show()

### Plot 2: Capacities for Each Hydro Plant Separately
plt.figure(figsize=(10, 6))
hydro_labels = [plant for plant in plant_capacities.keys() if "HYDRO_PLANT" in plant]
hydro_values = [capacity for plant, capacity in plant_capacities.items() if "HYDRO_PLANT" in plant]
colors = plt.cm.viridis(np.linspace(0, 1, len(hydro_labels)))
plt.bar(hydro_labels, hydro_values, color=colors)
plt.title('Capacities for Each Hydro Plant')
# plt.xticks(rotation=45)
# Annotate each hydro plant bar with its capacity
for i, v in enumerate(hydro_values):
    plt.text(i, v, f"{v:.3f}", ha='center', va='bottom')
plt.tight_layout()
plt.show()
# Out:
# Installed capacity of onshore = 2.498 GW
# Installed capacity of offshore = -0.000 GW
# Installed capacity of wave = 0.248 GW
# Installed capacity of hydro = 0.058 GW
# Installed capacity of hydro = 0.099 GW
# Installed capacity of hydro = 0.040 GW
#
# Total installed capacity = 2.943 GW

# %%
gas_demand = d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.demand
gas_demand = np.sum(gas_demand[:timehorizon])/1000
print("the gas demand is ", gas_demand, "TWh")
# Out:
# the gas demand is  1.2970272171668917 TWh

# %%
# LCH4 full production:
gas = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.methane.values) * 15.31 # kt/h * GWh/kt
gas_prod = np.sum(gas) # GWh
gas_prod/1000
# Out:
# 12.970272171668919

# %%
demand_in_mwh = gas_prod * 1e3  # Convert GWh to MWh
total_cost_in_euros = tot_cost * 1e6  # Convert million euros to euros

# Compute price per MWh in euros
price_per_mwh = total_cost_in_euros / demand_in_mwh

print(f"The price is {round(price_per_mwh, 3)} €/MWh \n")
print("In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh")  # Adjusted to €/MWh
print("This system is about", round((price_per_mwh / 45), 3), "times more expensive compared to a reference price of 45 €/MWh")
# Out:
# The price is 159.58 €/MWh
#
# In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh
# This system is about 3.546 times more expensive compared to a reference price of 45 €/MWh

# %%
def cost_rreh_detailed(ls):
    detailed_cost = {}
    if len(ls) == 0:
        return detailed_cost

    for ele in ls:
        node_cost = 0
        try:
            node_cost += np.sum(dico["solution"]["elements"][ele]["objectives"]["unnamed"])
        except:
            for e in dico["solution"]["elements"][ele]["objectives"]["named"].values():
                node_cost += e
        detailed_cost[ele] = node_cost
    
    return detailed_cost

# %%
import matplotlib.pyplot as plt
import numpy as np

cost_details_GR = cost_rreh_detailed(GR_nodes)

sorted_nodes_and_costs = sorted(cost_details_GR.items(), key=lambda item: item[1])
sorted_nodes = [item[0] for item in sorted_nodes_and_costs]
sorted_costs = [item[1] for item in sorted_nodes_and_costs]

# Convert costs to €/MWh
adjusted_costs = [cost *1e6 / demand_in_mwh for cost in sorted_costs]

# Generate colors - ensuring consistent colors across plots
colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_nodes)))

# Plot 1: Stacked Horizontal Bar Chart
plt.figure(figsize=(10, 2))
cumulative_cost = 0  # Start at 0 for the leftmost bar segment

for node, cost, color in zip(sorted_nodes, adjusted_costs, colors):
    plt.barh('GR Nodes', cost, left=cumulative_cost, color=color, label=node)
    cumulative_cost += cost

plt.xlabel('Cost (€/MWh)')
plt.title('Cost Breakdown per GR Node (€/MWh)')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Nodes')
plt.show()

# Plot 2: Vertical Bar Chart with Sorted Nodes
plt.figure(figsize=(10, 6))
bars = plt.bar(sorted_nodes, adjusted_costs, color=colors)

plt.xlabel('Nodes')
plt.ylabel('Cost (€/MWh)')
plt.title('Cost per GR Node (€/MWh)')
plt.xticks(rotation=45, ha="right")

# Adding the cost above each bar
for bar, cost in zip(bars, adjusted_costs):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f"{cost:.2f}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()  # Adjust layout to make room for the rotated x-axis labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_production_dynamics(offshore_wind_gr, onshore_wind_gr, hydro_gr1, hydro_gr2, hydro_gr3, wave, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=len(offshore_wind_gr), freq='H')

    # Create DataFrames
    offshore_wind_df_gr = pd.DataFrame(offshore_wind_gr, index=date_range, columns=['Elec'])
    onshore_wind_df_gr = pd.DataFrame(onshore_wind_gr, index=date_range, columns=['Elec'])
    hydro_df1_gr = pd.DataFrame(hydro_gr1, index=date_range, columns=['Elec'])
    hydro_df2_gr = pd.DataFrame(hydro_gr2, index=date_range, columns=['Elec']) 
    hydro_df3_gr = pd.DataFrame(hydro_gr3, index=date_range, columns=['Elec'])
    wave_df_gr = pd.DataFrame(wave, index=date_range, columns=['Elec'])

   
    # Smooth the data with a rolling mean
    offshore_wind_df_gr['Smoothed'] = offshore_wind_df_gr['Elec'].rolling(window=24).mean()
    onshore_wind_df_gr['Smoothed'] = onshore_wind_df_gr['Elec'].rolling(window=24).mean()
    hydro_df1_gr['Smoothed'] = hydro_df1_gr['Elec'].rolling(window=24).mean()
    hydro_df2_gr['Smoothed'] = hydro_df2_gr['Elec'].rolling(window=24).mean()
    hydro_df3_gr['Smoothed'] = hydro_df3_gr['Elec'].rolling(window=24).mean()
    wave_df_gr['Smoothed'] = wave_df_gr['Elec'].rolling(window=24).mean()     
   
    # Plotting
    fig, axs = plt.subplots(6, 1, figsize=(12, 8), sharex=True)

    colors = plt.cm.viridis(np.linspace(0, 1, 6))

    # Plot each storage type
    for ax, df, color, label in zip(axs,
                                    [offshore_wind_df_gr, onshore_wind_df_gr, hydro_df1_gr, hydro_df2_gr, hydro_df3_gr, wave_df_gr],
                                    colors,
                                    ['Offshore Wind Production (Greenland)', 'Onshore Wind Production (Greenland)', 'Hydro Production 03h (Greenland)', 'Hydro Production 03j (Greenland)', 'Hydro Production 05h (Greenland)', 'Wave Production (Greenland)']):
        ax.fill_between(df.index, df['Smoothed'], color=color)
        ax.set_title(label, fontsize=10, loc='left')
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.set_ylabel('GWh')

    # Adjust layout and show plot
    fig.tight_layout()
    plt.show()

# %%
offshore_prod_gr = np.array(d.solution.elements.OFF_WIND_PLANTS_GR.variables.electricity.values)
onshore_prod_gr = np.array(d.solution.elements.ON_WIND_PLANTS_GR.variables.electricity.values)
hydro_prod_03h_gr = np.array(d.solution.elements.HYDRO_PLANT_03h_GR.variables.electricity.values)
hydro_prod_03j_gr = np.array(d.solution.elements.HYDRO_PLANT_03j_GR.variables.electricity.values)
hydro_prod_05h_gr = np.array(d.solution.elements.HYDRO_PLANT_05h_GR.variables.electricity.values)
wave_prod_gr = np.array(d.solution.elements.WAVE_PLANT_GR.variables.electricity.values)

plot_production_dynamics(offshore_prod_gr, onshore_prod_gr, hydro_prod_03h_gr, hydro_prod_03j_gr, hydro_prod_05h_gr, wave_prod_gr)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import re

def plot_basin_dynamics(basins_data, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=17544, freq='H')
    
    for basin_name, basin_data in basins_data.items():
        fig, axs = plt.subplots(4, 1, figsize=(12, 12), sharex=True)
        window_size = 24  # Smooth over 24 hours
        parameters = ['inflow', 'storage', 'release', 'spill']
        colors = plt.cm.viridis(np.linspace(0, 1, 4))

        for idx, parameter in enumerate(parameters):
            data_df = pd.DataFrame(basin_data[parameter], index=date_range, columns=[parameter]).rolling(window=window_size).mean()
            axs[idx].plot(data_df.index, data_df[parameter], color=colors[idx], label=f"{parameter.title()} (Smoothed)")
            axs[idx].set_title(f"{basin_name} - {parameter.title()} Dynamics", fontsize=10, loc='left')
            axs[idx].set_ylabel('Volume (TCM/h)')
            axs[idx].set_ylim(bottom=0)  # Ensure y-axis starts at 0
            axs[idx].legend(loc='upper right')

        # Format x-axis
        axs[3].xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
        axs[3].xaxis.set_major_locator(mdates.MonthLocator())
        plt.xticks(rotation=45)
        plt.xlabel('Time')
        fig.tight_layout()
        plt.show()

# Assuming 'd' is your data object and 'ls_nodes' is a list of all node names
basins_data = {}

# Dynamically determine all hydro basins from ls_nodes
for node_name in ls_nodes:
    if re.match(r'HYDRO_BASIN_\w+_GR$', node_name):
        basins_data[node_name] = {
            'inflow': np.array(getattr(d.model.nodes, node_name).parameters.inflow_series[:17544]),
            'storage': np.array(getattr(d.solution.elements, node_name).variables.storage.values),
            'release': np.array(getattr(d.solution.elements, node_name).variables.release.values),
            'spill': np.array(getattr(d.solution.elements, node_name).variables.spill.values)
        }

plot_basin_dynamics(basins_data)

# %%
np.array(d.solution.elements.HYDRO_BASIN_03h_GR.variables.storage.values)
# Out:
# array([22500.        , 22499.98652299, 22499.97304598, ...,
#        22499.88097701, 22499.88097701, 22500.        ])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_storage_dynamics(battery_data, hydrogen_data, methane_data_src, methane_data_dest, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=len(battery_data), freq='H')

    # Create DataFrames
    battery_df = pd.DataFrame(battery_data, index=date_range, columns=['Battery'])
    hydrogen_df = pd.DataFrame(hydrogen_data, index=date_range, columns=['Hydrogen'])
    methane_df_gr = pd.DataFrame(methane_data_src, index=date_range, columns=['Methane'])
    methane_df_be = pd.DataFrame(methane_data_dest, index=date_range, columns=['Methane'])


    # Smooth the data with a rolling mean
    battery_df['Smoothed'] = battery_df['Battery'].rolling(window=24).mean()
    hydrogen_df['Smoothed'] = hydrogen_df['Hydrogen'].rolling(window=24).mean()
    methane_df_gr['Smoothed'] = methane_df_gr['Methane'].rolling(window=24).mean()
    methane_df_be['Smoothed'] = methane_df_be['Methane'].rolling(window=24).mean()

    # Plotting
    fig, axs = plt.subplots(4, 1, figsize=(12, 8), sharex=True)

    colors = plt.cm.viridis(np.linspace(0, 1, 4))

    # Plot each storage type
    for ax, df, color, label in zip(axs,
                                    [battery_df, hydrogen_df, methane_df_gr, methane_df_be],
                                    colors,
                                    ['Battery Storage Dynamics', 'Hydrogen Storage Dynamics', 'Liquid Methane Storage Dynamics (Greenland)', 'Liquid Methane Storage Dynamics (Belgium)']):
        ax.fill_between(df.index, df['Smoothed'], color=color)
        ax.set_title(label, fontsize=10, loc='left')
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.set_ylabel('GWh')

    # Adjust layout and show plot
    fig.tight_layout()
    plt.show()

# %%
battery_flow = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_stored.values)
h2_flow = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_stored.values)
lch4_flow_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_stored.values)
lch4_flow_be = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_stored.values)

plot_storage_dynamics(battery_flow, h2_flow, lch4_flow_gr, lch4_flow_be)

print(battery_flow[-1])
print(h2_flow[-1])
print(lch4_flow_gr[-1])
print(lch4_flow_be[-1])
# Out:
# 0.0
# 11.506838432770426
# 10.65789113897208
# 5.7158022320376585

# %%
leftover_lch4 = (lch4_flow_be[-1] + lch4_flow_gr[-1]) * 0.98 * 15.31 *1e3

leftover_lch4 # MWh
# Out:
# 245667.62059995587

# %%
demand_in_mwh = gas_prod * 1e3  # Convert TWh to MWh
total_cost_in_euros = tot_cost * 1e6  # Convert million euros to euros

# Compute price per MWh in euros
price_per_mwh = total_cost_in_euros / (demand_in_mwh+leftover_lch4)

print(f"The price is {round(price_per_mwh, 3)} €/MWh \n")
print("In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh")  # Adjusted to €/MWh
print("This system is about", round((price_per_mwh / 45), 3), "times more expensive compared to a reference price of 45 €/MWh")
# Out:
# The price is 156.613 €/MWh
#
# In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh
# This system is about 3.48 times more expensive compared to a reference price of 45 €/MWh

# %%
import pandas as pd

# Example input data
# If the CSV has no header row, set header=None and provide column names
column_name = ['WaveEnergyDensity']
wave_energy_df = pd.read_csv('../../data/wave_series_goff.csv', header=None, names=column_name)

length_of_installation = d.solution.elements.WAVE_PLANT_GR.variables.length.values[0]
unit_width = d.model.nodes.WAVE_PLANT_GR.parameters.unit_width[0]  # meters
space_between = d.model.nodes.WAVE_PLANT_GR.parameters.space_between[0]  # meters

# Calculate total space required per unit (width + space)
total_space_per_unit = unit_width + space_between

# Calculate the number of units that can be installed
number_of_units = length_of_installation // total_space_per_unit

# Calculate the total energy potential for each wave energy density value
wave_energy_df['TotalEnergyPotentialGW'] = wave_energy_df['WaveEnergyDensity'] * wave_n_units * unit_width

# Calculate the total rated energy capacity based on the number of units
total_rated_capacity_gw = number_of_units * wave_RP

# Check when the total energy potential exceeds the total rated capacity
wave_energy_df['ExceedsRatedPower'] = wave_energy_df['TotalEnergyPotentialGW'] > total_rated_capacity_gw

print(wave_energy_df)
# Out:
#        WaveEnergyDensity  TotalEnergyPotentialGW  ExceedsRatedPower
# 0               0.000022                0.244475              False
# 1               0.000049                0.534239               True
# 2               0.000049                0.537076               True
# 3               0.000019                0.205188              False
# 4               0.000050                0.541234               True
# ...                  ...                     ...                ...
# 43817           0.000047                0.512654               True
# 43818           0.000027                0.293987               True
# 43819           0.000047                0.512808               True
# 43820           0.000047                0.512784               True
# 43821           0.000026                0.286168               True
#
# [43822 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Slice the DataFrame to only include the first x rows
wave_energy_df_subset = wave_energy_df.head(timehorizon)

# Convert wave_prod array/list to a pandas Series for easy plotting (match the length of the DataFrame subset)
wave_prod = pd.Series(wave_prod_gr[:timehorizon])

# For visualization, calculate the total rated capacity again for the plot
total_rated_capacity_gw = number_of_units * wave_RP

# Plotting
plt.figure(figsize=(10, 6))

# Plot Total Energy Potential GW for the subset as grey bars with 90% transparency
plt.bar(wave_energy_df_subset.index, wave_energy_df_subset['TotalEnergyPotentialGW'], color='grey', alpha=0.9, label='Total Energy Potential (GW)')

# Plot the electricity production output as a grey line with 90% transparency
plt.plot(wave_energy_df_subset.index, wave_prod, color='blue', markersize=3, label='Electricity Production Output (GW)', alpha=0.3, linewidth=2)

# Plot a line for the Total Rated Capacity GW Threshold
plt.axhline(y=total_rated_capacity_gw, color='green', linestyle='-', label='Rated Power * Number of Units (GW)')

# Set the y-axis limit to 10 times the total rated capacity
plt.ylim(0, 10 * total_rated_capacity_gw)

plt.xlabel('Index')
plt.ylabel('Energy (GW)')
plt.title('Wave Energy Potential vs. Rated Capacity Threshold (First {} Entries)'.format(timehorizon))
plt.legend()
plt.grid(True)

plt.show()
# Out:
# C:\Users\gille\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
n=0
x=0
g=0
for t in range(len(wave_energy_df_subset)):
    calculated_prod = min(wave_energy_df_subset['WaveEnergyDensity'][t] * wave_n_units * unit_width, wave_RP * wave_n_units)
    if calculated_prod < wave_prod[t]:
        if 1.0001*calculated_prod< wave_prod[t]:
            n+=1
        print(f"Overprod at time {t}: Expected {round(calculated_prod,4)}, in Model {round(wave_prod[t],4)}")
    elif calculated_prod > wave_prod[t]: 
        if calculated_prod> 1.0001*wave_prod[t]:
            x+=1
        print(f"Underprod at time {t}: Expected {round(calculated_prod,4)}, in Model {round(wave_prod[t],4)}")
    elif calculated_prod == wave_prod[t]:
        g+=1
        print(f"Exactprod at time {t}: Expected {round(calculated_prod,4)}, in Model {round(wave_prod[t],4)}")
# Out:
# Underprod at time 0: Expected 0.2445, in Model 0.2445
# Exactprod at time 1: Expected 0.2478, in Model 0.2478
# Exactprod at time 2: Expected 0.2478, in Model 0.2478
# Exactprod at time 3: Expected 0.2052, in Model 0.2052
# Exactprod at time 4: Expected 0.2478, in Model 0.2478
# Exactprod at time 5: Expected 0.2478, in Model 0.2478
# Underprod at time 6: Expected 0.1755, in Model 0.1755
# Exactprod at time 7: Expected 0.2478, in Model 0.2478
# Exactprod at time 8: Expected 0.2478, in Model 0.2478
# Underprod at time 9: Expected 0.1095, in Model 0.1095
# Exactprod at time 10: Expected 0.2478, in Model 0.2478
# Exactprod at time 11: Expected 0.2478, in Model 0.2478
# Exactprod at time 12: Expected 0.2478, in Model 0.2478
# Exactprod at time 13: Expected 0.2478, in Model 0.2478
# Exactprod at time 14: Expected 0.2478, in Model 0.2478
# Underprod at time 15: Expected 0.1833, in Model 0.1833
# Exactprod at time 16: Expected 0.2478, in Model 0.2478
# Exactprod at time 17: Expected 0.2478, in Model 0.2478
# Exactprod at time 18: Expected 0.2478, in Model 0.2478
# Exactprod at time 19: Expected 0.2478, in Model 0.2478
# Exactprod at time 20: Expected 0.2478, in Model 0.2478
# Exactprod at time 21: Expected 0.2478, in Model 0.2478
# Exactprod at time 22: Expected 0.2478, in Model 0.2478
# Exactprod at time 23: Expected 0.2478, in Model 0.2478
# Overprod at time 24: Expected 0.1608, in Model 0.1608
# Exactprod at time 25: Expected 0.2478, in Model 0.2478
# Exactprod at time 26: Expected 0.2478, in Model 0.2478
# Exactprod at time 27: Expected 0.2478, in Model 0.2478
# Exactprod at time 28: Expected 0.2478, in Model 0.2478
# Exactprod at time 29: Expected 0.2478, in Model 0.2478
# Exactprod at time 30: Expected 0.168, in Model 0.168
# Exactprod at time 31: Expected 0.2478, in Model 0.2478
# Exactprod at time 32: Expected 0.2478, in Model 0.2478
# Exactprod at time 33: Expected 0.1494, in Model 0.1494
# Exactprod at time 34: Expected 0.2478, in Model 0.2478
# Exactprod at time 35: Expected 0.2478, in Model 0.2478
# Exactprod at time 36: Expected 0.2478, in Model 0.2478
# Exactprod at time 37: Expected 0.2478, in Model 0.2478
# Exactprod at time 38: Expected 0.2478, in Model 0.2478
# Overprod at time 39: Expected 0.2004, in Model 0.2004
# Exactprod at time 40: Expected 0.2478, in Model 0.2478
# Exactprod at time 41: Expected 0.2478, in Model 0.2478
# Exactprod at time 42: Expected 0.2478, in Model 0.2478
# Exactprod at time 43: Expected 0.2478, in Model 0.2478
# Exactprod at time 44: Expected 0.2478, in Model 0.2478
# Exactprod at time 45: Expected 0.2478, in Model 0.2478
# Exactprod at time 46: Expected 0.2478, in Model 0.2478
# Exactprod at time 47: Expected 0.2478, in Model 0.2478
# Exactprod at time 48: Expected 0.2478, in Model 0.2478
# Exactprod at time 49: Expected 0.2478, in Model 0.2478
# Exactprod at time 50: Expected 0.2478, in Model 0.2478
# Overprod at time 51: Expected 0.2069, in Model 0.2069
# Exactprod at time 52: Expected 0.2478, in Model 0.2478
# Exactprod at time 53: Expected 0.2478, in Model 0.2478
# Overprod at time 54: Expected 0.1623, in Model 0.1623
# Exactprod at time 55: Expected 0.2478, in Model 0.2478
# Exactprod at time 56: Expected 0.2478, in Model 0.2478
# Overprod at time 57: Expected 0.1759, in Model 0.1759
# Exactprod at time 58: Expected 0.2478, in Model 0.2478
# Exactprod at time 59: Expected 0.2478, in Model 0.2478
# Underprod at time 60: Expected 0.1824, in Model 0.1824
# Exactprod at time 61: Expected 0.2478, in Model 0.2478
# Exactprod at time 62: Expected 0.2478, in Model 0.2478
# Exactprod at time 63: Expected 0.2093, in Model 0.2093
# Exactprod at time 64: Expected 0.2478, in Model 0.2478
# Exactprod at time 65: Expected 0.2478, in Model 0.2478
# Overprod at time 66: Expected 0.2277, in Model 0.2277
# Exactprod at time 67: Expected 0.2478, in Model 0.2478
# Exactprod at time 68: Expected 0.2478, in Model 0.2478
# Exactprod at time 69: Expected 0.2086, in Model 0.2086
# Exactprod at time 70: Expected 0.2478, in Model 0.2478
# Exactprod at time 71: Expected 0.2478, in Model 0.2478
# Underprod at time 72: Expected 0.1585, in Model 0.1585
# Exactprod at time 73: Expected 0.2478, in Model 0.2478
# Exactprod at time 74: Expected 0.2478, in Model 0.2478
# Exactprod at time 75: Expected 0.103, in Model 0.103
# Exactprod at time 76: Expected 0.2478, in Model 0.2478
# Exactprod at time 77: Expected 0.2478, in Model 0.2478
# Exactprod at time 78: Expected 0.0688, in Model 0.0688
# Exactprod at time 79: Expected 0.2478, in Model 0.2478
# Exactprod at time 80: Expected 0.2478, in Model 0.2478
# Overprod at time 81: Expected 0.1006, in Model 0.1006
# Exactprod at time 82: Expected 0.2478, in Model 0.2478
# Exactprod at time 83: Expected 0.2478, in Model 0.2478
# Exactprod at time 84: Expected 0.2478, in Model 0.2478
# Exactprod at time 85: Expected 0.2478, in Model 0.2478
# Exactprod at time 86: Expected 0.2478, in Model 0.2478
# Exactprod at time 87: Expected 0.2478, in Model 0.2478
# Exactprod at time 88: Expected 0.2478, in Model 0.2478
# Exactprod at time 89: Expected 0.2478, in Model 0.2478
# Exactprod at time 90: Expected 0.2478, in Model 0.2478
# Exactprod at time 91: Expected 0.2478, in Model 0.2478
# Exactprod at time 92: Expected 0.2478, in Model 0.2478
# Exactprod at time 93: Expected 0.2478, in Model 0.2478
# Exactprod at time 94: Expected 0.2478, in Model 0.2478
# Exactprod at time 95: Expected 0.2478, in Model 0.2478
# Exactprod at time 96: Expected 0.2478, in Model 0.2478
# Exactprod at time 97: Expected 0.2478, in Model 0.2478
# Exactprod at time 98: Expected 0.2478, in Model 0.2478
# Exactprod at time 99: Expected 0.2478, in Model 0.2478
# Exactprod at time 100: Expected 0.2478, in Model 0.2478
# Exactprod at time 101: Expected 0.2478, in Model 0.2478
# Exactprod at time 102: Expected 0.2478, in Model 0.2478
# Exactprod at time 103: Expected 0.2478, in Model 0.2478
# Exactprod at time 104: Expected 0.2478, in Model 0.2478
# Exactprod at time 105: Expected 0.2478, in Model 0.2478
# Exactprod at time 106: Expected 0.2478, in Model 0.2478
# Exactprod at time 107: Expected 0.2478, in Model 0.2478
# Exactprod at time 108: Expected 0.2478, in Model 0.2478
# Exactprod at time 109: Expected 0.2478, in Model 0.2478
# Exactprod at time 110: Expected 0.2478, in Model 0.2478
# Exactprod at time 111: Expected 0.2478, in Model 0.2478
# Exactprod at time 112: Expected 0.2478, in Model 0.2478
# Exactprod at time 113: Expected 0.2478, in Model 0.2478
# Exactprod at time 114: Expected 0.2478, in Model 0.2478
# Exactprod at time 115: Expected 0.2478, in Model 0.2478
# Exactprod at time 116: Expected 0.2478, in Model 0.2478
# Underprod at time 117: Expected 0.2087, in Model 0.2087
# Exactprod at time 118: Expected 0.2478, in Model 0.2478
# Exactprod at time 119: Expected 0.2478, in Model 0.2478
# Exactprod at time 120: Expected 0.2419, in Model 0.2419
# Exactprod at time 121: Expected 0.2478, in Model 0.2478
# Exactprod at time 122: Expected 0.2478, in Model 0.2478
# Exactprod at time 123: Expected 0.2478, in Model 0.2478
# Exactprod at time 124: Expected 0.2478, in Model 0.2478
# Exactprod at time 125: Expected 0.2478, in Model 0.2478
# Exactprod at time 126: Expected 0.1926, in Model 0.1926
# Exactprod at time 127: Expected 0.2478, in Model 0.2478
# Exactprod at time 128: Expected 0.2478, in Model 0.2478
# Exactprod at time 129: Expected 0.1214, in Model 0.1214
# Exactprod at time 130: Expected 0.2478, in Model 0.2478
# Exactprod at time 131: Expected 0.2478, in Model 0.2478
# Exactprod at time 132: Expected 0.0701, in Model 0.0701
# Exactprod at time 133: Expected 0.2478, in Model 0.2478
# Exactprod at time 134: Expected 0.2478, in Model 0.2478
# Exactprod at time 135: Expected 0.0302, in Model 0.0302
# Exactprod at time 136: Expected 0.2478, in Model 0.2478
# Exactprod at time 137: Expected 0.2478, in Model 0.2478
# Exactprod at time 138: Expected 0.2478, in Model 0.2478
# Exactprod at time 139: Expected 0.2478, in Model 0.2478
# Exactprod at time 140: Expected 0.2478, in Model 0.2478
# Exactprod at time 141: Expected 0.2478, in Model 0.2478
# Exactprod at time 142: Expected 0.2478, in Model 0.2478
# Exactprod at time 143: Expected 0.2478, in Model 0.2478
# Exactprod at time 144: Expected 0.2478, in Model 0.2478
# Exactprod at time 145: Expected 0.2478, in Model 0.2478
# Exactprod at time 146: Expected 0.2478, in Model 0.2478
# Exactprod at time 147: Expected 0.2478, in Model 0.2478
# Exactprod at time 148: Expected 0.2478, in Model 0.2478
# Exactprod at time 149: Expected 0.2478, in Model 0.2478
# Exactprod at time 150: Expected 0.2478, in Model 0.2478
# Exactprod at time 151: Expected 0.2478, in Model 0.2478
# Exactprod at time 152: Expected 0.2478, in Model 0.2478
# Exactprod at time 153: Expected 0.2478, in Model 0.2478
# Exactprod at time 154: Expected 0.2478, in Model 0.2478
# Exactprod at time 155: Expected 0.2478, in Model 0.2478
# Exactprod at time 156: Expected 0.2478, in Model 0.2478
# Exactprod at time 157: Expected 0.2478, in Model 0.2478
# Exactprod at time 158: Expected 0.2478, in Model 0.2478
# Exactprod at time 159: Expected 0.2478, in Model 0.2478
# Exactprod at time 160: Expected 0.2478, in Model 0.2478
# Exactprod at time 161: Expected 0.2478, in Model 0.2478
# Exactprod at time 162: Expected 0.2478, in Model 0.2478
# Exactprod at time 163: Expected 0.2478, in Model 0.2478
# Exactprod at time 164: Expected 0.2478, in Model 0.2478
# Exactprod at time 165: Expected 0.2478, in Model 0.2478
# Exactprod at time 166: Expected 0.2478, in Model 0.2478
# Exactprod at time 167: Expected 0.2478, in Model 0.2478
# Exactprod at time 168: Expected 0.2478, in Model 0.2478
# Exactprod at time 169: Expected 0.2478, in Model 0.2478
# Exactprod at time 170: Expected 0.2478, in Model 0.2478
# Exactprod at time 171: Expected 0.2478, in Model 0.2478
# Exactprod at time 172: Expected 0.2478, in Model 0.2478
# Exactprod at time 173: Expected 0.2478, in Model 0.2478
# Exactprod at time 174: Expected 0.2478, in Model 0.2478
# Exactprod at time 175: Expected 0.2478, in Model 0.2478
# Exactprod at time 176: Expected 0.2478, in Model 0.2478
# Exactprod at time 177: Expected 0.2478, in Model 0.2478
# Exactprod at time 178: Expected 0.2478, in Model 0.2478
# Exactprod at time 179: Expected 0.2478, in Model 0.2478
# Exactprod at time 180: Expected 0.2478, in Model 0.2478
# Exactprod at time 181: Expected 0.2478, in Model 0.2478
# Exactprod at time 182: Expected 0.2478, in Model 0.2478
# Exactprod at time 183: Expected 0.2478, in Model 0.2478
# Exactprod at time 184: Expected 0.2478, in Model 0.2478
# Exactprod at time 185: Expected 0.2478, in Model 0.2478
# Exactprod at time 186: Expected 0.2478, in Model 0.2478
# Exactprod at time 187: Expected 0.2478, in Model 0.2478
# Exactprod at time 188: Expected 0.2478, in Model 0.2478
# Exactprod at time 189: Expected 0.2478, in Model 0.2478
# Exactprod at time 190: Expected 0.2478, in Model 0.2478
# Exactprod at time 191: Expected 0.2478, in Model 0.2478
# Exactprod at time 192: Expected 0.2478, in Model 0.2478
# Exactprod at time 193: Expected 0.2478, in Model 0.2478
# Exactprod at time 194: Expected 0.2478, in Model 0.2478
# Exactprod at time 195: Expected 0.2478, in Model 0.2478
# Exactprod at time 196: Expected 0.2478, in Model 0.2478
# Exactprod at time 197: Expected 0.2478, in Model 0.2478
# Exactprod at time 198: Expected 0.2478, in Model 0.2478
# Exactprod at time 199: Expected 0.2478, in Model 0.2478
# Exactprod at time 200: Expected 0.2478, in Model 0.2478
# Exactprod at time 201: Expected 0.2478, in Model 0.2478
# Exactprod at time 202: Expected 0.2478, in Model 0.2478
# Exactprod at time 203: Expected 0.2478, in Model 0.2478
# Underprod at time 204: Expected 0.2252, in Model 0.2252
# Exactprod at time 205: Expected 0.2478, in Model 0.2478
# Exactprod at time 206: Expected 0.2478, in Model 0.2478
# Exactprod at time 207: Expected 0.1924, in Model 0.1924
# Exactprod at time 208: Expected 0.2478, in Model 0.2478
# Exactprod at time 209: Expected 0.2478, in Model 0.2478
# Exactprod at time 210: Expected 0.2478, in Model 0.2478
# Exactprod at time 211: Expected 0.2478, in Model 0.2478
# Exactprod at time 212: Expected 0.2478, in Model 0.2478
# Exactprod at time 213: Expected 0.2478, in Model 0.2478
# Exactprod at time 214: Expected 0.2478, in Model 0.2478
# Exactprod at time 215: Expected 0.2478, in Model 0.2478
# Exactprod at time 216: Expected 0.2478, in Model 0.2478
# Exactprod at time 217: Expected 0.2478, in Model 0.2478
# Exactprod at time 218: Expected 0.2478, in Model 0.2478
# Exactprod at time 219: Expected 0.2478, in Model 0.2478
# Exactprod at time 220: Expected 0.2478, in Model 0.2478
# Exactprod at time 221: Expected 0.2478, in Model 0.2478
# Exactprod at time 222: Expected 0.2478, in Model 0.2478
# Exactprod at time 223: Expected 0.2478, in Model 0.2478
# Exactprod at time 224: Expected 0.2478, in Model 0.2478
# Exactprod at time 225: Expected 0.2478, in Model 0.2478
# Exactprod at time 226: Expected 0.2478, in Model 0.2478
# Exactprod at time 227: Expected 0.2478, in Model 0.2478
# Exactprod at time 228: Expected 0.2478, in Model 0.2478
# Exactprod at time 229: Expected 0.2478, in Model 0.2478
# Exactprod at time 230: Expected 0.2478, in Model 0.2478
# Exactprod at time 231: Expected 0.2478, in Model 0.2478
# Exactprod at time 232: Expected 0.2478, in Model 0.2478
# Exactprod at time 233: Expected 0.2478, in Model 0.2478
# Exactprod at time 234: Expected 0.2478, in Model 0.2478
# Exactprod at time 235: Expected 0.2478, in Model 0.2478
# Exactprod at time 236: Expected 0.2478, in Model 0.2478
# Exactprod at time 237: Expected 0.2478, in Model 0.2478
# Exactprod at time 238: Expected 0.2478, in Model 0.2478
# Exactprod at time 239: Expected 0.2478, in Model 0.2478
# Exactprod at time 240: Expected 0.2478, in Model 0.2478
# Exactprod at time 241: Expected 0.2478, in Model 0.2478
# Exactprod at time 242: Expected 0.2478, in Model 0.2478
# Exactprod at time 243: Expected 0.2478, in Model 0.2478
# Exactprod at time 244: Expected 0.2478, in Model 0.2478
# Exactprod at time 245: Expected 0.2478, in Model 0.2478
# Exactprod at time 246: Expected 0.2478, in Model 0.2478
# Exactprod at time 247: Expected 0.2478, in Model 0.2478
# Exactprod at time 248: Expected 0.2478, in Model 0.2478
# Exactprod at time 249: Expected 0.2478, in Model 0.2478
# Exactprod at time 250: Expected 0.2478, in Model 0.2478
# Exactprod at time 251: Expected 0.2478, in Model 0.2478
# Exactprod at time 252: Expected 0.2478, in Model 0.2478
# Exactprod at time 253: Expected 0.2478, in Model 0.2478
# Exactprod at time 254: Expected 0.2478, in Model 0.2478
# Exactprod at time 255: Expected 0.2478, in Model 0.2478
# Exactprod at time 256: Expected 0.2478, in Model 0.2478
# Exactprod at time 257: Expected 0.2478, in Model 0.2478
# Exactprod at time 258: Expected 0.2478, in Model 0.2478
# Exactprod at time 259: Expected 0.2478, in Model 0.2478
# Exactprod at time 260: Expected 0.2478, in Model 0.2478
# Exactprod at time 261: Expected 0.2478, in Model 0.2478
# Exactprod at time 262: Expected 0.2478, in Model 0.2478
# Exactprod at time 263: Expected 0.2478, in Model 0.2478
# Exactprod at time 264: Expected 0.2478, in Model 0.2478
# Exactprod at time 265: Expected 0.2478, in Model 0.2478
# Exactprod at time 266: Expected 0.2478, in Model 0.2478
# Exactprod at time 267: Expected 0.2478, in Model 0.2478
# Exactprod at time 268: Expected 0.2478, in Model 0.2478
# Exactprod at time 269: Expected 0.2478, in Model 0.2478
# Exactprod at time 270: Expected 0.2478, in Model 0.2478
# Exactprod at time 271: Expected 0.2478, in Model 0.2478
# Exactprod at time 272: Expected 0.2478, in Model 0.2478
# Exactprod at time 273: Expected 0.2478, in Model 0.2478
# Exactprod at time 274: Expected 0.2478, in Model 0.2478
# Exactprod at time 275: Expected 0.2478, in Model 0.2478
# Exactprod at time 276: Expected 0.2478, in Model 0.2478
# Exactprod at time 277: Expected 0.2478, in Model 0.2478
# Exactprod at time 278: Expected 0.2478, in Model 0.2478
# Exactprod at time 279: Expected 0.2478, in Model 0.2478
# Exactprod at time 280: Expected 0.2478, in Model 0.2478
# Exactprod at time 281: Expected 0.2478, in Model 0.2478
# Exactprod at time 282: Expected 0.2478, in Model 0.2478
# Exactprod at time 283: Expected 0.2478, in Model 0.2478
# Exactprod at time 284: Expected 0.2478, in Model 0.2478
# Exactprod at time 285: Expected 0.2478, in Model 0.2478
# Exactprod at time 286: Expected 0.2478, in Model 0.2478
# Exactprod at time 287: Expected 0.2478, in Model 0.2478
# Exactprod at time 288: Expected 0.2478, in Model 0.2478
# Exactprod at time 289: Expected 0.2478, in Model 0.2478
# Exactprod at time 290: Expected 0.2478, in Model 0.2478
# Exactprod at time 291: Expected 0.2478, in Model 0.2478
# Exactprod at time 292: Expected 0.2478, in Model 0.2478
# Exactprod at time 293: Expected 0.2478, in Model 0.2478
# Exactprod at time 294: Expected 0.2478, in Model 0.2478
# Exactprod at time 295: Expected 0.2478, in Model 0.2478
# Exactprod at time 296: Expected 0.2478, in Model 0.2478
# Exactprod at time 297: Expected 0.2478, in Model 0.2478
# Exactprod at time 298: Expected 0.2478, in Model 0.2478
# Exactprod at time 299: Expected 0.2478, in Model 0.2478
# Exactprod at time 300: Expected 0.2478, in Model 0.2478
# Exactprod at time 301: Expected 0.2478, in Model 0.2478
# Exactprod at time 302: Expected 0.2478, in Model 0.2478
# Exactprod at time 303: Expected 0.2478, in Model 0.2478
# Exactprod at time 304: Expected 0.2478, in Model 0.2478
# Exactprod at time 305: Expected 0.2478, in Model 0.2478
# Exactprod at time 306: Expected 0.2478, in Model 0.2478
# Exactprod at time 307: Expected 0.2478, in Model 0.2478
# Exactprod at time 308: Expected 0.2478, in Model 0.2478
# Exactprod at time 309: Expected 0.2478, in Model 0.2478
# Exactprod at time 310: Expected 0.2478, in Model 0.2478
# Exactprod at time 311: Expected 0.2478, in Model 0.2478
# Exactprod at time 312: Expected 0.2478, in Model 0.2478
# Exactprod at time 313: Expected 0.2478, in Model 0.2478
# Exactprod at time 314: Expected 0.2478, in Model 0.2478
# Exactprod at time 315: Expected 0.2478, in Model 0.2478
# Exactprod at time 316: Expected 0.2478, in Model 0.2478
# Exactprod at time 317: Expected 0.2478, in Model 0.2478
# Exactprod at time 318: Expected 0.2478, in Model 0.2478
# Exactprod at time 319: Expected 0.2478, in Model 0.2478
# Exactprod at time 320: Expected 0.2478, in Model 0.2478
# Exactprod at time 321: Expected 0.2478, in Model 0.2478
# Exactprod at time 322: Expected 0.2478, in Model 0.2478
# Exactprod at time 323: Expected 0.2478, in Model 0.2478
# Exactprod at time 324: Expected 0.1983, in Model 0.1983
# Exactprod at time 325: Expected 0.2478, in Model 0.2478
# Exactprod at time 326: Expected 0.2478, in Model 0.2478
# Exactprod at time 327: Expected 0.2478, in Model 0.2478
# Exactprod at time 328: Expected 0.2478, in Model 0.2478
# Exactprod at time 329: Expected 0.2478, in Model 0.2478
# Exactprod at time 330: Expected 0.2478, in Model 0.2478
# Exactprod at time 331: Expected 0.2478, in Model 0.2478
# Exactprod at time 332: Expected 0.2478, in Model 0.2478
# Exactprod at time 333: Expected 0.2478, in Model 0.2478
# Exactprod at time 334: Expected 0.2478, in Model 0.2478
# Exactprod at time 335: Expected 0.2478, in Model 0.2478
# Exactprod at time 336: Expected 0.2478, in Model 0.2478
# Exactprod at time 337: Expected 0.2478, in Model 0.2478
# Exactprod at time 338: Expected 0.2478, in Model 0.2478
# Exactprod at time 339: Expected 0.2478, in Model 0.2478
# Exactprod at time 340: Expected 0.2478, in Model 0.2478
# Exactprod at time 341: Expected 0.2478, in Model 0.2478
# Exactprod at time 342: Expected 0.2478, in Model 0.2478
# Exactprod at time 343: Expected 0.2478, in Model 0.2478
# Exactprod at time 344: Expected 0.2478, in Model 0.2478
# Exactprod at time 345: Expected 0.2478, in Model 0.2478
# Exactprod at time 346: Expected 0.2478, in Model 0.2478
# Exactprod at time 347: Expected 0.2478, in Model 0.2478
# Exactprod at time 348: Expected 0.2478, in Model 0.2478
# Exactprod at time 349: Expected 0.2478, in Model 0.2478
# Exactprod at time 350: Expected 0.2478, in Model 0.2478
# Exactprod at time 351: Expected 0.2478, in Model 0.2478
# Exactprod at time 352: Expected 0.2478, in Model 0.2478
# Exactprod at time 353: Expected 0.2478, in Model 0.2478
# Exactprod at time 354: Expected 0.2478, in Model 0.2478
# Exactprod at time 355: Expected 0.2478, in Model 0.2478
# Exactprod at time 356: Expected 0.2478, in Model 0.2478
# Exactprod at time 357: Expected 0.2478, in Model 0.2478
# Exactprod at time 358: Expected 0.2478, in Model 0.2478
# Exactprod at time 359: Expected 0.2478, in Model 0.2478
# Overprod at time 360: Expected 0.2198, in Model 0.2198
# Exactprod at time 361: Expected 0.2478, in Model 0.2478
# Exactprod at time 362: Expected 0.2478, in Model 0.2478
# Exactprod at time 363: Expected 0.2478, in Model 0.2478
# Exactprod at time 364: Expected 0.2478, in Model 0.2478
# Exactprod at time 365: Expected 0.2478, in Model 0.2478
# Exactprod at time 366: Expected 0.2478, in Model 0.2478
# Exactprod at time 367: Expected 0.2478, in Model 0.2478
# Exactprod at time 368: Expected 0.2478, in Model 0.2478
# Exactprod at time 369: Expected 0.2478, in Model 0.2478
# Exactprod at time 370: Expected 0.2478, in Model 0.2478
# Exactprod at time 371: Expected 0.2478, in Model 0.2478
# Exactprod at time 372: Expected 0.2478, in Model 0.2478
# Exactprod at time 373: Expected 0.2478, in Model 0.2478
# Exactprod at time 374: Expected 0.2478, in Model 0.2478
# Underprod at time 375: Expected 0.1838, in Model 0.1838
# Exactprod at time 376: Expected 0.2478, in Model 0.2478
# Exactprod at time 377: Expected 0.2478, in Model 0.2478
# Exactprod at time 378: Expected 0.1634, in Model 0.1634
# Exactprod at time 379: Expected 0.2478, in Model 0.2478
# Exactprod at time 380: Expected 0.2478, in Model 0.2478
# Exactprod at time 381: Expected 0.1632, in Model 0.1632
# Exactprod at time 382: Expected 0.2478, in Model 0.2478
# Exactprod at time 383: Expected 0.2478, in Model 0.2478
# Exactprod at time 384: Expected 0.1086, in Model 0.1086
# Exactprod at time 385: Expected 0.2478, in Model 0.2478
# Exactprod at time 386: Expected 0.2478, in Model 0.2478
# Underprod at time 387: Expected 0.1652, in Model 0.1652
# Exactprod at time 388: Expected 0.2478, in Model 0.2478
# Exactprod at time 389: Expected 0.2478, in Model 0.2478
# Exactprod at time 390: Expected 0.141, in Model 0.141
# Exactprod at time 391: Expected 0.2478, in Model 0.2478
# Exactprod at time 392: Expected 0.2478, in Model 0.2478
# Overprod at time 393: Expected 0.1074, in Model 0.1074
# Exactprod at time 394: Expected 0.2478, in Model 0.2478
# Exactprod at time 395: Expected 0.2478, in Model 0.2478
# Overprod at time 396: Expected 0.1128, in Model 0.1128
# Exactprod at time 397: Expected 0.2478, in Model 0.2478
# Exactprod at time 398: Expected 0.2478, in Model 0.2478
# Overprod at time 399: Expected 0.1329, in Model 0.1329
# Exactprod at time 400: Expected 0.2478, in Model 0.2478
# Exactprod at time 401: Expected 0.2478, in Model 0.2478
# Exactprod at time 402: Expected 0.1923, in Model 0.1923
# Exactprod at time 403: Expected 0.2478, in Model 0.2478
# Exactprod at time 404: Expected 0.2478, in Model 0.2478
# Exactprod at time 405: Expected 0.2182, in Model 0.2182
# Exactprod at time 406: Expected 0.2478, in Model 0.2478
# Exactprod at time 407: Expected 0.2478, in Model 0.2478
# Exactprod at time 408: Expected 0.2234, in Model 0.2234
# Exactprod at time 409: Expected 0.2478, in Model 0.2478
# Exactprod at time 410: Expected 0.2478, in Model 0.2478
# Exactprod at time 411: Expected 0.2478, in Model 0.2478
# Exactprod at time 412: Expected 0.2478, in Model 0.2478
# Exactprod at time 413: Expected 0.2478, in Model 0.2478
# Exactprod at time 414: Expected 0.2478, in Model 0.2478
# Exactprod at time 415: Expected 0.2478, in Model 0.2478
# Exactprod at time 416: Expected 0.2478, in Model 0.2478
# Exactprod at time 417: Expected 0.2478, in Model 0.2478
# Exactprod at time 418: Expected 0.2478, in Model 0.2478
# Exactprod at time 419: Expected 0.2478, in Model 0.2478
# Exactprod at time 420: Expected 0.2478, in Model 0.2478
# Exactprod at time 421: Expected 0.2478, in Model 0.2478
# Exactprod at time 422: Expected 0.2478, in Model 0.2478
# Exactprod at time 423: Expected 0.2478, in Model 0.2478
# Exactprod at time 424: Expected 0.2478, in Model 0.2478
# Exactprod at time 425: Expected 0.2478, in Model 0.2478
# Exactprod at time 426: Expected 0.2478, in Model 0.2478
# Exactprod at time 427: Expected 0.2478, in Model 0.2478
# Exactprod at time 428: Expected 0.2478, in Model 0.2478
# Exactprod at time 429: Expected 0.2478, in Model 0.2478
# Exactprod at time 430: Expected 0.2478, in Model 0.2478
# Exactprod at time 431: Expected 0.2478, in Model 0.2478
# Exactprod at time 432: Expected 0.2478, in Model 0.2478
# Exactprod at time 433: Expected 0.2478, in Model 0.2478
# Exactprod at time 434: Expected 0.2478, in Model 0.2478
# Exactprod at time 435: Expected 0.2478, in Model 0.2478
# Exactprod at time 436: Expected 0.2478, in Model 0.2478
# Exactprod at time 437: Expected 0.2478, in Model 0.2478
# Exactprod at time 438: Expected 0.2478, in Model 0.2478
# Exactprod at time 439: Expected 0.2478, in Model 0.2478
# Exactprod at time 440: Expected 0.2478, in Model 0.2478
# Exactprod at time 441: Expected 0.2478, in Model 0.2478
# Exactprod at time 442: Expected 0.2478, in Model 0.2478
# Exactprod at time 443: Expected 0.2478, in Model 0.2478
# Exactprod at time 444: Expected 0.2478, in Model 0.2478
# Exactprod at time 445: Expected 0.2478, in Model 0.2478
# Exactprod at time 446: Expected 0.2478, in Model 0.2478
# Exactprod at time 447: Expected 0.2478, in Model 0.2478
# Exactprod at time 448: Expected 0.2478, in Model 0.2478
# Exactprod at time 449: Expected 0.2478, in Model 0.2478
# Exactprod at time 450: Expected 0.2478, in Model 0.2478
# Exactprod at time 451: Expected 0.2478, in Model 0.2478
# Exactprod at time 452: Expected 0.2478, in Model 0.2478
# Exactprod at time 453: Expected 0.2478, in Model 0.2478
# Exactprod at time 454: Expected 0.2478, in Model 0.2478
# Exactprod at time 455: Expected 0.2478, in Model 0.2478
# Exactprod at time 456: Expected 0.2478, in Model 0.2478
# Exactprod at time 457: Expected 0.2478, in Model 0.2478
# Exactprod at time 458: Expected 0.2478, in Model 0.2478
# Exactprod at time 459: Expected 0.2478, in Model 0.2478
# Exactprod at time 460: Expected 0.2478, in Model 0.2478
# Exactprod at time 461: Expected 0.2478, in Model 0.2478
# Overprod at time 462: Expected 0.2132, in Model 0.2132
# Exactprod at time 463: Expected 0.2478, in Model 0.2478
# Exactprod at time 464: Expected 0.2478, in Model 0.2478
# Underprod at time 465: Expected 0.1787, in Model 0.1787
# Exactprod at time 466: Expected 0.2478, in Model 0.2478
# Exactprod at time 467: Expected 0.2478, in Model 0.2478
# Exactprod at time 468: Expected 0.2174, in Model 0.2174
# Exactprod at time 469: Expected 0.2478, in Model 0.2478
# Exactprod at time 470: Expected 0.2478, in Model 0.2478
# Exactprod at time 471: Expected 0.127, in Model 0.127
# Exactprod at time 472: Expected 0.2478, in Model 0.2478
# Exactprod at time 473: Expected 0.2478, in Model 0.2478
# Overprod at time 474: Expected 0.1861, in Model 0.1861
# Exactprod at time 475: Expected 0.2478, in Model 0.2478
# Exactprod at time 476: Expected 0.2478, in Model 0.2478
# Exactprod at time 477: Expected 0.1568, in Model 0.1568
# Exactprod at time 478: Expected 0.2478, in Model 0.2478
# Exactprod at time 479: Expected 0.2478, in Model 0.2478
# Exactprod at time 480: Expected 0.1246, in Model 0.1246
# Exactprod at time 481: Expected 0.2478, in Model 0.2478
# Exactprod at time 482: Expected 0.2478, in Model 0.2478
# Exactprod at time 483: Expected 0.0991, in Model 0.0991
# Exactprod at time 484: Expected 0.2478, in Model 0.2478
# Exactprod at time 485: Expected 0.2478, in Model 0.2478
# Underprod at time 486: Expected 0.1247, in Model 0.1247
# Exactprod at time 487: Expected 0.2478, in Model 0.2478
# Exactprod at time 488: Expected 0.2478, in Model 0.2478
# Exactprod at time 489: Expected 0.1506, in Model 0.1506
# Exactprod at time 490: Expected 0.2478, in Model 0.2478
# Exactprod at time 491: Expected 0.2478, in Model 0.2478
# Exactprod at time 492: Expected 0.2478, in Model 0.2478
# Exactprod at time 493: Expected 0.2478, in Model 0.2478
# Exactprod at time 494: Expected 0.2478, in Model 0.2478
# Exactprod at time 495: Expected 0.2478, in Model 0.2478
# Exactprod at time 496: Expected 0.2478, in Model 0.2478
# Exactprod at time 497: Expected 0.2478, in Model 0.2478
# Exactprod at time 498: Expected 0.2478, in Model 0.2478
# Exactprod at time 499: Expected 0.2478, in Model 0.2478
# Exactprod at time 500: Expected 0.2478, in Model 0.2478
# Exactprod at time 501: Expected 0.2478, in Model 0.2478
# Exactprod at time 502: Expected 0.2478, in Model 0.2478
# Exactprod at time 503: Expected 0.2478, in Model 0.2478
# Exactprod at time 504: Expected 0.2478, in Model 0.2478
# Exactprod at time 505: Expected 0.2478, in Model 0.2478
# Exactprod at time 506: Expected 0.2478, in Model 0.2478
# Exactprod at time 507: Expected 0.2478, in Model 0.2478
# Exactprod at time 508: Expected 0.2478, in Model 0.2478
# Exactprod at time 509: Expected 0.2478, in Model 0.2478
# Exactprod at time 510: Expected 0.2478, in Model 0.2478
# Exactprod at time 511: Expected 0.2478, in Model 0.2478
# Exactprod at time 512: Expected 0.2478, in Model 0.2478
# Exactprod at time 513: Expected 0.2478, in Model 0.2478
# Exactprod at time 514: Expected 0.2478, in Model 0.2478
# Exactprod at time 515: Expected 0.2478, in Model 0.2478
# Exactprod at time 516: Expected 0.2478, in Model 0.2478
# Exactprod at time 517: Expected 0.2478, in Model 0.2478
# Exactprod at time 518: Expected 0.2478, in Model 0.2478
# Exactprod at time 519: Expected 0.2478, in Model 0.2478
# Exactprod at time 520: Expected 0.2478, in Model 0.2478
# Exactprod at time 521: Expected 0.2478, in Model 0.2478
# Underprod at time 522: Expected 0.203, in Model 0.203
# Exactprod at time 523: Expected 0.2478, in Model 0.2478
# Exactprod at time 524: Expected 0.2478, in Model 0.2478
# Exactprod at time 525: Expected 0.1537, in Model 0.1537
# Exactprod at time 526: Expected 0.2478, in Model 0.2478
# Exactprod at time 527: Expected 0.2478, in Model 0.2478
# Overprod at time 528: Expected 0.109, in Model 0.109
# Exactprod at time 529: Expected 0.2478, in Model 0.2478
# Exactprod at time 530: Expected 0.2478, in Model 0.2478
# Exactprod at time 531: Expected 0.0756, in Model 0.0756
# Exactprod at time 532: Expected 0.2478, in Model 0.2478
# Exactprod at time 533: Expected 0.2478, in Model 0.2478
# Exactprod at time 534: Expected 0.0512, in Model 0.0512
# Exactprod at time 535: Expected 0.2478, in Model 0.2478
# Exactprod at time 536: Expected 0.2478, in Model 0.2478
# Overprod at time 537: Expected 0.0191, in Model 0.0191
# Exactprod at time 538: Expected 0.2478, in Model 0.2478
# Exactprod at time 539: Expected 0.2478, in Model 0.2478
# Exactprod at time 540: Expected 0.0276, in Model 0.0276
# Exactprod at time 541: Expected 0.2478, in Model 0.2478
# Exactprod at time 542: Expected 0.2478, in Model 0.2478
# Underprod at time 543: Expected 0.1672, in Model 0.1672
# Exactprod at time 544: Expected 0.2478, in Model 0.2478
# Exactprod at time 545: Expected 0.2478, in Model 0.2478
# Exactprod at time 546: Expected 0.154, in Model 0.154
# Exactprod at time 547: Expected 0.2478, in Model 0.2478
# Exactprod at time 548: Expected 0.2478, in Model 0.2478
# Exactprod at time 549: Expected 0.0972, in Model 0.0972
# Exactprod at time 550: Expected 0.2478, in Model 0.2478
# Exactprod at time 551: Expected 0.2478, in Model 0.2478
# Overprod at time 552: Expected 0.0679, in Model 0.0679
# Exactprod at time 553: Expected 0.2478, in Model 0.2478
# Exactprod at time 554: Expected 0.2478, in Model 0.2478
# Exactprod at time 555: Expected 0.0423, in Model 0.0423
# Exactprod at time 556: Expected 0.2478, in Model 0.2478
# Exactprod at time 557: Expected 0.2478, in Model 0.2478
# Exactprod at time 558: Expected 0.051, in Model 0.051
# Exactprod at time 559: Expected 0.2478, in Model 0.2478
# Exactprod at time 560: Expected 0.2478, in Model 0.2478
# Exactprod at time 561: Expected 0.0364, in Model 0.0364
# Exactprod at time 562: Expected 0.2478, in Model 0.2478
# Exactprod at time 563: Expected 0.2478, in Model 0.2478
# Exactprod at time 564: Expected 0.0775, in Model 0.0775
# Exactprod at time 565: Expected 0.2478, in Model 0.2478
# Exactprod at time 566: Expected 0.2478, in Model 0.2478
# Exactprod at time 567: Expected 0.1666, in Model 0.1666
# Exactprod at time 568: Expected 0.2478, in Model 0.2478
# Exactprod at time 569: Expected 0.2478, in Model 0.2478
# Exactprod at time 570: Expected 0.2478, in Model 0.2478
# Exactprod at time 571: Expected 0.2478, in Model 0.2478
# Exactprod at time 572: Expected 0.2478, in Model 0.2478
# Exactprod at time 573: Expected 0.2478, in Model 0.2478
# Exactprod at time 574: Expected 0.2478, in Model 0.2478
# Exactprod at time 575: Expected 0.2478, in Model 0.2478
# Exactprod at time 576: Expected 0.2478, in Model 0.2478
# Exactprod at time 577: Expected 0.2478, in Model 0.2478
# Exactprod at time 578: Expected 0.2478, in Model 0.2478
# Exactprod at time 579: Expected 0.2478, in Model 0.2478
# Exactprod at time 580: Expected 0.2478, in Model 0.2478
# Exactprod at time 581: Expected 0.2478, in Model 0.2478
# Exactprod at time 582: Expected 0.2478, in Model 0.2478
# Exactprod at time 583: Expected 0.2478, in Model 0.2478
# Exactprod at time 584: Expected 0.2478, in Model 0.2478
# Exactprod at time 585: Expected 0.2478, in Model 0.2478
# Exactprod at time 586: Expected 0.2478, in Model 0.2478
# Exactprod at time 587: Expected 0.2478, in Model 0.2478
# Overprod at time 588: Expected 0.2175, in Model 0.2175
# Exactprod at time 589: Expected 0.2478, in Model 0.2478
# Exactprod at time 590: Expected 0.2478, in Model 0.2478
# Exactprod at time 591: Expected 0.1618, in Model 0.1618
# Exactprod at time 592: Expected 0.2478, in Model 0.2478
# Exactprod at time 593: Expected 0.2478, in Model 0.2478
# Exactprod at time 594: Expected 0.2478, in Model 0.2478
# Exactprod at time 595: Expected 0.2478, in Model 0.2478
# Exactprod at time 596: Expected 0.2478, in Model 0.2478
# Exactprod at time 597: Expected 0.2478, in Model 0.2478
# Exactprod at time 598: Expected 0.2478, in Model 0.2478
# Exactprod at time 599: Expected 0.2478, in Model 0.2478
# Overprod at time 600: Expected 0.2193, in Model 0.2193
# Exactprod at time 601: Expected 0.2478, in Model 0.2478
# Exactprod at time 602: Expected 0.2478, in Model 0.2478
# Exactprod at time 603: Expected 0.1884, in Model 0.1884
# Exactprod at time 604: Expected 0.2478, in Model 0.2478
# Exactprod at time 605: Expected 0.2478, in Model 0.2478
# Exactprod at time 606: Expected 0.2478, in Model 0.2478
# Exactprod at time 607: Expected 0.2478, in Model 0.2478
# Exactprod at time 608: Expected 0.2478, in Model 0.2478
# Exactprod at time 609: Expected 0.2478, in Model 0.2478
# Exactprod at time 610: Expected 0.2478, in Model 0.2478
# Exactprod at time 611: Expected 0.2478, in Model 0.2478
# Exactprod at time 612: Expected 0.2478, in Model 0.2478
# Exactprod at time 613: Expected 0.2478, in Model 0.2478
# Exactprod at time 614: Expected 0.2478, in Model 0.2478
# Exactprod at time 615: Expected 0.2478, in Model 0.2478
# Exactprod at time 616: Expected 0.2478, in Model 0.2478
# Exactprod at time 617: Expected 0.2478, in Model 0.2478
# Exactprod at time 618: Expected 0.2478, in Model 0.2478
# Exactprod at time 619: Expected 0.2478, in Model 0.2478
# Exactprod at time 620: Expected 0.2478, in Model 0.2478
# Exactprod at time 621: Expected 0.2478, in Model 0.2478
# Exactprod at time 622: Expected 0.2478, in Model 0.2478
# Exactprod at time 623: Expected 0.2478, in Model 0.2478
# Exactprod at time 624: Expected 0.2478, in Model 0.2478
# Exactprod at time 625: Expected 0.2478, in Model 0.2478
# Exactprod at time 626: Expected 0.2478, in Model 0.2478
# Exactprod at time 627: Expected 0.2478, in Model 0.2478
# Exactprod at time 628: Expected 0.2478, in Model 0.2478
# Exactprod at time 629: Expected 0.2478, in Model 0.2478
# Exactprod at time 630: Expected 0.2478, in Model 0.2478
# Exactprod at time 631: Expected 0.2478, in Model 0.2478
# Exactprod at time 632: Expected 0.2478, in Model 0.2478
# Exactprod at time 633: Expected 0.2478, in Model 0.2478
# Exactprod at time 634: Expected 0.2478, in Model 0.2478
# Exactprod at time 635: Expected 0.2478, in Model 0.2478
# Exactprod at time 636: Expected 0.2478, in Model 0.2478
# Exactprod at time 637: Expected 0.2478, in Model 0.2478
# Exactprod at time 638: Expected 0.2478, in Model 0.2478
# Exactprod at time 639: Expected 0.2478, in Model 0.2478
# Exactprod at time 640: Expected 0.2478, in Model 0.2478
# Exactprod at time 641: Expected 0.2478, in Model 0.2478
# Exactprod at time 642: Expected 0.2478, in Model 0.2478
# Exactprod at time 643: Expected 0.2478, in Model 0.2478
# Exactprod at time 644: Expected 0.2478, in Model 0.2478
# Exactprod at time 645: Expected 0.2478, in Model 0.2478
# Exactprod at time 646: Expected 0.2478, in Model 0.2478
# Exactprod at time 647: Expected 0.2478, in Model 0.2478
# Exactprod at time 648: Expected 0.2478, in Model 0.2478
# Exactprod at time 649: Expected 0.2478, in Model 0.2478
# Exactprod at time 650: Expected 0.2478, in Model 0.2478
# Exactprod at time 651: Expected 0.2478, in Model 0.2478
# Exactprod at time 652: Expected 0.2478, in Model 0.2478
# Exactprod at time 653: Expected 0.2478, in Model 0.2478
# Exactprod at time 654: Expected 0.2478, in Model 0.2478
# Exactprod at time 655: Expected 0.2478, in Model 0.2478
# Exactprod at time 656: Expected 0.2478, in Model 0.2478
# Exactprod at time 657: Expected 0.2478, in Model 0.2478
# Exactprod at time 658: Expected 0.2478, in Model 0.2478
# Exactprod at time 659: Expected 0.2478, in Model 0.2478
# Exactprod at time 660: Expected 0.2478, in Model 0.2478
# Exactprod at time 661: Expected 0.2478, in Model 0.2478
# Exactprod at time 662: Expected 0.2478, in Model 0.2478
# Exactprod at time 663: Expected 0.2043, in Model 0.2043
# Exactprod at time 664: Expected 0.2478, in Model 0.2478
# Exactprod at time 665: Expected 0.2478, in Model 0.2478
# Exactprod at time 666: Expected 0.1665, in Model 0.1665
# Exactprod at time 667: Expected 0.2478, in Model 0.2478
# Exactprod at time 668: Expected 0.2478, in Model 0.2478
# Exactprod at time 669: Expected 0.2478, in Model 0.2478
# Exactprod at time 670: Expected 0.2478, in Model 0.2478
# Exactprod at time 671: Expected 0.2478, in Model 0.2478
# Exactprod at time 672: Expected 0.2478, in Model 0.2478
# Exactprod at time 673: Expected 0.2478, in Model 0.2478
# Exactprod at time 674: Expected 0.2478, in Model 0.2478
# Underprod at time 675: Expected 0.2268, in Model 0.2268
# Exactprod at time 676: Expected 0.2478, in Model 0.2478
# Exactprod at time 677: Expected 0.2478, in Model 0.2478
# Overprod at time 678: Expected 0.1294, in Model 0.1294
# Exactprod at time 679: Expected 0.2478, in Model 0.2478
# Exactprod at time 680: Expected 0.2478, in Model 0.2478
# Exactprod at time 681: Expected 0.0913, in Model 0.0913
# Exactprod at time 682: Expected 0.2478, in Model 0.2478
# Exactprod at time 683: Expected 0.2478, in Model 0.2478
# Overprod at time 684: Expected 0.0604, in Model 0.0604
# Exactprod at time 685: Expected 0.2478, in Model 0.2478
# Exactprod at time 686: Expected 0.2478, in Model 0.2478
# Exactprod at time 687: Expected 0.1698, in Model 0.1698
# Exactprod at time 688: Expected 0.2478, in Model 0.2478
# Exactprod at time 689: Expected 0.2478, in Model 0.2478
# Exactprod at time 690: Expected 0.2478, in Model 0.2478
# Exactprod at time 691: Expected 0.2478, in Model 0.2478
# Exactprod at time 692: Expected 0.2478, in Model 0.2478
# Exactprod at time 693: Expected 0.2478, in Model 0.2478
# Exactprod at time 694: Expected 0.2478, in Model 0.2478
# Exactprod at time 695: Expected 0.2478, in Model 0.2478
# Exactprod at time 696: Expected 0.2478, in Model 0.2478
# Exactprod at time 697: Expected 0.2478, in Model 0.2478
# Exactprod at time 698: Expected 0.2478, in Model 0.2478
# Exactprod at time 699: Expected 0.2478, in Model 0.2478
# Exactprod at time 700: Expected 0.2478, in Model 0.2478
# Exactprod at time 701: Expected 0.2478, in Model 0.2478
# Exactprod at time 702: Expected 0.2478, in Model 0.2478
# Exactprod at time 703: Expected 0.2478, in Model 0.2478
# Exactprod at time 704: Expected 0.2478, in Model 0.2478
# Exactprod at time 705: Expected 0.2478, in Model 0.2478
# Exactprod at time 706: Expected 0.2478, in Model 0.2478
# Exactprod at time 707: Expected 0.2478, in Model 0.2478
# Exactprod at time 708: Expected 0.2478, in Model 0.2478
# Exactprod at time 709: Expected 0.2478, in Model 0.2478
# Exactprod at time 710: Expected 0.2478, in Model 0.2478
# Exactprod at time 711: Expected 0.2478, in Model 0.2478
# Exactprod at time 712: Expected 0.2478, in Model 0.2478
# Exactprod at time 713: Expected 0.2478, in Model 0.2478
# Exactprod at time 714: Expected 0.2478, in Model 0.2478
# Exactprod at time 715: Expected 0.2478, in Model 0.2478
# Exactprod at time 716: Expected 0.2478, in Model 0.2478
# Exactprod at time 717: Expected 0.2111, in Model 0.2111
# Exactprod at time 718: Expected 0.2478, in Model 0.2478
# Exactprod at time 719: Expected 0.2478, in Model 0.2478
# Exactprod at time 720: Expected 0.2478, in Model 0.2478
# Exactprod at time 721: Expected 0.2478, in Model 0.2478
# Exactprod at time 722: Expected 0.2478, in Model 0.2478
# Exactprod at time 723: Expected 0.2478, in Model 0.2478
# Exactprod at time 724: Expected 0.2478, in Model 0.2478
# Exactprod at time 725: Expected 0.2478, in Model 0.2478
# Exactprod at time 726: Expected 0.2478, in Model 0.2478
# Exactprod at time 727: Expected 0.2478, in Model 0.2478
# Exactprod at time 728: Expected 0.2478, in Model 0.2478
# Exactprod at time 729: Expected 0.2478, in Model 0.2478
# Exactprod at time 730: Expected 0.2478, in Model 0.2478
# Exactprod at time 731: Expected 0.2478, in Model 0.2478
# Exactprod at time 732: Expected 0.2478, in Model 0.2478
# Exactprod at time 733: Expected 0.2478, in Model 0.2478
# Exactprod at time 734: Expected 0.2478, in Model 0.2478
# Exactprod at time 735: Expected 0.2, in Model 0.2
# Exactprod at time 736: Expected 0.2478, in Model 0.2478
# Exactprod at time 737: Expected 0.2478, in Model 0.2478
# Exactprod at time 738: Expected 0.1385, in Model 0.1385
# Exactprod at time 739: Expected 0.2478, in Model 0.2478
# Exactprod at time 740: Expected 0.2478, in Model 0.2478
# Exactprod at time 741: Expected 0.1509, in Model 0.1509
# Exactprod at time 742: Expected 0.2478, in Model 0.2478
# Exactprod at time 743: Expected 0.2478, in Model 0.2478
# Exactprod at time 744: Expected 0.2098, in Model 0.2098
# Exactprod at time 745: Expected 0.2478, in Model 0.2478
# Exactprod at time 746: Expected 0.2478, in Model 0.2478
# Exactprod at time 747: Expected 0.2114, in Model 0.2114
# Exactprod at time 748: Expected 0.2478, in Model 0.2478
# Exactprod at time 749: Expected 0.2478, in Model 0.2478
# Exactprod at time 750: Expected 0.2038, in Model 0.2038
# Exactprod at time 751: Expected 0.2478, in Model 0.2478
# Exactprod at time 752: Expected 0.2478, in Model 0.2478
# Overprod at time 753: Expected 0.1851, in Model 0.1851
# Exactprod at time 754: Expected 0.2478, in Model 0.2478
# Exactprod at time 755: Expected 0.2478, in Model 0.2478
# Exactprod at time 756: Expected 0.2033, in Model 0.2033
# Exactprod at time 757: Expected 0.2478, in Model 0.2478
# Exactprod at time 758: Expected 0.2478, in Model 0.2478
# Overprod at time 759: Expected 0.2253, in Model 0.2253
# Exactprod at time 760: Expected 0.2478, in Model 0.2478
# Exactprod at time 761: Expected 0.2478, in Model 0.2478
# Exactprod at time 762: Expected 0.2297, in Model 0.2297
# Exactprod at time 763: Expected 0.2478, in Model 0.2478
# Exactprod at time 764: Expected 0.2478, in Model 0.2478
# Exactprod at time 765: Expected 0.2225, in Model 0.2225
# Exactprod at time 766: Expected 0.2478, in Model 0.2478
# Exactprod at time 767: Expected 0.2478, in Model 0.2478
# Exactprod at time 768: Expected 0.1875, in Model 0.1875
# Exactprod at time 769: Expected 0.2478, in Model 0.2478
# Exactprod at time 770: Expected 0.2478, in Model 0.2478
# Exactprod at time 771: Expected 0.1618, in Model 0.1618
# Exactprod at time 772: Expected 0.2478, in Model 0.2478
# Exactprod at time 773: Expected 0.2478, in Model 0.2478
# Overprod at time 774: Expected 0.2226, in Model 0.2226
# Exactprod at time 775: Expected 0.2478, in Model 0.2478
# Exactprod at time 776: Expected 0.2478, in Model 0.2478
# Exactprod at time 777: Expected 0.2478, in Model 0.2478
# Exactprod at time 778: Expected 0.2478, in Model 0.2478
# Exactprod at time 779: Expected 0.2478, in Model 0.2478
# Exactprod at time 780: Expected 0.2478, in Model 0.2478
# Exactprod at time 781: Expected 0.2478, in Model 0.2478
# Exactprod at time 782: Expected 0.2478, in Model 0.2478
# Exactprod at time 783: Expected 0.2478, in Model 0.2478
# Exactprod at time 784: Expected 0.2478, in Model 0.2478
# Exactprod at time 785: Expected 0.2478, in Model 0.2478
# Exactprod at time 786: Expected 0.2478, in Model 0.2478
# Exactprod at time 787: Expected 0.2478, in Model 0.2478
# Exactprod at time 788: Expected 0.2478, in Model 0.2478
# Exactprod at time 789: Expected 0.2478, in Model 0.2478
# Exactprod at time 790: Expected 0.2478, in Model 0.2478
# Exactprod at time 791: Expected 0.2478, in Model 0.2478
# Exactprod at time 792: Expected 0.2478, in Model 0.2478
# Exactprod at time 793: Expected 0.2478, in Model 0.2478
# Exactprod at time 794: Expected 0.2478, in Model 0.2478
# Exactprod at time 795: Expected 0.2478, in Model 0.2478
# Exactprod at time 796: Expected 0.2478, in Model 0.2478
# Exactprod at time 797: Expected 0.2478, in Model 0.2478
# Exactprod at time 798: Expected 0.2478, in Model 0.2478
# Exactprod at time 799: Expected 0.2478, in Model 0.2478
# Exactprod at time 800: Expected 0.2478, in Model 0.2478
# Exactprod at time 801: Expected 0.2478, in Model 0.2478
# Exactprod at time 802: Expected 0.2478, in Model 0.2478
# Exactprod at time 803: Expected 0.2478, in Model 0.2478
# Exactprod at time 804: Expected 0.2478, in Model 0.2478
# Exactprod at time 805: Expected 0.2478, in Model 0.2478
# Exactprod at time 806: Expected 0.2478, in Model 0.2478
# Exactprod at time 807: Expected 0.2478, in Model 0.2478
# Exactprod at time 808: Expected 0.2478, in Model 0.2478
# Exactprod at time 809: Expected 0.2478, in Model 0.2478
# Exactprod at time 810: Expected 0.2478, in Model 0.2478
# Exactprod at time 811: Expected 0.2478, in Model 0.2478
# Exactprod at time 812: Expected 0.2478, in Model 0.2478
# Exactprod at time 813: Expected 0.2478, in Model 0.2478
# Exactprod at time 814: Expected 0.2478, in Model 0.2478
# Exactprod at time 815: Expected 0.2478, in Model 0.2478
# Exactprod at time 816: Expected 0.2478, in Model 0.2478
# Exactprod at time 817: Expected 0.2478, in Model 0.2478
# Exactprod at time 818: Expected 0.2478, in Model 0.2478
# Exactprod at time 819: Expected 0.2478, in Model 0.2478
# Exactprod at time 820: Expected 0.2478, in Model 0.2478
# Exactprod at time 821: Expected 0.2478, in Model 0.2478
# Exactprod at time 822: Expected 0.0635, in Model 0.0635
# Exactprod at time 823: Expected 0.2478, in Model 0.2478
# Exactprod at time 824: Expected 0.2478, in Model 0.2478
# Exactprod at time 825: Expected 0.0754, in Model 0.0754
# Exactprod at time 826: Expected 0.2478, in Model 0.2478
# Exactprod at time 827: Expected 0.2478, in Model 0.2478
# Exactprod at time 828: Expected 0.2478, in Model 0.2478
# Exactprod at time 829: Expected 0.2478, in Model 0.2478
# Exactprod at time 830: Expected 0.2478, in Model 0.2478
# Exactprod at time 831: Expected 0.2478, in Model 0.2478
# Exactprod at time 832: Expected 0.2478, in Model 0.2478
# Exactprod at time 833: Expected 0.2478, in Model 0.2478
# Exactprod at time 834: Expected 0.2478, in Model 0.2478
# Exactprod at time 835: Expected 0.2478, in Model 0.2478
# Exactprod at time 836: Expected 0.2478, in Model 0.2478
# Exactprod at time 837: Expected 0.2478, in Model 0.2478
# Exactprod at time 838: Expected 0.2478, in Model 0.2478
# Exactprod at time 839: Expected 0.2478, in Model 0.2478
# Exactprod at time 840: Expected 0.2478, in Model 0.2478
# Exactprod at time 841: Expected 0.2478, in Model 0.2478
# Exactprod at time 842: Expected 0.2478, in Model 0.2478
# Exactprod at time 843: Expected 0.2478, in Model 0.2478
# Exactprod at time 844: Expected 0.2478, in Model 0.2478
# Exactprod at time 845: Expected 0.2478, in Model 0.2478
# Exactprod at time 846: Expected 0.2478, in Model 0.2478
# Exactprod at time 847: Expected 0.2478, in Model 0.2478
# Exactprod at time 848: Expected 0.2478, in Model 0.2478
# Exactprod at time 849: Expected 0.2478, in Model 0.2478
# Exactprod at time 850: Expected 0.2478, in Model 0.2478
# Exactprod at time 851: Expected 0.2478, in Model 0.2478
# Exactprod at time 852: Expected 0.2478, in Model 0.2478
# Exactprod at time 853: Expected 0.2478, in Model 0.2478
# Exactprod at time 854: Expected 0.2478, in Model 0.2478
# Underprod at time 855: Expected 0.0806, in Model 0.0806
# Exactprod at time 856: Expected 0.2478, in Model 0.2478
# Exactprod at time 857: Expected 0.2478, in Model 0.2478
# Exactprod at time 858: Expected 0.2478, in Model 0.2478
# ...
# Exactprod at time 17268: Expected 0.2478, in Model 0.2478
# Exactprod at time 17269: Expected 0.2478, in Model 0.2478
# Exactprod at time 17270: Expected 0.2478, in Model 0.2478
# Exactprod at time 17271: Expected 0.2478, in Model 0.2478
# Exactprod at time 17272: Expected 0.2478, in Model 0.2478
# Exactprod at time 17273: Expected 0.2478, in Model 0.2478
# Exactprod at time 17274: Expected 0.2478, in Model 0.2478
# Exactprod at time 17275: Expected 0.2478, in Model 0.2478
# Exactprod at time 17276: Expected 0.2478, in Model 0.2478
# Exactprod at time 17277: Expected 0.2478, in Model 0.2478
# Exactprod at time 17278: Expected 0.2478, in Model 0.2478
# Exactprod at time 17279: Expected 0.2478, in Model 0.2478
# Exactprod at time 17280: Expected 0.2478, in Model 0.2478
# Exactprod at time 17281: Expected 0.2478, in Model 0.2478
# Exactprod at time 17282: Expected 0.2478, in Model 0.2478
# Exactprod at time 17283: Expected 0.2478, in Model 0.2478
# Exactprod at time 17284: Expected 0.2478, in Model 0.2478
# Exactprod at time 17285: Expected 0.2478, in Model 0.2478
# Exactprod at time 17286: Expected 0.2478, in Model 0.2478
# Exactprod at time 17287: Expected 0.2478, in Model 0.2478
# Exactprod at time 17288: Expected 0.2478, in Model 0.2478
# Exactprod at time 17289: Expected 0.2466, in Model 0.2466
# Exactprod at time 17290: Expected 0.2478, in Model 0.2478
# Exactprod at time 17291: Expected 0.2478, in Model 0.2478
# Overprod at time 17292: Expected 0.1718, in Model 0.1718
# Exactprod at time 17293: Expected 0.2478, in Model 0.2478
# Exactprod at time 17294: Expected 0.2478, in Model 0.2478
# Exactprod at time 17295: Expected 0.0966, in Model 0.0966
# Exactprod at time 17296: Expected 0.2478, in Model 0.2478
# Exactprod at time 17297: Expected 0.2478, in Model 0.2478
# Underprod at time 17298: Expected 0.0938, in Model 0.0938
# Exactprod at time 17299: Expected 0.2478, in Model 0.2478
# Exactprod at time 17300: Expected 0.2478, in Model 0.2478
# Exactprod at time 17301: Expected 0.2335, in Model 0.2335
# Exactprod at time 17302: Expected 0.2478, in Model 0.2478
# Exactprod at time 17303: Expected 0.2478, in Model 0.2478
# Exactprod at time 17304: Expected 0.2056, in Model 0.2056
# Exactprod at time 17305: Expected 0.2478, in Model 0.2478
# Exactprod at time 17306: Expected 0.2478, in Model 0.2478
# Exactprod at time 17307: Expected 0.1963, in Model 0.1963
# Exactprod at time 17308: Expected 0.2478, in Model 0.2478
# Exactprod at time 17309: Expected 0.2478, in Model 0.2478
# Exactprod at time 17310: Expected 0.2478, in Model 0.2478
# Exactprod at time 17311: Expected 0.2478, in Model 0.2478
# Exactprod at time 17312: Expected 0.2478, in Model 0.2478
# Exactprod at time 17313: Expected 0.2478, in Model 0.2478
# Exactprod at time 17314: Expected 0.2478, in Model 0.2478
# Exactprod at time 17315: Expected 0.2478, in Model 0.2478
# Exactprod at time 17316: Expected 0.2215, in Model 0.2215
# Exactprod at time 17317: Expected 0.2478, in Model 0.2478
# Exactprod at time 17318: Expected 0.2478, in Model 0.2478
# Exactprod at time 17319: Expected 0.0981, in Model 0.0981
# Exactprod at time 17320: Expected 0.2478, in Model 0.2478
# Exactprod at time 17321: Expected 0.2478, in Model 0.2478
# Underprod at time 17322: Expected 0.1392, in Model 0.1392
# Exactprod at time 17323: Expected 0.2478, in Model 0.2478
# Exactprod at time 17324: Expected 0.2478, in Model 0.2478
# Overprod at time 17325: Expected 0.1534, in Model 0.1534
# Exactprod at time 17326: Expected 0.2478, in Model 0.2478
# Exactprod at time 17327: Expected 0.2478, in Model 0.2478
# Underprod at time 17328: Expected 0.1382, in Model 0.1382
# Exactprod at time 17329: Expected 0.2478, in Model 0.2478
# Exactprod at time 17330: Expected 0.2478, in Model 0.2478
# Exactprod at time 17331: Expected 0.1096, in Model 0.1096
# Exactprod at time 17332: Expected 0.2478, in Model 0.2478
# Exactprod at time 17333: Expected 0.2478, in Model 0.2478
# Exactprod at time 17334: Expected 0.0901, in Model 0.0901
# Exactprod at time 17335: Expected 0.2478, in Model 0.2478
# Exactprod at time 17336: Expected 0.2478, in Model 0.2478
# Overprod at time 17337: Expected 0.0852, in Model 0.0852
# Exactprod at time 17338: Expected 0.2478, in Model 0.2478
# Exactprod at time 17339: Expected 0.2478, in Model 0.2478
# Underprod at time 17340: Expected 0.0972, in Model 0.0972
# Exactprod at time 17341: Expected 0.2478, in Model 0.2478
# Exactprod at time 17342: Expected 0.2478, in Model 0.2478
# Exactprod at time 17343: Expected 0.0695, in Model 0.0695
# Exactprod at time 17344: Expected 0.2478, in Model 0.2478
# Exactprod at time 17345: Expected 0.2478, in Model 0.2478
# Underprod at time 17346: Expected 0.2043, in Model 0.2043
# Exactprod at time 17347: Expected 0.2478, in Model 0.2478
# Exactprod at time 17348: Expected 0.2478, in Model 0.2478
# Exactprod at time 17349: Expected 0.2478, in Model 0.2478
# Exactprod at time 17350: Expected 0.2478, in Model 0.2478
# Exactprod at time 17351: Expected 0.2478, in Model 0.2478
# Exactprod at time 17352: Expected 0.2429, in Model 0.2429
# Exactprod at time 17353: Expected 0.2478, in Model 0.2478
# Exactprod at time 17354: Expected 0.2478, in Model 0.2478
# Underprod at time 17355: Expected 0.1684, in Model 0.1684
# Exactprod at time 17356: Expected 0.2478, in Model 0.2478
# Exactprod at time 17357: Expected 0.2478, in Model 0.2478
# Underprod at time 17358: Expected 0.1322, in Model 0.1322
# Exactprod at time 17359: Expected 0.2478, in Model 0.2478
# Exactprod at time 17360: Expected 0.2478, in Model 0.2478
# Exactprod at time 17361: Expected 0.1211, in Model 0.1211
# Exactprod at time 17362: Expected 0.2478, in Model 0.2478
# Exactprod at time 17363: Expected 0.2478, in Model 0.2478
# Overprod at time 17364: Expected 0.0548, in Model 0.0548
# Exactprod at time 17365: Expected 0.2478, in Model 0.2478
# Exactprod at time 17366: Expected 0.2478, in Model 0.2478
# Exactprod at time 17367: Expected 0.0637, in Model 0.0637
# Exactprod at time 17368: Expected 0.2478, in Model 0.2478
# Exactprod at time 17369: Expected 0.2478, in Model 0.2478
# Exactprod at time 17370: Expected 0.0589, in Model 0.0589
# Exactprod at time 17371: Expected 0.2478, in Model 0.2478
# Exactprod at time 17372: Expected 0.2478, in Model 0.2478
# Overprod at time 17373: Expected 0.0616, in Model 0.0616
# Exactprod at time 17374: Expected 0.2478, in Model 0.2478
# Exactprod at time 17375: Expected 0.2478, in Model 0.2478
# Exactprod at time 17376: Expected 0.0504, in Model 0.0504
# Exactprod at time 17377: Expected 0.2478, in Model 0.2478
# Exactprod at time 17378: Expected 0.2478, in Model 0.2478
# Exactprod at time 17379: Expected 0.0406, in Model 0.0406
# Exactprod at time 17380: Expected 0.2478, in Model 0.2478
# Exactprod at time 17381: Expected 0.2478, in Model 0.2478
# Overprod at time 17382: Expected 0.0143, in Model 0.0143
# Exactprod at time 17383: Expected 0.2478, in Model 0.2478
# Exactprod at time 17384: Expected 0.2478, in Model 0.2478
# Exactprod at time 17385: Expected 0.047, in Model 0.047
# Exactprod at time 17386: Expected 0.2478, in Model 0.2478
# Exactprod at time 17387: Expected 0.2478, in Model 0.2478
# Overprod at time 17388: Expected 0.1172, in Model 0.1172
# Exactprod at time 17389: Expected 0.2478, in Model 0.2478
# Exactprod at time 17390: Expected 0.2478, in Model 0.2478
# Exactprod at time 17391: Expected 0.1923, in Model 0.1923
# Exactprod at time 17392: Expected 0.2478, in Model 0.2478
# Exactprod at time 17393: Expected 0.2478, in Model 0.2478
# Exactprod at time 17394: Expected 0.2478, in Model 0.2478
# Exactprod at time 17395: Expected 0.2478, in Model 0.2478
# Exactprod at time 17396: Expected 0.2478, in Model 0.2478
# Exactprod at time 17397: Expected 0.2478, in Model 0.2478
# Exactprod at time 17398: Expected 0.2478, in Model 0.2478
# Exactprod at time 17399: Expected 0.2478, in Model 0.2478
# Exactprod at time 17400: Expected 0.2478, in Model 0.2478
# Exactprod at time 17401: Expected 0.2478, in Model 0.2478
# Exactprod at time 17402: Expected 0.2478, in Model 0.2478
# Exactprod at time 17403: Expected 0.2478, in Model 0.2478
# Exactprod at time 17404: Expected 0.2478, in Model 0.2478
# Exactprod at time 17405: Expected 0.2478, in Model 0.2478
# Exactprod at time 17406: Expected 0.2246, in Model 0.2246
# Exactprod at time 17407: Expected 0.2478, in Model 0.2478
# Exactprod at time 17408: Expected 0.2478, in Model 0.2478
# Exactprod at time 17409: Expected 0.2478, in Model 0.2478
# Exactprod at time 17410: Expected 0.2478, in Model 0.2478
# Exactprod at time 17411: Expected 0.2478, in Model 0.2478
# Exactprod at time 17412: Expected 0.2478, in Model 0.2478
# Exactprod at time 17413: Expected 0.2478, in Model 0.2478
# Exactprod at time 17414: Expected 0.2478, in Model 0.2478
# Exactprod at time 17415: Expected 0.2478, in Model 0.2478
# Exactprod at time 17416: Expected 0.2478, in Model 0.2478
# Exactprod at time 17417: Expected 0.2478, in Model 0.2478
# Exactprod at time 17418: Expected 0.2478, in Model 0.2478
# Exactprod at time 17419: Expected 0.2478, in Model 0.2478
# Exactprod at time 17420: Expected 0.2478, in Model 0.2478
# Exactprod at time 17421: Expected 0.2478, in Model 0.2478
# Exactprod at time 17422: Expected 0.2478, in Model 0.2478
# Exactprod at time 17423: Expected 0.2478, in Model 0.2478
# Exactprod at time 17424: Expected 0.2478, in Model 0.2478
# Exactprod at time 17425: Expected 0.2478, in Model 0.2478
# Exactprod at time 17426: Expected 0.2478, in Model 0.2478
# Exactprod at time 17427: Expected 0.2478, in Model 0.2478
# Exactprod at time 17428: Expected 0.2478, in Model 0.2478
# Exactprod at time 17429: Expected 0.2478, in Model 0.2478
# Exactprod at time 17430: Expected 0.2478, in Model 0.2478
# Exactprod at time 17431: Expected 0.2478, in Model 0.2478
# Exactprod at time 17432: Expected 0.2478, in Model 0.2478
# Exactprod at time 17433: Expected 0.2478, in Model 0.2478
# Exactprod at time 17434: Expected 0.2478, in Model 0.2478
# Exactprod at time 17435: Expected 0.2478, in Model 0.2478
# Exactprod at time 17436: Expected 0.2478, in Model 0.2478
# Exactprod at time 17437: Expected 0.2478, in Model 0.2478
# Exactprod at time 17438: Expected 0.2478, in Model 0.2478
# Exactprod at time 17439: Expected 0.2478, in Model 0.2478
# Exactprod at time 17440: Expected 0.2478, in Model 0.2478
# Exactprod at time 17441: Expected 0.2478, in Model 0.2478
# Exactprod at time 17442: Expected 0.2478, in Model 0.2478
# Exactprod at time 17443: Expected 0.2478, in Model 0.2478
# Exactprod at time 17444: Expected 0.2478, in Model 0.2478
# Exactprod at time 17445: Expected 0.2478, in Model 0.2478
# Exactprod at time 17446: Expected 0.2478, in Model 0.2478
# Exactprod at time 17447: Expected 0.2478, in Model 0.2478
# Exactprod at time 17448: Expected 0.2478, in Model 0.2478
# Exactprod at time 17449: Expected 0.2478, in Model 0.2478
# Exactprod at time 17450: Expected 0.2478, in Model 0.2478
# Overprod at time 17451: Expected 0.2356, in Model 0.2356
# Exactprod at time 17452: Expected 0.2478, in Model 0.2478
# Exactprod at time 17453: Expected 0.2478, in Model 0.2478
# Exactprod at time 17454: Expected 0.2385, in Model 0.2385
# Exactprod at time 17455: Expected 0.2478, in Model 0.2478
# Exactprod at time 17456: Expected 0.2478, in Model 0.2478
# Exactprod at time 17457: Expected 0.2131, in Model 0.2131
# Exactprod at time 17458: Expected 0.2478, in Model 0.2478
# Exactprod at time 17459: Expected 0.2478, in Model 0.2478
# Exactprod at time 17460: Expected 0.1862, in Model 0.1862
# Exactprod at time 17461: Expected 0.2478, in Model 0.2478
# Exactprod at time 17462: Expected 0.2478, in Model 0.2478
# Overprod at time 17463: Expected 0.1758, in Model 0.1758
# Exactprod at time 17464: Expected 0.2478, in Model 0.2478
# Exactprod at time 17465: Expected 0.2478, in Model 0.2478
# Exactprod at time 17466: Expected 0.1645, in Model 0.1645
# Exactprod at time 17467: Expected 0.2478, in Model 0.2478
# Exactprod at time 17468: Expected 0.2478, in Model 0.2478
# Exactprod at time 17469: Expected 0.1559, in Model 0.1559
# Exactprod at time 17470: Expected 0.2478, in Model 0.2478
# Exactprod at time 17471: Expected 0.2478, in Model 0.2478
# Exactprod at time 17472: Expected 0.1509, in Model 0.1509
# Exactprod at time 17473: Expected 0.2478, in Model 0.2478
# Exactprod at time 17474: Expected 0.2478, in Model 0.2478
# Exactprod at time 17475: Expected 0.1347, in Model 0.1347
# Exactprod at time 17476: Expected 0.2478, in Model 0.2478
# Exactprod at time 17477: Expected 0.2478, in Model 0.2478
# Underprod at time 17478: Expected 0.1211, in Model 0.1211
# Exactprod at time 17479: Expected 0.2478, in Model 0.2478
# Exactprod at time 17480: Expected 0.2478, in Model 0.2478
# Exactprod at time 17481: Expected 0.1705, in Model 0.1705
# Exactprod at time 17482: Expected 0.2478, in Model 0.2478
# Exactprod at time 17483: Expected 0.2478, in Model 0.2478
# Exactprod at time 17484: Expected 0.2478, in Model 0.2478
# Exactprod at time 17485: Expected 0.2478, in Model 0.2478
# Exactprod at time 17486: Expected 0.2478, in Model 0.2478
# Exactprod at time 17487: Expected 0.2478, in Model 0.2478
# Exactprod at time 17488: Expected 0.2478, in Model 0.2478
# Exactprod at time 17489: Expected 0.2478, in Model 0.2478
# Exactprod at time 17490: Expected 0.2478, in Model 0.2478
# Exactprod at time 17491: Expected 0.2478, in Model 0.2478
# Exactprod at time 17492: Expected 0.2478, in Model 0.2478
# Exactprod at time 17493: Expected 0.2478, in Model 0.2478
# Exactprod at time 17494: Expected 0.2478, in Model 0.2478
# Exactprod at time 17495: Expected 0.2478, in Model 0.2478
# Exactprod at time 17496: Expected 0.2128, in Model 0.2128
# Exactprod at time 17497: Expected 0.2478, in Model 0.2478
# Exactprod at time 17498: Expected 0.2478, in Model 0.2478
# Exactprod at time 17499: Expected 0.1669, in Model 0.1669
# Exactprod at time 17500: Expected 0.2478, in Model 0.2478
# Exactprod at time 17501: Expected 0.2478, in Model 0.2478
# Underprod at time 17502: Expected 0.1511, in Model 0.1511
# Exactprod at time 17503: Expected 0.2478, in Model 0.2478
# Exactprod at time 17504: Expected 0.2478, in Model 0.2478
# Underprod at time 17505: Expected 0.1066, in Model 0.1066
# Exactprod at time 17506: Expected 0.2478, in Model 0.2478
# Exactprod at time 17507: Expected 0.2478, in Model 0.2478
# Exactprod at time 17508: Expected 0.0935, in Model 0.0935
# Exactprod at time 17509: Expected 0.2478, in Model 0.2478
# Exactprod at time 17510: Expected 0.2478, in Model 0.2478
# Exactprod at time 17511: Expected 0.0651, in Model 0.0651
# Exactprod at time 17512: Expected 0.2478, in Model 0.2478
# Exactprod at time 17513: Expected 0.2478, in Model 0.2478
# Underprod at time 17514: Expected 0.0435, in Model 0.0435
# Exactprod at time 17515: Expected 0.2478, in Model 0.2478
# Exactprod at time 17516: Expected 0.2478, in Model 0.2478
# Exactprod at time 17517: Expected 0.0679, in Model 0.0679
# Exactprod at time 17518: Expected 0.2478, in Model 0.2478
# Exactprod at time 17519: Expected 0.2478, in Model 0.2478
# Exactprod at time 17520: Expected 0.1845, in Model 0.1845
# Exactprod at time 17521: Expected 0.2478, in Model 0.2478
# Exactprod at time 17522: Expected 0.2478, in Model 0.2478
# Exactprod at time 17523: Expected 0.1551, in Model 0.1551
# Overprod at time 17524: Expected 0.2475, in Model 0.2475
# Exactprod at time 17525: Expected 0.2472, in Model 0.2472
# Exactprod at time 17526: Expected 0.1035, in Model 0.1035
# Exactprod at time 17527: Expected 0.2478, in Model 0.2478
# Exactprod at time 17528: Expected 0.2478, in Model 0.2478
# Overprod at time 17529: Expected 0.0579, in Model 0.0579
# Exactprod at time 17530: Expected 0.2478, in Model 0.2478
# Exactprod at time 17531: Expected 0.2478, in Model 0.2478
# Exactprod at time 17532: Expected 0.1071, in Model 0.1071
# Exactprod at time 17533: Expected 0.2478, in Model 0.2478
# Exactprod at time 17534: Expected 0.2478, in Model 0.2478
# Exactprod at time 17535: Expected 0.1049, in Model 0.1049
# Exactprod at time 17536: Expected 0.2478, in Model 0.2478
# Exactprod at time 17537: Expected 0.2478, in Model 0.2478
# Exactprod at time 17538: Expected 0.187, in Model 0.187
# Exactprod at time 17539: Expected 0.2478, in Model 0.2478
# Exactprod at time 17540: Expected 0.2478, in Model 0.2478
# Exactprod at time 17541: Expected 0.2478, in Model 0.2478
# Exactprod at time 17542: Expected 0.2478, in Model 0.2478
# Exactprod at time 17543: Expected 0.2478, in Model 0.2478

# %%
print(n)
print(x)
print(g)
# Out:
# 0
# 0
# 13500

# %%
import calendar

def energy_demand():
    def daily_sum(ts):
        elec = np.array(ts[0])
        elec = elec.reshape((elec.shape[0]//24, 24))
        sum_elec = np.sum(elec, axis=1)
        
        return sum_elec

    df_elec = pd.read_csv("../../data/demand_el.csv", header=None)
    df_gas = pd.read_csv("../../data/demand_ng.csv", header=None)

    sum_elec = daily_sum(df_elec)
    sum_gas = daily_sum(df_gas)

    years = 2

    month_names = [calendar.month_name[i] for i in range(1, 13)]
    month_names = list(map(lambda x: x + " 2015", month_names)) + list(map(lambda x: x + " 2016", month_names)) + ['']

    # month_names = [calendar.month_name[i] for i in range(1, 13)] * years + [''] # add a placeholder string

    tmp = (sum_elec.shape[0] // 3) * years
    months= [x for x in range(0,tmp)]

    days = [x for x in range(tmp)]

    plt.figure(figsize=(10,8))

    color1, color2 = 'steelblue', 'lightcoral'

    linewidth = 2

    plt.plot([],[], color=color2, label='Gas', linewidth=linewidth)

    plt.stackplot(days, sum_gas[:tmp], colors=[color2], alpha=.7, linewidth=linewidth)

    plt.legend()
    plt.xlim(0, tmp)
    freq = 4
    plt.xticks(months[::30*freq], month_names[::freq], rotation=0)

    plt.ylabel('Energy demand [GWh/day]')

    plt.axhline(color='black', linewidth=1)

    plt.show()

# %%
energy_demand()
