# %% [markdown]
# # Triple Analysis
# ## Offshore and Onshore wind, 3 Hydro plants, wave no production in Belgium

# %%
from datetime import datetime

def is_leap_year(year):
    """Determine whether a year is a leap year."""
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

def sum_hours_over_years(start_year, end_year):
    """Calculate the sum of hours from start_year to end_year, inclusive."""
    total_hours = 0
    for year in range(start_year, end_year + 1):
        if is_leap_year(year):
            total_hours += 366 * 24  # Leap year has 366 days
        else:
            total_hours += 365 * 24  # Non-leap year has 365 days
    return total_hours

# Now, we will iterate over the years from 2015 to 2019 as per the requirement.
start_year = 2015
end_year = 2019
yearly_hours = {}

# Calculating the sum of hours for each range starting from 2015
for year in range(start_year, end_year + 1):
    yearly_hours[f"{start_year}-{year}"] = sum_hours_over_years(start_year, year)

yearly_hours
# Out:
# {'2015-2015': 8760,
#  '2015-2016': 17544,
#  '2015-2017': 26304,
#  '2015-2018': 35064,
#  '2015-2019': 43824}

# %%
from gboml import GbomlGraph

timehorizon = 17544


gboml_model = GbomlGraph(timehorizon=timehorizon)
nodes, edges, param = gboml_model.import_all_nodes_and_edges("../../models/hydro/greenland_hydro.gboml")
gboml_model.add_global_parameters(param)
gboml_model.add_nodes_in_model(*nodes)
gboml_model.add_hyperedges_in_model(*edges)
gboml_model.build_model()
solution, obj, status, solver_info, constr_info, _ = gboml_model.solve_gurobi(opt_file="gurobi.txt")
print("Solved")
# Out:
# Check variables of node LIQUEFIED_METHANE_CARRIERS_GR : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_STORAGE_HUB_GR : --- 0.0 seconds ---
# Check variables of node METHANE_LIQUEFACTION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node METHANATION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node WATER_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node CARBON_DIOXIDE_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node HYDROGEN_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node DIRECT_AIR_CAPTURE_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node DESALINATION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node HVDC_GR : --- 0.0 seconds ---
# Check variables of node BATTERY_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node WAVE_PLANT_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_PLANT_05h_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_BASIN_05h_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_PLANT_03j_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_BASIN_03j_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_PLANT_03h_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_BASIN_03h_GR : --- 0.0 seconds ---
# Check variables of node ON_WIND_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node OFF_WIND_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node ENERGY_DEMAND_BE : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_STORAGE_DESTINATION : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_REGASIFICATION : --- 0.0 seconds ---
# Check hyperlink COASTAL_CARBON_DIOXIDE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_LIQUEFIED_METHANE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_METHANE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_WATER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_HYDROGEN_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_POWER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink INLAND_POWER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_05h : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_03j : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_03h : --- 0.0 seconds ---
# Check hyperlink DESTINATION_LIQUEFIED_METHANE_BALANCE : --- 0.0 seconds ---
# Warning : Hyperedge constraint using variables from a single node at line 41
# Check hyperlink DESTINATION_METHANE_BALANCE : --- 0.0 seconds ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-12-03
#
# Reading Gurobi options from file gurobi.opt
# Set parameter Method to value 2
# Set parameter BarHomogeneous to value 1
# Set parameter Crossover to value 0
#
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 7735HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2649171 rows, 1087755 columns and 4936439 nonzeros
# Model fingerprint: 0x054c1bb6
# Variable types: 1087754 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [5e-05, 3e+02]
#   Objective range  [2e-04, 3e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-02, 6e+07]
# Presolve removed 1954563 rows and 620991 columns (presolve time = 5s) ...
# Presolve removed 1979266 rows and 624558 columns (presolve time = 10s) ...
# Presolve removed 2003016 rows and 648307 columns
# Presolve time: 11.98s
# Presolved: 646155 rows, 439448 columns, 1912583 nonzeros
# Variable types: 439447 continuous, 1 integer (0 binary)
# Root barrier log...
#
# Ordering time: 0.13s
#
# Barrier statistics:
#  Dense cols : 23
#  AA' NZ     : 1.876e+06
#  Factor NZ  : 1.054e+07 (roughly 500 MB of memory)
#  Factor Ops : 2.046e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.84397665e+08 -3.61931362e+12  3.07e+05 2.01e-02  7.23e+06    14s
#    1   7.14557918e+08 -8.33992917e+11  2.30e+05 3.04e+05  2.18e+06    15s
#    2   6.78341256e+08 -1.61023001e+11  1.84e+05 1.23e+05  7.84e+05    15s
#    3   4.20585195e+08 -6.91087444e+10  1.43e+05 8.25e+04  5.23e+05    16s
#    4   1.64431506e+08 -3.14722530e+10  3.76e+04 1.65e+05  1.60e+05    16s
#    5   6.93077149e+07 -1.52813529e+10  9.70e+03 1.00e+05  5.36e+04    16s
#    6   5.27591050e+07 -1.01314130e+10  5.16e+03 6.80e+04  3.19e+04    16s
#    7   3.91459638e+07 -5.29666054e+09  1.85e+03 3.68e+04  1.43e+04    17s
#    8   2.77624539e+07 -1.60376100e+09  3.67e+02 1.15e+04  3.53e+03    17s
#    9   1.73523921e+07 -1.87125296e+08  4.71e+01 1.48e+03  3.71e+02    17s
#   10   1.41009934e+07 -4.71101654e+07  3.21e+01 4.21e+02  1.24e+02    18s
#   11   1.31928732e+07 -2.61532213e+07  2.91e+01 2.51e+02  8.42e+01    18s
#   12   7.63857925e+06 -9.09469531e+06  1.43e+01 1.00e+02  3.31e+01    18s
#   13   4.47854807e+06 -3.74810999e+06  7.56e+00 4.75e+01  1.52e+01    19s
#   14   2.77047888e+06 -3.01998411e+06  4.37e+00 3.82e+01  9.78e+00    19s
#   15   2.25794483e+06 -2.66646710e+06  3.49e+00 3.42e+01  8.10e+00    19s
#   16   1.16622478e+06 -1.65998052e+06  1.72e+00 2.21e+01  4.30e+00    20s
#   17   2.55262688e+05 -2.52581785e+05  3.82e-01 3.66e+00  7.15e-01    20s
#   18   3.34903849e+04 -4.92863229e+04  6.24e-02 5.98e-01  9.79e-02    20s
#   19   1.24209101e+04 -1.54265495e+04  1.77e-02 1.87e-01  3.06e-02    21s
#   20   8.99996370e+03 -9.09228624e+03  1.18e-02 1.17e-01  1.97e-02    21s
#   21   7.86417982e+03 -8.29570208e+03  1.01e-02 1.08e-01  1.75e-02    22s
#   22   7.53481761e+03 -4.82049632e+03  9.58e-03 6.44e-02  1.32e-02    22s
#   23   7.49732139e+03 -3.65207250e+03  9.52e-03 5.23e-02  1.19e-02    22s
#   24   6.70538805e+03 -3.28581954e+02  8.28e-03 2.14e-02  7.38e-03    23s
#   25   3.51301743e+03  4.33793218e+02  2.76e-03 1.38e-02  3.24e-03    23s
#   26   2.72958571e+03  1.47557741e+03  1.27e-03 4.68e-03  1.31e-03    24s
#   27   2.45580651e+03  1.69127050e+03  7.64e-04 2.91e-03  7.94e-04    24s
#   28   2.31220084e+03  1.74462926e+03  4.94e-04 2.48e-03  5.90e-04    24s
#   29   2.25772646e+03  1.87378630e+03  3.91e-04 1.42e-03  3.96e-04    25s
#   30   2.20586094e+03  1.91757749e+03  2.94e-04 1.06e-03  2.97e-04    25s
#   31   2.19867111e+03  1.97152556e+03  2.81e-04 6.13e-04  2.32e-04    25s
#   32   2.13733135e+03  2.01307156e+03  1.66e-04 2.85e-04  1.26e-04    26s
#   33   2.11023257e+03  2.02727370e+03  1.12e-04 1.85e-04  8.42e-05    26s
#   34   2.09354130e+03  2.03640278e+03  7.85e-05 1.21e-04  5.79e-05    27s
#   35   2.08641105e+03  2.04062273e+03  6.39e-05 9.31e-05  4.63e-05    27s
#   36   2.08074276e+03  2.04291297e+03  5.20e-05 7.88e-05  3.83e-05    28s
#   37   2.07623693e+03  2.04479607e+03  4.26e-05 6.73e-05  3.18e-05    28s
#   38   2.07197432e+03  2.05024312e+03  3.35e-05 3.44e-05  2.19e-05    29s
#   39   2.06697967e+03  2.05177038e+03  2.29e-05 2.54e-05  1.54e-05    29s
#   40   2.06473869e+03  2.05323532e+03  1.81e-05 1.79e-05  1.16e-05    29s
#   41   2.06205883e+03  2.05394600e+03  1.24e-05 1.37e-05  8.19e-06    30s
#   42   2.06009990e+03  2.05452411e+03  8.95e-06 1.02e-05  5.63e-06    30s
#   43   2.05881446e+03  2.05488741e+03  7.66e-06 8.17e-06  3.97e-06    31s
#   44   2.05867573e+03  2.05507014e+03  7.61e-06 7.16e-06  3.64e-06    31s
#   45   2.05774513e+03  2.05548998e+03  6.10e-06 4.92e-06  2.28e-06    31s
#   46   2.05759758e+03  2.05565945e+03  5.67e-06 3.96e-06  1.96e-06    32s
#   47   2.05726690e+03  2.05582136e+03  4.80e-06 3.06e-06  1.46e-06    32s
#   48   2.05704715e+03  2.05590040e+03  3.80e-06 2.62e-06  1.16e-06    33s
#   49   2.05686217e+03  2.05592670e+03  3.05e-06 2.48e-06  9.50e-07    33s
#   50   2.05677904e+03  2.05626306e+03  2.47e-06 6.13e-07  5.19e-07    34s
#   51   2.05674051e+03  2.05628167e+03  2.21e-06 5.35e-07  4.61e-07    34s
#   52   2.05668474e+03  2.05629157e+03  1.84e-06 4.93e-07  3.95e-07    35s
#   53   2.05662803e+03  2.05630237e+03  1.46e-06 4.50e-07  3.28e-07    35s
#   54   2.05658276e+03  2.05633333e+03  1.13e-06 3.31e-07  2.51e-07    36s
#   55   2.05655927e+03  2.05634313e+03  9.59e-07 2.96e-07  2.17e-07    36s
#   56   2.05648812e+03  2.05638928e+03  4.32e-07 1.40e-07  9.97e-08    37s
#   57   2.05644205e+03  2.05641023e+03  1.63e-06 6.47e-08  3.21e-08    38s
#   58   2.05643766e+03  2.05641370e+03  3.64e-06 5.20e-08  2.44e-08    39s
#   59   2.05643510e+03  2.05642147e+03  6.28e-06 7.89e-08  1.39e-08    39s
#   60   2.05643024e+03  2.05642550e+03  1.81e-06 3.03e-08  4.93e-09    40s
#   61   2.05642918e+03  2.05642739e+03  8.80e-07 8.49e-09  1.88e-09    40s
#   62   2.05642851e+03  2.05642805e+03  2.99e-07 1.24e-09  4.96e-10    41s
#   63   2.05642850e+03  2.05642806e+03  2.93e-07 1.01e-09  4.72e-10    42s
#   64   2.05642832e+03  2.05642813e+03  2.67e-07 1.40e-07  2.06e-10    42s
#   65   2.05642827e+03  2.05642817e+03  1.67e-07 1.18e-08  1.07e-10    42s
#   66   2.05642826e+03  2.05642817e+03  4.03e-07 3.27e-08  9.47e-11    43s
#   67   2.05642825e+03  2.05642818e+03  3.45e-07 9.45e-06  7.95e-11    43s
#   68   2.05642824e+03  2.05642818e+03  2.98e-07 5.66e-06  6.75e-11    44s
#   69   2.05642821e+03  2.05642818e+03  1.91e-07 1.75e-06  3.23e-11    44s
#   70   2.05642820e+03  2.05642818e+03  1.27e-07 8.59e-08  2.08e-11    45s
#
# Barrier solved model in 70 iterations and 44.51 seconds (48.53 work units)
# Optimal objective 2.05642820e+03
#
#
# Root crossover log...
#
#   175056 DPushes remaining with DInf 4.3211140e-02                45s
#    18805 DPushes remaining with DInf 0.0000000e+00                50s
#    16979 DPushes remaining with DInf 0.0000000e+00                56s
#    16155 DPushes remaining with DInf 0.0000000e+00                63s
#    15743 DPushes remaining with DInf 0.0000000e+00                66s
#    14919 DPushes remaining with DInf 0.0000000e+00                73s
#    14507 DPushes remaining with DInf 0.0000000e+00                76s
#    13683 DPushes remaining with DInf 0.0000000e+00                83s
#    13271 DPushes remaining with DInf 0.0000000e+00                86s
#    12447 DPushes remaining with DInf 0.0000000e+00                93s
#    12035 DPushes remaining with DInf 0.0000000e+00                97s
#    11211 DPushes remaining with DInf 0.0000000e+00               103s
#    10799 DPushes remaining with DInf 0.0000000e+00               107s
#    10387 DPushes remaining with DInf 0.0000000e+00               110s
#     8739 DPushes remaining with DInf 0.0000000e+00               118s
#     8327 DPushes remaining with DInf 0.0000000e+00               121s
#     7915 DPushes remaining with DInf 0.0000000e+00               125s
#     6679 DPushes remaining with DInf 0.0000000e+00               131s
#     5644 DPushes remaining with DInf 0.0000000e+00               138s
#     5232 DPushes remaining with DInf 0.0000000e+00               142s
#     4820 DPushes remaining with DInf 0.0000000e+00               145s
#     3996 DPushes remaining with DInf 0.0000000e+00               152s
#     3240 DPushes remaining with DInf 0.0000000e+00               158s
#     2828 DPushes remaining with DInf 0.0000000e+00               162s
#     2416 DPushes remaining with DInf 0.0000000e+00               165s
#     1592 DPushes remaining with DInf 0.0000000e+00               172s
#     1180 DPushes remaining with DInf 0.0000000e+00               175s
#      356 DPushes remaining with DInf 0.0000000e+00               182s
#        0 DPushes remaining with DInf 0.0000000e+00               186s
#
#    59548 PPushes remaining with PInf 0.0000000e+00               186s
#    28359 PPushes remaining with PInf 0.0000000e+00               195s
#    10297 PPushes remaining with PInf 0.0000000e+00               201s
#     9473 PPushes remaining with PInf 0.0000000e+00               206s
#     8649 PPushes remaining with PInf 0.0000000e+00               211s
#     7825 PPushes remaining with PInf 0.0000000e+00               215s
#     6589 PPushes remaining with PInf 0.0000000e+00               221s
#     5765 PPushes remaining with PInf 0.0000000e+00               227s
#     5353 PPushes remaining with PInf 0.0000000e+00               230s
#     4529 PPushes remaining with PInf 0.0000000e+00               236s
#     3705 PPushes remaining with PInf 0.0000000e+00               242s
#      860 PPushes remaining with PInf 0.0000000e+00               246s
#        0 PPushes remaining with PInf 0.0000000e+00               246s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.1253242e+01    246s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   118163    2.0564282e+03   0.000000e+00   5.125324e+01    247s
#   118987    2.0564282e+03   0.000000e+00   1.669980e-02    252s
#   118988    2.0564282e+03   0.000000e+00   0.000000e+00    253s
#   118988    2.0564282e+03   0.000000e+00   0.000000e+00    254s
#
# Root relaxation: objective 2.056428e+03, 118988 iterations, 241.24 seconds (759.30 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2056.42818    0    1          - 2056.42818      -     -  254s
# H    0     0                    2057.2735941 2056.42818  0.04%     -  310s
#      0     0 2056.42818    0    1 2057.27359 2056.42818  0.04%     -  312s
#      0     2 2056.42818    0    1 2057.27359 2056.42818  0.04%     -  353s
# *    1     0               1    2056.4349998 2056.42834  0.00%   603  375s
#
# Explored 3 nodes (120699 simplex iterations) in 375.75 seconds (1077.78 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 2056.43 2057.27
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (3.1280e-06) exceeds tolerance
# Best objective 2.056434999844e+03, best bound 2.056434999844e+03, gap 0.0000%
# Solved

# %%
import json

gathered_data = gboml_model.turn_solution_to_dictionary(solver_info, status, solution, obj, constr_info)
print("Json done")
with open(f'../../models/hydro/results/RREH.json', "w") as fp:json.dump(gathered_data, fp, indent=4)
# Out:
# Json done

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
class MakeMeReadable:
    def __init__(self, d):
        self.d = d
    
    def __dir__(self):
        return self.d.keys()
    
    def __getattr__(self, v):
        try:
            out = self.d[v]
            if isinstance(out, dict):
                return MakeMeReadable(out)
            return out
        except:
            return getattr(self.d, v)
        
    def __str__(self):
        return str(self.d)
    
    def __repr__(self):
        return repr(self.d)

# %%
dico = {}
with open('../../models/hydro/results/RREH.json', 'r') as f:
    dico = json.load(f)
            
d = MakeMeReadable(dico)
    
if isinstance(dico, dict):
    print('The data is a dictionary')
else:
    print('The data is not a dictionary')
# Out:
# The data is a dictionary

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(18, 15), constrained_layout=True)
ylim = (-0.1, 0.1)
axs = axs.flatten()
def plot_balance(ax, data, title):
    ax.plot(data)
    ax.set_ylim(ylim)
    ax.set_title(title)
    
# GR_CO2 Balance
co2_storage_gr_in = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.carbon_dioxide_in.values)
co2_storage_gr_out = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.carbon_dioxide_out.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.carbon_dioxide.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.carbon_dioxide.values)
co2_balance_gr = dac_gr + co2_storage_gr_out - co2_storage_gr_in - methanation_gr

plot_balance(axs[0], co2_balance_gr, 'GR_CO2 Balance')

# GR_LCH4 Balance
lch4_carriers_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_CARRIERS_GR.variables.liquefied_methane_in.values)
lch4_storage_gr_in = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_in.values)
lch4_storage_gr_out = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_out.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.liquefied_methane.values)
lch4_balance_gr = ch4_liquefaction_gr + lch4_storage_gr_out - lch4_storage_gr_in - lch4_carriers_gr

plot_balance(axs[1], lch4_balance_gr, 'GR_LCH4 Balance')

# Check BE_CH4 Balance
conversion_factor = d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.conversion_factor
demand_CH4 = np.array(d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.demand)
lch4_regasification_be = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.methane.values)
ch4_balance_be = conversion_factor * lch4_regasification_be - 10 * demand_CH4[:timehorizon]

plot_balance(axs[2], ch4_balance_be, 'BE_CH4 Balance')


# Check BE_LCH4 Balance
lch4_carriers_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_CARRIERS_GR.variables.liquefied_methane_out.values)
lch4_storage_dest_in = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_in.values)
lch4_storage_dest_out = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_out.values)
lch4_regasification_be = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.liquefied_methane.values)
lch4_balance_be = lch4_carriers_gr + lch4_storage_dest_out - lch4_storage_dest_in - lch4_regasification_be

plot_balance(axs[3], lch4_balance_be, 'BE_LCH4 Balance')


# Check GR_INLAND CH4 Balance
battery_storage_gr_out = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_out.values)
battery_storage_gr_in = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_in.values)
hvdc_gr_in = np.array(d.solution.elements.HVDC_GR.variables.electricity_in.values)
hydro_03h_gr = np.array(d.solution.elements.HYDRO_PLANT_03h_GR.variables.electricity.values)
hydro_03j_gr = np.array(d.solution.elements.HYDRO_PLANT_03j_GR.variables.electricity.values)
hydro_05h_gr = np.array(d.solution.elements.HYDRO_PLANT_05h_GR.variables.electricity.values)

power_balance_gr = hydro_03h_gr + hydro_03j_gr + hydro_05h_gr + battery_storage_gr_out - battery_storage_gr_in - hvdc_gr_in

plot_balance(axs[4], power_balance_gr, 'GR_Inland CH4 Balance')


# Check GR_Coastal Power Balance
hvdc_gr_out = np.array(d.solution.elements.HVDC_GR.variables.electricity_out.values)
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.electricity.values)
h2_storage_gr = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.electricity.values)
desalination_gr = np.array(d.solution.elements.DESALINATION_PLANTS_GR.variables.electricity.values)
h2o_storage_gr = np.array(d.solution.elements.WATER_STORAGE_GR.variables.electricity.values)
co2_storage_gr = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.electricity.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.electricity.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.electricity.values)
power_balance_gr = hvdc_gr_out - electrolysis_gr - h2_storage_gr - desalination_gr - h2o_storage_gr - co2_storage_gr - ch4_liquefaction_gr - dac_gr 

plot_balance(axs[5], power_balance_gr, 'GR_Coastal Power Balance')


# Check GR_Coastal H2 Balance
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.hydrogen.values)
h2_storage_gr_out = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_out.values)
h2_storage_gr_in = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_in.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.hydrogen.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.hydrogen.values)
h2_balance_gr = electrolysis_gr + h2_storage_gr_out - h2_storage_gr_in - methanation_gr - dac_gr

plot_balance(axs[6], h2_balance_gr, 'GR_Coastal H2 Balance')


# Check GR_Coastal H2O Balance
desalination_gr = np.array(d.solution.elements.DESALINATION_PLANTS_GR.variables.water.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.water.values)
h2o_storage_gr_out = np.array(d.solution.elements.WATER_STORAGE_GR.variables.water_out.values)
h2o_storage_gr_in = np.array(d.solution.elements.WATER_STORAGE_GR.variables.water_in.values)
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.water.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.water.values)
h20_balance_gr = desalination_gr + methanation_gr + h2o_storage_gr_out - h2o_storage_gr_in - electrolysis_gr - dac_gr

plot_balance(axs[7], h20_balance_gr, 'GR_Coastal H2O Balance')

# Check GR_Coastal CH4 Balance
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.methane.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.liquefied_methane.values)
ch4_balance_gr = methanation_gr - ch4_liquefaction_gr

plot_balance(axs[8], ch4_balance_gr, 'GR_Coastal CH4 Balance')

plt.show()

print()

# %%
ls_nodes = list(d.model.nodes.keys())

print(ls_nodes)
# Out:
# ['LIQUEFIED_METHANE_CARRIERS_GR', 'LIQUEFIED_METHANE_STORAGE_HUB_GR', 'METHANE_LIQUEFACTION_PLANTS_GR', 'METHANATION_PLANTS_GR', 'WATER_STORAGE_GR', 'CARBON_DIOXIDE_STORAGE_GR', 'HYDROGEN_STORAGE_GR', 'DIRECT_AIR_CAPTURE_PLANTS_GR', 'DESALINATION_PLANTS_GR', 'ELECTROLYSIS_PLANTS_GR', 'HVDC_GR', 'BATTERY_STORAGE_GR', 'WAVE_PLANT_GR', 'HYDRO_PLANT_05h_GR', 'HYDRO_BASIN_05h_GR', 'HYDRO_PLANT_03j_GR', 'HYDRO_BASIN_03j_GR', 'HYDRO_PLANT_03h_GR', 'HYDRO_BASIN_03h_GR', 'ON_WIND_PLANTS_GR', 'OFF_WIND_PLANTS_GR', 'ENERGY_DEMAND_BE', 'LIQUEFIED_METHANE_STORAGE_DESTINATION', 'LIQUEFIED_METHANE_REGASIFICATION']

# %%
def cost_rreh(ls:list):
    if len(ls) == 0:
        return 0.0

    cost = 0

    for ele in ls:
        # print(f"{ele = }")
        # print(dico["solution"]["elements"][ele]["objectives"])
        try:
            cost += np.sum(dico["solution"]["elements"][ele]["objectives"]["unnamed"])
        except:
            for e in dico["solution"]["elements"][ele]["objectives"]["named"].values():
                # print(f"{e = }")
                cost += e
        # print(f"{cost = }")
    
    return cost

# %%
import re 

excluded_hydro_basins = [node for node in ls_nodes if re.match(r'HYDRO_BASIN_[\w]+_GR$', node)]

try:
    GR_nodes = [node for node in ls_nodes if node.endswith("_GR") and node not in excluded_hydro_basins]
except:
    GR_nodes = []
BE_nodes = list(map(lambda string: string if string[-3:] == "_BE" or string in ["PCCC_CCGT", "PCCC", "CO2_EXPORT", "LIQUEFIED_METHANE_STORAGE_DESTINATION","LIQUEFIED_METHANE_REGASIFICATION"] else None, ls_nodes))

try:
    GR_nodes = list(filter(lambda x: x not in [None, "PCCC", "PROD_CO2", "CO2_EXPORT"], GR_nodes))
except:
    GR_nodes = []
BE_nodes = list(filter(lambda x: x not in [None, "PROD_CO2"], BE_nodes))

cost_GR = cost_rreh(GR_nodes)
cost_BE = cost_rreh(BE_nodes)


print(f"GR {cost_GR = }")
print(f"BE {cost_BE = }")


obj_cost = d.solution.objective
tot_cost = np.sum([cost_GR, cost_BE])

abs_diff = np.abs(d.solution.objective - np.sum([cost_GR, cost_BE]))
print(f"{obj_cost = }")
print(f"{tot_cost = }")
print(abs_diff < 0.1)
# Out:
# GR cost_GR = 2038.4074774547728
# BE cost_BE = 18.027522389570443
# obj_cost = 2056.434999845476
# tot_cost = 2056.434999844343
# True

# %%
# Initialize a dictionary to hold individual capacities
plant_capacities = {}

# Dynamically identify HYDRO_PLANT capacities and store them
for element_name in ls_nodes:
    if re.match(r'HYDRO_PLANT_\w+_GR$', element_name):
        # Extract capacity and store it in the dictionary
        plant_capacities[element_name] = dico["solution"]["elements"][element_name]["variables"]["capacity"]["values"][0]

# Compute the total installed capacity by summing all individual capacities
total_installed_capacity = sum(plant_capacities.values())

# %%
import matplotlib.pyplot as plt
import numpy as np

# Print installed capacities
for plant, capacity in plant_capacities.items():
    plant_type = "hydro" if "HYDRO_PLANT" in plant else "onshore" if "onshore" in plant else "offshore" if "wind_off" in plant else "wave"
    print(f"Installed capacity of {plant_type} = {capacity:.3f} GW")

# Calculate the total installed capacity
total_installed_capacity = sum(plant_capacities.values())

print(f"\nTotal installed capacity = {total_installed_capacity:.3f} GW")

# Calculate total hydro capacity by summing all hydro plant capacities
total_hydro_capacity = sum(capacity for plant, capacity in plant_capacities.items() if "HYDRO_PLANT" in plant)

# Data for the first plot
categories = ['Onshore Wind', 'Offshore Wind', 'Wave', 'Total Hydro']
capacities = [
    plant_capacities.get('wind_onshore_gr', 0),
    plant_capacities.get('wind_off_gr', 0),
    plant_capacities.get('wave_off_gr', 0),
    total_hydro_capacity
]

### Plot 1: Combined Wind and Total Hydro Capacities
plt.figure(figsize=(10, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(categories)))
plt.bar(categories, capacities, color=colors)
plt.ylabel('Installed Capacity (GW)')
plt.title('On-Offshore Wind and Total Hydro Capacities')
# Annotate each bar with its capacity
for i, v in enumerate(capacities):
    plt.text(i, v, f"{v:.3f}", ha='center', va='bottom')
plt.tight_layout()
plt.show()

### Plot 2: Capacities for Each Hydro Plant Separately
plt.figure(figsize=(10, 6))
hydro_labels = [plant for plant in plant_capacities.keys() if "HYDRO_PLANT" in plant]
hydro_values = [capacity for plant, capacity in plant_capacities.items() if "HYDRO_PLANT" in plant]
colors = plt.cm.viridis(np.linspace(0, 1, len(hydro_labels)))
plt.bar(hydro_labels, hydro_values, color=colors)
plt.title('Capacities for Each Hydro Plant')
# plt.xticks(rotation=45)
# Annotate each hydro plant bar with its capacity
for i, v in enumerate(hydro_values):
    plt.text(i, v, f"{v:.3f}", ha='center', va='bottom')
plt.tight_layout()
plt.show()
# Out:
# Installed capacity of onshore = 2.168 GW
# Installed capacity of offshore = 0.116 GW
# Installed capacity of wave = 0.566 GW
# Installed capacity of hydro = 0.058 GW
# Installed capacity of hydro = 0.099 GW
# Installed capacity of hydro = 0.040 GW
#
# Total installed capacity = 3.048 GW

# %%
gas_demand = d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.demand
gas_demand = np.sum(gas_demand[:timehorizon])/1000
print("the gas demand is ", gas_demand, "TWh")
# Out:
# the gas demand is  1.2970272171668917 TWh

# %%
# LCH4 full production:
gas = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.methane.values) * 15.31 # kt/h * GWh/kt
gas_prod = np.sum(gas) # GWh
gas_prod/1000
# Out:
# 12.970272171668919

# %%
demand_in_mwh = gas_prod * 1e3  # Convert GWh to MWh
total_cost_in_euros = tot_cost * 1e6  # Convert million euros to euros

# Compute price per MWh in euros
price_per_mwh = total_cost_in_euros / demand_in_mwh

print(f"The price is {round(price_per_mwh, 3)} €/MWh \n")
print("In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh")  # Adjusted to €/MWh
print("This system is about", round((price_per_mwh / 45), 3), "times more expensive compared to a reference price of 45 €/MWh")
# Out:
# The price is 158.55 €/MWh
#
# In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh
# This system is about 3.523 times more expensive compared to a reference price of 45 €/MWh

# %%
def cost_rreh_detailed(ls):
    detailed_cost = {}
    if len(ls) == 0:
        return detailed_cost

    for ele in ls:
        node_cost = 0
        try:
            node_cost += np.sum(dico["solution"]["elements"][ele]["objectives"]["unnamed"])
        except:
            for e in dico["solution"]["elements"][ele]["objectives"]["named"].values():
                node_cost += e
        detailed_cost[ele] = node_cost
    
    return detailed_cost

# %%
import matplotlib.pyplot as plt
import numpy as np

cost_details_GR = cost_rreh_detailed(GR_nodes)

sorted_nodes_and_costs = sorted(cost_details_GR.items(), key=lambda item: item[1])
sorted_nodes = [item[0] for item in sorted_nodes_and_costs]
sorted_costs = [item[1] for item in sorted_nodes_and_costs]

# Convert costs to €/MWh
adjusted_costs = [cost *1e6 / demand_in_mwh for cost in sorted_costs]

# Generate colors - ensuring consistent colors across plots
colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_nodes)))

# Plot 1: Stacked Horizontal Bar Chart
plt.figure(figsize=(10, 2))
cumulative_cost = 0  # Start at 0 for the leftmost bar segment

for node, cost, color in zip(sorted_nodes, adjusted_costs, colors):
    plt.barh('GR Nodes', cost, left=cumulative_cost, color=color, label=node)
    cumulative_cost += cost

plt.xlabel('Cost (€/MWh)')
plt.title('Cost Breakdown per GR Node (€/MWh)')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Nodes')
plt.show()

# Plot 2: Vertical Bar Chart with Sorted Nodes
plt.figure(figsize=(10, 6))
bars = plt.bar(sorted_nodes, adjusted_costs, color=colors)

plt.xlabel('Nodes')
plt.ylabel('Cost (€/MWh)')
plt.title('Cost per GR Node (€/MWh)')
plt.xticks(rotation=45, ha="right")

# Adding the cost above each bar
for bar, cost in zip(bars, adjusted_costs):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f"{cost:.2f}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()  # Adjust layout to make room for the rotated x-axis labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_production_dynamics(offshore_wind_gr, onshore_wind_gr, hydro_gr1, hydro_gr2, hydro_gr3, wave, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=len(offshore_wind_gr), freq='H')

    # Create DataFrames
    offshore_wind_df_gr = pd.DataFrame(offshore_wind_gr, index=date_range, columns=['Elec'])
    onshore_wind_df_gr = pd.DataFrame(onshore_wind_gr, index=date_range, columns=['Elec'])
    hydro_df1_gr = pd.DataFrame(hydro_gr1, index=date_range, columns=['Elec'])
    hydro_df2_gr = pd.DataFrame(hydro_gr2, index=date_range, columns=['Elec']) 
    hydro_df3_gr = pd.DataFrame(hydro_gr3, index=date_range, columns=['Elec'])
    wave_df_gr = pd.DataFrame(wave, index=date_range, columns=['Elec'])

   
    # Smooth the data with a rolling mean
    offshore_wind_df_gr['Smoothed'] = offshore_wind_df_gr['Elec'].rolling(window=24).mean()
    onshore_wind_df_gr['Smoothed'] = onshore_wind_df_gr['Elec'].rolling(window=24).mean()
    hydro_df1_gr['Smoothed'] = hydro_df1_gr['Elec'].rolling(window=24).mean()
    hydro_df2_gr['Smoothed'] = hydro_df2_gr['Elec'].rolling(window=24).mean()
    hydro_df3_gr['Smoothed'] = hydro_df3_gr['Elec'].rolling(window=24).mean()
    wave_df_gr['Smoothed'] = wave_df_gr['Elec'].rolling(window=24).mean()     
   
    # Plotting
    fig, axs = plt.subplots(6, 1, figsize=(12, 8), sharex=True)

    colors = plt.cm.viridis(np.linspace(0, 1, 6))

    # Plot each storage type
    for ax, df, color, label in zip(axs,
                                    [offshore_wind_df_gr, onshore_wind_df_gr, hydro_df1_gr, hydro_df2_gr, hydro_df3_gr, wave_df_gr],
                                    colors,
                                    ['Offshore Wind Production (Greenland)', 'Onshore Wind Production (Greenland)', 'Hydro Production 03h (Greenland)', 'Hydro Production 03j (Greenland)', 'Hydro Production 05h (Greenland)', 'Wave Production (Greenland)']):
        ax.fill_between(df.index, df['Smoothed'], color=color)
        ax.set_title(label, fontsize=10, loc='left')
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.set_ylabel('GWh')

    # Adjust layout and show plot
    fig.tight_layout()
    plt.show()

# %%
offshore_prod_gr = np.array(d.solution.elements.OFF_WIND_PLANTS_GR.variables.electricity.values)
onshore_prod_gr = np.array(d.solution.elements.ON_WIND_PLANTS_GR.variables.electricity.values)
hydro_prod_03h_gr = np.array(d.solution.elements.HYDRO_PLANT_03h_GR.variables.electricity.values)
hydro_prod_03j_gr = np.array(d.solution.elements.HYDRO_PLANT_03j_GR.variables.electricity.values)
hydro_prod_05h_gr = np.array(d.solution.elements.HYDRO_PLANT_05h_GR.variables.electricity.values)
wave_prod_gr = np.array(d.solution.elements.WAVE_PLANT_GR.variables.electricity.values)

plot_production_dynamics(offshore_prod_gr, onshore_prod_gr, hydro_prod_03h_gr, hydro_prod_03j_gr, hydro_prod_05h_gr, wave_prod_gr)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import re

def plot_basin_dynamics(basins_data, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=17544, freq='H')
    
    for basin_name, basin_data in basins_data.items():
        fig, axs = plt.subplots(4, 1, figsize=(12, 12), sharex=True)
        window_size = 24  # Smooth over 24 hours
        parameters = ['inflow', 'storage', 'release', 'spill']
        colors = plt.cm.viridis(np.linspace(0, 1, 4))

        for idx, parameter in enumerate(parameters):
            data_df = pd.DataFrame(basin_data[parameter], index=date_range, columns=[parameter]).rolling(window=window_size).mean()
            axs[idx].plot(data_df.index, data_df[parameter], color=colors[idx], label=f"{parameter.title()} (Smoothed)")
            axs[idx].set_title(f"{basin_name} - {parameter.title()} Dynamics", fontsize=10, loc='left')
            axs[idx].set_ylabel('Volume (m³/h)')
            axs[idx].set_ylim(bottom=0)  # Ensure y-axis starts at 0
            axs[idx].legend(loc='upper right')

        # Format x-axis
        axs[3].xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
        axs[3].xaxis.set_major_locator(mdates.MonthLocator())
        plt.xticks(rotation=45)
        plt.xlabel('Time')
        fig.tight_layout()
        plt.show()

# Assuming 'd' is your data object and 'ls_nodes' is a list of all node names
basins_data = {}

# Dynamically determine all hydro basins from ls_nodes
for node_name in ls_nodes:
    if re.match(r'HYDRO_BASIN_\w+_GR$', node_name):
        basins_data[node_name] = {
            'inflow': np.array(getattr(d.model.nodes, node_name).parameters.inflow_series[:17544]),
            'storage': np.array(getattr(d.solution.elements, node_name).variables.storage.values),
            'release': np.array(getattr(d.solution.elements, node_name).variables.release.values),
            'spill': np.array(getattr(d.solution.elements, node_name).variables.spill.values)
        }

plot_basin_dynamics(basins_data)

# %%
np.array(d.solution.elements.HYDRO_BASIN_03h_GR.variables.storage.values)
# Out:
# array([22499967.54597702, 22499967.54597702, 22499967.54597702, ...,
#        22499835.04597702, 22499802.59195403, 22499967.54597702])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_storage_dynamics(battery_data, hydrogen_data, methane_data_src, methane_data_dest, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=len(battery_data), freq='H')

    # Create DataFrames
    battery_df = pd.DataFrame(battery_data, index=date_range, columns=['Battery'])
    hydrogen_df = pd.DataFrame(hydrogen_data, index=date_range, columns=['Hydrogen'])
    methane_df_gr = pd.DataFrame(methane_data_src, index=date_range, columns=['Methane'])
    methane_df_be = pd.DataFrame(methane_data_dest, index=date_range, columns=['Methane'])


    # Smooth the data with a rolling mean
    battery_df['Smoothed'] = battery_df['Battery'].rolling(window=24).mean()
    hydrogen_df['Smoothed'] = hydrogen_df['Hydrogen'].rolling(window=24).mean()
    methane_df_gr['Smoothed'] = methane_df_gr['Methane'].rolling(window=24).mean()
    methane_df_be['Smoothed'] = methane_df_be['Methane'].rolling(window=24).mean()

    # Plotting
    fig, axs = plt.subplots(4, 1, figsize=(12, 8), sharex=True)

    colors = plt.cm.viridis(np.linspace(0, 1, 4))

    # Plot each storage type
    for ax, df, color, label in zip(axs,
                                    [battery_df, hydrogen_df, methane_df_gr, methane_df_be],
                                    colors,
                                    ['Battery Storage Dynamics', 'Hydrogen Storage Dynamics', 'Liquid Methane Storage Dynamics (Greenland)', 'Liquid Methane Storage Dynamics (Belgium)']):
        ax.fill_between(df.index, df['Smoothed'], color=color)
        ax.set_title(label, fontsize=10, loc='left')
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.set_ylabel('GWh')

    # Adjust layout and show plot
    fig.tight_layout()
    plt.show()

# %%
battery_flow = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_stored.values)
h2_flow = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_stored.values)
lch4_flow_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_stored.values)
lch4_flow_be = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_stored.values)

plot_storage_dynamics(battery_flow, h2_flow, lch4_flow_gr, lch4_flow_be)

print(battery_flow[-1])
print(h2_flow[-1])
print(lch4_flow_gr[-1])
print(lch4_flow_be[-1])
# Out:
# 0.0
# 10.607883066187087
# 10.657891138972237
# 5.715802232037658

# %%
leftover_lch4 = (lch4_flow_be[-1] + lch4_flow_gr[-1]) * 0.98 * 15.31 *1e3

leftover_lch4 # MWh
# Out:
# 245667.62059995826

# %%
demand_in_mwh = gas_prod * 1e3  # Convert TWh to MWh
total_cost_in_euros = tot_cost * 1e6  # Convert million euros to euros

# Compute price per MWh in euros
price_per_mwh = total_cost_in_euros / (demand_in_mwh+leftover_lch4)

print(f"The price is {round(price_per_mwh, 3)} €/MWh \n")
print("In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh")  # Adjusted to €/MWh
print("This system is about", round((price_per_mwh / 45), 3), "times more expensive compared to a reference price of 45 €/MWh")
# Out:
# The price is 155.603 €/MWh
#
# In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh
# This system is about 3.458 times more expensive compared to a reference price of 45 €/MWh

# %%
import pandas as pd

# Example input data
# If the CSV has no header row, set header=None and provide column names
column_name = ['WaveEnergyDensity']
wave_energy_df = pd.read_csv('../../data/wave_series_goff.csv', header=None, names=column_name)

length_of_installation = d.solution.elements.WAVE_PLANT_GR.variables.length.values[0]
unit_width = d.model.nodes.WAVE_PLANT_GR.parameters.unit_width[0]  # meters
space_between = d.model.nodes.WAVE_PLANT_GR.parameters.space_between[0]  # meters

# Calculate total space required per unit (width + space)
total_space_per_unit = unit_width + space_between

# Calculate the number of units that can be installed
number_of_units = length_of_installation // total_space_per_unit

# Calculate the total energy potential for each wave energy density value
wave_energy_df['TotalEnergyPotentialGW'] = wave_energy_df['WaveEnergyDensity'] * wave_n_units * unit_width

# Calculate the total rated energy capacity based on the number of units
total_rated_capacity_gw = number_of_units * wave_RP

# Check when the total energy potential exceeds the total rated capacity
wave_energy_df['ExceedsRatedPower'] = wave_energy_df['TotalEnergyPotentialGW'] > total_rated_capacity_gw

print(wave_energy_df)
# Out:
#        WaveEnergyDensity  TotalEnergyPotentialGW  ExceedsRatedPower
# 0               0.000022                0.558799              False
# 1               0.000049                1.221118               True
# 2               0.000049                1.227603               True
# 3               0.000019                0.469001              False
# 4               0.000050                1.237106               True
# ...                  ...                     ...                ...
# 43817           0.000047                1.171781               True
# 43818           0.000027                0.671970               True
# 43819           0.000047                1.172134               True
# 43820           0.000047                1.172077               True
# 43821           0.000026                0.654098               True
#
# [43822 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Slice the DataFrame to only include the first x rows
wave_energy_df_subset = wave_energy_df.head(timehorizon)

# Convert wave_prod array/list to a pandas Series for easy plotting (match the length of the DataFrame subset)
wave_prod = pd.Series(wave_prod_gr[:timehorizon])

# For visualization, calculate the total rated capacity again for the plot
total_rated_capacity_gw = number_of_units * wave_RP

# Plotting
plt.figure(figsize=(10, 6))

# Plot Total Energy Potential GW for the subset as grey bars with 90% transparency
plt.bar(wave_energy_df_subset.index, wave_energy_df_subset['TotalEnergyPotentialGW'], color='grey', alpha=0.9, label='Total Energy Potential (GW)')

# Plot the electricity production output as a grey line with 90% transparency
plt.plot(wave_energy_df_subset.index, wave_prod, color='blue', markersize=3, label='Electricity Production Output (GW)', alpha=0.3, linewidth=2)

# Plot a line for the Total Rated Capacity GW Threshold
plt.axhline(y=total_rated_capacity_gw, color='green', linestyle='-', label='Rated Power * Number of Units (GW)')

# Set the y-axis limit to 10 times the total rated capacity
plt.ylim(0, 10 * total_rated_capacity_gw)

plt.xlabel('Index')
plt.ylabel('Energy (GW)')
plt.title('Wave Energy Potential vs. Rated Capacity Threshold (First {} Entries)'.format(timehorizon))
plt.legend()
plt.grid(True)

plt.show()
# Out:
# C:\Users\gille\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
n=0
for t in range(len(wave_energy_df_subset)):
    calculated_prod = min(wave_energy_df_subset['WaveEnergyDensity'][t] * wave_n_units * unit_width, wave_RP * wave_n_units)
    if calculated_prod < wave_prod[t]:
        if 1.1*calculated_prod< wave_prod[t]:
            n+=1
        print(f"Overprod at time {t}: Calculated {round(calculated_prod,4)}, Existing {round(wave_prod[t],4)}")
    elif calculated_prod > wave_prod[t]: 
        print(f"Underprod at time {t}: Calculated {round(calculated_prod,4)}, Existing {round(wave_prod[t],4)}")
    elif calculated_prod == wave_prod[t]:
        print(f"Exactprod at time {t}: Calculated {round(calculated_prod,4)}, Existing {round(wave_prod[t],4)}")
# Out:
# Underprod at time 0: Calculated 0.5588, Existing 0.0
# Underprod at time 1: Calculated 0.5664, Existing 0.0
# Underprod at time 2: Calculated 0.5664, Existing 0.0
# Underprod at time 3: Calculated 0.469, Existing 0.0
# Underprod at time 4: Calculated 0.5664, Existing 0.0
# Underprod at time 5: Calculated 0.5664, Existing 0.0151
# Underprod at time 6: Calculated 0.4012, Existing 0.0145
# Underprod at time 7: Calculated 0.5664, Existing 0.0212
# Underprod at time 8: Calculated 0.5664, Existing 0.0407
# Underprod at time 9: Calculated 0.2503, Existing 0.103
# Underprod at time 10: Calculated 0.5664, Existing 0.3063
# Underprod at time 11: Calculated 0.5664, Existing 0.4296
# Exactprod at time 12: Calculated 0.5664, Existing 0.5664
# Underprod at time 13: Calculated 0.5664, Existing 0.5664
# Underprod at time 14: Calculated 0.5664, Existing 0.4636
# Underprod at time 15: Calculated 0.419, Existing 0.419
# Underprod at time 16: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17: Calculated 0.5664, Existing 0.5664
# Exactprod at time 18: Calculated 0.5664, Existing 0.5664
# Underprod at time 19: Calculated 0.5664, Existing 0.5663
# Exactprod at time 20: Calculated 0.5664, Existing 0.5664
# Exactprod at time 21: Calculated 0.5664, Existing 0.5664
# Underprod at time 22: Calculated 0.5664, Existing 0.5664
# Exactprod at time 23: Calculated 0.5664, Existing 0.5664
# Exactprod at time 24: Calculated 0.3676, Existing 0.3676
# Underprod at time 25: Calculated 0.5664, Existing 0.5664
# Exactprod at time 26: Calculated 0.5664, Existing 0.5664
# Exactprod at time 27: Calculated 0.5664, Existing 0.5664
# Exactprod at time 28: Calculated 0.5664, Existing 0.5664
# Exactprod at time 29: Calculated 0.5664, Existing 0.5664
# Underprod at time 30: Calculated 0.384, Existing 0.384
# Exactprod at time 31: Calculated 0.5664, Existing 0.5664
# Exactprod at time 32: Calculated 0.5664, Existing 0.5664
# Overprod at time 33: Calculated 0.3415, Existing 0.3415
# Exactprod at time 34: Calculated 0.5664, Existing 0.5664
# Exactprod at time 35: Calculated 0.5664, Existing 0.5664
# Exactprod at time 36: Calculated 0.5664, Existing 0.5664
# Exactprod at time 37: Calculated 0.5664, Existing 0.5664
# Exactprod at time 38: Calculated 0.5664, Existing 0.5664
# Underprod at time 39: Calculated 0.458, Existing 0.458
# Exactprod at time 40: Calculated 0.5664, Existing 0.5664
# Exactprod at time 41: Calculated 0.5664, Existing 0.5664
# Underprod at time 42: Calculated 0.5664, Existing 0.5664
# Exactprod at time 43: Calculated 0.5664, Existing 0.5664
# Exactprod at time 44: Calculated 0.5664, Existing 0.5664
# Underprod at time 45: Calculated 0.5664, Existing 0.5664
# Underprod at time 46: Calculated 0.5664, Existing 0.5664
# Exactprod at time 47: Calculated 0.5664, Existing 0.5664
# Underprod at time 48: Calculated 0.5664, Existing 0.4941
# Underprod at time 49: Calculated 0.5664, Existing 0.239
# Underprod at time 50: Calculated 0.5664, Existing 0.1081
# Underprod at time 51: Calculated 0.4729, Existing 0.0959
# Underprod at time 52: Calculated 0.5664, Existing 0.0892
# Underprod at time 53: Calculated 0.5664, Existing 0.0963
# Underprod at time 54: Calculated 0.3709, Existing 0.1016
# Underprod at time 55: Calculated 0.5664, Existing 0.1016
# Underprod at time 56: Calculated 0.5664, Existing 0.0975
# Underprod at time 57: Calculated 0.4021, Existing 0.0962
# Underprod at time 58: Calculated 0.5664, Existing 0.1027
# Underprod at time 59: Calculated 0.5664, Existing 0.1069
# Underprod at time 60: Calculated 0.4169, Existing 0.1068
# Underprod at time 61: Calculated 0.5664, Existing 0.1008
# Underprod at time 62: Calculated 0.5664, Existing 0.0898
# Underprod at time 63: Calculated 0.4784, Existing 0.0764
# Underprod at time 64: Calculated 0.5664, Existing 0.1727
# Underprod at time 65: Calculated 0.5664, Existing 0.4914
# Underprod at time 66: Calculated 0.5204, Existing 0.5012
# Underprod at time 67: Calculated 0.5664, Existing 0.432
# Exactprod at time 68: Calculated 0.5664, Existing 0.5664
# Exactprod at time 69: Calculated 0.4768, Existing 0.4768
# Underprod at time 70: Calculated 0.5664, Existing 0.5664
# Exactprod at time 71: Calculated 0.5664, Existing 0.5664
# Underprod at time 72: Calculated 0.3622, Existing 0.3622
# Exactprod at time 73: Calculated 0.5664, Existing 0.5664
# Exactprod at time 74: Calculated 0.5664, Existing 0.5664
# Underprod at time 75: Calculated 0.2355, Existing 0.2355
# Exactprod at time 76: Calculated 0.5664, Existing 0.5664
# Exactprod at time 77: Calculated 0.5664, Existing 0.5664
# Underprod at time 78: Calculated 0.1573, Existing 0.1573
# Exactprod at time 79: Calculated 0.5664, Existing 0.5664
# Underprod at time 80: Calculated 0.5664, Existing 0.2842
# Underprod at time 81: Calculated 0.2299, Existing 0.2299
# Underprod at time 82: Calculated 0.5664, Existing 0.5094
# Exactprod at time 83: Calculated 0.5664, Existing 0.5664
# Underprod at time 84: Calculated 0.5664, Existing 0.416
# Underprod at time 85: Calculated 0.5664, Existing 0.1225
# Underprod at time 86: Calculated 0.5664, Existing 0.0
# Underprod at time 87: Calculated 0.5664, Existing 0.0521
# Underprod at time 88: Calculated 0.5664, Existing 0.0432
# Underprod at time 89: Calculated 0.5664, Existing 0.1616
# Underprod at time 90: Calculated 0.5664, Existing 0.3783
# Underprod at time 91: Calculated 0.5664, Existing 0.5664
# Underprod at time 92: Calculated 0.5664, Existing 0.4708
# Underprod at time 93: Calculated 0.5664, Existing 0.4128
# Underprod at time 94: Calculated 0.5664, Existing 0.5664
# Underprod at time 95: Calculated 0.5664, Existing 0.5664
# Exactprod at time 96: Calculated 0.5664, Existing 0.5664
# Underprod at time 97: Calculated 0.5664, Existing 0.5664
# Underprod at time 98: Calculated 0.5664, Existing 0.5094
# Underprod at time 99: Calculated 0.5664, Existing 0.0828
# Underprod at time 100: Calculated 0.5664, Existing 0.0
# Underprod at time 101: Calculated 0.5664, Existing 0.0
# Underprod at time 102: Calculated 0.5664, Existing 0.0
# Underprod at time 103: Calculated 0.5664, Existing 0.0
# Underprod at time 104: Calculated 0.5664, Existing 0.0
# Underprod at time 105: Calculated 0.5664, Existing 0.0
# Underprod at time 106: Calculated 0.5664, Existing 0.0
# Underprod at time 107: Calculated 0.5664, Existing 0.0
# Underprod at time 108: Calculated 0.5664, Existing 0.0
# Underprod at time 109: Calculated 0.5664, Existing 0.0
# Underprod at time 110: Calculated 0.5664, Existing 0.0
# Underprod at time 111: Calculated 0.5664, Existing 0.0
# Underprod at time 112: Calculated 0.5664, Existing 0.0
# Underprod at time 113: Calculated 0.5664, Existing 0.0
# Underprod at time 114: Calculated 0.5664, Existing 0.0
# Underprod at time 115: Calculated 0.5664, Existing 0.0
# Underprod at time 116: Calculated 0.5664, Existing 0.0
# Underprod at time 117: Calculated 0.477, Existing 0.0047
# Underprod at time 118: Calculated 0.5664, Existing 0.0119
# Exactprod at time 119: Calculated 0.5664, Existing 0.5664
# Underprod at time 120: Calculated 0.5529, Existing 0.2808
# Underprod at time 121: Calculated 0.5664, Existing 0.1103
# Underprod at time 122: Calculated 0.5664, Existing 0.1066
# Underprod at time 123: Calculated 0.5664, Existing 0.1391
# Exactprod at time 124: Calculated 0.5664, Existing 0.5664
# Exactprod at time 125: Calculated 0.5664, Existing 0.5664
# Exactprod at time 126: Calculated 0.4403, Existing 0.4403
# Exactprod at time 127: Calculated 0.5664, Existing 0.5664
# Underprod at time 128: Calculated 0.5664, Existing 0.5664
# Exactprod at time 129: Calculated 0.2775, Existing 0.2775
# Exactprod at time 130: Calculated 0.5664, Existing 0.5664
# Exactprod at time 131: Calculated 0.5664, Existing 0.5664
# Exactprod at time 132: Calculated 0.1602, Existing 0.1602
# Underprod at time 133: Calculated 0.5664, Existing 0.3284
# Underprod at time 134: Calculated 0.5664, Existing 0.0
# Underprod at time 135: Calculated 0.069, Existing 0.0088
# Underprod at time 136: Calculated 0.5664, Existing 0.0158
# Underprod at time 137: Calculated 0.5664, Existing 0.0278
# Underprod at time 138: Calculated 0.5664, Existing 0.0474
# Underprod at time 139: Calculated 0.5664, Existing 0.0133
# Underprod at time 140: Calculated 0.5664, Existing 0.0
# Underprod at time 141: Calculated 0.5664, Existing 0.0
# Underprod at time 142: Calculated 0.5664, Existing 0.0
# Underprod at time 143: Calculated 0.5664, Existing 0.0
# Exactprod at time 144: Calculated 0.5664, Existing 0.5664
# Underprod at time 145: Calculated 0.5664, Existing 0.1142
# Underprod at time 146: Calculated 0.5664, Existing 0.1142
# Underprod at time 147: Calculated 0.5664, Existing 0.1142
# Underprod at time 148: Calculated 0.5664, Existing 0.1142
# Underprod at time 149: Calculated 0.5664, Existing 0.1142
# Underprod at time 150: Calculated 0.5664, Existing 0.1142
# Underprod at time 151: Calculated 0.5664, Existing 0.1142
# Underprod at time 152: Calculated 0.5664, Existing 0.1142
# Underprod at time 153: Calculated 0.5664, Existing 0.1142
# Underprod at time 154: Calculated 0.5664, Existing 0.1142
# Underprod at time 155: Calculated 0.5664, Existing 0.1142
# Underprod at time 156: Calculated 0.5664, Existing 0.1142
# Underprod at time 157: Calculated 0.5664, Existing 0.1142
# Underprod at time 158: Calculated 0.5664, Existing 0.1142
# Underprod at time 159: Calculated 0.5664, Existing 0.1142
# Underprod at time 160: Calculated 0.5664, Existing 0.1142
# Underprod at time 161: Calculated 0.5664, Existing 0.115
# Underprod at time 162: Calculated 0.5664, Existing 0.1142
# Underprod at time 163: Calculated 0.5664, Existing 0.0
# Underprod at time 164: Calculated 0.5664, Existing 0.0094
# Underprod at time 165: Calculated 0.5664, Existing 0.0462
# Underprod at time 166: Calculated 0.5664, Existing 0.1041
# Underprod at time 167: Calculated 0.5664, Existing 0.2352
# Underprod at time 168: Calculated 0.5664, Existing 0.3622
# Underprod at time 169: Calculated 0.5664, Existing 0.3621
# Underprod at time 170: Calculated 0.5664, Existing 0.3684
# Underprod at time 171: Calculated 0.5664, Existing 0.3016
# Underprod at time 172: Calculated 0.5664, Existing 0.3314
# Underprod at time 173: Calculated 0.5664, Existing 0.5414
# Underprod at time 174: Calculated 0.5664, Existing 0.5664
# Exactprod at time 175: Calculated 0.5664, Existing 0.5664
# Exactprod at time 176: Calculated 0.5664, Existing 0.5664
# Exactprod at time 177: Calculated 0.5664, Existing 0.5664
# Exactprod at time 178: Calculated 0.5664, Existing 0.5664
# Exactprod at time 179: Calculated 0.5664, Existing 0.5664
# Underprod at time 180: Calculated 0.5664, Existing 0.5664
# Exactprod at time 181: Calculated 0.5664, Existing 0.5664
# Exactprod at time 182: Calculated 0.5664, Existing 0.5664
# Underprod at time 183: Calculated 0.5664, Existing 0.5664
# Exactprod at time 184: Calculated 0.5664, Existing 0.5664
# Exactprod at time 185: Calculated 0.5664, Existing 0.5664
# Underprod at time 186: Calculated 0.5664, Existing 0.5664
# Exactprod at time 187: Calculated 0.5664, Existing 0.5664
# Exactprod at time 188: Calculated 0.5664, Existing 0.5664
# Underprod at time 189: Calculated 0.5664, Existing 0.5664
# Exactprod at time 190: Calculated 0.5664, Existing 0.5664
# Exactprod at time 191: Calculated 0.5664, Existing 0.5664
# Exactprod at time 192: Calculated 0.5664, Existing 0.5664
# Underprod at time 193: Calculated 0.5664, Existing 0.5664
# Exactprod at time 194: Calculated 0.5664, Existing 0.5664
# Exactprod at time 195: Calculated 0.5664, Existing 0.5664
# Exactprod at time 196: Calculated 0.5664, Existing 0.5664
# Underprod at time 197: Calculated 0.5664, Existing 0.5664
# Underprod at time 198: Calculated 0.5664, Existing 0.5664
# Underprod at time 199: Calculated 0.5664, Existing 0.3193
# Underprod at time 200: Calculated 0.5664, Existing 0.3134
# Exactprod at time 201: Calculated 0.5664, Existing 0.5664
# Underprod at time 202: Calculated 0.5664, Existing 0.5664
# Underprod at time 203: Calculated 0.5664, Existing 0.4772
# Underprod at time 204: Calculated 0.5148, Existing 0.4974
# Exactprod at time 205: Calculated 0.5664, Existing 0.5664
# Underprod at time 206: Calculated 0.5664, Existing 0.1142
# Underprod at time 207: Calculated 0.4397, Existing 0.1149
# Underprod at time 208: Calculated 0.5664, Existing 0.1142
# Underprod at time 209: Calculated 0.5664, Existing 0.1142
# Underprod at time 210: Calculated 0.5664, Existing 0.1142
# Underprod at time 211: Calculated 0.5664, Existing 0.115
# Underprod at time 212: Calculated 0.5664, Existing 0.0
# Underprod at time 213: Calculated 0.5664, Existing 0.0
# Underprod at time 214: Calculated 0.5664, Existing 0.0
# Underprod at time 215: Calculated 0.5664, Existing 0.0
# Underprod at time 216: Calculated 0.5664, Existing 0.0
# Underprod at time 217: Calculated 0.5664, Existing 0.0085
# Underprod at time 218: Calculated 0.5664, Existing 0.0355
# Underprod at time 219: Calculated 0.5664, Existing 0.0212
# Underprod at time 220: Calculated 0.5664, Existing 0.1807
# Underprod at time 221: Calculated 0.5664, Existing 0.5664
# Exactprod at time 222: Calculated 0.5664, Existing 0.5664
# Underprod at time 223: Calculated 0.5664, Existing 0.5664
# Exactprod at time 224: Calculated 0.5664, Existing 0.5664
# Exactprod at time 225: Calculated 0.5664, Existing 0.5664
# Exactprod at time 226: Calculated 0.5664, Existing 0.5664
# Exactprod at time 227: Calculated 0.5664, Existing 0.5664
# Exactprod at time 228: Calculated 0.5664, Existing 0.5664
# Exactprod at time 229: Calculated 0.5664, Existing 0.5664
# Underprod at time 230: Calculated 0.5664, Existing 0.5664
# Underprod at time 231: Calculated 0.5664, Existing 0.5664
# Exactprod at time 232: Calculated 0.5664, Existing 0.5664
# Exactprod at time 233: Calculated 0.5664, Existing 0.5664
# Exactprod at time 234: Calculated 0.5664, Existing 0.5664
# Exactprod at time 235: Calculated 0.5664, Existing 0.5664
# Underprod at time 236: Calculated 0.5664, Existing 0.5664
# Underprod at time 237: Calculated 0.5664, Existing 0.1797
# Underprod at time 238: Calculated 0.5664, Existing 0.036
# Underprod at time 239: Calculated 0.5664, Existing 0.0586
# Underprod at time 240: Calculated 0.5664, Existing 0.0902
# Underprod at time 241: Calculated 0.5664, Existing 0.0833
# Underprod at time 242: Calculated 0.5664, Existing 0.0528
# Underprod at time 243: Calculated 0.5664, Existing 0.0177
# Underprod at time 244: Calculated 0.5664, Existing 0.0828
# Underprod at time 245: Calculated 0.5664, Existing 0.3778
# Exactprod at time 246: Calculated 0.5664, Existing 0.5664
# Exactprod at time 247: Calculated 0.5664, Existing 0.5664
# Exactprod at time 248: Calculated 0.5664, Existing 0.5664
# Exactprod at time 249: Calculated 0.5664, Existing 0.5664
# Exactprod at time 250: Calculated 0.5664, Existing 0.5664
# Exactprod at time 251: Calculated 0.5664, Existing 0.5664
# Exactprod at time 252: Calculated 0.5664, Existing 0.5664
# Exactprod at time 253: Calculated 0.5664, Existing 0.5664
# Exactprod at time 254: Calculated 0.5664, Existing 0.5664
# Exactprod at time 255: Calculated 0.5664, Existing 0.5664
# Exactprod at time 256: Calculated 0.5664, Existing 0.5664
# Underprod at time 257: Calculated 0.5664, Existing 0.5664
# Underprod at time 258: Calculated 0.5664, Existing 0.3033
# Underprod at time 259: Calculated 0.5664, Existing 0.1139
# Underprod at time 260: Calculated 0.5664, Existing 0.1181
# Underprod at time 261: Calculated 0.5664, Existing 0.088
# Underprod at time 262: Calculated 0.5664, Existing 0.0301
# Underprod at time 263: Calculated 0.5664, Existing 0.0008
# Underprod at time 264: Calculated 0.5664, Existing 0.0011
# Underprod at time 265: Calculated 0.5664, Existing 0.0017
# Underprod at time 266: Calculated 0.5664, Existing 0.0
# Underprod at time 267: Calculated 0.5664, Existing 0.0
# Underprod at time 268: Calculated 0.5664, Existing 0.0
# Underprod at time 269: Calculated 0.5664, Existing 0.0
# Underprod at time 270: Calculated 0.5664, Existing 0.0
# Underprod at time 271: Calculated 0.5664, Existing 0.0
# Underprod at time 272: Calculated 0.5664, Existing 0.0
# Underprod at time 273: Calculated 0.5664, Existing 0.0
# Underprod at time 274: Calculated 0.5664, Existing 0.0
# Underprod at time 275: Calculated 0.5664, Existing 0.0
# Underprod at time 276: Calculated 0.5664, Existing 0.0
# Underprod at time 277: Calculated 0.5664, Existing 0.0
# Underprod at time 278: Calculated 0.5664, Existing 0.0
# Underprod at time 279: Calculated 0.5664, Existing 0.0
# Underprod at time 280: Calculated 0.5664, Existing 0.0
# Underprod at time 281: Calculated 0.5664, Existing 0.0
# Underprod at time 282: Calculated 0.5664, Existing 0.0
# Underprod at time 283: Calculated 0.5664, Existing 0.0
# Underprod at time 284: Calculated 0.5664, Existing 0.0
# Underprod at time 285: Calculated 0.5664, Existing 0.0
# Underprod at time 286: Calculated 0.5664, Existing 0.0
# Underprod at time 287: Calculated 0.5664, Existing 0.0
# Underprod at time 288: Calculated 0.5664, Existing 0.0
# Underprod at time 289: Calculated 0.5664, Existing 0.0
# Underprod at time 290: Calculated 0.5664, Existing 0.0
# Underprod at time 291: Calculated 0.5664, Existing 0.0
# Underprod at time 292: Calculated 0.5664, Existing 0.0
# Underprod at time 293: Calculated 0.5664, Existing 0.0
# Underprod at time 294: Calculated 0.5664, Existing 0.0
# Underprod at time 295: Calculated 0.5664, Existing 0.0
# Underprod at time 296: Calculated 0.5664, Existing 0.0
# Underprod at time 297: Calculated 0.5664, Existing 0.0034
# Underprod at time 298: Calculated 0.5664, Existing 0.0219
# Underprod at time 299: Calculated 0.5664, Existing 0.0451
# Underprod at time 300: Calculated 0.5664, Existing 0.0649
# Underprod at time 301: Calculated 0.5664, Existing 0.0345
# Underprod at time 302: Calculated 0.5664, Existing 0.0435
# Underprod at time 303: Calculated 0.5664, Existing 0.0226
# Underprod at time 304: Calculated 0.5664, Existing 0.0185
# Underprod at time 305: Calculated 0.5664, Existing 0.017
# Underprod at time 306: Calculated 0.5664, Existing 0.0188
# Underprod at time 307: Calculated 0.5664, Existing 0.089
# Underprod at time 308: Calculated 0.5664, Existing 0.0
# Underprod at time 309: Calculated 0.5664, Existing 0.0
# Underprod at time 310: Calculated 0.5664, Existing 0.0
# Underprod at time 311: Calculated 0.5664, Existing 0.0
# Underprod at time 312: Calculated 0.5664, Existing 0.1142
# Underprod at time 313: Calculated 0.5664, Existing 0.1142
# Underprod at time 314: Calculated 0.5664, Existing 0.1142
# Underprod at time 315: Calculated 0.5664, Existing 0.1142
# Underprod at time 316: Calculated 0.5664, Existing 0.1142
# Underprod at time 317: Calculated 0.5664, Existing 0.1142
# Underprod at time 318: Calculated 0.5664, Existing 0.1142
# Underprod at time 319: Calculated 0.5664, Existing 0.1142
# Underprod at time 320: Calculated 0.5664, Existing 0.1142
# Underprod at time 321: Calculated 0.5664, Existing 0.1142
# Underprod at time 322: Calculated 0.5664, Existing 0.1142
# Underprod at time 323: Calculated 0.5664, Existing 0.0
# Underprod at time 324: Calculated 0.4533, Existing 0.0
# Underprod at time 325: Calculated 0.5664, Existing 0.0
# Underprod at time 326: Calculated 0.5664, Existing 0.0
# Underprod at time 327: Calculated 0.5664, Existing 0.0
# Underprod at time 328: Calculated 0.5664, Existing 0.0
# Underprod at time 329: Calculated 0.5664, Existing 0.0431
# Underprod at time 330: Calculated 0.5664, Existing 0.0947
# Underprod at time 331: Calculated 0.5664, Existing 0.0724
# Underprod at time 332: Calculated 0.5664, Existing 0.0126
# Underprod at time 333: Calculated 0.5664, Existing 0.193
# Underprod at time 334: Calculated 0.5664, Existing 0.4009
# Underprod at time 335: Calculated 0.5664, Existing 0.5664
# Exactprod at time 336: Calculated 0.5664, Existing 0.5664
# Underprod at time 337: Calculated 0.5664, Existing 0.5664
# Exactprod at time 338: Calculated 0.5664, Existing 0.5664
# Exactprod at time 339: Calculated 0.5664, Existing 0.5664
# Exactprod at time 340: Calculated 0.5664, Existing 0.5664
# Exactprod at time 341: Calculated 0.5664, Existing 0.5664
# Exactprod at time 342: Calculated 0.5664, Existing 0.5664
# Exactprod at time 343: Calculated 0.5664, Existing 0.5664
# Underprod at time 344: Calculated 0.5664, Existing 0.5664
# Exactprod at time 345: Calculated 0.5664, Existing 0.5664
# Exactprod at time 346: Calculated 0.5664, Existing 0.5664
# Underprod at time 347: Calculated 0.5664, Existing 0.5664
# Underprod at time 348: Calculated 0.5664, Existing 0.5664
# Exactprod at time 349: Calculated 0.5664, Existing 0.5664
# Exactprod at time 350: Calculated 0.5664, Existing 0.5664
# Exactprod at time 351: Calculated 0.5664, Existing 0.5664
# Exactprod at time 352: Calculated 0.5664, Existing 0.5664
# Exactprod at time 353: Calculated 0.5664, Existing 0.5664
# Exactprod at time 354: Calculated 0.5664, Existing 0.5664
# Exactprod at time 355: Calculated 0.5664, Existing 0.5664
# Exactprod at time 356: Calculated 0.5664, Existing 0.5664
# Exactprod at time 357: Calculated 0.5664, Existing 0.5664
# Underprod at time 358: Calculated 0.5664, Existing 0.5664
# Underprod at time 359: Calculated 0.5664, Existing 0.5664
# Underprod at time 360: Calculated 0.5025, Existing 0.5025
# Underprod at time 361: Calculated 0.5664, Existing 0.5664
# Underprod at time 362: Calculated 0.5664, Existing 0.5664
# Exactprod at time 363: Calculated 0.5664, Existing 0.5664
# Exactprod at time 364: Calculated 0.5664, Existing 0.5664
# Exactprod at time 365: Calculated 0.5664, Existing 0.5664
# Exactprod at time 366: Calculated 0.5664, Existing 0.5664
# Exactprod at time 367: Calculated 0.5664, Existing 0.5664
# Exactprod at time 368: Calculated 0.5664, Existing 0.5664
# Exactprod at time 369: Calculated 0.5664, Existing 0.5664
# Exactprod at time 370: Calculated 0.5664, Existing 0.5664
# Exactprod at time 371: Calculated 0.5664, Existing 0.5664
# Exactprod at time 372: Calculated 0.5664, Existing 0.5664
# Exactprod at time 373: Calculated 0.5664, Existing 0.5664
# Exactprod at time 374: Calculated 0.5664, Existing 0.5664
# Underprod at time 375: Calculated 0.4202, Existing 0.4202
# Exactprod at time 376: Calculated 0.5664, Existing 0.5664
# Exactprod at time 377: Calculated 0.5664, Existing 0.5664
# Exactprod at time 378: Calculated 0.3734, Existing 0.3734
# Exactprod at time 379: Calculated 0.5664, Existing 0.5664
# Exactprod at time 380: Calculated 0.5664, Existing 0.5664
# Underprod at time 381: Calculated 0.373, Existing 0.373
# Exactprod at time 382: Calculated 0.5664, Existing 0.5664
# Underprod at time 383: Calculated 0.5664, Existing 0.5664
# Exactprod at time 384: Calculated 0.2481, Existing 0.2481
# Exactprod at time 385: Calculated 0.5664, Existing 0.5664
# Exactprod at time 386: Calculated 0.5664, Existing 0.5664
# Underprod at time 387: Calculated 0.3775, Existing 0.3775
# Underprod at time 388: Calculated 0.5664, Existing 0.2758
# Underprod at time 389: Calculated 0.5664, Existing 0.1684
# Underprod at time 390: Calculated 0.3222, Existing 0.0912
# Underprod at time 391: Calculated 0.5664, Existing 0.0673
# Underprod at time 392: Calculated 0.5664, Existing 0.0398
# Underprod at time 393: Calculated 0.2454, Existing 0.0462
# Underprod at time 394: Calculated 0.5664, Existing 0.0627
# Underprod at time 395: Calculated 0.5664, Existing 0.0168
# Underprod at time 396: Calculated 0.2579, Existing 0.0
# Underprod at time 397: Calculated 0.5664, Existing 0.0
# Exactprod at time 398: Calculated 0.5664, Existing 0.5664
# Exactprod at time 399: Calculated 0.3037, Existing 0.3037
# Exactprod at time 400: Calculated 0.5664, Existing 0.5664
# Exactprod at time 401: Calculated 0.5664, Existing 0.5664
# Exactprod at time 402: Calculated 0.4395, Existing 0.4395
# Exactprod at time 403: Calculated 0.5664, Existing 0.5664
# Exactprod at time 404: Calculated 0.5664, Existing 0.5664
# Underprod at time 405: Calculated 0.4989, Existing 0.4989
# Exactprod at time 406: Calculated 0.5664, Existing 0.5664
# Exactprod at time 407: Calculated 0.5664, Existing 0.5664
# Exactprod at time 408: Calculated 0.5106, Existing 0.5106
# Exactprod at time 409: Calculated 0.5664, Existing 0.5664
# Underprod at time 410: Calculated 0.5664, Existing 0.1142
# Underprod at time 411: Calculated 0.5664, Existing 0.1142
# Underprod at time 412: Calculated 0.5664, Existing 0.1142
# Underprod at time 413: Calculated 0.5664, Existing 0.1142
# Exactprod at time 414: Calculated 0.5664, Existing 0.5664
# Underprod at time 415: Calculated 0.5664, Existing 0.1142
# Underprod at time 416: Calculated 0.5664, Existing 0.1142
# Underprod at time 417: Calculated 0.5664, Existing 0.1142
# Underprod at time 418: Calculated 0.5664, Existing 0.1142
# Underprod at time 419: Calculated 0.5664, Existing 0.1143
# Underprod at time 420: Calculated 0.5664, Existing 0.5069
# Underprod at time 421: Calculated 0.5664, Existing 0.1202
# Underprod at time 422: Calculated 0.5664, Existing 0.1142
# Underprod at time 423: Calculated 0.5664, Existing 0.1142
# Underprod at time 424: Calculated 0.5664, Existing 0.0
# Underprod at time 425: Calculated 0.5664, Existing 0.0
# Exactprod at time 426: Calculated 0.5664, Existing 0.5664
# Exactprod at time 427: Calculated 0.5664, Existing 0.5664
# Exactprod at time 428: Calculated 0.5664, Existing 0.5664
# Exactprod at time 429: Calculated 0.5664, Existing 0.5664
# Exactprod at time 430: Calculated 0.5664, Existing 0.5664
# Exactprod at time 431: Calculated 0.5664, Existing 0.5664
# Underprod at time 432: Calculated 0.5664, Existing 0.1142
# Underprod at time 433: Calculated 0.5664, Existing 0.1142
# Underprod at time 434: Calculated 0.5664, Existing 0.1142
# Underprod at time 435: Calculated 0.5664, Existing 0.1142
# Underprod at time 436: Calculated 0.5664, Existing 0.1143
# Underprod at time 437: Calculated 0.5664, Existing 0.115
# Underprod at time 438: Calculated 0.5664, Existing 0.1205
# Underprod at time 439: Calculated 0.5664, Existing 0.1272
# Underprod at time 440: Calculated 0.5664, Existing 0.2206
# Underprod at time 441: Calculated 0.5664, Existing 0.395
# Exactprod at time 442: Calculated 0.5664, Existing 0.5664
# Exactprod at time 443: Calculated 0.5664, Existing 0.5664
# Exactprod at time 444: Calculated 0.5664, Existing 0.5664
# Exactprod at time 445: Calculated 0.5664, Existing 0.5664
# Underprod at time 446: Calculated 0.5664, Existing 0.4064
# Underprod at time 447: Calculated 0.5664, Existing 0.2102
# Underprod at time 448: Calculated 0.5664, Existing 0.3134
# Underprod at time 449: Calculated 0.5664, Existing 0.1661
# Underprod at time 450: Calculated 0.5664, Existing 0.1985
# Underprod at time 451: Calculated 0.5664, Existing 0.0
# Underprod at time 452: Calculated 0.5664, Existing 0.0
# Underprod at time 453: Calculated 0.5664, Existing 0.0
# Underprod at time 454: Calculated 0.5664, Existing 0.0
# Underprod at time 455: Calculated 0.5664, Existing 0.0
# Underprod at time 456: Calculated 0.5664, Existing 0.1149
# Underprod at time 457: Calculated 0.5664, Existing 0.1142
# Underprod at time 458: Calculated 0.5664, Existing 0.1528
# Underprod at time 459: Calculated 0.5664, Existing 0.2221
# Underprod at time 460: Calculated 0.5664, Existing 0.2766
# Underprod at time 461: Calculated 0.5664, Existing 0.4388
# Exactprod at time 462: Calculated 0.4873, Existing 0.4873
# Underprod at time 463: Calculated 0.5664, Existing 0.4064
# Underprod at time 464: Calculated 0.5664, Existing 0.2729
# Underprod at time 465: Calculated 0.4085, Existing 0.1661
# Underprod at time 466: Calculated 0.5664, Existing 0.0891
# Underprod at time 467: Calculated 0.5664, Existing 0.0206
# Underprod at time 468: Calculated 0.4968, Existing 0.0
# Underprod at time 469: Calculated 0.5664, Existing 0.0145
# Underprod at time 470: Calculated 0.5664, Existing 0.0426
# Underprod at time 471: Calculated 0.2902, Existing 0.132
# Underprod at time 472: Calculated 0.5664, Existing 0.4436
# Exactprod at time 473: Calculated 0.5664, Existing 0.5664
# Exactprod at time 474: Calculated 0.4255, Existing 0.4255
# Exactprod at time 475: Calculated 0.5664, Existing 0.5664
# Exactprod at time 476: Calculated 0.5664, Existing 0.5664
# Underprod at time 477: Calculated 0.3584, Existing 0.3584
# Underprod at time 478: Calculated 0.5664, Existing 0.5664
# Underprod at time 479: Calculated 0.5664, Existing 0.5664
# Underprod at time 480: Calculated 0.2847, Existing 0.2847
# Exactprod at time 481: Calculated 0.5664, Existing 0.5664
# Exactprod at time 482: Calculated 0.5664, Existing 0.5664
# Underprod at time 483: Calculated 0.2264, Existing 0.2264
# Exactprod at time 484: Calculated 0.5664, Existing 0.5664
# Underprod at time 485: Calculated 0.5664, Existing 0.0
# Underprod at time 486: Calculated 0.2851, Existing 0.0
# Underprod at time 487: Calculated 0.5664, Existing 0.0
# Underprod at time 488: Calculated 0.5664, Existing 0.0
# Underprod at time 489: Calculated 0.3442, Existing 0.0411
# Underprod at time 490: Calculated 0.5664, Existing 0.2225
# Underprod at time 491: Calculated 0.5664, Existing 0.1146
# Underprod at time 492: Calculated 0.5664, Existing 0.0019
# Underprod at time 493: Calculated 0.5664, Existing 0.0
# Underprod at time 494: Calculated 0.5664, Existing 0.0
# Underprod at time 495: Calculated 0.5664, Existing 0.0
# Underprod at time 496: Calculated 0.5664, Existing 0.0
# Underprod at time 497: Calculated 0.5664, Existing 0.0
# Underprod at time 498: Calculated 0.5664, Existing 0.0
# Underprod at time 499: Calculated 0.5664, Existing 0.0006
# Underprod at time 500: Calculated 0.5664, Existing 0.0024
# Underprod at time 501: Calculated 0.5664, Existing 0.0545
# Underprod at time 502: Calculated 0.5664, Existing 0.1468
# Exactprod at time 503: Calculated 0.5664, Existing 0.5664
# Underprod at time 504: Calculated 0.5664, Existing 0.0
# Underprod at time 505: Calculated 0.5664, Existing 0.0165
# Underprod at time 506: Calculated 0.5664, Existing 0.0755
# Underprod at time 507: Calculated 0.5664, Existing 0.11
# Underprod at time 508: Calculated 0.5664, Existing 0.1142
# Underprod at time 509: Calculated 0.5664, Existing 0.0
# Underprod at time 510: Calculated 0.5664, Existing 0.0
# Underprod at time 511: Calculated 0.5664, Existing 0.0
# Underprod at time 512: Calculated 0.5664, Existing 0.0
# Underprod at time 513: Calculated 0.5664, Existing 0.1142
# Underprod at time 514: Calculated 0.5664, Existing 0.1142
# Underprod at time 515: Calculated 0.5664, Existing 0.1142
# Underprod at time 516: Calculated 0.5664, Existing 0.1142
# Underprod at time 517: Calculated 0.5664, Existing 0.1142
# Underprod at time 518: Calculated 0.5664, Existing 0.1142
# Underprod at time 519: Calculated 0.5664, Existing 0.1142
# Underprod at time 520: Calculated 0.5664, Existing 0.1142
# Underprod at time 521: Calculated 0.5664, Existing 0.1142
# Underprod at time 522: Calculated 0.4641, Existing 0.1142
# Underprod at time 523: Calculated 0.5664, Existing 0.1142
# Underprod at time 524: Calculated 0.5664, Existing 0.1142
# Underprod at time 525: Calculated 0.3513, Existing 0.1142
# Underprod at time 526: Calculated 0.5664, Existing 0.1142
# Underprod at time 527: Calculated 0.5664, Existing 0.1147
# Underprod at time 528: Calculated 0.2492, Existing 0.1142
# Underprod at time 529: Calculated 0.5664, Existing 0.1663
# Underprod at time 530: Calculated 0.5664, Existing 0.3196
# Underprod at time 531: Calculated 0.1727, Existing 0.1727
# Exactprod at time 532: Calculated 0.5664, Existing 0.5664
# Exactprod at time 533: Calculated 0.5664, Existing 0.5664
# Exactprod at time 534: Calculated 0.117, Existing 0.117
# Underprod at time 535: Calculated 0.5664, Existing 0.5664
# Exactprod at time 536: Calculated 0.5664, Existing 0.5664
# Underprod at time 537: Calculated 0.0436, Existing 0.0436
# Exactprod at time 538: Calculated 0.5664, Existing 0.5664
# Exactprod at time 539: Calculated 0.5664, Existing 0.5664
# Exactprod at time 540: Calculated 0.063, Existing 0.063
# Exactprod at time 541: Calculated 0.5664, Existing 0.5664
# Exactprod at time 542: Calculated 0.5664, Existing 0.5664
# Underprod at time 543: Calculated 0.3823, Existing 0.3823
# Exactprod at time 544: Calculated 0.5664, Existing 0.5664
# Exactprod at time 545: Calculated 0.5664, Existing 0.5664
# Underprod at time 546: Calculated 0.3519, Existing 0.3519
# Underprod at time 547: Calculated 0.5664, Existing 0.5664
# Underprod at time 548: Calculated 0.5664, Existing 0.5664
# Underprod at time 549: Calculated 0.2221, Existing 0.2221
# Underprod at time 550: Calculated 0.5664, Existing 0.5664
# Exactprod at time 551: Calculated 0.5664, Existing 0.5664
# Underprod at time 552: Calculated 0.1552, Existing 0.1552
# Exactprod at time 553: Calculated 0.5664, Existing 0.5664
# Underprod at time 554: Calculated 0.5664, Existing 0.5664
# Exactprod at time 555: Calculated 0.0966, Existing 0.0966
# Exactprod at time 556: Calculated 0.5664, Existing 0.5664
# Exactprod at time 557: Calculated 0.5664, Existing 0.5664
# Exactprod at time 558: Calculated 0.1167, Existing 0.1167
# Exactprod at time 559: Calculated 0.5664, Existing 0.5664
# Underprod at time 560: Calculated 0.5664, Existing 0.5664
# Overprod at time 561: Calculated 0.0832, Existing 0.0832
# Exactprod at time 562: Calculated 0.5664, Existing 0.5664
# Exactprod at time 563: Calculated 0.5664, Existing 0.5664
# Underprod at time 564: Calculated 0.1772, Existing 0.1772
# Exactprod at time 565: Calculated 0.5664, Existing 0.5664
# Underprod at time 566: Calculated 0.5664, Existing 0.5664
# Exactprod at time 567: Calculated 0.3809, Existing 0.3809
# Underprod at time 568: Calculated 0.5664, Existing 0.44
# Underprod at time 569: Calculated 0.5664, Existing 0.225
# Underprod at time 570: Calculated 0.5664, Existing 0.1157
# Underprod at time 571: Calculated 0.5664, Existing 0.1059
# Underprod at time 572: Calculated 0.5664, Existing 0.0803
# Underprod at time 573: Calculated 0.5664, Existing 0.0525
# Underprod at time 574: Calculated 0.5664, Existing 0.0225
# Underprod at time 575: Calculated 0.5664, Existing 0.0104
# Underprod at time 576: Calculated 0.5664, Existing 0.0015
# Underprod at time 577: Calculated 0.5664, Existing 0.0003
# Underprod at time 578: Calculated 0.5664, Existing 0.0039
# Underprod at time 579: Calculated 0.5664, Existing 0.0651
# Underprod at time 580: Calculated 0.5664, Existing 0.1561
# Underprod at time 581: Calculated 0.5664, Existing 0.3754
# Exactprod at time 582: Calculated 0.5664, Existing 0.5664
# Underprod at time 583: Calculated 0.5664, Existing 0.5664
# Exactprod at time 584: Calculated 0.5664, Existing 0.5664
# Underprod at time 585: Calculated 0.5664, Existing 0.5664
# Exactprod at time 586: Calculated 0.5664, Existing 0.5664
# Exactprod at time 587: Calculated 0.5664, Existing 0.5664
# Exactprod at time 588: Calculated 0.4971, Existing 0.4971
# Exactprod at time 589: Calculated 0.5664, Existing 0.5664
# Exactprod at time 590: Calculated 0.5664, Existing 0.5664
# Underprod at time 591: Calculated 0.3698, Existing 0.3698
# Exactprod at time 592: Calculated 0.5664, Existing 0.5664
# Exactprod at time 593: Calculated 0.5664, Existing 0.5664
# Exactprod at time 594: Calculated 0.5664, Existing 0.5664
# Underprod at time 595: Calculated 0.5664, Existing 0.5664
# Underprod at time 596: Calculated 0.5664, Existing 0.1718
# Underprod at time 597: Calculated 0.5664, Existing 0.0633
# Underprod at time 598: Calculated 0.5664, Existing 0.0
# Underprod at time 599: Calculated 0.5664, Existing 0.0
# Underprod at time 600: Calculated 0.5012, Existing 0.0
# Underprod at time 601: Calculated 0.5664, Existing 0.0
# Underprod at time 602: Calculated 0.5664, Existing 0.0
# Underprod at time 603: Calculated 0.4305, Existing 0.0
# Exactprod at time 604: Calculated 0.5664, Existing 0.5664
# Exactprod at time 605: Calculated 0.5664, Existing 0.5664
# Exactprod at time 606: Calculated 0.5664, Existing 0.5664
# Exactprod at time 607: Calculated 0.5664, Existing 0.5664
# Exactprod at time 608: Calculated 0.5664, Existing 0.5664
# Exactprod at time 609: Calculated 0.5664, Existing 0.5664
# Exactprod at time 610: Calculated 0.5664, Existing 0.5664
# Exactprod at time 611: Calculated 0.5664, Existing 0.5664
# Exactprod at time 612: Calculated 0.5664, Existing 0.5664
# Underprod at time 613: Calculated 0.5664, Existing 0.0015
# Underprod at time 614: Calculated 0.5664, Existing 0.0293
# Underprod at time 615: Calculated 0.5664, Existing 0.0362
# Underprod at time 616: Calculated 0.5664, Existing 0.0102
# Underprod at time 617: Calculated 0.5664, Existing 0.0001
# Underprod at time 618: Calculated 0.5664, Existing 0.0
# Underprod at time 619: Calculated 0.5664, Existing 0.0
# Underprod at time 620: Calculated 0.5664, Existing 0.0
# Underprod at time 621: Calculated 0.5664, Existing 0.0
# Underprod at time 622: Calculated 0.5664, Existing 0.0145
# Exactprod at time 623: Calculated 0.5664, Existing 0.5664
# Exactprod at time 624: Calculated 0.5664, Existing 0.5664
# Underprod at time 625: Calculated 0.5664, Existing 0.0
# Exactprod at time 626: Calculated 0.5664, Existing 0.5664
# Exactprod at time 627: Calculated 0.5664, Existing 0.5664
# Exactprod at time 628: Calculated 0.5664, Existing 0.5664
# Exactprod at time 629: Calculated 0.5664, Existing 0.5664
# Exactprod at time 630: Calculated 0.5664, Existing 0.5664
# Exactprod at time 631: Calculated 0.5664, Existing 0.5664
# Underprod at time 632: Calculated 0.5664, Existing 0.1142
# Underprod at time 633: Calculated 0.5664, Existing 0.1142
# Underprod at time 634: Calculated 0.5664, Existing 0.1142
# Underprod at time 635: Calculated 0.5664, Existing 0.1142
# Underprod at time 636: Calculated 0.5664, Existing 0.1142
# Underprod at time 637: Calculated 0.5664, Existing 0.1142
# Underprod at time 638: Calculated 0.5664, Existing 0.1142
# Underprod at time 639: Calculated 0.5664, Existing 0.1142
# Underprod at time 640: Calculated 0.5664, Existing 0.1143
# Underprod at time 641: Calculated 0.5664, Existing 0.1142
# Underprod at time 642: Calculated 0.5664, Existing 0.1142
# Underprod at time 643: Calculated 0.5664, Existing 0.1142
# Underprod at time 644: Calculated 0.5664, Existing 0.1142
# Underprod at time 645: Calculated 0.5664, Existing 0.1142
# Underprod at time 646: Calculated 0.5664, Existing 0.0
# Underprod at time 647: Calculated 0.5664, Existing 0.0
# Underprod at time 648: Calculated 0.5664, Existing 0.1142
# Underprod at time 649: Calculated 0.5664, Existing 0.0
# Underprod at time 650: Calculated 0.5664, Existing 0.0
# Underprod at time 651: Calculated 0.5664, Existing 0.0
# Underprod at time 652: Calculated 0.5664, Existing 0.0
# Underprod at time 653: Calculated 0.5664, Existing 0.0
# Underprod at time 654: Calculated 0.5664, Existing 0.1149
# Underprod at time 655: Calculated 0.5664, Existing 0.0436
# Underprod at time 656: Calculated 0.5664, Existing 0.4708
# Underprod at time 657: Calculated 0.5664, Existing 0.5664
# Exactprod at time 658: Calculated 0.5664, Existing 0.5664
# Exactprod at time 659: Calculated 0.5664, Existing 0.5664
# Underprod at time 660: Calculated 0.5664, Existing 0.4096
# Underprod at time 661: Calculated 0.5664, Existing 0.1939
# Underprod at time 662: Calculated 0.5664, Existing 0.0554
# Underprod at time 663: Calculated 0.467, Existing 0.0156
# Underprod at time 664: Calculated 0.5664, Existing 0.0
# Underprod at time 665: Calculated 0.5664, Existing 0.0
# Underprod at time 666: Calculated 0.3806, Existing 0.0
# Underprod at time 667: Calculated 0.5664, Existing 0.0
# Underprod at time 668: Calculated 0.5664, Existing 0.0
# Underprod at time 669: Calculated 0.5664, Existing 0.0
# Underprod at time 670: Calculated 0.5664, Existing 0.0
# Underprod at time 671: Calculated 0.5664, Existing 0.0
# Underprod at time 672: Calculated 0.5664, Existing 0.0
# Underprod at time 673: Calculated 0.5664, Existing 0.0
# Underprod at time 674: Calculated 0.5664, Existing 0.0192
# Underprod at time 675: Calculated 0.5185, Existing 0.0863
# Underprod at time 676: Calculated 0.5664, Existing 0.1116
# Underprod at time 677: Calculated 0.5664, Existing 0.3262
# Exactprod at time 678: Calculated 0.2959, Existing 0.2959
# Exactprod at time 679: Calculated 0.5664, Existing 0.5664
# Exactprod at time 680: Calculated 0.5664, Existing 0.5664
# Overprod at time 681: Calculated 0.2088, Existing 0.2088
# Exactprod at time 682: Calculated 0.5664, Existing 0.5664
# Underprod at time 683: Calculated 0.5664, Existing 0.5664
# Underprod at time 684: Calculated 0.138, Existing 0.138
# Exactprod at time 685: Calculated 0.5664, Existing 0.5664
# Exactprod at time 686: Calculated 0.5664, Existing 0.5664
# Exactprod at time 687: Calculated 0.3882, Existing 0.3882
# Exactprod at time 688: Calculated 0.5664, Existing 0.5664
# Exactprod at time 689: Calculated 0.5664, Existing 0.5664
# Exactprod at time 690: Calculated 0.5664, Existing 0.5664
# Exactprod at time 691: Calculated 0.5664, Existing 0.5664
# Exactprod at time 692: Calculated 0.5664, Existing 0.5664
# Exactprod at time 693: Calculated 0.5664, Existing 0.5664
# Exactprod at time 694: Calculated 0.5664, Existing 0.5664
# Exactprod at time 695: Calculated 0.5664, Existing 0.5664
# Exactprod at time 696: Calculated 0.5664, Existing 0.5664
# Exactprod at time 697: Calculated 0.5664, Existing 0.5664
# Exactprod at time 698: Calculated 0.5664, Existing 0.5664
# Exactprod at time 699: Calculated 0.5664, Existing 0.5664
# Exactprod at time 700: Calculated 0.5664, Existing 0.5664
# Exactprod at time 701: Calculated 0.5664, Existing 0.5664
# Exactprod at time 702: Calculated 0.5664, Existing 0.5664
# Exactprod at time 703: Calculated 0.5664, Existing 0.5664
# Exactprod at time 704: Calculated 0.5664, Existing 0.5664
# Exactprod at time 705: Calculated 0.5664, Existing 0.5664
# Exactprod at time 706: Calculated 0.5664, Existing 0.5664
# Exactprod at time 707: Calculated 0.5664, Existing 0.5664
# Exactprod at time 708: Calculated 0.5664, Existing 0.5664
# Exactprod at time 709: Calculated 0.5664, Existing 0.5664
# Exactprod at time 710: Calculated 0.5664, Existing 0.5664
# Exactprod at time 711: Calculated 0.5664, Existing 0.5664
# Exactprod at time 712: Calculated 0.5664, Existing 0.5664
# Exactprod at time 713: Calculated 0.5664, Existing 0.5664
# Exactprod at time 714: Calculated 0.5664, Existing 0.5664
# Exactprod at time 715: Calculated 0.5664, Existing 0.5664
# Exactprod at time 716: Calculated 0.5664, Existing 0.5664
# Underprod at time 717: Calculated 0.4824, Existing 0.4824
# Exactprod at time 718: Calculated 0.5664, Existing 0.5664
# Exactprod at time 719: Calculated 0.5664, Existing 0.5664
# Exactprod at time 720: Calculated 0.5664, Existing 0.5664
# Exactprod at time 721: Calculated 0.5664, Existing 0.5664
# Exactprod at time 722: Calculated 0.5664, Existing 0.5664
# Exactprod at time 723: Calculated 0.5664, Existing 0.5664
# Exactprod at time 724: Calculated 0.5664, Existing 0.5664
# Exactprod at time 725: Calculated 0.5664, Existing 0.5664
# Exactprod at time 726: Calculated 0.5664, Existing 0.5664
# Exactprod at time 727: Calculated 0.5664, Existing 0.5664
# Exactprod at time 728: Calculated 0.5664, Existing 0.5664
# Exactprod at time 729: Calculated 0.5664, Existing 0.5664
# Exactprod at time 730: Calculated 0.5664, Existing 0.5664
# Exactprod at time 731: Calculated 0.5664, Existing 0.5664
# Exactprod at time 732: Calculated 0.5664, Existing 0.5664
# Exactprod at time 733: Calculated 0.5664, Existing 0.5664
# Exactprod at time 734: Calculated 0.5664, Existing 0.5664
# Underprod at time 735: Calculated 0.4572, Existing 0.4572
# Exactprod at time 736: Calculated 0.5664, Existing 0.5664
# Exactprod at time 737: Calculated 0.5664, Existing 0.5664
# Underprod at time 738: Calculated 0.3166, Existing 0.3166
# Underprod at time 739: Calculated 0.5664, Existing 0.2504
# Underprod at time 740: Calculated 0.5664, Existing 0.1915
# Underprod at time 741: Calculated 0.345, Existing 0.2092
# Underprod at time 742: Calculated 0.5664, Existing 0.2266
# Underprod at time 743: Calculated 0.5664, Existing 0.2372
# Underprod at time 744: Calculated 0.4796, Existing 0.2719
# Underprod at time 745: Calculated 0.5664, Existing 0.2628
# Underprod at time 746: Calculated 0.5664, Existing 0.3037
# Underprod at time 747: Calculated 0.4831, Existing 0.3021
# Underprod at time 748: Calculated 0.5664, Existing 0.295
# Underprod at time 749: Calculated 0.5664, Existing 0.2333
# Underprod at time 750: Calculated 0.4659, Existing 0.2145
# Underprod at time 751: Calculated 0.5664, Existing 0.2856
# Underprod at time 752: Calculated 0.5664, Existing 0.5192
# Overprod at time 753: Calculated 0.4231, Existing 0.4231
# Underprod at time 754: Calculated 0.5664, Existing 0.5664
# Exactprod at time 755: Calculated 0.5664, Existing 0.5664
# Underprod at time 756: Calculated 0.4646, Existing 0.4646
# Exactprod at time 757: Calculated 0.5664, Existing 0.5664
# Exactprod at time 758: Calculated 0.5664, Existing 0.5664
# Exactprod at time 759: Calculated 0.515, Existing 0.515
# Exactprod at time 760: Calculated 0.5664, Existing 0.5664
# Exactprod at time 761: Calculated 0.5664, Existing 0.5664
# Exactprod at time 762: Calculated 0.5251, Existing 0.5251
# Exactprod at time 763: Calculated 0.5664, Existing 0.5664
# Underprod at time 764: Calculated 0.5664, Existing 0.1503
# Underprod at time 765: Calculated 0.5086, Existing 0.0001
# Underprod at time 766: Calculated 0.5664, Existing 0.0
# Underprod at time 767: Calculated 0.5664, Existing 0.0
# Underprod at time 768: Calculated 0.4286, Existing 0.0
# Underprod at time 769: Calculated 0.5664, Existing 0.0
# Underprod at time 770: Calculated 0.5664, Existing 0.0
# Underprod at time 771: Calculated 0.3698, Existing 0.0
# Underprod at time 772: Calculated 0.5664, Existing 0.0
# Underprod at time 773: Calculated 0.5664, Existing 0.0
# Underprod at time 774: Calculated 0.5089, Existing 0.1142
# Underprod at time 775: Calculated 0.5664, Existing 0.1142
# Underprod at time 776: Calculated 0.5664, Existing 0.1142
# Underprod at time 777: Calculated 0.5664, Existing 0.1142
# Underprod at time 778: Calculated 0.5664, Existing 0.1142
# Exactprod at time 779: Calculated 0.5664, Existing 0.5664
# Exactprod at time 780: Calculated 0.5664, Existing 0.5664
# Exactprod at time 781: Calculated 0.5664, Existing 0.5664
# Exactprod at time 782: Calculated 0.5664, Existing 0.5664
# Exactprod at time 783: Calculated 0.5664, Existing 0.5664
# Exactprod at time 784: Calculated 0.5664, Existing 0.5664
# Exactprod at time 785: Calculated 0.5664, Existing 0.5664
# Exactprod at time 786: Calculated 0.5664, Existing 0.5664
# Exactprod at time 787: Calculated 0.5664, Existing 0.5664
# Exactprod at time 788: Calculated 0.5664, Existing 0.5664
# Exactprod at time 789: Calculated 0.5664, Existing 0.5664
# Exactprod at time 790: Calculated 0.5664, Existing 0.5664
# Exactprod at time 791: Calculated 0.5664, Existing 0.5664
# Exactprod at time 792: Calculated 0.5664, Existing 0.5664
# Exactprod at time 793: Calculated 0.5664, Existing 0.5664
# Exactprod at time 794: Calculated 0.5664, Existing 0.5664
# Exactprod at time 795: Calculated 0.5664, Existing 0.5664
# Underprod at time 796: Calculated 0.5664, Existing 0.0177
# Underprod at time 797: Calculated 0.5664, Existing 0.0002
# Underprod at time 798: Calculated 0.5664, Existing 0.0
# Underprod at time 799: Calculated 0.5664, Existing 0.4455
# Exactprod at time 800: Calculated 0.5664, Existing 0.5664
# Exactprod at time 801: Calculated 0.5664, Existing 0.5664
# Exactprod at time 802: Calculated 0.5664, Existing 0.5664
# Underprod at time 803: Calculated 0.5664, Existing 0.5664
# Underprod at time 804: Calculated 0.5664, Existing 0.4837
# Underprod at time 805: Calculated 0.5664, Existing 0.5382
# Exactprod at time 806: Calculated 0.5664, Existing 0.5664
# Exactprod at time 807: Calculated 0.5664, Existing 0.5664
# Exactprod at time 808: Calculated 0.5664, Existing 0.5664
# Exactprod at time 809: Calculated 0.5664, Existing 0.5664
# Exactprod at time 810: Calculated 0.5664, Existing 0.5664
# Exactprod at time 811: Calculated 0.5664, Existing 0.5664
# Exactprod at time 812: Calculated 0.5664, Existing 0.5664
# Exactprod at time 813: Calculated 0.5664, Existing 0.5664
# Exactprod at time 814: Calculated 0.5664, Existing 0.5664
# Exactprod at time 815: Calculated 0.5664, Existing 0.5664
# Underprod at time 816: Calculated 0.5664, Existing 0.1136
# Underprod at time 817: Calculated 0.5664, Existing 0.0689
# Underprod at time 818: Calculated 0.5664, Existing 0.068
# Underprod at time 819: Calculated 0.5664, Existing 0.0329
# Underprod at time 820: Calculated 0.5664, Existing 0.0015
# Exactprod at time 821: Calculated 0.5664, Existing 0.5664
# Exactprod at time 822: Calculated 0.1451, Existing 0.1451
# Underprod at time 823: Calculated 0.5664, Existing 0.0
# Underprod at time 824: Calculated 0.5664, Existing 0.0
# Underprod at time 825: Calculated 0.1724, Existing 0.0
# Underprod at time 826: Calculated 0.5664, Existing 0.0
# Underprod at time 827: Calculated 0.5664, Existing 0.0
# Underprod at time 828: Calculated 0.5664, Existing 0.0
# Underprod at time 829: Calculated 0.5664, Existing 0.0
# Underprod at time 830: Calculated 0.5664, Existing 0.0
# Underprod at time 831: Calculated 0.5664, Existing 0.0
# Underprod at time 832: Calculated 0.5664, Existing 0.0
# Underprod at time 833: Calculated 0.5664, Existing 0.0
# Underprod at time 834: Calculated 0.5664, Existing 0.1209
# Exactprod at time 835: Calculated 0.5664, Existing 0.5664
# Exactprod at time 836: Calculated 0.5664, Existing 0.5664
# ...
# Underprod at time 17276: Calculated 0.5664, Existing 0.1142
# Underprod at time 17277: Calculated 0.5664, Existing 0.17
# Underprod at time 17278: Calculated 0.5664, Existing 0.3701
# Underprod at time 17279: Calculated 0.5664, Existing 0.3866
# Underprod at time 17280: Calculated 0.5664, Existing 0.115
# Underprod at time 17281: Calculated 0.5664, Existing 0.1142
# Underprod at time 17282: Calculated 0.5664, Existing 0.1142
# Underprod at time 17283: Calculated 0.5664, Existing 0.1142
# Underprod at time 17284: Calculated 0.5664, Existing 0.1149
# Underprod at time 17285: Calculated 0.5664, Existing 0.1853
# Underprod at time 17286: Calculated 0.5664, Existing 0.1184
# Underprod at time 17287: Calculated 0.5664, Existing 0.1778
# Underprod at time 17288: Calculated 0.5664, Existing 0.454
# Underprod at time 17289: Calculated 0.5637, Existing 0.5614
# Underprod at time 17290: Calculated 0.5664, Existing 0.3866
# Underprod at time 17291: Calculated 0.5664, Existing 0.5517
# Overprod at time 17292: Calculated 0.3927, Existing 0.3927
# Underprod at time 17293: Calculated 0.5664, Existing 0.3811
# Underprod at time 17294: Calculated 0.5664, Existing 0.1894
# Underprod at time 17295: Calculated 0.2209, Existing 0.185
# Underprod at time 17296: Calculated 0.5664, Existing 0.2483
# Underprod at time 17297: Calculated 0.5664, Existing 0.3016
# Underprod at time 17298: Calculated 0.2144, Existing 0.2144
# Underprod at time 17299: Calculated 0.5664, Existing 0.29
# Underprod at time 17300: Calculated 0.5664, Existing 0.3497
# Underprod at time 17301: Calculated 0.5337, Existing 0.4128
# Underprod at time 17302: Calculated 0.5664, Existing 0.4578
# Exactprod at time 17303: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17304: Calculated 0.47, Existing 0.47
# Exactprod at time 17305: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17306: Calculated 0.5664, Existing 0.5664
# Underprod at time 17307: Calculated 0.4487, Existing 0.4487
# Exactprod at time 17308: Calculated 0.5664, Existing 0.5664
# Underprod at time 17309: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17310: Calculated 0.5664, Existing 0.5664
# Underprod at time 17311: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17312: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17313: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17314: Calculated 0.5664, Existing 0.5664
# Underprod at time 17315: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17316: Calculated 0.5062, Existing 0.5062
# Exactprod at time 17317: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17318: Calculated 0.5664, Existing 0.5664
# Underprod at time 17319: Calculated 0.2241, Existing 0.2241
# Underprod at time 17320: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17321: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17322: Calculated 0.3181, Existing 0.3181
# Exactprod at time 17323: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17324: Calculated 0.5664, Existing 0.5664
# Overprod at time 17325: Calculated 0.3507, Existing 0.3507
# Exactprod at time 17326: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17327: Calculated 0.5664, Existing 0.5664
# Underprod at time 17328: Calculated 0.3159, Existing 0.3159
# Exactprod at time 17329: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17330: Calculated 0.5664, Existing 0.5664
# Underprod at time 17331: Calculated 0.2506, Existing 0.2506
# Exactprod at time 17332: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17333: Calculated 0.5664, Existing 0.5664
# Underprod at time 17334: Calculated 0.2059, Existing 0.2059
# Exactprod at time 17335: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17336: Calculated 0.5664, Existing 0.5664
# Overprod at time 17337: Calculated 0.1948, Existing 0.1948
# Exactprod at time 17338: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17339: Calculated 0.5664, Existing 0.5664
# Underprod at time 17340: Calculated 0.2221, Existing 0.2221
# Underprod at time 17341: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17342: Calculated 0.5664, Existing 0.5664
# Overprod at time 17343: Calculated 0.1589, Existing 0.1589
# Exactprod at time 17344: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17345: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17346: Calculated 0.4669, Existing 0.4669
# Underprod at time 17347: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17348: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17349: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17350: Calculated 0.5664, Existing 0.5664
# Underprod at time 17351: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17352: Calculated 0.5553, Existing 0.5553
# Exactprod at time 17353: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17354: Calculated 0.5664, Existing 0.5664
# Underprod at time 17355: Calculated 0.3849, Existing 0.3849
# Exactprod at time 17356: Calculated 0.5664, Existing 0.5664
# Underprod at time 17357: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17358: Calculated 0.3022, Existing 0.3022
# Underprod at time 17359: Calculated 0.5664, Existing 0.5664
# Underprod at time 17360: Calculated 0.5664, Existing 0.4804
# Underprod at time 17361: Calculated 0.2768, Existing 0.2378
# Underprod at time 17362: Calculated 0.5664, Existing 0.084
# Underprod at time 17363: Calculated 0.5664, Existing 0.0
# Underprod at time 17364: Calculated 0.1253, Existing 0.0
# Underprod at time 17365: Calculated 0.5664, Existing 0.0
# Underprod at time 17366: Calculated 0.5664, Existing 0.0
# Underprod at time 17367: Calculated 0.1457, Existing 0.0
# Underprod at time 17368: Calculated 0.5664, Existing 0.0
# Underprod at time 17369: Calculated 0.5664, Existing 0.0
# Underprod at time 17370: Calculated 0.1347, Existing 0.0
# Underprod at time 17371: Calculated 0.5664, Existing 0.0
# Underprod at time 17372: Calculated 0.5664, Existing 0.0
# Underprod at time 17373: Calculated 0.1409, Existing 0.0
# Underprod at time 17374: Calculated 0.5664, Existing 0.0
# Underprod at time 17375: Calculated 0.5664, Existing 0.0403
# Overprod at time 17376: Calculated 0.1151, Existing 0.1151
# Underprod at time 17377: Calculated 0.5664, Existing 0.2164
# Underprod at time 17378: Calculated 0.5664, Existing 0.339
# Overprod at time 17379: Calculated 0.0928, Existing 0.0928
# Underprod at time 17380: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17381: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17382: Calculated 0.0327, Existing 0.0327
# Exactprod at time 17383: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17384: Calculated 0.5664, Existing 0.5664
# Underprod at time 17385: Calculated 0.1074, Existing 0.1074
# Exactprod at time 17386: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17387: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17388: Calculated 0.268, Existing 0.268
# Exactprod at time 17389: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17390: Calculated 0.5664, Existing 0.5664
# Underprod at time 17391: Calculated 0.4396, Existing 0.4396
# Exactprod at time 17392: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17393: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17394: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17395: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17396: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17397: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17398: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17399: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17400: Calculated 0.5664, Existing 0.5664
# Underprod at time 17401: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17402: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17403: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17404: Calculated 0.5664, Existing 0.5664
# Underprod at time 17405: Calculated 0.5664, Existing 0.4611
# Underprod at time 17406: Calculated 0.5134, Existing 0.1131
# Underprod at time 17407: Calculated 0.5664, Existing 0.0756
# Underprod at time 17408: Calculated 0.5664, Existing 0.0126
# Underprod at time 17409: Calculated 0.5664, Existing 0.0
# Underprod at time 17410: Calculated 0.5664, Existing 0.0166
# Underprod at time 17411: Calculated 0.5664, Existing 0.0436
# Underprod at time 17412: Calculated 0.5664, Existing 0.0688
# Underprod at time 17413: Calculated 0.5664, Existing 0.0525
# Underprod at time 17414: Calculated 0.5664, Existing 0.0058
# Underprod at time 17415: Calculated 0.5664, Existing 0.0
# Underprod at time 17416: Calculated 0.5664, Existing 0.0
# Underprod at time 17417: Calculated 0.5664, Existing 0.0034
# Underprod at time 17418: Calculated 0.5664, Existing 0.0031
# Underprod at time 17419: Calculated 0.5664, Existing 0.0
# Underprod at time 17420: Calculated 0.5664, Existing 0.0
# Underprod at time 17421: Calculated 0.5664, Existing 0.0
# Underprod at time 17422: Calculated 0.5664, Existing 0.0
# Underprod at time 17423: Calculated 0.5664, Existing 0.0
# Underprod at time 17424: Calculated 0.5664, Existing 0.0
# Underprod at time 17425: Calculated 0.5664, Existing 0.0
# Underprod at time 17426: Calculated 0.5664, Existing 0.0
# Underprod at time 17427: Calculated 0.5664, Existing 0.0
# Underprod at time 17428: Calculated 0.5664, Existing 0.0634
# Underprod at time 17429: Calculated 0.5664, Existing 0.0249
# Underprod at time 17430: Calculated 0.5664, Existing 0.1142
# Underprod at time 17431: Calculated 0.5664, Existing 0.115
# Underprod at time 17432: Calculated 0.5664, Existing 0.1142
# Underprod at time 17433: Calculated 0.5664, Existing 0.1142
# Underprod at time 17434: Calculated 0.5664, Existing 0.1142
# Underprod at time 17435: Calculated 0.5664, Existing 0.1144
# Underprod at time 17436: Calculated 0.5664, Existing 0.1142
# Underprod at time 17437: Calculated 0.5664, Existing 0.1142
# Underprod at time 17438: Calculated 0.5664, Existing 0.1143
# Underprod at time 17439: Calculated 0.5664, Existing 0.1142
# Underprod at time 17440: Calculated 0.5664, Existing 0.1142
# Underprod at time 17441: Calculated 0.5664, Existing 0.0
# Underprod at time 17442: Calculated 0.5664, Existing 0.0
# Underprod at time 17443: Calculated 0.5664, Existing 0.0944
# Underprod at time 17444: Calculated 0.5664, Existing 0.4358
# Underprod at time 17445: Calculated 0.5664, Existing 0.551
# Underprod at time 17446: Calculated 0.5664, Existing 0.4578
# Exactprod at time 17447: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17448: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17449: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17450: Calculated 0.5664, Existing 0.5664
# Underprod at time 17451: Calculated 0.5386, Existing 0.5386
# Exactprod at time 17452: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17453: Calculated 0.5664, Existing 0.5664
# Underprod at time 17454: Calculated 0.5451, Existing 0.5451
# Exactprod at time 17455: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17456: Calculated 0.5664, Existing 0.5664
# Underprod at time 17457: Calculated 0.4871, Existing 0.4871
# Exactprod at time 17458: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17459: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17460: Calculated 0.4255, Existing 0.4255
# Exactprod at time 17461: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17462: Calculated 0.5664, Existing 0.5664
# Overprod at time 17463: Calculated 0.4019, Existing 0.4019
# Exactprod at time 17464: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17465: Calculated 0.5664, Existing 0.5664
# Underprod at time 17466: Calculated 0.376, Existing 0.376
# Exactprod at time 17467: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17468: Calculated 0.5664, Existing 0.5664
# Underprod at time 17469: Calculated 0.3564, Existing 0.3564
# Underprod at time 17470: Calculated 0.5664, Existing 0.3104
# Underprod at time 17471: Calculated 0.5664, Existing 0.0428
# Underprod at time 17472: Calculated 0.345, Existing 0.0034
# Underprod at time 17473: Calculated 0.5664, Existing 0.0
# Underprod at time 17474: Calculated 0.5664, Existing 0.0
# Underprod at time 17475: Calculated 0.3078, Existing 0.0
# Underprod at time 17476: Calculated 0.5664, Existing 0.1144
# Underprod at time 17477: Calculated 0.5664, Existing 0.1142
# Underprod at time 17478: Calculated 0.2768, Existing 0.1142
# Underprod at time 17479: Calculated 0.5664, Existing 0.1142
# Underprod at time 17480: Calculated 0.5664, Existing 0.1142
# Underprod at time 17481: Calculated 0.3898, Existing 0.1142
# Underprod at time 17482: Calculated 0.5664, Existing 0.1142
# Underprod at time 17483: Calculated 0.5664, Existing 0.1147
# Underprod at time 17484: Calculated 0.5664, Existing 0.1142
# Underprod at time 17485: Calculated 0.5664, Existing 0.1142
# Underprod at time 17486: Calculated 0.5664, Existing 0.1468
# Underprod at time 17487: Calculated 0.5664, Existing 0.2206
# Underprod at time 17488: Calculated 0.5664, Existing 0.3756
# Underprod at time 17489: Calculated 0.5664, Existing 0.5573
# Underprod at time 17490: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17491: Calculated 0.5664, Existing 0.5664
# Underprod at time 17492: Calculated 0.5664, Existing 0.5542
# Underprod at time 17493: Calculated 0.5664, Existing 0.4192
# Underprod at time 17494: Calculated 0.5664, Existing 0.2673
# Underprod at time 17495: Calculated 0.5664, Existing 0.3104
# Underprod at time 17496: Calculated 0.4865, Existing 0.3497
# Underprod at time 17497: Calculated 0.5664, Existing 0.3778
# Underprod at time 17498: Calculated 0.5664, Existing 0.4479
# Exactprod at time 17499: Calculated 0.3815, Existing 0.3815
# Underprod at time 17500: Calculated 0.5664, Existing 0.2993
# Underprod at time 17501: Calculated 0.5664, Existing 0.0917
# Underprod at time 17502: Calculated 0.3454, Existing 0.1056
# Underprod at time 17503: Calculated 0.5664, Existing 0.093
# Underprod at time 17504: Calculated 0.5664, Existing 0.0525
# Underprod at time 17505: Calculated 0.2436, Existing 0.0489
# Underprod at time 17506: Calculated 0.5664, Existing 0.0634
# Underprod at time 17507: Calculated 0.5664, Existing 0.1258
# Underprod at time 17508: Calculated 0.2137, Existing 0.2137
# Underprod at time 17509: Calculated 0.5664, Existing 0.3467
# Underprod at time 17510: Calculated 0.5664, Existing 0.3653
# Overprod at time 17511: Calculated 0.1489, Existing 0.1489
# Underprod at time 17512: Calculated 0.5664, Existing 0.2842
# Underprod at time 17513: Calculated 0.5664, Existing 0.3529
# Underprod at time 17514: Calculated 0.0993, Existing 0.0993
# Exactprod at time 17515: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17516: Calculated 0.5664, Existing 0.5664
# Underprod at time 17517: Calculated 0.1552, Existing 0.1552
# Exactprod at time 17518: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17519: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17520: Calculated 0.4216, Existing 0.4216
# Exactprod at time 17521: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17522: Calculated 0.5664, Existing 0.5664
# Underprod at time 17523: Calculated 0.3545, Existing 0.3545
# Underprod at time 17524: Calculated 0.5658, Existing 0.205
# Underprod at time 17525: Calculated 0.565, Existing 0.1108
# Underprod at time 17526: Calculated 0.2366, Existing 0.1141
# Underprod at time 17527: Calculated 0.5664, Existing 0.1094
# Underprod at time 17528: Calculated 0.5664, Existing 0.09
# Underprod at time 17529: Calculated 0.1323, Existing 0.062
# Underprod at time 17530: Calculated 0.5664, Existing 0.0419
# Underprod at time 17531: Calculated 0.5664, Existing 0.0232
# Underprod at time 17532: Calculated 0.2448, Existing 0.0083
# Exactprod at time 17533: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17534: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17535: Calculated 0.2397, Existing 0.2397
# Exactprod at time 17536: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17537: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17538: Calculated 0.4274, Existing 0.4274
# Exactprod at time 17539: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17540: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17541: Calculated 0.5664, Existing 0.5664
# Exactprod at time 17542: Calculated 0.5664, Existing 0.5664
# Underprod at time 17543: Calculated 0.5664, Existing 0.0

# %%
print(n)
# Out:
# 0

# %%
import calendar

def energy_demand():
    def daily_sum(ts):
        elec = np.array(ts[0])
        elec = elec.reshape((elec.shape[0]//24, 24))
        sum_elec = np.sum(elec, axis=1)
        
        return sum_elec

    df_elec = pd.read_csv("../../data/demand_el.csv", header=None)
    df_gas = pd.read_csv("../../data/demand_ng.csv", header=None)

    sum_elec = daily_sum(df_elec)
    sum_gas = daily_sum(df_gas)

    years = 2

    month_names = [calendar.month_name[i] for i in range(1, 13)]
    month_names = list(map(lambda x: x + " 2015", month_names)) + list(map(lambda x: x + " 2016", month_names)) + ['']

    # month_names = [calendar.month_name[i] for i in range(1, 13)] * years + [''] # add a placeholder string

    tmp = (sum_elec.shape[0] // 3) * years
    months= [x for x in range(0,tmp)]

    days = [x for x in range(tmp)]

    plt.figure(figsize=(10,8))

    color1, color2 = 'steelblue', 'lightcoral'

    linewidth = 2

    plt.plot([],[], color=color1, label='Electricity', linewidth=linewidth)
    plt.plot([],[], color=color2, label='Gas', linewidth=linewidth)

    plt.stackplot(days, sum_elec[:tmp], colors=[color1], alpha=1., linewidth=linewidth)
    plt.stackplot(days, sum_gas[:tmp], colors=[color2], alpha=.7, linewidth=linewidth)

    plt.legend()
    plt.xlim(0, tmp)
    freq = 4
    plt.xticks(months[::30*freq], month_names[::freq], rotation=0)

    plt.ylabel('Energy demand [GWh/day]')

    plt.axhline(color='black', linewidth=1)

    plt.show()

# %%
energy_demand()
