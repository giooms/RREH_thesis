# %% [markdown]
# # Triple Analysis
# ## Offshore and Onshore wind, 3 Hydro plants, wave and no production in Belgium

# %%
from datetime import datetime

def is_leap_year(year):
    """Determine whether a year is a leap year."""
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

def sum_hours_over_years(start_year, end_year):
    """Calculate the sum of hours from start_year to end_year, inclusive."""
    total_hours = 0
    for year in range(start_year, end_year + 1):
        if is_leap_year(year):
            total_hours += 366 * 24  # Leap year has 366 days
        else:
            total_hours += 365 * 24  # Non-leap year has 365 days
    return total_hours

# Now, we will iterate over the years from 2015 to 2019 as per the requirement.
start_year = 2015
end_year = 2019
yearly_hours = {}

# Calculating the sum of hours for each range starting from 2015
for year in range(start_year, end_year + 1):
    yearly_hours[f"{start_year}-{year}"] = sum_hours_over_years(start_year, year)

yearly_hours
# Out:
# {'2015-2015': 8760,
#  '2015-2016': 17544,
#  '2015-2017': 26304,
#  '2015-2018': 35064,
#  '2015-2019': 43824}

# %%
from gboml import GbomlGraph

timehorizon = 17544


gboml_model = GbomlGraph(timehorizon=timehorizon)
nodes, edges, param = gboml_model.import_all_nodes_and_edges("../../models/hydro_wave_wind/greenland_hydro-wave-wind.gboml")
gboml_model.add_global_parameters(param)
gboml_model.add_nodes_in_model(*nodes)
gboml_model.add_hyperedges_in_model(*edges)
gboml_model.build_model()
solution, obj, status, solver_info, constr_info, _ = gboml_model.solve_gurobi(opt_file="gurobi.txt")
print("Solved")
# Out:
# Check variables of node LIQUEFIED_METHANE_CARRIERS_GR : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_STORAGE_HUB_GR : --- 0.0 seconds ---
# Check variables of node METHANE_LIQUEFACTION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node METHANATION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node WATER_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node CARBON_DIOXIDE_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node HYDROGEN_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node DIRECT_AIR_CAPTURE_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node DESALINATION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node HVDC_GR : --- 0.0 seconds ---
# Check variables of node BATTERY_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node WAVE_PLANT_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_PLANT_05h_GR : --- 0.007006406784057617 seconds ---
# Check variables of node HYDRO_BASIN_05h_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_PLANT_03j_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_BASIN_03j_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_PLANT_03h_GR : --- 0.0 seconds ---
# Check variables of node HYDRO_BASIN_03h_GR : --- 0.0 seconds ---
# Check variables of node ON_WIND_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node OFF_WIND_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node ENERGY_DEMAND_BE : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_STORAGE_DESTINATION : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_REGASIFICATION : --- 0.0 seconds ---
# Check hyperlink COASTAL_CARBON_DIOXIDE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_LIQUEFIED_METHANE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_METHANE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_WATER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_HYDROGEN_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_POWER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink INLAND_POWER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_05h : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_03j : --- 0.0 seconds ---
# Check hyperlink BASIN_TO_HYDRO_03h : --- 0.0 seconds ---
# Check hyperlink DESTINATION_LIQUEFIED_METHANE_BALANCE : --- 0.0 seconds ---
# Warning : Hyperedge constraint using variables from a single node at line 41
# Check hyperlink DESTINATION_METHANE_BALANCE : --- 0.0 seconds ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-12-03
#
# Reading Gurobi options from file gurobi.opt
# Set parameter Method to value 2
# Set parameter BarHomogeneous to value 1
# Set parameter Crossover to value 0
#
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 7735HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2666713 rows, 1105299 columns and 4971523 nonzeros
# Model fingerprint: 0x7055c3fb
# Variable types: 1105298 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [5e-05, 3e+02]
#   Objective range  [2e-04, 3e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-02, 6e+07]
# Presolve removed 1972105 rows and 638535 columns (presolve time = 5s) ...
# Presolve removed 1994706 rows and 640000 columns (presolve time = 10s) ...
# Presolve removed 2020558 rows and 665851 columns
# Presolve time: 11.95s
# Presolved: 646155 rows, 439448 columns, 1912583 nonzeros
# Variable types: 439447 continuous, 1 integer (0 binary)
# Root barrier log...
#
# Ordering time: 0.13s
#
# Barrier statistics:
#  Dense cols : 23
#  AA' NZ     : 1.876e+06
#  Factor NZ  : 1.056e+07 (roughly 500 MB of memory)
#  Factor Ops : 1.984e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.84397665e+08 -3.61931362e+12  3.07e+05 2.01e-02  7.23e+06    14s
#    1   7.14557977e+08 -8.33994679e+11  2.30e+05 5.68e+05  2.18e+06    15s
#    2   6.78340923e+08 -1.61023142e+11  1.84e+05 1.84e+05  7.84e+05    15s
#    3   4.19680413e+08 -6.84851320e+10  1.42e+05 8.62e+04  5.22e+05    15s
#    4   1.63694478e+08 -3.11553498e+10  3.74e+04 9.63e+04  1.59e+05    16s
#    5   6.90987623e+07 -1.51615831e+10  9.62e+03 5.05e+04  5.32e+04    16s
#    6   5.29104719e+07 -1.00923965e+10  5.09e+03 3.69e+04  3.18e+04    16s
#    7   4.00650171e+07 -4.34166122e+09  2.02e+03 1.52e+04  1.30e+04    17s
#    8   2.59562265e+07 -1.31813383e+09  2.84e+02 4.88e+03  2.80e+03    17s
#    9   1.80714423e+07 -1.42544187e+08  6.24e+01 5.30e+02  3.30e+02    17s
#   10   1.51049107e+07 -5.79311958e+07  4.50e+01 2.30e+02  1.59e+02    18s
#   11   1.41670865e+07 -2.59281749e+07  4.03e+01 1.15e+02  9.63e+01    18s
#   12   7.81601099e+06 -1.42681742e+07  1.81e+01 6.78e+01  4.50e+01    18s
#   13   5.41327418e+06 -5.79183626e+06  1.10e+01 3.15e+01  2.21e+01    19s
#   14   3.68622984e+06 -3.59132088e+06  6.79e+00 2.02e+01  1.34e+01    19s
#   15   2.56513317e+06 -2.82779724e+06  4.45e+00 1.61e+01  9.24e+00    19s
#   16   2.35375434e+06 -2.69543045e+06  4.01e+00 1.54e+01  8.50e+00    20s
#   17   1.60989612e+06 -1.90502368e+06  2.58e+00 1.11e+01  5.62e+00    20s
#   18   3.96406380e+05 -3.36703031e+05  5.69e-01 1.08e+00  1.03e+00    20s
#   19   3.27496086e+04 -5.50256452e+04  6.43e-02 1.26e-01  1.05e-01    21s
#   20   1.70851215e+04 -1.89453390e+04  2.88e-02 4.42e-02  4.00e-02    21s
#   21   9.59065335e+03 -1.03246892e+04  1.42e-02 2.45e-02  2.16e-02    21s
#   22   7.19196483e+03 -6.41826467e+03  9.98e-03 1.71e-02  1.46e-02    22s
#   23   6.76290815e+03 -6.03856017e+03  9.25e-03 1.62e-02  1.37e-02    22s
#   24   6.18517115e+03 -5.05420846e+03  8.24e-03 1.41e-02  1.20e-02    22s
#   25   5.20848500e+03  2.64363812e+02  6.51e-03 3.51e-03  5.18e-03    23s
#   26   3.20364149e+03  1.03647148e+03  2.44e-03 1.95e-03  2.27e-03    23s
#   27   2.61752779e+03  1.55080266e+03  1.22e-03 9.27e-04  1.11e-03    24s
#   28   2.48739732e+03  1.66211774e+03  9.44e-04 7.08e-04  8.56e-04    24s
#   29   2.34425536e+03  1.79631543e+03  6.36e-04 4.63e-04  5.66e-04    24s
#   30   2.26528205e+03  1.86076815e+03  4.66e-04 3.45e-04  4.17e-04    25s
#   31   2.20177162e+03  1.92012144e+03  3.30e-04 2.35e-04  2.90e-04    25s
#   32   2.15034731e+03  1.99519752e+03  2.18e-04 9.30e-05  1.58e-04    26s
#   33   2.13866395e+03  2.00696708e+03  1.92e-04 7.13e-05  1.34e-04    26s
#   34   2.11110059e+03  2.02177609e+03  1.31e-04 4.80e-05  9.07e-05    27s
#   35   2.10318752e+03  2.02777559e+03  1.13e-04 3.91e-05  7.65e-05    27s
#   36   2.09517546e+03  2.03156356e+03  9.37e-05 3.36e-05  6.45e-05    28s
#   37   2.08726359e+03  2.03613104e+03  7.52e-05 2.69e-05  5.18e-05    28s
#   38   2.08169918e+03  2.03845970e+03  6.17e-05 2.37e-05  4.39e-05    28s
#   39   2.07544283e+03  2.04691891e+03  4.68e-05 1.20e-05  2.88e-05    29s
#   40   2.07075593e+03  2.04852845e+03  3.54e-05 9.87e-06  2.25e-05    29s
#   41   2.06686446e+03  2.05054584e+03  2.59e-05 6.78e-06  1.65e-05    30s
#   42   2.06476888e+03  2.05252741e+03  2.08e-05 4.03e-06  1.24e-05    30s
#   43   2.06173617e+03  2.05316000e+03  1.47e-05 3.58e-06  8.67e-06    31s
#   44   2.05993159e+03  2.05488779e+03  1.20e-05 1.64e-06  5.09e-06    31s
#   45   2.05969282e+03  2.05494862e+03  1.15e-05 1.60e-06  4.78e-06    32s
#   46   2.05900042e+03  2.05530598e+03  9.81e-06 1.13e-06  3.73e-06    32s
#   47   2.05861703e+03  2.05533238e+03  8.80e-06 1.10e-06  3.32e-06    32s
#   48   2.05781264e+03  2.05566775e+03  5.95e-06 1.01e-06  2.17e-06    33s
#   49   2.05759913e+03  2.05574525e+03  5.06e-06 9.29e-07  1.87e-06    33s
#   50   2.05725868e+03  2.05595627e+03  3.57e-06 5.94e-07  1.31e-06    34s
#   51   2.05710028e+03  2.05600008e+03  2.92e-06 5.32e-07  1.11e-06    34s
#   52   2.05686805e+03  2.05603396e+03  1.97e-06 5.10e-07  8.44e-07    35s
#   53   2.05681402e+03  2.05607297e+03  1.74e-06 4.54e-07  7.50e-07    35s
#   54   2.05676008e+03  2.05612022e+03  1.48e-06 3.93e-07  6.48e-07    36s
#   55   2.05673318e+03  2.05614562e+03  1.36e-06 3.59e-07  5.95e-07    37s
#   56   2.05665451e+03  2.05618920e+03  1.01e-06 3.01e-07  4.71e-07    37s
#   57   2.05657469e+03  2.05622140e+03  6.42e-07 2.60e-07  3.58e-07    38s
#   58   2.05656162e+03  2.05625864e+03  5.83e-07 2.13e-07  3.07e-07    38s
#   59   2.05648878e+03  2.05628110e+03  2.60e-07 1.85e-07  2.11e-07    39s
#   60   2.05647170e+03  2.05633034e+03  1.84e-07 1.23e-07  1.44e-07    39s
#   61   2.05644837e+03  2.05637825e+03  8.20e-08 6.38e-08  7.14e-08    40s
#   62   2.05644453e+03  2.05638485e+03  4.04e-07 5.57e-08  6.08e-08    41s
#   63   2.05643753e+03  2.05639115e+03  4.54e-07 4.78e-08  4.73e-08    42s
#   64   2.05643560e+03  2.05639643e+03  3.62e-07 4.10e-08  4.00e-08    43s
#   65   2.05643474e+03  2.05640817e+03  3.17e-07 2.61e-08  2.71e-08    43s
#   66   2.05643006e+03  2.05642057e+03  2.43e-06 3.70e-07  9.74e-09    44s
#   67   2.05642969e+03  2.05642796e+03  3.73e-06 6.59e-07  1.78e-09    44s
#   68   2.05642848e+03  2.05642815e+03  7.78e-07 2.82e-07  3.47e-10    45s
#   69   2.05642827e+03  2.05642817e+03  2.56e-07 1.81e-07  1.09e-10    45s
#   70   2.05642827e+03  2.05642817e+03  2.53e-07 7.15e-07  1.02e-10    46s
#   71   2.05642824e+03  2.05642818e+03  2.02e-07 3.17e-07  6.55e-11    46s
#   72   2.05642821e+03  2.05642818e+03  1.49e-07 5.77e-08  3.47e-11    47s
#   73   2.05642819e+03  2.05642818e+03  5.90e-08 2.20e-08  9.56e-12    47s
#
# Barrier solved model in 73 iterations and 47.49 seconds (49.98 work units)
# Optimal objective 2.05642819e+03
#
#
# Root crossover log...
#
#   172273 DPushes remaining with DInf 0.0000000e+00                48s
#    22385 DPushes remaining with DInf 0.0000000e+00                51s
#    18677 DPushes remaining with DInf 0.0000000e+00                55s
#    16205 DPushes remaining with DInf 0.0000000e+00                61s
#    14969 DPushes remaining with DInf 0.0000000e+00                65s
#    13321 DPushes remaining with DInf 0.0000000e+00                71s
#    11261 DPushes remaining with DInf 0.0000000e+00                75s
#     8377 DPushes remaining with DInf 0.0000000e+00                80s
#     2057 DPushes remaining with DInf 0.0000000e+00                85s
#        0 DPushes remaining with DInf 0.0000000e+00                88s
#
#    58989 PPushes remaining with PInf 9.7599297e-05                88s
#    42427 PPushes remaining with PInf 0.0000000e+00                93s
#    26348 PPushes remaining with PInf 0.0000000e+00                97s
#    21133 PPushes remaining with PInf 0.0000000e+00               102s
#    10299 PPushes remaining with PInf 0.0000000e+00               106s
#     9475 PPushes remaining with PInf 0.0000000e+00               113s
#     9063 PPushes remaining with PInf 0.0000000e+00               116s
#     8239 PPushes remaining with PInf 0.0000000e+00               123s
#     7827 PPushes remaining with PInf 0.0000000e+00               126s
#     7003 PPushes remaining with PInf 0.0000000e+00               133s
#     6591 PPushes remaining with PInf 0.0000000e+00               136s
#     5767 PPushes remaining with PInf 0.0000000e+00               143s
#     5355 PPushes remaining with PInf 0.0000000e+00               146s
#     4531 PPushes remaining with PInf 0.0000000e+00               152s
#     4119 PPushes remaining with PInf 0.0000000e+00               156s
#     2883 PPushes remaining with PInf 0.0000000e+00               160s
#        0 PPushes remaining with PInf 0.0000000e+00               163s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.9358006e+01    163s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   118139    2.0564282e+03   0.000000e+00   1.935801e+01    164s
#   118354    2.0564282e+03   0.000000e+00   0.000000e+00    165s
#   118354    2.0564282e+03   0.000000e+00   0.000000e+00    166s
#
# Root relaxation: objective 2.056428e+03, 118354 iterations, 153.39 seconds (732.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2056.42818    0    1          - 2056.42818      -     -  166s
# H    0     0                    2057.2735941 2056.42818  0.04%     -  228s
#      0     0 2056.42818    0    1 2057.27359 2056.42818  0.04%     -  230s
#      0     2 2056.42818    0    1 2057.27359 2056.42818  0.04%     -  253s
# *    1     0               1    2056.4349998 2056.42845  0.00%   516  281s
#
# Explored 3 nodes (120187 simplex iterations) in 281.29 seconds (1070.57 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 2056.43 2057.27
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (3.1280e-06) exceeds tolerance
# Best objective 2.056434999844e+03, best bound 2.056434999844e+03, gap 0.0000%
# Solved

# %%
import json

gathered_data = gboml_model.turn_solution_to_dictionary(solver_info, status, solution, obj, constr_info)
print("Json done")
with open(f'../../models/hydro_wave_wind/results/RREH.json', "w") as fp:json.dump(gathered_data, fp, indent=4)
# Out:
# Json done

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
class MakeMeReadable:
    def __init__(self, d):
        self.d = d
    
    def __dir__(self):
        return self.d.keys()
    
    def __getattr__(self, v):
        try:
            out = self.d[v]
            if isinstance(out, dict):
                return MakeMeReadable(out)
            return out
        except:
            return getattr(self.d, v)
        
    def __str__(self):
        return str(self.d)
    
    def __repr__(self):
        return repr(self.d)

# %%
dico = {}
with open('../../models/hydro_wave_wind/results/RREH.json', 'r') as f:
    dico = json.load(f)
            
d = MakeMeReadable(dico)
    
if isinstance(dico, dict):
    print('The data is a dictionary')
else:
    print('The data is not a dictionary')
# Out:
# The data is a dictionary

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(18, 15), constrained_layout=True)
ylim = (-0.1, 0.1)
axs = axs.flatten()
def plot_balance(ax, data, title):
    ax.plot(data)
    ax.set_ylim(ylim)
    ax.set_title(title)
    
# GR_CO2 Balance
co2_storage_gr_in = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.carbon_dioxide_in.values)
co2_storage_gr_out = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.carbon_dioxide_out.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.carbon_dioxide.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.carbon_dioxide.values)
co2_balance_gr = dac_gr + co2_storage_gr_out - co2_storage_gr_in - methanation_gr

plot_balance(axs[0], co2_balance_gr, 'GR_CO2 Balance')

# GR_LCH4 Balance
lch4_carriers_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_CARRIERS_GR.variables.liquefied_methane_in.values)
lch4_storage_gr_in = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_in.values)
lch4_storage_gr_out = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_out.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.liquefied_methane.values)
lch4_balance_gr = ch4_liquefaction_gr + lch4_storage_gr_out - lch4_storage_gr_in - lch4_carriers_gr

plot_balance(axs[1], lch4_balance_gr, 'GR_LCH4 Balance')

# Check BE_CH4 Balance
conversion_factor = d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.conversion_factor
demand_CH4 = np.array(d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.demand)
lch4_regasification_be = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.methane.values)
ch4_balance_be = conversion_factor * lch4_regasification_be - 10 * demand_CH4[:timehorizon]

plot_balance(axs[2], ch4_balance_be, 'BE_CH4 Balance')


# Check BE_LCH4 Balance
lch4_carriers_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_CARRIERS_GR.variables.liquefied_methane_out.values)
lch4_storage_dest_in = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_in.values)
lch4_storage_dest_out = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_out.values)
lch4_regasification_be = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.liquefied_methane.values)
lch4_balance_be = lch4_carriers_gr + lch4_storage_dest_out - lch4_storage_dest_in - lch4_regasification_be

plot_balance(axs[3], lch4_balance_be, 'BE_LCH4 Balance')


# Check GR_INLAND CH4 Balance
off_wind_gr = np.array(d.solution.elements.OFF_WIND_PLANTS_GR.variables.electricity.values)
on_wind_gr = np.array(d.solution.elements.ON_WIND_PLANTS_GR.variables.electricity.values)
battery_storage_gr_out = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_out.values)
battery_storage_gr_in = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_in.values)
hvdc_gr_in = np.array(d.solution.elements.HVDC_GR.variables.electricity_in.values)
hydro_03h_gr = np.array(d.solution.elements.HYDRO_PLANT_03h_GR.variables.electricity.values)
hydro_03j_gr = np.array(d.solution.elements.HYDRO_PLANT_03j_GR.variables.electricity.values)
hydro_05h_gr = np.array(d.solution.elements.HYDRO_PLANT_05h_GR.variables.electricity.values)
wave_gr = np.array(d.solution.elements.WAVE_PLANT_GR.variables.electricity.values)

power_balance_gr = off_wind_gr + on_wind_gr + hydro_03h_gr + hydro_03j_gr + hydro_05h_gr + wave_gr + battery_storage_gr_out - battery_storage_gr_in - hvdc_gr_in

plot_balance(axs[4], power_balance_gr, 'GR_Inland CH4 Balance')


# Check GR_Coastal Power Balance
hvdc_gr_out = np.array(d.solution.elements.HVDC_GR.variables.electricity_out.values)
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.electricity.values)
h2_storage_gr = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.electricity.values)
desalination_gr = np.array(d.solution.elements.DESALINATION_PLANTS_GR.variables.electricity.values)
h2o_storage_gr = np.array(d.solution.elements.WATER_STORAGE_GR.variables.electricity.values)
co2_storage_gr = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.electricity.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.electricity.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.electricity.values)
power_balance_gr = hvdc_gr_out - electrolysis_gr - h2_storage_gr - desalination_gr - h2o_storage_gr - co2_storage_gr - ch4_liquefaction_gr - dac_gr 

plot_balance(axs[5], power_balance_gr, 'GR_Coastal Power Balance')


# Check GR_Coastal H2 Balance
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.hydrogen.values)
h2_storage_gr_out = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_out.values)
h2_storage_gr_in = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_in.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.hydrogen.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.hydrogen.values)
h2_balance_gr = electrolysis_gr + h2_storage_gr_out - h2_storage_gr_in - methanation_gr - dac_gr

plot_balance(axs[6], h2_balance_gr, 'GR_Coastal H2 Balance')


# Check GR_Coastal H2O Balance
desalination_gr = np.array(d.solution.elements.DESALINATION_PLANTS_GR.variables.water.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.water.values)
h2o_storage_gr_out = np.array(d.solution.elements.WATER_STORAGE_GR.variables.water_out.values)
h2o_storage_gr_in = np.array(d.solution.elements.WATER_STORAGE_GR.variables.water_in.values)
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.water.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.water.values)
h20_balance_gr = desalination_gr + methanation_gr + h2o_storage_gr_out - h2o_storage_gr_in - electrolysis_gr - dac_gr

plot_balance(axs[7], h20_balance_gr, 'GR_Coastal H2O Balance')

# Check GR_Coastal CH4 Balance
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.methane.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.liquefied_methane.values)
ch4_balance_gr = methanation_gr - ch4_liquefaction_gr

plot_balance(axs[8], ch4_balance_gr, 'GR_Coastal CH4 Balance')

plt.show()

print()

# %%
ls_nodes = list(d.model.nodes.keys())

print(ls_nodes)
# Out:
# ['LIQUEFIED_METHANE_CARRIERS_GR', 'LIQUEFIED_METHANE_STORAGE_HUB_GR', 'METHANE_LIQUEFACTION_PLANTS_GR', 'METHANATION_PLANTS_GR', 'WATER_STORAGE_GR', 'CARBON_DIOXIDE_STORAGE_GR', 'HYDROGEN_STORAGE_GR', 'DIRECT_AIR_CAPTURE_PLANTS_GR', 'DESALINATION_PLANTS_GR', 'ELECTROLYSIS_PLANTS_GR', 'HVDC_GR', 'BATTERY_STORAGE_GR', 'WAVE_PLANT_GR', 'HYDRO_PLANT_05h_GR', 'HYDRO_BASIN_05h_GR', 'HYDRO_PLANT_03j_GR', 'HYDRO_BASIN_03j_GR', 'HYDRO_PLANT_03h_GR', 'HYDRO_BASIN_03h_GR', 'ON_WIND_PLANTS_GR', 'OFF_WIND_PLANTS_GR', 'ENERGY_DEMAND_BE', 'LIQUEFIED_METHANE_STORAGE_DESTINATION', 'LIQUEFIED_METHANE_REGASIFICATION']

# %%
def cost_rreh(ls:list):
    if len(ls) == 0:
        return 0.0

    cost = 0

    for ele in ls:
        # print(f"{ele = }")
        # print(dico["solution"]["elements"][ele]["objectives"])
        try:
            cost += np.sum(dico["solution"]["elements"][ele]["objectives"]["unnamed"])
        except:
            for e in dico["solution"]["elements"][ele]["objectives"]["named"].values():
                # print(f"{e = }")
                cost += e
        # print(f"{cost = }")
    
    return cost

# %%
import re 

excluded_hydro_basins = [node for node in ls_nodes if re.match(r'HYDRO_BASIN_[\w]+_GR$', node)]

try:
    GR_nodes = [node for node in ls_nodes if node.endswith("_GR") and node not in excluded_hydro_basins]
except:
    GR_nodes = []
BE_nodes = list(map(lambda string: string if string[-3:] == "_BE" or string in ["PCCC_CCGT", "PCCC", "CO2_EXPORT", "LIQUEFIED_METHANE_STORAGE_DESTINATION","LIQUEFIED_METHANE_REGASIFICATION"] else None, ls_nodes))

try:
    GR_nodes = list(filter(lambda x: x not in [None, "PCCC", "PROD_CO2", "CO2_EXPORT"], GR_nodes))
except:
    GR_nodes = []
BE_nodes = list(filter(lambda x: x not in [None, "PROD_CO2"], BE_nodes))

cost_GR = cost_rreh(GR_nodes)
cost_BE = cost_rreh(BE_nodes)


print(f"GR {cost_GR = }")
print(f"BE {cost_BE = }")


obj_cost = d.solution.objective
tot_cost = np.sum([cost_GR, cost_BE])

abs_diff = np.abs(d.solution.objective - np.sum([cost_GR, cost_BE]))
print(f"{obj_cost = }")
print(f"{tot_cost = }")
print(abs_diff < 0.1)
# Out:
# GR cost_GR = 2038.4074774546189
# BE cost_BE = 18.027522389570443
# obj_cost = 2056.4349998453235
# tot_cost = 2056.4349998441894
# True

# %%
# Initialize a dictionary to hold individual capacities
plant_capacities = {}

# Store wind capacities individually and add them to the total capacity
plant_capacities['wind_onshore_gr'] = d.solution.elements.ON_WIND_PLANTS_GR.variables.capacity.values[0]
plant_capacities['wind_off_gr'] = d.solution.elements.OFF_WIND_PLANTS_GR.variables.capacity.values[0]

wave_n_units = d.solution.elements.WAVE_PLANT_GR.variables.num_units.values[0]
wave_RP = d.model.nodes.WAVE_PLANT_GR.parameters.unit_rated_power[0]
plant_capacities['wave_off_gr'] = wave_RP * wave_n_units

# Dynamically identify HYDRO_PLANT capacities and store them
for element_name in ls_nodes:
    if re.match(r'HYDRO_PLANT_\w+_GR$', element_name):
        # Extract capacity and store it in the dictionary
        plant_capacities[element_name] = dico["solution"]["elements"][element_name]["variables"]["capacity"]["values"][0]

# Compute the total installed capacity by summing all individual capacities
total_installed_capacity = sum(plant_capacities.values())

# %%
# Doesn't install on/offshore wind turbines if 1,7GW of Hydro

import matplotlib.pyplot as plt
import numpy as np

# Print installed capacities
for plant, capacity in plant_capacities.items():
    plant_type = "hydro" if "HYDRO_PLANT" in plant else "onshore" if "onshore" in plant else "offshore" if "wind_off" in plant else "wave"
    print(f"Installed capacity of {plant_type} = {capacity:.3f} GW")

# Calculate the total installed capacity
total_installed_capacity = sum(plant_capacities.values())

print(f"\nTotal installed capacity = {total_installed_capacity:.3f} GW")

# Calculate total hydro capacity by summing all hydro plant capacities
total_hydro_capacity = sum(capacity for plant, capacity in plant_capacities.items() if "HYDRO_PLANT" in plant)

# Data for the first plot
categories = ['Onshore Wind', 'Offshore Wind', 'Wave', 'Total Hydro']
capacities = [
    plant_capacities.get('wind_onshore_gr', 0),
    plant_capacities.get('wind_off_gr', 0),
    plant_capacities.get('wave_off_gr', 0),
    total_hydro_capacity
]

### Plot 1: Combined Wind and Total Hydro Capacities
plt.figure(figsize=(10, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(categories)))
plt.bar(categories, capacities, color=colors)
plt.ylabel('Installed Capacity (GW)')
plt.title('On-Offshore Wind and Total Hydro Capacities')
# Annotate each bar with its capacity
for i, v in enumerate(capacities):
    plt.text(i, v, f"{v:.3f}", ha='center', va='bottom')
plt.tight_layout()
plt.show()

### Plot 2: Capacities for Each Hydro Plant Separately
plt.figure(figsize=(10, 6))
hydro_labels = [plant for plant in plant_capacities.keys() if "HYDRO_PLANT" in plant]
hydro_values = [capacity for plant, capacity in plant_capacities.items() if "HYDRO_PLANT" in plant]
colors = plt.cm.viridis(np.linspace(0, 1, len(hydro_labels)))
plt.bar(hydro_labels, hydro_values, color=colors)
plt.title('Capacities for Each Hydro Plant')
# plt.xticks(rotation=45)
# Annotate each hydro plant bar with its capacity
for i, v in enumerate(hydro_values):
    plt.text(i, v, f"{v:.3f}", ha='center', va='bottom')
plt.tight_layout()
plt.show()
# Out:
# Installed capacity of onshore = 2.168 GW
# Installed capacity of offshore = 0.116 GW
# Installed capacity of wave = 0.566 GW
# Installed capacity of hydro = 0.058 GW
# Installed capacity of hydro = 0.099 GW
# Installed capacity of hydro = 0.040 GW
#
# Total installed capacity = 3.048 GW

# %%
gas_demand = d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.demand
gas_demand = np.sum(gas_demand[:timehorizon])/1000
print("the gas demand is ", gas_demand, "TWh")
# Out:
# the gas demand is  1.2970272171668917 TWh

# %%
# LCH4 full production:
gas = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.methane.values) * 15.31 # kt/h * GWh/kt
gas_prod = np.sum(gas) # GWh
gas_prod/1000
# Out:
# 12.970272171668919

# %%
demand_in_mwh = gas_prod * 1e3  # Convert GWh to MWh
total_cost_in_euros = tot_cost * 1e6  # Convert million euros to euros

# Compute price per MWh in euros
price_per_mwh = total_cost_in_euros / demand_in_mwh

print(f"The price is {round(price_per_mwh, 3)} €/MWh \n")
print("In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh")  # Adjusted to €/MWh
print("This system is about", round((price_per_mwh / 45), 3), "times more expensive compared to a reference price of 45 €/MWh")
# Out:
# The price is 158.55 €/MWh
#
# In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh
# This system is about 3.523 times more expensive compared to a reference price of 45 €/MWh

# %%
def cost_rreh_detailed(ls):
    detailed_cost = {}
    if len(ls) == 0:
        return detailed_cost

    for ele in ls:
        node_cost = 0
        try:
            node_cost += np.sum(dico["solution"]["elements"][ele]["objectives"]["unnamed"])
        except:
            for e in dico["solution"]["elements"][ele]["objectives"]["named"].values():
                node_cost += e
        detailed_cost[ele] = node_cost
    
    return detailed_cost

# %%
import matplotlib.pyplot as plt
import numpy as np

cost_details_GR = cost_rreh_detailed(GR_nodes)

sorted_nodes_and_costs = sorted(cost_details_GR.items(), key=lambda item: item[1])
sorted_nodes = [item[0] for item in sorted_nodes_and_costs]
sorted_costs = [item[1] for item in sorted_nodes_and_costs]

# Convert costs to €/MWh
adjusted_costs = [cost *1e6 / demand_in_mwh for cost in sorted_costs]

# Generate colors - ensuring consistent colors across plots
colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_nodes)))

# Plot 1: Stacked Horizontal Bar Chart
plt.figure(figsize=(10, 2))
cumulative_cost = 0  # Start at 0 for the leftmost bar segment

for node, cost, color in zip(sorted_nodes, adjusted_costs, colors):
    plt.barh('GR Nodes', cost, left=cumulative_cost, color=color, label=node)
    cumulative_cost += cost

plt.xlabel('Cost (€/MWh)')
plt.title('Cost Breakdown per GR Node (€/MWh)')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Nodes')
plt.show()

# Plot 2: Vertical Bar Chart with Sorted Nodes
plt.figure(figsize=(10, 6))
bars = plt.bar(sorted_nodes, adjusted_costs, color=colors)

plt.xlabel('Nodes')
plt.ylabel('Cost (€/MWh)')
plt.title('Cost per GR Node (€/MWh)')
plt.xticks(rotation=45, ha="right")

# Adding the cost above each bar
for bar, cost in zip(bars, adjusted_costs):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f"{cost:.2f}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()  # Adjust layout to make room for the rotated x-axis labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_production_dynamics(offshore_wind_gr, onshore_wind_gr, hydro_gr1, hydro_gr2, hydro_gr3, wave, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=len(offshore_wind_gr), freq='H')

    # Create DataFrames
    offshore_wind_df_gr = pd.DataFrame(offshore_wind_gr, index=date_range, columns=['Elec'])
    onshore_wind_df_gr = pd.DataFrame(onshore_wind_gr, index=date_range, columns=['Elec'])
    hydro_df1_gr = pd.DataFrame(hydro_gr1, index=date_range, columns=['Elec'])
    hydro_df2_gr = pd.DataFrame(hydro_gr2, index=date_range, columns=['Elec']) 
    hydro_df3_gr = pd.DataFrame(hydro_gr3, index=date_range, columns=['Elec'])
    wave_df_gr = pd.DataFrame(wave, index=date_range, columns=['Elec'])

   
    # Smooth the data with a rolling mean
    offshore_wind_df_gr['Smoothed'] = offshore_wind_df_gr['Elec'].rolling(window=24).mean()
    onshore_wind_df_gr['Smoothed'] = onshore_wind_df_gr['Elec'].rolling(window=24).mean()
    hydro_df1_gr['Smoothed'] = hydro_df1_gr['Elec'].rolling(window=24).mean()
    hydro_df2_gr['Smoothed'] = hydro_df2_gr['Elec'].rolling(window=24).mean()
    hydro_df3_gr['Smoothed'] = hydro_df3_gr['Elec'].rolling(window=24).mean()
    wave_df_gr['Smoothed'] = wave_df_gr['Elec'].rolling(window=24).mean()     
   
    # Plotting
    fig, axs = plt.subplots(6, 1, figsize=(12, 8), sharex=True)

    colors = plt.cm.viridis(np.linspace(0, 1, 6))

    # Plot each storage type
    for ax, df, color, label in zip(axs,
                                    [offshore_wind_df_gr, onshore_wind_df_gr, hydro_df1_gr, hydro_df2_gr, hydro_df3_gr, wave_df_gr],
                                    colors,
                                    ['Offshore Wind Production (Greenland)', 'Onshore Wind Production (Greenland)', 'Hydro Production 03h (Greenland)', 'Hydro Production 03j (Greenland)', 'Hydro Production 05h (Greenland)', 'Wave Production (Greenland)']):
        ax.fill_between(df.index, df['Smoothed'], color=color)
        ax.set_title(label, fontsize=10, loc='left')
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.set_ylabel('GWh')

    # Adjust layout and show plot
    fig.tight_layout()
    plt.show()

# %%
offshore_prod_gr = np.array(d.solution.elements.OFF_WIND_PLANTS_GR.variables.electricity.values)
onshore_prod_gr = np.array(d.solution.elements.ON_WIND_PLANTS_GR.variables.electricity.values)
hydro_prod_03h_gr = np.array(d.solution.elements.HYDRO_PLANT_03h_GR.variables.electricity.values)
hydro_prod_03j_gr = np.array(d.solution.elements.HYDRO_PLANT_03j_GR.variables.electricity.values)
hydro_prod_05h_gr = np.array(d.solution.elements.HYDRO_PLANT_05h_GR.variables.electricity.values)
wave_prod_gr = np.array(d.solution.elements.WAVE_PLANT_GR.variables.electricity.values)

plot_production_dynamics(offshore_prod_gr, onshore_prod_gr, hydro_prod_03h_gr, hydro_prod_03j_gr, hydro_prod_05h_gr, wave_prod_gr)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import re

def plot_basin_dynamics(basins_data, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=17544, freq='H')
    
    for basin_name, basin_data in basins_data.items():
        fig, axs = plt.subplots(4, 1, figsize=(12, 12), sharex=True)
        window_size = 24  # Smooth over 24 hours
        parameters = ['inflow', 'storage', 'release', 'spill']
        colors = plt.cm.viridis(np.linspace(0, 1, 4))

        for idx, parameter in enumerate(parameters):
            data_df = pd.DataFrame(basin_data[parameter], index=date_range, columns=[parameter]).rolling(window=window_size).mean()
            axs[idx].plot(data_df.index, data_df[parameter], color=colors[idx], label=f"{parameter.title()} (Smoothed)")
            axs[idx].set_title(f"{basin_name} - {parameter.title()} Dynamics", fontsize=10, loc='left')
            axs[idx].set_ylabel('Volume (TCM/h)')
            axs[idx].set_ylim(bottom=0)  # Ensure y-axis starts at 0
            axs[idx].legend(loc='upper right')

        # Format x-axis
        axs[3].xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
        axs[3].xaxis.set_major_locator(mdates.MonthLocator())
        plt.xticks(rotation=45)
        plt.xlabel('Time')
        fig.tight_layout()
        plt.show()

# Assuming 'd' is your data object and 'ls_nodes' is a list of all node names
basins_data = {}

# Dynamically determine all hydro basins from ls_nodes
for node_name in ls_nodes:
    if re.match(r'HYDRO_BASIN_\w+_GR$', node_name):
        basins_data[node_name] = {
            'inflow': np.array(getattr(d.model.nodes, node_name).parameters.inflow_series[:17544]),
            'storage': np.array(getattr(d.solution.elements, node_name).variables.storage.values),
            'release': np.array(getattr(d.solution.elements, node_name).variables.release.values),
            'spill': np.array(getattr(d.solution.elements, node_name).variables.spill.values)
        }

plot_basin_dynamics(basins_data)

# %%
np.array(d.solution.elements.HYDRO_BASIN_03h_GR.variables.storage.values)
# Out:
# array([22499967.54597702, 22499967.54597702, 22499967.54597702, ...,
#        22499835.04597702, 22499802.59195403, 22499967.54597702])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_storage_dynamics(battery_data, hydrogen_data, methane_data_src, methane_data_dest, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=len(battery_data), freq='H')

    # Create DataFrames
    battery_df = pd.DataFrame(battery_data, index=date_range, columns=['Battery'])
    hydrogen_df = pd.DataFrame(hydrogen_data, index=date_range, columns=['Hydrogen'])
    methane_df_gr = pd.DataFrame(methane_data_src, index=date_range, columns=['Methane'])
    methane_df_be = pd.DataFrame(methane_data_dest, index=date_range, columns=['Methane'])


    # Smooth the data with a rolling mean
    battery_df['Smoothed'] = battery_df['Battery'].rolling(window=24).mean()
    hydrogen_df['Smoothed'] = hydrogen_df['Hydrogen'].rolling(window=24).mean()
    methane_df_gr['Smoothed'] = methane_df_gr['Methane'].rolling(window=24).mean()
    methane_df_be['Smoothed'] = methane_df_be['Methane'].rolling(window=24).mean()

    # Plotting
    fig, axs = plt.subplots(4, 1, figsize=(12, 8), sharex=True)

    colors = plt.cm.viridis(np.linspace(0, 1, 4))

    # Plot each storage type
    for ax, df, color, label in zip(axs,
                                    [battery_df, hydrogen_df, methane_df_gr, methane_df_be],
                                    colors,
                                    ['Battery Storage Dynamics', 'Hydrogen Storage Dynamics', 'Liquid Methane Storage Dynamics (Greenland)', 'Liquid Methane Storage Dynamics (Belgium)']):
        ax.fill_between(df.index, df['Smoothed'], color=color)
        ax.set_title(label, fontsize=10, loc='left')
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.set_ylabel('GWh')

    # Adjust layout and show plot
    fig.tight_layout()
    plt.show()

# %%
battery_flow = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_stored.values)
h2_flow = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_stored.values)
lch4_flow_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_stored.values)
lch4_flow_be = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_stored.values)

plot_storage_dynamics(battery_flow, h2_flow, lch4_flow_gr, lch4_flow_be)

print(battery_flow[-1])
print(h2_flow[-1])
print(lch4_flow_gr[-1])
print(lch4_flow_be[-1])
# Out:
# 0.0
# 10.60788306619873
# 10.65789113897224
# 5.715802232037658

# %%
leftover_lch4 = (lch4_flow_be[-1] + lch4_flow_gr[-1]) * 0.98 * 15.31 *1e3

leftover_lch4 # MWh
# Out:
# 245667.62059995826

# %%
demand_in_mwh = gas_prod * 1e3  # Convert TWh to MWh
total_cost_in_euros = tot_cost * 1e6  # Convert million euros to euros

# Compute price per MWh in euros
price_per_mwh = total_cost_in_euros / (demand_in_mwh+leftover_lch4)

print(f"The price is {round(price_per_mwh, 3)} €/MWh \n")
print("In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh")  # Adjusted to €/MWh
print("This system is about", round((price_per_mwh / 45), 3), "times more expensive compared to a reference price of 45 €/MWh")
# Out:
# The price is 155.603 €/MWh
#
# In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh
# This system is about 3.458 times more expensive compared to a reference price of 45 €/MWh

# %%
import pandas as pd

# Example input data
# If the CSV has no header row, set header=None and provide column names
column_name = ['WaveEnergyDensity']
wave_energy_df = pd.read_csv('../../data/wave_series_goff.csv', header=None, names=column_name)

length_of_installation = d.solution.elements.WAVE_PLANT_GR.variables.length.values[0]
unit_width = d.model.nodes.WAVE_PLANT_GR.parameters.unit_width[0]  # meters
space_between = d.model.nodes.WAVE_PLANT_GR.parameters.space_between[0]  # meters

# Calculate total space required per unit (width + space)
total_space_per_unit = unit_width + space_between

# Calculate the number of units that can be installed
number_of_units = length_of_installation // total_space_per_unit

# Calculate the total energy potential for each wave energy density value
wave_energy_df['TotalEnergyPotentialGW'] = wave_energy_df['WaveEnergyDensity'] * wave_n_units * unit_width

# Calculate the total rated energy capacity based on the number of units
total_rated_capacity_gw = number_of_units * wave_RP

# Check when the total energy potential exceeds the total rated capacity
wave_energy_df['ExceedsRatedPower'] = wave_energy_df['TotalEnergyPotentialGW'] > total_rated_capacity_gw

print(wave_energy_df)
# Out:
#        WaveEnergyDensity  TotalEnergyPotentialGW  ExceedsRatedPower
# 0               0.000022                0.558799              False
# 1               0.000049                1.221118               True
# 2               0.000049                1.227603               True
# 3               0.000019                0.469001              False
# 4               0.000050                1.237106               True
# ...                  ...                     ...                ...
# 43817           0.000047                1.171781               True
# 43818           0.000027                0.671970               True
# 43819           0.000047                1.172134               True
# 43820           0.000047                1.172077               True
# 43821           0.000026                0.654098               True
#
# [43822 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Slice the DataFrame to only include the first x rows
wave_energy_df_subset = wave_energy_df.head(timehorizon)

# Convert wave_prod array/list to a pandas Series for easy plotting (match the length of the DataFrame subset)
wave_prod = pd.Series(wave_prod_gr[:timehorizon])

# For visualization, calculate the total rated capacity again for the plot
total_rated_capacity_gw = number_of_units * wave_RP

# Plotting
plt.figure(figsize=(10, 6))

# Plot Total Energy Potential GW for the subset as grey bars with 90% transparency
plt.bar(wave_energy_df_subset.index, wave_energy_df_subset['TotalEnergyPotentialGW'], color='grey', alpha=0.9, label='Total Energy Potential (GW)')

# Plot the electricity production output as a grey line with 90% transparency
plt.plot(wave_energy_df_subset.index, wave_prod, color='blue', markersize=3, label='Electricity Production Output (GW)', alpha=0.3, linewidth=2)

# Plot a line for the Total Rated Capacity GW Threshold
plt.axhline(y=total_rated_capacity_gw, color='green', linestyle='-', label='Rated Power * Number of Units (GW)')

# Set the y-axis limit to 10 times the total rated capacity
plt.ylim(0, 10 * total_rated_capacity_gw)

plt.xlabel('Index')
plt.ylabel('Energy (GW)')
plt.title('Wave Energy Potential vs. Rated Capacity Threshold (First {} Entries)'.format(timehorizon))
plt.legend()
plt.grid(True)

plt.show()

# %%
n=0
for t in range(len(wave_energy_df_subset)):
    calculated_prod = min(wave_energy_df_subset['WaveEnergyDensity'][t] * wave_n_units * unit_width, wave_RP * wave_n_units)
    if calculated_prod < wave_prod[t]:
        if 1.1*calculated_prod< wave_prod[t]:
            n+=1
        print(f"Overprod at time {t}: Expected {round(calculated_prod,4)}, in Model {round(wave_prod[t],4)}")
    elif calculated_prod > wave_prod[t]: 
        print(f"Underprod at time {t}: Expected {round(calculated_prod,4)}, in Model {round(wave_prod[t],4)}")
    elif calculated_prod == wave_prod[t]:
        print(f"Exactprod at time {t}: Expected {round(calculated_prod,4)}, in Model {round(wave_prod[t],4)}")
# Out:
# Underprod at time 0: Expected 0.5588, in Model 0.0
# Underprod at time 1: Expected 0.5664, in Model 0.0
# Underprod at time 2: Expected 0.5664, in Model 0.0
# Underprod at time 3: Expected 0.469, in Model 0.0
# Underprod at time 4: Expected 0.5664, in Model 0.0
# Underprod at time 5: Expected 0.5664, in Model 0.0151
# Underprod at time 6: Expected 0.4012, in Model 0.0145
# Underprod at time 7: Expected 0.5664, in Model 0.0212
# Underprod at time 8: Expected 0.5664, in Model 0.0407
# Underprod at time 9: Expected 0.2503, in Model 0.103
# Underprod at time 10: Expected 0.5664, in Model 0.3063
# Underprod at time 11: Expected 0.5664, in Model 0.4296
# Underprod at time 12: Expected 0.5664, in Model 0.5664
# Exactprod at time 13: Expected 0.5664, in Model 0.5664
# Underprod at time 14: Expected 0.5664, in Model 0.4636
# Underprod at time 15: Expected 0.419, in Model 0.419
# Exactprod at time 16: Expected 0.5664, in Model 0.5664
# Exactprod at time 17: Expected 0.5664, in Model 0.5664
# Exactprod at time 18: Expected 0.5664, in Model 0.5664
# Underprod at time 19: Expected 0.5664, in Model 0.5663
# Exactprod at time 20: Expected 0.5664, in Model 0.5664
# Exactprod at time 21: Expected 0.5664, in Model 0.5664
# Exactprod at time 22: Expected 0.5664, in Model 0.5664
# Underprod at time 23: Expected 0.5664, in Model 0.5664
# Exactprod at time 24: Expected 0.3676, in Model 0.3676
# Exactprod at time 25: Expected 0.5664, in Model 0.5664
# Exactprod at time 26: Expected 0.5664, in Model 0.5664
# Exactprod at time 27: Expected 0.5664, in Model 0.5664
# Exactprod at time 28: Expected 0.5664, in Model 0.5664
# Exactprod at time 29: Expected 0.5664, in Model 0.5664
# Exactprod at time 30: Expected 0.384, in Model 0.384
# Exactprod at time 31: Expected 0.5664, in Model 0.5664
# Exactprod at time 32: Expected 0.5664, in Model 0.5664
# Overprod at time 33: Expected 0.3415, in Model 0.3415
# Exactprod at time 34: Expected 0.5664, in Model 0.5664
# Exactprod at time 35: Expected 0.5664, in Model 0.5664
# Exactprod at time 36: Expected 0.5664, in Model 0.5664
# Exactprod at time 37: Expected 0.5664, in Model 0.5664
# Exactprod at time 38: Expected 0.5664, in Model 0.5664
# Underprod at time 39: Expected 0.458, in Model 0.458
# Exactprod at time 40: Expected 0.5664, in Model 0.5664
# Exactprod at time 41: Expected 0.5664, in Model 0.5664
# Exactprod at time 42: Expected 0.5664, in Model 0.5664
# Exactprod at time 43: Expected 0.5664, in Model 0.5664
# Underprod at time 44: Expected 0.5664, in Model 0.5664
# Exactprod at time 45: Expected 0.5664, in Model 0.5664
# Exactprod at time 46: Expected 0.5664, in Model 0.5664
# Exactprod at time 47: Expected 0.5664, in Model 0.5664
# Underprod at time 48: Expected 0.5664, in Model 0.4941
# Underprod at time 49: Expected 0.5664, in Model 0.239
# Underprod at time 50: Expected 0.5664, in Model 0.1081
# Underprod at time 51: Expected 0.4729, in Model 0.0959
# Underprod at time 52: Expected 0.5664, in Model 0.0892
# Underprod at time 53: Expected 0.5664, in Model 0.0963
# Underprod at time 54: Expected 0.3709, in Model 0.1016
# Underprod at time 55: Expected 0.5664, in Model 0.1016
# Underprod at time 56: Expected 0.5664, in Model 0.0975
# Underprod at time 57: Expected 0.4021, in Model 0.0962
# Underprod at time 58: Expected 0.5664, in Model 0.1027
# Underprod at time 59: Expected 0.5664, in Model 0.1069
# Underprod at time 60: Expected 0.4169, in Model 0.1068
# Underprod at time 61: Expected 0.5664, in Model 0.1008
# Underprod at time 62: Expected 0.5664, in Model 0.0898
# Underprod at time 63: Expected 0.4784, in Model 0.0764
# Underprod at time 64: Expected 0.5664, in Model 0.1727
# Underprod at time 65: Expected 0.5664, in Model 0.4914
# Underprod at time 66: Expected 0.5204, in Model 0.5012
# Underprod at time 67: Expected 0.5664, in Model 0.432
# Exactprod at time 68: Expected 0.5664, in Model 0.5664
# Exactprod at time 69: Expected 0.4768, in Model 0.4768
# Exactprod at time 70: Expected 0.5664, in Model 0.5664
# Exactprod at time 71: Expected 0.5664, in Model 0.5664
# Exactprod at time 72: Expected 0.3622, in Model 0.3622
# Exactprod at time 73: Expected 0.5664, in Model 0.5664
# Exactprod at time 74: Expected 0.5664, in Model 0.5664
# Underprod at time 75: Expected 0.2355, in Model 0.2355
# Exactprod at time 76: Expected 0.5664, in Model 0.5664
# Exactprod at time 77: Expected 0.5664, in Model 0.5664
# Underprod at time 78: Expected 0.1573, in Model 0.1573
# Exactprod at time 79: Expected 0.5664, in Model 0.5664
# Underprod at time 80: Expected 0.5664, in Model 0.2842
# Underprod at time 81: Expected 0.2299, in Model 0.2299
# Underprod at time 82: Expected 0.5664, in Model 0.5094
# Exactprod at time 83: Expected 0.5664, in Model 0.5664
# Underprod at time 84: Expected 0.5664, in Model 0.416
# Underprod at time 85: Expected 0.5664, in Model 0.1225
# Underprod at time 86: Expected 0.5664, in Model 0.0
# Underprod at time 87: Expected 0.5664, in Model 0.0521
# Underprod at time 88: Expected 0.5664, in Model 0.0432
# Underprod at time 89: Expected 0.5664, in Model 0.1616
# Underprod at time 90: Expected 0.5664, in Model 0.3783
# Exactprod at time 91: Expected 0.5664, in Model 0.5664
# Underprod at time 92: Expected 0.5664, in Model 0.4708
# Underprod at time 93: Expected 0.5664, in Model 0.4128
# Exactprod at time 94: Expected 0.5664, in Model 0.5664
# Exactprod at time 95: Expected 0.5664, in Model 0.5664
# Exactprod at time 96: Expected 0.5664, in Model 0.5664
# Exactprod at time 97: Expected 0.5664, in Model 0.5664
# Underprod at time 98: Expected 0.5664, in Model 0.5094
# Underprod at time 99: Expected 0.5664, in Model 0.0828
# Underprod at time 100: Expected 0.5664, in Model 0.0
# Underprod at time 101: Expected 0.5664, in Model 0.0
# Underprod at time 102: Expected 0.5664, in Model 0.0
# Underprod at time 103: Expected 0.5664, in Model 0.0
# Underprod at time 104: Expected 0.5664, in Model 0.0
# Underprod at time 105: Expected 0.5664, in Model 0.0
# Underprod at time 106: Expected 0.5664, in Model 0.0
# Underprod at time 107: Expected 0.5664, in Model 0.0
# Underprod at time 108: Expected 0.5664, in Model 0.0
# Underprod at time 109: Expected 0.5664, in Model 0.0
# Underprod at time 110: Expected 0.5664, in Model 0.0
# Underprod at time 111: Expected 0.5664, in Model 0.0
# Underprod at time 112: Expected 0.5664, in Model 0.0
# Underprod at time 113: Expected 0.5664, in Model 0.0
# Underprod at time 114: Expected 0.5664, in Model 0.0
# Underprod at time 115: Expected 0.5664, in Model 0.0
# Underprod at time 116: Expected 0.5664, in Model 0.0
# Underprod at time 117: Expected 0.477, in Model 0.0047
# Underprod at time 118: Expected 0.5664, in Model 0.0119
# Exactprod at time 119: Expected 0.5664, in Model 0.5664
# Underprod at time 120: Expected 0.5529, in Model 0.2808
# Underprod at time 121: Expected 0.5664, in Model 0.1103
# Underprod at time 122: Expected 0.5664, in Model 0.1066
# Underprod at time 123: Expected 0.5664, in Model 0.1391
# Exactprod at time 124: Expected 0.5664, in Model 0.5664
# Exactprod at time 125: Expected 0.5664, in Model 0.5664
# Underprod at time 126: Expected 0.4403, in Model 0.4403
# Exactprod at time 127: Expected 0.5664, in Model 0.5664
# Exactprod at time 128: Expected 0.5664, in Model 0.5664
# Exactprod at time 129: Expected 0.2775, in Model 0.2775
# Exactprod at time 130: Expected 0.5664, in Model 0.5664
# Exactprod at time 131: Expected 0.5664, in Model 0.5664
# Underprod at time 132: Expected 0.1602, in Model 0.1602
# Underprod at time 133: Expected 0.5664, in Model 0.3284
# Underprod at time 134: Expected 0.5664, in Model 0.0
# Underprod at time 135: Expected 0.069, in Model 0.0088
# Underprod at time 136: Expected 0.5664, in Model 0.0158
# Underprod at time 137: Expected 0.5664, in Model 0.0278
# Underprod at time 138: Expected 0.5664, in Model 0.0474
# Underprod at time 139: Expected 0.5664, in Model 0.0133
# Underprod at time 140: Expected 0.5664, in Model 0.0
# Underprod at time 141: Expected 0.5664, in Model 0.0
# Underprod at time 142: Expected 0.5664, in Model 0.0
# Underprod at time 143: Expected 0.5664, in Model 0.0
# Exactprod at time 144: Expected 0.5664, in Model 0.5664
# Underprod at time 145: Expected 0.5664, in Model 0.1142
# Underprod at time 146: Expected 0.5664, in Model 0.1142
# Underprod at time 147: Expected 0.5664, in Model 0.1142
# Underprod at time 148: Expected 0.5664, in Model 0.1142
# Underprod at time 149: Expected 0.5664, in Model 0.1142
# Underprod at time 150: Expected 0.5664, in Model 0.1142
# Underprod at time 151: Expected 0.5664, in Model 0.1142
# Underprod at time 152: Expected 0.5664, in Model 0.1142
# Underprod at time 153: Expected 0.5664, in Model 0.1142
# Underprod at time 154: Expected 0.5664, in Model 0.1142
# Underprod at time 155: Expected 0.5664, in Model 0.1142
# Underprod at time 156: Expected 0.5664, in Model 0.1142
# Underprod at time 157: Expected 0.5664, in Model 0.1142
# Underprod at time 158: Expected 0.5664, in Model 0.1142
# Underprod at time 159: Expected 0.5664, in Model 0.1142
# Underprod at time 160: Expected 0.5664, in Model 0.1142
# Underprod at time 161: Expected 0.5664, in Model 0.115
# Underprod at time 162: Expected 0.5664, in Model 0.1142
# Underprod at time 163: Expected 0.5664, in Model 0.0
# Underprod at time 164: Expected 0.5664, in Model 0.0094
# Underprod at time 165: Expected 0.5664, in Model 0.0462
# Underprod at time 166: Expected 0.5664, in Model 0.1041
# Underprod at time 167: Expected 0.5664, in Model 0.2352
# Underprod at time 168: Expected 0.5664, in Model 0.3622
# Underprod at time 169: Expected 0.5664, in Model 0.3621
# Underprod at time 170: Expected 0.5664, in Model 0.3684
# Underprod at time 171: Expected 0.5664, in Model 0.3016
# Underprod at time 172: Expected 0.5664, in Model 0.3314
# Underprod at time 173: Expected 0.5664, in Model 0.5414
# Underprod at time 174: Expected 0.5664, in Model 0.5664
# Exactprod at time 175: Expected 0.5664, in Model 0.5664
# Exactprod at time 176: Expected 0.5664, in Model 0.5664
# Exactprod at time 177: Expected 0.5664, in Model 0.5664
# Exactprod at time 178: Expected 0.5664, in Model 0.5664
# Exactprod at time 179: Expected 0.5664, in Model 0.5664
# Exactprod at time 180: Expected 0.5664, in Model 0.5664
# Exactprod at time 181: Expected 0.5664, in Model 0.5664
# Underprod at time 182: Expected 0.5664, in Model 0.5664
# Underprod at time 183: Expected 0.5664, in Model 0.5664
# Underprod at time 184: Expected 0.5664, in Model 0.5664
# Exactprod at time 185: Expected 0.5664, in Model 0.5664
# Exactprod at time 186: Expected 0.5664, in Model 0.5664
# Exactprod at time 187: Expected 0.5664, in Model 0.5664
# Underprod at time 188: Expected 0.5664, in Model 0.5664
# Exactprod at time 189: Expected 0.5664, in Model 0.5664
# Exactprod at time 190: Expected 0.5664, in Model 0.5664
# Exactprod at time 191: Expected 0.5664, in Model 0.5664
# Underprod at time 192: Expected 0.5664, in Model 0.5664
# Underprod at time 193: Expected 0.5664, in Model 0.5664
# Exactprod at time 194: Expected 0.5664, in Model 0.5664
# Exactprod at time 195: Expected 0.5664, in Model 0.5664
# Underprod at time 196: Expected 0.5664, in Model 0.5664
# Underprod at time 197: Expected 0.5664, in Model 0.5664
# Exactprod at time 198: Expected 0.5664, in Model 0.5664
# Underprod at time 199: Expected 0.5664, in Model 0.3193
# Underprod at time 200: Expected 0.5664, in Model 0.3134
# Exactprod at time 201: Expected 0.5664, in Model 0.5664
# Exactprod at time 202: Expected 0.5664, in Model 0.5664
# Underprod at time 203: Expected 0.5664, in Model 0.4772
# Underprod at time 204: Expected 0.5148, in Model 0.4974
# Exactprod at time 205: Expected 0.5664, in Model 0.5664
# Underprod at time 206: Expected 0.5664, in Model 0.1142
# Underprod at time 207: Expected 0.4397, in Model 0.1149
# Underprod at time 208: Expected 0.5664, in Model 0.1142
# Underprod at time 209: Expected 0.5664, in Model 0.1142
# Underprod at time 210: Expected 0.5664, in Model 0.1142
# Underprod at time 211: Expected 0.5664, in Model 0.115
# Underprod at time 212: Expected 0.5664, in Model 0.0
# Underprod at time 213: Expected 0.5664, in Model 0.0
# Underprod at time 214: Expected 0.5664, in Model 0.0
# Underprod at time 215: Expected 0.5664, in Model 0.0
# Underprod at time 216: Expected 0.5664, in Model 0.0
# Underprod at time 217: Expected 0.5664, in Model 0.0085
# Underprod at time 218: Expected 0.5664, in Model 0.0355
# Underprod at time 219: Expected 0.5664, in Model 0.0212
# Underprod at time 220: Expected 0.5664, in Model 0.1807
# Exactprod at time 221: Expected 0.5664, in Model 0.5664
# Exactprod at time 222: Expected 0.5664, in Model 0.5664
# Exactprod at time 223: Expected 0.5664, in Model 0.5664
# Underprod at time 224: Expected 0.5664, in Model 0.5664
# Exactprod at time 225: Expected 0.5664, in Model 0.5664
# Exactprod at time 226: Expected 0.5664, in Model 0.5664
# Exactprod at time 227: Expected 0.5664, in Model 0.5664
# Exactprod at time 228: Expected 0.5664, in Model 0.5664
# Underprod at time 229: Expected 0.5664, in Model 0.5664
# Underprod at time 230: Expected 0.5664, in Model 0.5664
# Exactprod at time 231: Expected 0.5664, in Model 0.5664
# Exactprod at time 232: Expected 0.5664, in Model 0.5664
# Exactprod at time 233: Expected 0.5664, in Model 0.5664
# Exactprod at time 234: Expected 0.5664, in Model 0.5664
# Exactprod at time 235: Expected 0.5664, in Model 0.5664
# Underprod at time 236: Expected 0.5664, in Model 0.5664
# Underprod at time 237: Expected 0.5664, in Model 0.1797
# Underprod at time 238: Expected 0.5664, in Model 0.036
# Underprod at time 239: Expected 0.5664, in Model 0.0586
# Underprod at time 240: Expected 0.5664, in Model 0.0902
# Underprod at time 241: Expected 0.5664, in Model 0.0833
# Underprod at time 242: Expected 0.5664, in Model 0.0528
# Underprod at time 243: Expected 0.5664, in Model 0.0177
# Underprod at time 244: Expected 0.5664, in Model 0.0828
# Underprod at time 245: Expected 0.5664, in Model 0.3778
# Exactprod at time 246: Expected 0.5664, in Model 0.5664
# Exactprod at time 247: Expected 0.5664, in Model 0.5664
# Exactprod at time 248: Expected 0.5664, in Model 0.5664
# Exactprod at time 249: Expected 0.5664, in Model 0.5664
# Underprod at time 250: Expected 0.5664, in Model 0.5664
# Exactprod at time 251: Expected 0.5664, in Model 0.5664
# Exactprod at time 252: Expected 0.5664, in Model 0.5664
# Exactprod at time 253: Expected 0.5664, in Model 0.5664
# Exactprod at time 254: Expected 0.5664, in Model 0.5664
# Exactprod at time 255: Expected 0.5664, in Model 0.5664
# Exactprod at time 256: Expected 0.5664, in Model 0.5664
# Exactprod at time 257: Expected 0.5664, in Model 0.5664
# Underprod at time 258: Expected 0.5664, in Model 0.3033
# Underprod at time 259: Expected 0.5664, in Model 0.1139
# Underprod at time 260: Expected 0.5664, in Model 0.1181
# Underprod at time 261: Expected 0.5664, in Model 0.088
# Underprod at time 262: Expected 0.5664, in Model 0.0301
# Underprod at time 263: Expected 0.5664, in Model 0.0008
# Underprod at time 264: Expected 0.5664, in Model 0.0011
# Underprod at time 265: Expected 0.5664, in Model 0.0017
# Underprod at time 266: Expected 0.5664, in Model 0.0
# Underprod at time 267: Expected 0.5664, in Model 0.0
# Underprod at time 268: Expected 0.5664, in Model 0.0
# Underprod at time 269: Expected 0.5664, in Model 0.0
# Underprod at time 270: Expected 0.5664, in Model 0.0
# Underprod at time 271: Expected 0.5664, in Model 0.0
# Underprod at time 272: Expected 0.5664, in Model 0.0
# Underprod at time 273: Expected 0.5664, in Model 0.0
# Underprod at time 274: Expected 0.5664, in Model 0.0
# Underprod at time 275: Expected 0.5664, in Model 0.0
# Underprod at time 276: Expected 0.5664, in Model 0.0
# Underprod at time 277: Expected 0.5664, in Model 0.0
# Underprod at time 278: Expected 0.5664, in Model 0.0
# Underprod at time 279: Expected 0.5664, in Model 0.0
# Underprod at time 280: Expected 0.5664, in Model 0.0
# Underprod at time 281: Expected 0.5664, in Model 0.0
# Underprod at time 282: Expected 0.5664, in Model 0.0
# Underprod at time 283: Expected 0.5664, in Model 0.0
# Underprod at time 284: Expected 0.5664, in Model 0.0
# Underprod at time 285: Expected 0.5664, in Model 0.0
# Underprod at time 286: Expected 0.5664, in Model 0.0
# Underprod at time 287: Expected 0.5664, in Model 0.0
# Underprod at time 288: Expected 0.5664, in Model 0.0
# Underprod at time 289: Expected 0.5664, in Model 0.0
# Underprod at time 290: Expected 0.5664, in Model 0.0
# Underprod at time 291: Expected 0.5664, in Model 0.0
# Underprod at time 292: Expected 0.5664, in Model 0.0
# Underprod at time 293: Expected 0.5664, in Model 0.0
# Underprod at time 294: Expected 0.5664, in Model 0.0
# Underprod at time 295: Expected 0.5664, in Model 0.0
# Underprod at time 296: Expected 0.5664, in Model 0.0
# Underprod at time 297: Expected 0.5664, in Model 0.0034
# Underprod at time 298: Expected 0.5664, in Model 0.0219
# Underprod at time 299: Expected 0.5664, in Model 0.0451
# Underprod at time 300: Expected 0.5664, in Model 0.0649
# Underprod at time 301: Expected 0.5664, in Model 0.0345
# Underprod at time 302: Expected 0.5664, in Model 0.0435
# Underprod at time 303: Expected 0.5664, in Model 0.0226
# Underprod at time 304: Expected 0.5664, in Model 0.0185
# Underprod at time 305: Expected 0.5664, in Model 0.017
# Underprod at time 306: Expected 0.5664, in Model 0.0188
# Underprod at time 307: Expected 0.5664, in Model 0.089
# Underprod at time 308: Expected 0.5664, in Model 0.0
# Underprod at time 309: Expected 0.5664, in Model 0.0
# Underprod at time 310: Expected 0.5664, in Model 0.0
# Underprod at time 311: Expected 0.5664, in Model 0.0
# Underprod at time 312: Expected 0.5664, in Model 0.1142
# Underprod at time 313: Expected 0.5664, in Model 0.1142
# Underprod at time 314: Expected 0.5664, in Model 0.1142
# Underprod at time 315: Expected 0.5664, in Model 0.1142
# Underprod at time 316: Expected 0.5664, in Model 0.1142
# Underprod at time 317: Expected 0.5664, in Model 0.1142
# Underprod at time 318: Expected 0.5664, in Model 0.1142
# Underprod at time 319: Expected 0.5664, in Model 0.1142
# Underprod at time 320: Expected 0.5664, in Model 0.1142
# Underprod at time 321: Expected 0.5664, in Model 0.1142
# Underprod at time 322: Expected 0.5664, in Model 0.1142
# Underprod at time 323: Expected 0.5664, in Model 0.0
# Underprod at time 324: Expected 0.4533, in Model 0.0
# Underprod at time 325: Expected 0.5664, in Model 0.0
# Underprod at time 326: Expected 0.5664, in Model 0.0
# Underprod at time 327: Expected 0.5664, in Model 0.0
# Underprod at time 328: Expected 0.5664, in Model 0.0
# Underprod at time 329: Expected 0.5664, in Model 0.0431
# Underprod at time 330: Expected 0.5664, in Model 0.0947
# Underprod at time 331: Expected 0.5664, in Model 0.0724
# Underprod at time 332: Expected 0.5664, in Model 0.0126
# Underprod at time 333: Expected 0.5664, in Model 0.193
# Underprod at time 334: Expected 0.5664, in Model 0.4009
# Underprod at time 335: Expected 0.5664, in Model 0.5664
# Exactprod at time 336: Expected 0.5664, in Model 0.5664
# Underprod at time 337: Expected 0.5664, in Model 0.5664
# Exactprod at time 338: Expected 0.5664, in Model 0.5664
# Exactprod at time 339: Expected 0.5664, in Model 0.5664
# Exactprod at time 340: Expected 0.5664, in Model 0.5664
# Exactprod at time 341: Expected 0.5664, in Model 0.5664
# Exactprod at time 342: Expected 0.5664, in Model 0.5664
# Exactprod at time 343: Expected 0.5664, in Model 0.5664
# Exactprod at time 344: Expected 0.5664, in Model 0.5664
# Underprod at time 345: Expected 0.5664, in Model 0.5664
# Underprod at time 346: Expected 0.5664, in Model 0.5664
# Exactprod at time 347: Expected 0.5664, in Model 0.5664
# Underprod at time 348: Expected 0.5664, in Model 0.5664
# Exactprod at time 349: Expected 0.5664, in Model 0.5664
# Exactprod at time 350: Expected 0.5664, in Model 0.5664
# Exactprod at time 351: Expected 0.5664, in Model 0.5664
# Exactprod at time 352: Expected 0.5664, in Model 0.5664
# Exactprod at time 353: Expected 0.5664, in Model 0.5664
# Exactprod at time 354: Expected 0.5664, in Model 0.5664
# Underprod at time 355: Expected 0.5664, in Model 0.5664
# Exactprod at time 356: Expected 0.5664, in Model 0.5664
# Exactprod at time 357: Expected 0.5664, in Model 0.5664
# Exactprod at time 358: Expected 0.5664, in Model 0.5664
# Underprod at time 359: Expected 0.5664, in Model 0.5664
# Underprod at time 360: Expected 0.5025, in Model 0.5025
# Exactprod at time 361: Expected 0.5664, in Model 0.5664
# Exactprod at time 362: Expected 0.5664, in Model 0.5664
# Exactprod at time 363: Expected 0.5664, in Model 0.5664
# Underprod at time 364: Expected 0.5664, in Model 0.5664
# Exactprod at time 365: Expected 0.5664, in Model 0.5664
# Exactprod at time 366: Expected 0.5664, in Model 0.5664
# Exactprod at time 367: Expected 0.5664, in Model 0.5664
# Exactprod at time 368: Expected 0.5664, in Model 0.5664
# Exactprod at time 369: Expected 0.5664, in Model 0.5664
# Exactprod at time 370: Expected 0.5664, in Model 0.5664
# Exactprod at time 371: Expected 0.5664, in Model 0.5664
# Exactprod at time 372: Expected 0.5664, in Model 0.5664
# Exactprod at time 373: Expected 0.5664, in Model 0.5664
# Exactprod at time 374: Expected 0.5664, in Model 0.5664
# Underprod at time 375: Expected 0.4202, in Model 0.4202
# Exactprod at time 376: Expected 0.5664, in Model 0.5664
# Exactprod at time 377: Expected 0.5664, in Model 0.5664
# Exactprod at time 378: Expected 0.3734, in Model 0.3734
# Exactprod at time 379: Expected 0.5664, in Model 0.5664
# Underprod at time 380: Expected 0.5664, in Model 0.5664
# Underprod at time 381: Expected 0.373, in Model 0.373
# Underprod at time 382: Expected 0.5664, in Model 0.5664
# Exactprod at time 383: Expected 0.5664, in Model 0.5664
# Underprod at time 384: Expected 0.2481, in Model 0.2481
# Underprod at time 385: Expected 0.5664, in Model 0.5664
# Underprod at time 386: Expected 0.5664, in Model 0.5664
# Underprod at time 387: Expected 0.3775, in Model 0.3775
# Underprod at time 388: Expected 0.5664, in Model 0.2758
# Underprod at time 389: Expected 0.5664, in Model 0.1684
# Underprod at time 390: Expected 0.3222, in Model 0.0912
# Underprod at time 391: Expected 0.5664, in Model 0.0673
# Underprod at time 392: Expected 0.5664, in Model 0.0398
# Underprod at time 393: Expected 0.2454, in Model 0.0462
# Underprod at time 394: Expected 0.5664, in Model 0.0627
# Underprod at time 395: Expected 0.5664, in Model 0.0168
# Underprod at time 396: Expected 0.2579, in Model 0.0
# Underprod at time 397: Expected 0.5664, in Model 0.0
# Exactprod at time 398: Expected 0.5664, in Model 0.5664
# Underprod at time 399: Expected 0.3037, in Model 0.3037
# Exactprod at time 400: Expected 0.5664, in Model 0.5664
# Exactprod at time 401: Expected 0.5664, in Model 0.5664
# Exactprod at time 402: Expected 0.4395, in Model 0.4395
# Exactprod at time 403: Expected 0.5664, in Model 0.5664
# Exactprod at time 404: Expected 0.5664, in Model 0.5664
# Underprod at time 405: Expected 0.4989, in Model 0.4989
# Exactprod at time 406: Expected 0.5664, in Model 0.5664
# Exactprod at time 407: Expected 0.5664, in Model 0.5664
# Exactprod at time 408: Expected 0.5106, in Model 0.5106
# Exactprod at time 409: Expected 0.5664, in Model 0.5664
# Underprod at time 410: Expected 0.5664, in Model 0.1142
# Underprod at time 411: Expected 0.5664, in Model 0.1142
# Underprod at time 412: Expected 0.5664, in Model 0.1142
# Underprod at time 413: Expected 0.5664, in Model 0.1142
# Exactprod at time 414: Expected 0.5664, in Model 0.5664
# Underprod at time 415: Expected 0.5664, in Model 0.1142
# Underprod at time 416: Expected 0.5664, in Model 0.1142
# Underprod at time 417: Expected 0.5664, in Model 0.1142
# Underprod at time 418: Expected 0.5664, in Model 0.1142
# Underprod at time 419: Expected 0.5664, in Model 0.1143
# Underprod at time 420: Expected 0.5664, in Model 0.5069
# Underprod at time 421: Expected 0.5664, in Model 0.1202
# Underprod at time 422: Expected 0.5664, in Model 0.1142
# Underprod at time 423: Expected 0.5664, in Model 0.1142
# Underprod at time 424: Expected 0.5664, in Model 0.0
# Underprod at time 425: Expected 0.5664, in Model 0.0
# Exactprod at time 426: Expected 0.5664, in Model 0.5664
# Exactprod at time 427: Expected 0.5664, in Model 0.5664
# Exactprod at time 428: Expected 0.5664, in Model 0.5664
# Exactprod at time 429: Expected 0.5664, in Model 0.5664
# Exactprod at time 430: Expected 0.5664, in Model 0.5664
# Exactprod at time 431: Expected 0.5664, in Model 0.5664
# Underprod at time 432: Expected 0.5664, in Model 0.1142
# Underprod at time 433: Expected 0.5664, in Model 0.1142
# Underprod at time 434: Expected 0.5664, in Model 0.1142
# Underprod at time 435: Expected 0.5664, in Model 0.1142
# Underprod at time 436: Expected 0.5664, in Model 0.1143
# Underprod at time 437: Expected 0.5664, in Model 0.115
# Underprod at time 438: Expected 0.5664, in Model 0.1205
# Underprod at time 439: Expected 0.5664, in Model 0.1272
# Underprod at time 440: Expected 0.5664, in Model 0.2206
# Underprod at time 441: Expected 0.5664, in Model 0.395
# Exactprod at time 442: Expected 0.5664, in Model 0.5664
# Underprod at time 443: Expected 0.5664, in Model 0.5664
# Underprod at time 444: Expected 0.5664, in Model 0.5664
# Exactprod at time 445: Expected 0.5664, in Model 0.5664
# Underprod at time 446: Expected 0.5664, in Model 0.4064
# Underprod at time 447: Expected 0.5664, in Model 0.2102
# Underprod at time 448: Expected 0.5664, in Model 0.3134
# Underprod at time 449: Expected 0.5664, in Model 0.1661
# Underprod at time 450: Expected 0.5664, in Model 0.1985
# Underprod at time 451: Expected 0.5664, in Model 0.0
# Underprod at time 452: Expected 0.5664, in Model 0.0
# Underprod at time 453: Expected 0.5664, in Model 0.0
# Underprod at time 454: Expected 0.5664, in Model 0.0
# Underprod at time 455: Expected 0.5664, in Model 0.0
# Underprod at time 456: Expected 0.5664, in Model 0.1149
# Underprod at time 457: Expected 0.5664, in Model 0.1142
# Underprod at time 458: Expected 0.5664, in Model 0.1528
# Underprod at time 459: Expected 0.5664, in Model 0.2221
# Underprod at time 460: Expected 0.5664, in Model 0.2766
# Underprod at time 461: Expected 0.5664, in Model 0.4388
# Exactprod at time 462: Expected 0.4873, in Model 0.4873
# Underprod at time 463: Expected 0.5664, in Model 0.4064
# Underprod at time 464: Expected 0.5664, in Model 0.2729
# Underprod at time 465: Expected 0.4085, in Model 0.1661
# Underprod at time 466: Expected 0.5664, in Model 0.0891
# Underprod at time 467: Expected 0.5664, in Model 0.0206
# Underprod at time 468: Expected 0.4968, in Model 0.0
# Underprod at time 469: Expected 0.5664, in Model 0.0145
# Underprod at time 470: Expected 0.5664, in Model 0.0426
# Underprod at time 471: Expected 0.2902, in Model 0.132
# Underprod at time 472: Expected 0.5664, in Model 0.4436
# Exactprod at time 473: Expected 0.5664, in Model 0.5664
# Underprod at time 474: Expected 0.4255, in Model 0.4255
# Exactprod at time 475: Expected 0.5664, in Model 0.5664
# Exactprod at time 476: Expected 0.5664, in Model 0.5664
# Underprod at time 477: Expected 0.3584, in Model 0.3584
# Underprod at time 478: Expected 0.5664, in Model 0.5664
# Exactprod at time 479: Expected 0.5664, in Model 0.5664
# Underprod at time 480: Expected 0.2847, in Model 0.2847
# Exactprod at time 481: Expected 0.5664, in Model 0.5664
# Exactprod at time 482: Expected 0.5664, in Model 0.5664
# Underprod at time 483: Expected 0.2264, in Model 0.2264
# Exactprod at time 484: Expected 0.5664, in Model 0.5664
# Underprod at time 485: Expected 0.5664, in Model 0.0
# Underprod at time 486: Expected 0.2851, in Model 0.0
# Underprod at time 487: Expected 0.5664, in Model 0.0
# Underprod at time 488: Expected 0.5664, in Model 0.0
# Underprod at time 489: Expected 0.3442, in Model 0.0411
# Underprod at time 490: Expected 0.5664, in Model 0.2225
# Underprod at time 491: Expected 0.5664, in Model 0.1146
# Underprod at time 492: Expected 0.5664, in Model 0.0019
# Underprod at time 493: Expected 0.5664, in Model 0.0
# Underprod at time 494: Expected 0.5664, in Model 0.0
# Underprod at time 495: Expected 0.5664, in Model 0.0
# Underprod at time 496: Expected 0.5664, in Model 0.0
# Underprod at time 497: Expected 0.5664, in Model 0.0
# Underprod at time 498: Expected 0.5664, in Model 0.0
# Underprod at time 499: Expected 0.5664, in Model 0.0006
# Underprod at time 500: Expected 0.5664, in Model 0.0024
# Underprod at time 501: Expected 0.5664, in Model 0.0545
# Underprod at time 502: Expected 0.5664, in Model 0.1468
# Exactprod at time 503: Expected 0.5664, in Model 0.5664
# Underprod at time 504: Expected 0.5664, in Model 0.0
# Underprod at time 505: Expected 0.5664, in Model 0.0165
# Underprod at time 506: Expected 0.5664, in Model 0.0755
# Underprod at time 507: Expected 0.5664, in Model 0.11
# Underprod at time 508: Expected 0.5664, in Model 0.1142
# Underprod at time 509: Expected 0.5664, in Model 0.0
# Underprod at time 510: Expected 0.5664, in Model 0.0
# Underprod at time 511: Expected 0.5664, in Model 0.0
# Underprod at time 512: Expected 0.5664, in Model 0.0
# Underprod at time 513: Expected 0.5664, in Model 0.1142
# Underprod at time 514: Expected 0.5664, in Model 0.1142
# Underprod at time 515: Expected 0.5664, in Model 0.1142
# Underprod at time 516: Expected 0.5664, in Model 0.1142
# Underprod at time 517: Expected 0.5664, in Model 0.1142
# Underprod at time 518: Expected 0.5664, in Model 0.1142
# Underprod at time 519: Expected 0.5664, in Model 0.1142
# Underprod at time 520: Expected 0.5664, in Model 0.1142
# Underprod at time 521: Expected 0.5664, in Model 0.1142
# Underprod at time 522: Expected 0.4641, in Model 0.1142
# Underprod at time 523: Expected 0.5664, in Model 0.1142
# Underprod at time 524: Expected 0.5664, in Model 0.1142
# Underprod at time 525: Expected 0.3513, in Model 0.1142
# Underprod at time 526: Expected 0.5664, in Model 0.1142
# Underprod at time 527: Expected 0.5664, in Model 0.1147
# Underprod at time 528: Expected 0.2492, in Model 0.1142
# Underprod at time 529: Expected 0.5664, in Model 0.1663
# Underprod at time 530: Expected 0.5664, in Model 0.3196
# Underprod at time 531: Expected 0.1727, in Model 0.1727
# Underprod at time 532: Expected 0.5664, in Model 0.5664
# Exactprod at time 533: Expected 0.5664, in Model 0.5664
# Underprod at time 534: Expected 0.117, in Model 0.117
# Exactprod at time 535: Expected 0.5664, in Model 0.5664
# Exactprod at time 536: Expected 0.5664, in Model 0.5664
# Underprod at time 537: Expected 0.0436, in Model 0.0436
# Exactprod at time 538: Expected 0.5664, in Model 0.5664
# Exactprod at time 539: Expected 0.5664, in Model 0.5664
# Underprod at time 540: Expected 0.063, in Model 0.063
# Exactprod at time 541: Expected 0.5664, in Model 0.5664
# Exactprod at time 542: Expected 0.5664, in Model 0.5664
# Underprod at time 543: Expected 0.3823, in Model 0.3823
# Exactprod at time 544: Expected 0.5664, in Model 0.5664
# Exactprod at time 545: Expected 0.5664, in Model 0.5664
# Exactprod at time 546: Expected 0.3519, in Model 0.3519
# Exactprod at time 547: Expected 0.5664, in Model 0.5664
# Exactprod at time 548: Expected 0.5664, in Model 0.5664
# Exactprod at time 549: Expected 0.2221, in Model 0.2221
# Underprod at time 550: Expected 0.5664, in Model 0.5664
# Exactprod at time 551: Expected 0.5664, in Model 0.5664
# Underprod at time 552: Expected 0.1552, in Model 0.1552
# Exactprod at time 553: Expected 0.5664, in Model 0.5664
# Underprod at time 554: Expected 0.5664, in Model 0.5664
# Exactprod at time 555: Expected 0.0966, in Model 0.0966
# Exactprod at time 556: Expected 0.5664, in Model 0.5664
# Exactprod at time 557: Expected 0.5664, in Model 0.5664
# Exactprod at time 558: Expected 0.1167, in Model 0.1167
# Underprod at time 559: Expected 0.5664, in Model 0.5664
# Underprod at time 560: Expected 0.5664, in Model 0.5664
# Underprod at time 561: Expected 0.0832, in Model 0.0832
# Exactprod at time 562: Expected 0.5664, in Model 0.5664
# Exactprod at time 563: Expected 0.5664, in Model 0.5664
# Underprod at time 564: Expected 0.1772, in Model 0.1772
# Exactprod at time 565: Expected 0.5664, in Model 0.5664
# Exactprod at time 566: Expected 0.5664, in Model 0.5664
# Underprod at time 567: Expected 0.3809, in Model 0.3809
# Underprod at time 568: Expected 0.5664, in Model 0.44
# Underprod at time 569: Expected 0.5664, in Model 0.225
# Underprod at time 570: Expected 0.5664, in Model 0.1157
# Underprod at time 571: Expected 0.5664, in Model 0.1059
# Underprod at time 572: Expected 0.5664, in Model 0.0803
# Underprod at time 573: Expected 0.5664, in Model 0.0525
# Underprod at time 574: Expected 0.5664, in Model 0.0225
# Underprod at time 575: Expected 0.5664, in Model 0.0104
# Underprod at time 576: Expected 0.5664, in Model 0.0015
# Underprod at time 577: Expected 0.5664, in Model 0.0003
# Underprod at time 578: Expected 0.5664, in Model 0.0039
# Underprod at time 579: Expected 0.5664, in Model 0.0651
# Underprod at time 580: Expected 0.5664, in Model 0.1561
# Underprod at time 581: Expected 0.5664, in Model 0.3754
# Underprod at time 582: Expected 0.5664, in Model 0.5664
# Underprod at time 583: Expected 0.5664, in Model 0.5664
# Exactprod at time 584: Expected 0.5664, in Model 0.5664
# Exactprod at time 585: Expected 0.5664, in Model 0.5664
# Exactprod at time 586: Expected 0.5664, in Model 0.5664
# Exactprod at time 587: Expected 0.5664, in Model 0.5664
# Underprod at time 588: Expected 0.4971, in Model 0.4971
# Exactprod at time 589: Expected 0.5664, in Model 0.5664
# Exactprod at time 590: Expected 0.5664, in Model 0.5664
# Underprod at time 591: Expected 0.3698, in Model 0.3698
# Exactprod at time 592: Expected 0.5664, in Model 0.5664
# Exactprod at time 593: Expected 0.5664, in Model 0.5664
# Exactprod at time 594: Expected 0.5664, in Model 0.5664
# Exactprod at time 595: Expected 0.5664, in Model 0.5664
# Underprod at time 596: Expected 0.5664, in Model 0.1718
# Underprod at time 597: Expected 0.5664, in Model 0.0633
# Underprod at time 598: Expected 0.5664, in Model 0.0
# Underprod at time 599: Expected 0.5664, in Model 0.0
# Underprod at time 600: Expected 0.5012, in Model 0.0
# Underprod at time 601: Expected 0.5664, in Model 0.0
# Underprod at time 602: Expected 0.5664, in Model 0.0
# Underprod at time 603: Expected 0.4305, in Model 0.0
# Exactprod at time 604: Expected 0.5664, in Model 0.5664
# Exactprod at time 605: Expected 0.5664, in Model 0.5664
# Exactprod at time 606: Expected 0.5664, in Model 0.5664
# Exactprod at time 607: Expected 0.5664, in Model 0.5664
# Exactprod at time 608: Expected 0.5664, in Model 0.5664
# Exactprod at time 609: Expected 0.5664, in Model 0.5664
# Exactprod at time 610: Expected 0.5664, in Model 0.5664
# Exactprod at time 611: Expected 0.5664, in Model 0.5664
# Exactprod at time 612: Expected 0.5664, in Model 0.5664
# Underprod at time 613: Expected 0.5664, in Model 0.0015
# Underprod at time 614: Expected 0.5664, in Model 0.0293
# Underprod at time 615: Expected 0.5664, in Model 0.0362
# Underprod at time 616: Expected 0.5664, in Model 0.0102
# Underprod at time 617: Expected 0.5664, in Model 0.0001
# Underprod at time 618: Expected 0.5664, in Model 0.0
# Underprod at time 619: Expected 0.5664, in Model 0.0
# Underprod at time 620: Expected 0.5664, in Model 0.0
# Underprod at time 621: Expected 0.5664, in Model 0.0
# Underprod at time 622: Expected 0.5664, in Model 0.0145
# Exactprod at time 623: Expected 0.5664, in Model 0.5664
# Exactprod at time 624: Expected 0.5664, in Model 0.5664
# Underprod at time 625: Expected 0.5664, in Model 0.0
# Exactprod at time 626: Expected 0.5664, in Model 0.5664
# Exactprod at time 627: Expected 0.5664, in Model 0.5664
# Exactprod at time 628: Expected 0.5664, in Model 0.5664
# Exactprod at time 629: Expected 0.5664, in Model 0.5664
# Exactprod at time 630: Expected 0.5664, in Model 0.5664
# Exactprod at time 631: Expected 0.5664, in Model 0.5664
# Underprod at time 632: Expected 0.5664, in Model 0.1142
# Underprod at time 633: Expected 0.5664, in Model 0.1142
# Underprod at time 634: Expected 0.5664, in Model 0.1142
# Underprod at time 635: Expected 0.5664, in Model 0.1142
# Underprod at time 636: Expected 0.5664, in Model 0.1142
# Underprod at time 637: Expected 0.5664, in Model 0.1142
# Underprod at time 638: Expected 0.5664, in Model 0.1142
# Underprod at time 639: Expected 0.5664, in Model 0.1142
# Underprod at time 640: Expected 0.5664, in Model 0.1143
# Underprod at time 641: Expected 0.5664, in Model 0.1142
# Underprod at time 642: Expected 0.5664, in Model 0.1142
# Underprod at time 643: Expected 0.5664, in Model 0.1142
# Underprod at time 644: Expected 0.5664, in Model 0.1142
# Underprod at time 645: Expected 0.5664, in Model 0.1142
# Underprod at time 646: Expected 0.5664, in Model 0.0
# Underprod at time 647: Expected 0.5664, in Model 0.0
# Underprod at time 648: Expected 0.5664, in Model 0.1142
# Underprod at time 649: Expected 0.5664, in Model 0.0
# Underprod at time 650: Expected 0.5664, in Model 0.0
# Underprod at time 651: Expected 0.5664, in Model 0.0
# Underprod at time 652: Expected 0.5664, in Model 0.0
# Underprod at time 653: Expected 0.5664, in Model 0.0
# Underprod at time 654: Expected 0.5664, in Model 0.1149
# Underprod at time 655: Expected 0.5664, in Model 0.0436
# Underprod at time 656: Expected 0.5664, in Model 0.4708
# Underprod at time 657: Expected 0.5664, in Model 0.5664
# Exactprod at time 658: Expected 0.5664, in Model 0.5664
# Exactprod at time 659: Expected 0.5664, in Model 0.5664
# Underprod at time 660: Expected 0.5664, in Model 0.4096
# Underprod at time 661: Expected 0.5664, in Model 0.1939
# Underprod at time 662: Expected 0.5664, in Model 0.0554
# Underprod at time 663: Expected 0.467, in Model 0.0156
# Underprod at time 664: Expected 0.5664, in Model 0.0
# Underprod at time 665: Expected 0.5664, in Model 0.0
# Underprod at time 666: Expected 0.3806, in Model 0.0
# Underprod at time 667: Expected 0.5664, in Model 0.0
# Underprod at time 668: Expected 0.5664, in Model 0.0
# Underprod at time 669: Expected 0.5664, in Model 0.0
# Underprod at time 670: Expected 0.5664, in Model 0.0
# Underprod at time 671: Expected 0.5664, in Model 0.0
# Underprod at time 672: Expected 0.5664, in Model 0.0
# Underprod at time 673: Expected 0.5664, in Model 0.0
# Underprod at time 674: Expected 0.5664, in Model 0.0192
# Underprod at time 675: Expected 0.5185, in Model 0.0863
# Underprod at time 676: Expected 0.5664, in Model 0.1116
# Underprod at time 677: Expected 0.5664, in Model 0.3262
# Underprod at time 678: Expected 0.2959, in Model 0.2959
# Exactprod at time 679: Expected 0.5664, in Model 0.5664
# Exactprod at time 680: Expected 0.5664, in Model 0.5664
# Underprod at time 681: Expected 0.2088, in Model 0.2088
# Exactprod at time 682: Expected 0.5664, in Model 0.5664
# Exactprod at time 683: Expected 0.5664, in Model 0.5664
# Overprod at time 684: Expected 0.138, in Model 0.138
# Underprod at time 685: Expected 0.5664, in Model 0.5664
# Underprod at time 686: Expected 0.5664, in Model 0.5664
# Exactprod at time 687: Expected 0.3882, in Model 0.3882
# Exactprod at time 688: Expected 0.5664, in Model 0.5664
# Exactprod at time 689: Expected 0.5664, in Model 0.5664
# Exactprod at time 690: Expected 0.5664, in Model 0.5664
# Exactprod at time 691: Expected 0.5664, in Model 0.5664
# Exactprod at time 692: Expected 0.5664, in Model 0.5664
# Exactprod at time 693: Expected 0.5664, in Model 0.5664
# Exactprod at time 694: Expected 0.5664, in Model 0.5664
# Exactprod at time 695: Expected 0.5664, in Model 0.5664
# Underprod at time 696: Expected 0.5664, in Model 0.5664
# Exactprod at time 697: Expected 0.5664, in Model 0.5664
# Exactprod at time 698: Expected 0.5664, in Model 0.5664
# Exactprod at time 699: Expected 0.5664, in Model 0.5664
# Exactprod at time 700: Expected 0.5664, in Model 0.5664
# Exactprod at time 701: Expected 0.5664, in Model 0.5664
# Exactprod at time 702: Expected 0.5664, in Model 0.5664
# Exactprod at time 703: Expected 0.5664, in Model 0.5664
# Exactprod at time 704: Expected 0.5664, in Model 0.5664
# Exactprod at time 705: Expected 0.5664, in Model 0.5664
# Exactprod at time 706: Expected 0.5664, in Model 0.5664
# Exactprod at time 707: Expected 0.5664, in Model 0.5664
# Exactprod at time 708: Expected 0.5664, in Model 0.5664
# Exactprod at time 709: Expected 0.5664, in Model 0.5664
# Exactprod at time 710: Expected 0.5664, in Model 0.5664
# Exactprod at time 711: Expected 0.5664, in Model 0.5664
# Exactprod at time 712: Expected 0.5664, in Model 0.5664
# Exactprod at time 713: Expected 0.5664, in Model 0.5664
# Exactprod at time 714: Expected 0.5664, in Model 0.5664
# Exactprod at time 715: Expected 0.5664, in Model 0.5664
# Exactprod at time 716: Expected 0.5664, in Model 0.5664
# Overprod at time 717: Expected 0.4824, in Model 0.4824
# Exactprod at time 718: Expected 0.5664, in Model 0.5664
# Exactprod at time 719: Expected 0.5664, in Model 0.5664
# Exactprod at time 720: Expected 0.5664, in Model 0.5664
# Exactprod at time 721: Expected 0.5664, in Model 0.5664
# Exactprod at time 722: Expected 0.5664, in Model 0.5664
# Exactprod at time 723: Expected 0.5664, in Model 0.5664
# Exactprod at time 724: Expected 0.5664, in Model 0.5664
# Exactprod at time 725: Expected 0.5664, in Model 0.5664
# Exactprod at time 726: Expected 0.5664, in Model 0.5664
# Exactprod at time 727: Expected 0.5664, in Model 0.5664
# Exactprod at time 728: Expected 0.5664, in Model 0.5664
# Exactprod at time 729: Expected 0.5664, in Model 0.5664
# Exactprod at time 730: Expected 0.5664, in Model 0.5664
# Exactprod at time 731: Expected 0.5664, in Model 0.5664
# Exactprod at time 732: Expected 0.5664, in Model 0.5664
# Exactprod at time 733: Expected 0.5664, in Model 0.5664
# Exactprod at time 734: Expected 0.5664, in Model 0.5664
# Underprod at time 735: Expected 0.4572, in Model 0.4572
# Exactprod at time 736: Expected 0.5664, in Model 0.5664
# Exactprod at time 737: Expected 0.5664, in Model 0.5664
# Exactprod at time 738: Expected 0.3166, in Model 0.3166
# Underprod at time 739: Expected 0.5664, in Model 0.2504
# Underprod at time 740: Expected 0.5664, in Model 0.1915
# Underprod at time 741: Expected 0.345, in Model 0.2092
# Underprod at time 742: Expected 0.5664, in Model 0.2266
# Underprod at time 743: Expected 0.5664, in Model 0.2372
# Underprod at time 744: Expected 0.4796, in Model 0.2719
# Underprod at time 745: Expected 0.5664, in Model 0.2628
# Underprod at time 746: Expected 0.5664, in Model 0.3037
# Underprod at time 747: Expected 0.4831, in Model 0.3021
# Underprod at time 748: Expected 0.5664, in Model 0.295
# Underprod at time 749: Expected 0.5664, in Model 0.2333
# Underprod at time 750: Expected 0.4659, in Model 0.2145
# Underprod at time 751: Expected 0.5664, in Model 0.2856
# Underprod at time 752: Expected 0.5664, in Model 0.5192
# Underprod at time 753: Expected 0.4231, in Model 0.4231
# Exactprod at time 754: Expected 0.5664, in Model 0.5664
# Exactprod at time 755: Expected 0.5664, in Model 0.5664
# Underprod at time 756: Expected 0.4646, in Model 0.4646
# Exactprod at time 757: Expected 0.5664, in Model 0.5664
# Exactprod at time 758: Expected 0.5664, in Model 0.5664
# Exactprod at time 759: Expected 0.515, in Model 0.515
# Exactprod at time 760: Expected 0.5664, in Model 0.5664
# Exactprod at time 761: Expected 0.5664, in Model 0.5664
# Exactprod at time 762: Expected 0.5251, in Model 0.5251
# Exactprod at time 763: Expected 0.5664, in Model 0.5664
# Underprod at time 764: Expected 0.5664, in Model 0.1503
# Underprod at time 765: Expected 0.5086, in Model 0.0001
# Underprod at time 766: Expected 0.5664, in Model 0.0
# Underprod at time 767: Expected 0.5664, in Model 0.0
# Underprod at time 768: Expected 0.4286, in Model 0.0
# Underprod at time 769: Expected 0.5664, in Model 0.0
# Underprod at time 770: Expected 0.5664, in Model 0.0
# Underprod at time 771: Expected 0.3698, in Model 0.0
# Underprod at time 772: Expected 0.5664, in Model 0.0
# Underprod at time 773: Expected 0.5664, in Model 0.0
# Underprod at time 774: Expected 0.5089, in Model 0.1142
# Underprod at time 775: Expected 0.5664, in Model 0.1142
# Underprod at time 776: Expected 0.5664, in Model 0.1142
# Underprod at time 777: Expected 0.5664, in Model 0.1142
# Underprod at time 778: Expected 0.5664, in Model 0.1142
# Exactprod at time 779: Expected 0.5664, in Model 0.5664
# Exactprod at time 780: Expected 0.5664, in Model 0.5664
# Exactprod at time 781: Expected 0.5664, in Model 0.5664
# Exactprod at time 782: Expected 0.5664, in Model 0.5664
# Exactprod at time 783: Expected 0.5664, in Model 0.5664
# Exactprod at time 784: Expected 0.5664, in Model 0.5664
# Exactprod at time 785: Expected 0.5664, in Model 0.5664
# Exactprod at time 786: Expected 0.5664, in Model 0.5664
# Exactprod at time 787: Expected 0.5664, in Model 0.5664
# Exactprod at time 788: Expected 0.5664, in Model 0.5664
# Exactprod at time 789: Expected 0.5664, in Model 0.5664
# Exactprod at time 790: Expected 0.5664, in Model 0.5664
# Exactprod at time 791: Expected 0.5664, in Model 0.5664
# Exactprod at time 792: Expected 0.5664, in Model 0.5664
# Exactprod at time 793: Expected 0.5664, in Model 0.5664
# Exactprod at time 794: Expected 0.5664, in Model 0.5664
# Exactprod at time 795: Expected 0.5664, in Model 0.5664
# Underprod at time 796: Expected 0.5664, in Model 0.0177
# Underprod at time 797: Expected 0.5664, in Model 0.0002
# Underprod at time 798: Expected 0.5664, in Model 0.0
# Underprod at time 799: Expected 0.5664, in Model 0.4455
# Exactprod at time 800: Expected 0.5664, in Model 0.5664
# Underprod at time 801: Expected 0.5664, in Model 0.5664
# Exactprod at time 802: Expected 0.5664, in Model 0.5664
# Underprod at time 803: Expected 0.5664, in Model 0.5664
# Underprod at time 804: Expected 0.5664, in Model 0.4837
# Underprod at time 805: Expected 0.5664, in Model 0.5382
# Exactprod at time 806: Expected 0.5664, in Model 0.5664
# Exactprod at time 807: Expected 0.5664, in Model 0.5664
# Exactprod at time 808: Expected 0.5664, in Model 0.5664
# Exactprod at time 809: Expected 0.5664, in Model 0.5664
# Underprod at time 810: Expected 0.5664, in Model 0.5664
# Exactprod at time 811: Expected 0.5664, in Model 0.5664
# Exactprod at time 812: Expected 0.5664, in Model 0.5664
# Exactprod at time 813: Expected 0.5664, in Model 0.5664
# Exactprod at time 814: Expected 0.5664, in Model 0.5664
# Underprod at time 815: Expected 0.5664, in Model 0.5664
# Underprod at time 816: Expected 0.5664, in Model 0.1136
# Underprod at time 817: Expected 0.5664, in Model 0.0689
# Underprod at time 818: Expected 0.5664, in Model 0.068
# Underprod at time 819: Expected 0.5664, in Model 0.0329
# Underprod at time 820: Expected 0.5664, in Model 0.0015
# Exactprod at time 821: Expected 0.5664, in Model 0.5664
# Exactprod at time 822: Expected 0.1451, in Model 0.1451
# Underprod at time 823: Expected 0.5664, in Model 0.0
# Underprod at time 824: Expected 0.5664, in Model 0.0
# Underprod at time 825: Expected 0.1724, in Model 0.0
# Underprod at time 826: Expected 0.5664, in Model 0.0
# Underprod at time 827: Expected 0.5664, in Model 0.0
# Underprod at time 828: Expected 0.5664, in Model 0.0
# Underprod at time 829: Expected 0.5664, in Model 0.0
# Underprod at time 830: Expected 0.5664, in Model 0.0
# Underprod at time 831: Expected 0.5664, in Model 0.0
# Underprod at time 832: Expected 0.5664, in Model 0.0
# Underprod at time 833: Expected 0.5664, in Model 0.0
# Underprod at time 834: Expected 0.5664, in Model 0.1209
# Exactprod at time 835: Expected 0.5664, in Model 0.5664
# Exactprod at time 836: Expected 0.5664, in Model 0.5664
# Exactprod at time 837: Expected 0.5664, in Model 0.5664
# Exactprod at time 838: Expected 0.5664, in Model 0.5664
# Exactprod at time 839: Expected 0.5664, in Model 0.5664
# Exactprod at time 840: Expected 0.5664, in Model 0.5664
# Underprod at time 841: Expected 0.5664, in Model 0.4078
# Underprod at time 842: Expected 0.5664, in Model 0.5664
# Exactprod at time 843: Expected 0.5664, in Model 0.5664
# Exactprod at time 844: Expected 0.5664, in Model 0.5664
# Exactprod at time 845: Expected 0.5664, in Model 0.5664
# Exactprod at time 846: Expected 0.5664, in Model 0.5664
# Exactprod at time 847: Expected 0.5664, in Model 0.5664
# Underprod at time 848: Expected 0.5664, in Model 0.5329
# Underprod at time 849: Expected 0.5664, in Model 0.5664
# Exactprod at time 850: Expected 0.5664, in Model 0.5664
# Exactprod at time 851: Expected 0.5664, in Model 0.5664
# Underprod at time 852: Expected 0.5664, in Model 0.5664
# Exactprod at time 853: Expected 0.5664, in Model 0.5664
# Underprod at time 854: Expected 0.5664, in Model 0.0037
# Underprod at time 855: Expected 0.1841, in Model 0.0
# Underprod at time 856: Expected 0.5664, in Model 0.0
# Underprod at time 857: Expected 0.5664, in Model 0.0
# Underprod at time 858: Expected 0.5664, in Model 0.0
# Underprod at time 859: Expected 0.5664, in Model 0.1146
# Underprod at time 860: Expected 0.5664, in Model 0.5664
# Exactprod at time 861: Expected 0.5664, in Model 0.5664
# Exactprod at time 862: Expected 0.5664, in Model 0.5664
# Exactprod at time 863: Expected 0.5664, in Model 0.5664
# Exactprod at time 864: Expected 0.2815, in Model 0.2815
# Exactprod at time 865: Expected 0.5664, in Model 0.5664
# Exactprod at time 866: Expected 0.5664, in Model 0.5664
# Exactprod at time 867: Expected 0.2625, in Model 0.2625
# ...
# Underprod at time 17266: Expected 0.5664, in Model 0.1142
# Underprod at time 17267: Expected 0.5664, in Model 0.1142
# Underprod at time 17268: Expected 0.5664, in Model 0.1143
# Underprod at time 17269: Expected 0.5664, in Model 0.1142
# Underprod at time 17270: Expected 0.5664, in Model 0.1142
# Underprod at time 17271: Expected 0.5664, in Model 0.1142
# Underprod at time 17272: Expected 0.5664, in Model 0.1142
# Underprod at time 17273: Expected 0.5664, in Model 0.115
# Underprod at time 17274: Expected 0.5664, in Model 0.1149
# Underprod at time 17275: Expected 0.5664, in Model 0.1142
# Underprod at time 17276: Expected 0.5664, in Model 0.1142
# Underprod at time 17277: Expected 0.5664, in Model 0.17
# Underprod at time 17278: Expected 0.5664, in Model 0.3701
# Underprod at time 17279: Expected 0.5664, in Model 0.3866
# Underprod at time 17280: Expected 0.5664, in Model 0.115
# Underprod at time 17281: Expected 0.5664, in Model 0.1142
# Underprod at time 17282: Expected 0.5664, in Model 0.1142
# Underprod at time 17283: Expected 0.5664, in Model 0.1142
# Underprod at time 17284: Expected 0.5664, in Model 0.1149
# Underprod at time 17285: Expected 0.5664, in Model 0.1853
# Underprod at time 17286: Expected 0.5664, in Model 0.1184
# Underprod at time 17287: Expected 0.5664, in Model 0.1778
# Underprod at time 17288: Expected 0.5664, in Model 0.454
# Underprod at time 17289: Expected 0.5637, in Model 0.5614
# Underprod at time 17290: Expected 0.5664, in Model 0.3866
# Underprod at time 17291: Expected 0.5664, in Model 0.5517
# Overprod at time 17292: Expected 0.3927, in Model 0.3927
# Underprod at time 17293: Expected 0.5664, in Model 0.3811
# Underprod at time 17294: Expected 0.5664, in Model 0.1894
# Underprod at time 17295: Expected 0.2209, in Model 0.185
# Underprod at time 17296: Expected 0.5664, in Model 0.2483
# Underprod at time 17297: Expected 0.5664, in Model 0.3016
# Underprod at time 17298: Expected 0.2144, in Model 0.2144
# Underprod at time 17299: Expected 0.5664, in Model 0.29
# Underprod at time 17300: Expected 0.5664, in Model 0.3497
# Underprod at time 17301: Expected 0.5337, in Model 0.4128
# Underprod at time 17302: Expected 0.5664, in Model 0.4578
# Exactprod at time 17303: Expected 0.5664, in Model 0.5664
# Exactprod at time 17304: Expected 0.47, in Model 0.47
# Exactprod at time 17305: Expected 0.5664, in Model 0.5664
# Exactprod at time 17306: Expected 0.5664, in Model 0.5664
# Exactprod at time 17307: Expected 0.4487, in Model 0.4487
# Underprod at time 17308: Expected 0.5664, in Model 0.5664
# Exactprod at time 17309: Expected 0.5664, in Model 0.5664
# Exactprod at time 17310: Expected 0.5664, in Model 0.5664
# Underprod at time 17311: Expected 0.5664, in Model 0.5664
# Exactprod at time 17312: Expected 0.5664, in Model 0.5664
# Underprod at time 17313: Expected 0.5664, in Model 0.5664
# Exactprod at time 17314: Expected 0.5664, in Model 0.5664
# Underprod at time 17315: Expected 0.5664, in Model 0.5664
# Exactprod at time 17316: Expected 0.5062, in Model 0.5062
# Exactprod at time 17317: Expected 0.5664, in Model 0.5664
# Exactprod at time 17318: Expected 0.5664, in Model 0.5664
# Underprod at time 17319: Expected 0.2241, in Model 0.2241
# Exactprod at time 17320: Expected 0.5664, in Model 0.5664
# Exactprod at time 17321: Expected 0.5664, in Model 0.5664
# Exactprod at time 17322: Expected 0.3181, in Model 0.3181
# Exactprod at time 17323: Expected 0.5664, in Model 0.5664
# Exactprod at time 17324: Expected 0.5664, in Model 0.5664
# Overprod at time 17325: Expected 0.3507, in Model 0.3507
# Exactprod at time 17326: Expected 0.5664, in Model 0.5664
# Exactprod at time 17327: Expected 0.5664, in Model 0.5664
# Underprod at time 17328: Expected 0.3159, in Model 0.3159
# Underprod at time 17329: Expected 0.5664, in Model 0.5664
# Exactprod at time 17330: Expected 0.5664, in Model 0.5664
# Exactprod at time 17331: Expected 0.2506, in Model 0.2506
# Exactprod at time 17332: Expected 0.5664, in Model 0.5664
# Underprod at time 17333: Expected 0.5664, in Model 0.5664
# Exactprod at time 17334: Expected 0.2059, in Model 0.2059
# Exactprod at time 17335: Expected 0.5664, in Model 0.5664
# Exactprod at time 17336: Expected 0.5664, in Model 0.5664
# Overprod at time 17337: Expected 0.1948, in Model 0.1948
# Exactprod at time 17338: Expected 0.5664, in Model 0.5664
# Exactprod at time 17339: Expected 0.5664, in Model 0.5664
# Underprod at time 17340: Expected 0.2221, in Model 0.2221
# Exactprod at time 17341: Expected 0.5664, in Model 0.5664
# Exactprod at time 17342: Expected 0.5664, in Model 0.5664
# Overprod at time 17343: Expected 0.1589, in Model 0.1589
# Exactprod at time 17344: Expected 0.5664, in Model 0.5664
# Exactprod at time 17345: Expected 0.5664, in Model 0.5664
# Underprod at time 17346: Expected 0.4669, in Model 0.4669
# Exactprod at time 17347: Expected 0.5664, in Model 0.5664
# Exactprod at time 17348: Expected 0.5664, in Model 0.5664
# Exactprod at time 17349: Expected 0.5664, in Model 0.5664
# Exactprod at time 17350: Expected 0.5664, in Model 0.5664
# Exactprod at time 17351: Expected 0.5664, in Model 0.5664
# Exactprod at time 17352: Expected 0.5553, in Model 0.5553
# Underprod at time 17353: Expected 0.5664, in Model 0.5664
# Exactprod at time 17354: Expected 0.5664, in Model 0.5664
# Underprod at time 17355: Expected 0.3849, in Model 0.3849
# Exactprod at time 17356: Expected 0.5664, in Model 0.5664
# Exactprod at time 17357: Expected 0.5664, in Model 0.5664
# Underprod at time 17358: Expected 0.3022, in Model 0.3022
# Exactprod at time 17359: Expected 0.5664, in Model 0.5664
# Underprod at time 17360: Expected 0.5664, in Model 0.4804
# Underprod at time 17361: Expected 0.2768, in Model 0.2378
# Underprod at time 17362: Expected 0.5664, in Model 0.084
# Underprod at time 17363: Expected 0.5664, in Model 0.0
# Underprod at time 17364: Expected 0.1253, in Model 0.0
# Underprod at time 17365: Expected 0.5664, in Model 0.0
# Underprod at time 17366: Expected 0.5664, in Model 0.0
# Underprod at time 17367: Expected 0.1457, in Model 0.0
# Underprod at time 17368: Expected 0.5664, in Model 0.0
# Underprod at time 17369: Expected 0.5664, in Model 0.0
# Underprod at time 17370: Expected 0.1347, in Model 0.0
# Underprod at time 17371: Expected 0.5664, in Model 0.0
# Underprod at time 17372: Expected 0.5664, in Model 0.0
# Underprod at time 17373: Expected 0.1409, in Model 0.0
# Underprod at time 17374: Expected 0.5664, in Model 0.0
# Underprod at time 17375: Expected 0.5664, in Model 0.0403
# Overprod at time 17376: Expected 0.1151, in Model 0.1151
# Underprod at time 17377: Expected 0.5664, in Model 0.2164
# Underprod at time 17378: Expected 0.5664, in Model 0.339
# Exactprod at time 17379: Expected 0.0928, in Model 0.0928
# Exactprod at time 17380: Expected 0.5664, in Model 0.5664
# Underprod at time 17381: Expected 0.5664, in Model 0.5664
# Underprod at time 17382: Expected 0.0327, in Model 0.0327
# Underprod at time 17383: Expected 0.5664, in Model 0.5664
# Exactprod at time 17384: Expected 0.5664, in Model 0.5664
# Overprod at time 17385: Expected 0.1074, in Model 0.1074
# Exactprod at time 17386: Expected 0.5664, in Model 0.5664
# Exactprod at time 17387: Expected 0.5664, in Model 0.5664
# Overprod at time 17388: Expected 0.268, in Model 0.268
# Exactprod at time 17389: Expected 0.5664, in Model 0.5664
# Exactprod at time 17390: Expected 0.5664, in Model 0.5664
# Underprod at time 17391: Expected 0.4396, in Model 0.4396
# Exactprod at time 17392: Expected 0.5664, in Model 0.5664
# Exactprod at time 17393: Expected 0.5664, in Model 0.5664
# Exactprod at time 17394: Expected 0.5664, in Model 0.5664
# Exactprod at time 17395: Expected 0.5664, in Model 0.5664
# Exactprod at time 17396: Expected 0.5664, in Model 0.5664
# Exactprod at time 17397: Expected 0.5664, in Model 0.5664
# Exactprod at time 17398: Expected 0.5664, in Model 0.5664
# Exactprod at time 17399: Expected 0.5664, in Model 0.5664
# Exactprod at time 17400: Expected 0.5664, in Model 0.5664
# Exactprod at time 17401: Expected 0.5664, in Model 0.5664
# Underprod at time 17402: Expected 0.5664, in Model 0.5664
# Exactprod at time 17403: Expected 0.5664, in Model 0.5664
# Exactprod at time 17404: Expected 0.5664, in Model 0.5664
# Underprod at time 17405: Expected 0.5664, in Model 0.4611
# Underprod at time 17406: Expected 0.5134, in Model 0.1131
# Underprod at time 17407: Expected 0.5664, in Model 0.0756
# Underprod at time 17408: Expected 0.5664, in Model 0.0126
# Underprod at time 17409: Expected 0.5664, in Model 0.0
# Underprod at time 17410: Expected 0.5664, in Model 0.0166
# Underprod at time 17411: Expected 0.5664, in Model 0.0436
# Underprod at time 17412: Expected 0.5664, in Model 0.0688
# Underprod at time 17413: Expected 0.5664, in Model 0.0525
# Underprod at time 17414: Expected 0.5664, in Model 0.0058
# Underprod at time 17415: Expected 0.5664, in Model 0.0
# Underprod at time 17416: Expected 0.5664, in Model 0.0
# Underprod at time 17417: Expected 0.5664, in Model 0.0034
# Underprod at time 17418: Expected 0.5664, in Model 0.0031
# Underprod at time 17419: Expected 0.5664, in Model 0.0
# Underprod at time 17420: Expected 0.5664, in Model 0.0
# Underprod at time 17421: Expected 0.5664, in Model 0.0
# Underprod at time 17422: Expected 0.5664, in Model 0.0
# Underprod at time 17423: Expected 0.5664, in Model 0.0
# Underprod at time 17424: Expected 0.5664, in Model 0.0
# Underprod at time 17425: Expected 0.5664, in Model 0.0
# Underprod at time 17426: Expected 0.5664, in Model 0.0
# Underprod at time 17427: Expected 0.5664, in Model 0.0
# Underprod at time 17428: Expected 0.5664, in Model 0.0634
# Underprod at time 17429: Expected 0.5664, in Model 0.0249
# Underprod at time 17430: Expected 0.5664, in Model 0.1142
# Underprod at time 17431: Expected 0.5664, in Model 0.115
# Underprod at time 17432: Expected 0.5664, in Model 0.1142
# Underprod at time 17433: Expected 0.5664, in Model 0.1142
# Underprod at time 17434: Expected 0.5664, in Model 0.1142
# Underprod at time 17435: Expected 0.5664, in Model 0.1144
# Underprod at time 17436: Expected 0.5664, in Model 0.1142
# Underprod at time 17437: Expected 0.5664, in Model 0.1142
# Underprod at time 17438: Expected 0.5664, in Model 0.1143
# Underprod at time 17439: Expected 0.5664, in Model 0.1142
# Underprod at time 17440: Expected 0.5664, in Model 0.1142
# Underprod at time 17441: Expected 0.5664, in Model 0.0
# Underprod at time 17442: Expected 0.5664, in Model 0.0
# Underprod at time 17443: Expected 0.5664, in Model 0.0944
# Underprod at time 17444: Expected 0.5664, in Model 0.4358
# Underprod at time 17445: Expected 0.5664, in Model 0.551
# Underprod at time 17446: Expected 0.5664, in Model 0.4578
# Exactprod at time 17447: Expected 0.5664, in Model 0.5664
# Exactprod at time 17448: Expected 0.5664, in Model 0.5664
# Underprod at time 17449: Expected 0.5664, in Model 0.5664
# Underprod at time 17450: Expected 0.5664, in Model 0.5664
# Underprod at time 17451: Expected 0.5386, in Model 0.5386
# Exactprod at time 17452: Expected 0.5664, in Model 0.5664
# Underprod at time 17453: Expected 0.5664, in Model 0.5664
# Exactprod at time 17454: Expected 0.5451, in Model 0.5451
# Exactprod at time 17455: Expected 0.5664, in Model 0.5664
# Exactprod at time 17456: Expected 0.5664, in Model 0.5664
# Underprod at time 17457: Expected 0.4871, in Model 0.4871
# Exactprod at time 17458: Expected 0.5664, in Model 0.5664
# Exactprod at time 17459: Expected 0.5664, in Model 0.5664
# Underprod at time 17460: Expected 0.4255, in Model 0.4255
# Exactprod at time 17461: Expected 0.5664, in Model 0.5664
# Underprod at time 17462: Expected 0.5664, in Model 0.5664
# Exactprod at time 17463: Expected 0.4019, in Model 0.4019
# Exactprod at time 17464: Expected 0.5664, in Model 0.5664
# Exactprod at time 17465: Expected 0.5664, in Model 0.5664
# Overprod at time 17466: Expected 0.376, in Model 0.376
# Exactprod at time 17467: Expected 0.5664, in Model 0.5664
# Exactprod at time 17468: Expected 0.5664, in Model 0.5664
# Underprod at time 17469: Expected 0.3564, in Model 0.3564
# Underprod at time 17470: Expected 0.5664, in Model 0.3104
# Underprod at time 17471: Expected 0.5664, in Model 0.0428
# Underprod at time 17472: Expected 0.345, in Model 0.0034
# Underprod at time 17473: Expected 0.5664, in Model 0.0
# Underprod at time 17474: Expected 0.5664, in Model 0.0
# Underprod at time 17475: Expected 0.3078, in Model 0.0
# Underprod at time 17476: Expected 0.5664, in Model 0.1144
# Underprod at time 17477: Expected 0.5664, in Model 0.1142
# Underprod at time 17478: Expected 0.2768, in Model 0.1142
# Underprod at time 17479: Expected 0.5664, in Model 0.1142
# Underprod at time 17480: Expected 0.5664, in Model 0.1142
# Underprod at time 17481: Expected 0.3898, in Model 0.1142
# Underprod at time 17482: Expected 0.5664, in Model 0.1142
# Underprod at time 17483: Expected 0.5664, in Model 0.1147
# Underprod at time 17484: Expected 0.5664, in Model 0.1142
# Underprod at time 17485: Expected 0.5664, in Model 0.1142
# Underprod at time 17486: Expected 0.5664, in Model 0.1468
# Underprod at time 17487: Expected 0.5664, in Model 0.2206
# Underprod at time 17488: Expected 0.5664, in Model 0.3756
# Underprod at time 17489: Expected 0.5664, in Model 0.5573
# Underprod at time 17490: Expected 0.5664, in Model 0.5664
# Exactprod at time 17491: Expected 0.5664, in Model 0.5664
# Underprod at time 17492: Expected 0.5664, in Model 0.5542
# Underprod at time 17493: Expected 0.5664, in Model 0.4192
# Underprod at time 17494: Expected 0.5664, in Model 0.2673
# Underprod at time 17495: Expected 0.5664, in Model 0.3104
# Underprod at time 17496: Expected 0.4865, in Model 0.3497
# Underprod at time 17497: Expected 0.5664, in Model 0.3778
# Underprod at time 17498: Expected 0.5664, in Model 0.4479
# Exactprod at time 17499: Expected 0.3815, in Model 0.3815
# Underprod at time 17500: Expected 0.5664, in Model 0.2993
# Underprod at time 17501: Expected 0.5664, in Model 0.0917
# Underprod at time 17502: Expected 0.3454, in Model 0.1056
# Underprod at time 17503: Expected 0.5664, in Model 0.093
# Underprod at time 17504: Expected 0.5664, in Model 0.0525
# Underprod at time 17505: Expected 0.2436, in Model 0.0489
# Underprod at time 17506: Expected 0.5664, in Model 0.0634
# Underprod at time 17507: Expected 0.5664, in Model 0.1258
# Exactprod at time 17508: Expected 0.2137, in Model 0.2137
# Underprod at time 17509: Expected 0.5664, in Model 0.3467
# Underprod at time 17510: Expected 0.5664, in Model 0.3653
# Underprod at time 17511: Expected 0.1489, in Model 0.1489
# Underprod at time 17512: Expected 0.5664, in Model 0.2842
# Underprod at time 17513: Expected 0.5664, in Model 0.3529
# Underprod at time 17514: Expected 0.0993, in Model 0.0993
# Underprod at time 17515: Expected 0.5664, in Model 0.5664
# Exactprod at time 17516: Expected 0.5664, in Model 0.5664
# Underprod at time 17517: Expected 0.1552, in Model 0.1552
# Exactprod at time 17518: Expected 0.5664, in Model 0.5664
# Exactprod at time 17519: Expected 0.5664, in Model 0.5664
# Exactprod at time 17520: Expected 0.4216, in Model 0.4216
# Exactprod at time 17521: Expected 0.5664, in Model 0.5664
# Exactprod at time 17522: Expected 0.5664, in Model 0.5664
# Underprod at time 17523: Expected 0.3545, in Model 0.3545
# Underprod at time 17524: Expected 0.5658, in Model 0.205
# Underprod at time 17525: Expected 0.565, in Model 0.1108
# Underprod at time 17526: Expected 0.2366, in Model 0.1141
# Underprod at time 17527: Expected 0.5664, in Model 0.1094
# Underprod at time 17528: Expected 0.5664, in Model 0.09
# Underprod at time 17529: Expected 0.1323, in Model 0.062
# Underprod at time 17530: Expected 0.5664, in Model 0.0419
# Underprod at time 17531: Expected 0.5664, in Model 0.0232
# Underprod at time 17532: Expected 0.2448, in Model 0.0083
# Exactprod at time 17533: Expected 0.5664, in Model 0.5664
# Exactprod at time 17534: Expected 0.5664, in Model 0.5664
# Exactprod at time 17535: Expected 0.2397, in Model 0.2397
# Exactprod at time 17536: Expected 0.5664, in Model 0.5664
# Exactprod at time 17537: Expected 0.5664, in Model 0.5664
# Exactprod at time 17538: Expected 0.4274, in Model 0.4274
# Exactprod at time 17539: Expected 0.5664, in Model 0.5664
# Exactprod at time 17540: Expected 0.5664, in Model 0.5664
# Exactprod at time 17541: Expected 0.5664, in Model 0.5664
# Exactprod at time 17542: Expected 0.5664, in Model 0.5664
# Underprod at time 17543: Expected 0.5664, in Model 0.0

# %%
print(n)
# Out:
# 0

# %%
import calendar

def energy_demand():
    def daily_sum(ts):
        elec = np.array(ts[0])
        elec = elec.reshape((elec.shape[0]//24, 24))
        sum_elec = np.sum(elec, axis=1)
        
        return sum_elec

    df_elec = pd.read_csv("../../data/demand_el.csv", header=None)
    df_gas = pd.read_csv("../../data/demand_ng.csv", header=None)

    sum_elec = daily_sum(df_elec)
    sum_gas = daily_sum(df_gas)

    years = 2

    month_names = [calendar.month_name[i] for i in range(1, 13)]
    month_names = list(map(lambda x: x + " 2015", month_names)) + list(map(lambda x: x + " 2016", month_names)) + ['']

    # month_names = [calendar.month_name[i] for i in range(1, 13)] * years + [''] # add a placeholder string

    tmp = (sum_elec.shape[0] // 3) * years
    months= [x for x in range(0,tmp)]

    days = [x for x in range(tmp)]

    plt.figure(figsize=(10,8))

    color1, color2 = 'steelblue', 'lightcoral'

    linewidth = 2

    plt.plot([],[], color=color2, label='Gas', linewidth=linewidth)

    plt.stackplot(days, sum_gas[:tmp], colors=[color2], alpha=.7, linewidth=linewidth)

    plt.legend()
    plt.xlim(0, tmp)
    freq = 4
    plt.xticks(months[::30*freq], month_names[::freq], rotation=0)

    plt.ylabel('Energy demand [GWh/day]')

    plt.axhline(color='black', linewidth=1)

    plt.show()

# %%
energy_demand()
