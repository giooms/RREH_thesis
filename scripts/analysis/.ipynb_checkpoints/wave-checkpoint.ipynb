# %% [markdown]
# # Simple Analysis
# ## Wave, no production in Belgium

# %%
from datetime import datetime

def is_leap_year(year):
    """Determine whether a year is a leap year."""
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

def sum_hours_over_years(start_year, end_year):
    """Calculate the sum of hours from start_year to end_year, inclusive."""
    total_hours = 0
    for year in range(start_year, end_year + 1):
        if is_leap_year(year):
            total_hours += 366 * 24  # Leap year has 366 days
        else:
            total_hours += 365 * 24  # Non-leap year has 365 days
    return total_hours

# Now, we will iterate over the years from 2015 to 2019 as per the requirement.
start_year = 2015
end_year = 2019
yearly_hours = {}

# Calculating the sum of hours for each range starting from 2015
for year in range(start_year, end_year + 1):
    yearly_hours[f"{start_year}-{year}"] = sum_hours_over_years(start_year, year)

yearly_hours
# Out:
# {'2015-2015': 8760,
#  '2015-2016': 17544,
#  '2015-2017': 26304,
#  '2015-2018': 35064,
#  '2015-2019': 43824}

# %%
from gboml import GbomlGraph

timehorizon = 17544

# Initialize and build the model
gboml_model = GbomlGraph(timehorizon=timehorizon)
nodes, edges, param = gboml_model.import_all_nodes_and_edges("../../models/wave/greenland_wave.gboml")
gboml_model.add_global_parameters(param)
gboml_model.add_nodes_in_model(*nodes)
gboml_model.add_hyperedges_in_model(*edges)
gboml_model.build_model()

# Solve the model
solution, obj, status, solver_info, constr_info, _ = gboml_model.solve_gurobi(opt_file="gurobi.txt", details=True)

print("Solved")
# Out:
# Check variables of node LIQUEFIED_METHANE_CARRIERS_GR : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_STORAGE_HUB_GR : --- 0.0 seconds ---
# Check variables of node METHANE_LIQUEFACTION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node METHANATION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node WATER_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node CARBON_DIOXIDE_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node HYDROGEN_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node DIRECT_AIR_CAPTURE_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node DESALINATION_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS_GR : --- 0.0 seconds ---
# Check variables of node HVDC_GR : --- 0.0 seconds ---
# Check variables of node BATTERY_STORAGE_GR : --- 0.0 seconds ---
# Check variables of node WAVE_PLANT_GR : --- 0.0 seconds ---
# Check variables of node ENERGY_DEMAND_BE : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_STORAGE_DESTINATION : --- 0.0 seconds ---
# Check variables of node LIQUEFIED_METHANE_REGASIFICATION : --- 0.0 seconds ---
# Check hyperlink COASTAL_CARBON_DIOXIDE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_LIQUEFIED_METHANE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_METHANE_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_WATER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_HYDROGEN_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink COASTAL_POWER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink INLAND_POWER_BALANCE_GR : --- 0.0 seconds ---
# Check hyperlink DESTINATION_LIQUEFIED_METHANE_BALANCE : --- 0.0 seconds ---
# Warning : Hyperedge constraint using variables from a single node at line 41
# Check hyperlink DESTINATION_METHANE_BALANCE : --- 0.0 seconds ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-12-03
#
# Reading Gurobi options from file gurobi.opt
# Set parameter Method to value 1
# Set parameter BarHomogeneous to value 1
# Set parameter Crossover to value 0
# No parameters matching 'ScaleFlag=1' found
# Skipping unknown option 'ScaleFlag=1'
# No parameters matching 'TimeLimit=3600' found
# Skipping unknown option 'TimeLimit=3600'
# No parameters matching 'IterationLimit=1000000' found
# Skipping unknown option 'IterationLimit=1000000'
#
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 7735HS with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2122839 rows, 807046 columns and 3992808 nonzeros
# Model fingerprint: 0xf6847349
# Variable types: 807045 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [5e-05, 3e+02]
#   Objective range  [2e-04, 3e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-01, 1e+03]
# Presolve removed 1557536 rows and 463761 columns (presolve time = 6s) ...
# Presolve removed 1595715 rows and 486634 columns (presolve time = 10s) ...
# Presolve removed 1595715 rows and 486634 columns
# Presolve time: 10.13s
# Presolved: 527124 rows, 320412 columns, 1608099 nonzeros
# Variable types: 320411 continuous, 1 integer (0 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8027522e+01   1.372310e+03   0.000000e+00     22s
#    55388    2.2571628e+02   4.746496e+06   0.000000e+00     25s
#    64959    3.9798646e+02   8.526370e+05   0.000000e+00     32s
#    67899    4.0562629e+02   2.339554e+05   0.000000e+00     37s
#    70783    4.0803159e+02   1.030180e+04   0.000000e+00     43s
#    73033    4.0808394e+02   8.426090e+03   0.000000e+00     46s
#    74643    4.0840764e+02   8.525206e+03   0.000000e+00     52s
#    75373    4.2243530e+02   6.321873e+03   0.000000e+00     55s
#    76763    4.2278358e+02   6.562512e+03   0.000000e+00     61s
#    78153    4.2309436e+02   2.950424e+03   0.000000e+00     66s
#    79523    4.2474796e+02   4.883980e+03   0.000000e+00     71s
#    81063    4.4339983e+02   2.709876e+03   0.000000e+00     78s
#    81773    4.4350537e+02   2.794846e+03   0.000000e+00     80s
#    83213    4.8096563e+02   1.101340e+06   0.000000e+00     86s
#    86723    4.9022867e+02   9.760343e+05   0.000000e+00     90s
#    96433    4.9342062e+02   4.336362e+03   0.000000e+00     97s
#    98183    4.9383671e+02   5.585225e+03   0.000000e+00    101s
#   100573    4.9441281e+02   6.312120e+03   0.000000e+00    107s
#   102213    4.9488661e+02   4.940214e+03   0.000000e+00    112s
#   103653    4.9521756e+02   1.825077e+03   0.000000e+00    116s
#   105023    4.9544969e+02   5.811153e+03   0.000000e+00    120s
#   107143    4.9619709e+02   1.351753e+03   0.000000e+00    126s
#   109233    4.9688676e+02   5.212222e+03   0.000000e+00    132s
#   110623    4.9732700e+02   5.213578e+03   0.000000e+00    135s
#   113010    5.0222693e+02   1.104079e+04   0.000000e+00    141s
#   116328    5.5093475e+02   9.379256e+03   0.000000e+00    147s
#   118638    5.5364668e+02   9.485203e+03   0.000000e+00    151s
#   122228    5.5571768e+02   1.109054e+04   0.000000e+00    157s
#   124688    5.5974829e+02   1.195974e+04   0.000000e+00    162s
#   127138    5.5991898e+02   7.567309e+03   0.000000e+00    166s
#   129528    5.5991984e+02   8.215166e+03   0.000000e+00    170s
#   132590    6.4082419e+02   6.380811e+03   0.000000e+00    176s
#   133918    7.2338440e+02   2.568860e+04   0.000000e+00    180s
#   135844    8.9019572e+02   2.621859e+04   0.000000e+00    188s
#   136665    9.3277941e+02   3.083134e+07   0.000000e+00    191s
#   137793    1.0610221e+03   2.924729e+04   0.000000e+00    197s
#   138545    1.0790455e+03   2.998158e+05   0.000000e+00    201s
#   140437    1.0845500e+03   1.779799e+05   0.000000e+00    208s
#   141177    1.0846167e+03   2.177504e+05   0.000000e+00    210s
#   142657    1.1187961e+03   1.348890e+06   0.000000e+00    216s
#   144077    1.1279738e+03   2.574916e+05   0.000000e+00    223s
#   144767    1.1280399e+03   2.486133e+05   0.000000e+00    226s
#   146367    1.1286664e+03   7.866619e+04   0.000000e+00    234s
#   147054    1.1288521e+03   7.434868e+05   0.000000e+00    239s
#   148004    1.1292410e+03   8.177253e+05   0.000000e+00    243s
#   148874    1.1293848e+03   7.943627e+06   0.000000e+00    248s
#   149764    1.1295592e+03   7.911386e+06   0.000000e+00    254s
#   150804    1.1296506e+03   7.950615e+06   0.000000e+00    259s
#   151854    1.1297743e+03   8.022849e+06   0.000000e+00    267s
#   152683    1.1760102e+03   5.807428e+05   0.000000e+00    272s
#   153553    1.1760496e+03   4.760182e+05   0.000000e+00    278s
#   154343    1.1760984e+03   4.849981e+05   0.000000e+00    283s
#   155653    1.1973162e+03   3.595612e+06   0.000000e+00    289s
#   156963    1.1983832e+03   3.670360e+05   0.000000e+00    294s
#   157743    1.1984242e+03   2.062837e+05   0.000000e+00    300s
#   158573    1.1984592e+03   2.022613e+05   0.000000e+00    306s
#   159403    1.1985033e+03   2.078213e+05   0.000000e+00    311s
#   160343    1.2005635e+03   1.925485e+05   0.000000e+00    318s
#   161303    1.2014611e+03   5.103536e+06   0.000000e+00    325s
#   161722    1.2023419e+03   6.376721e+06   0.000000e+00    328s
#   162098    1.2045300e+03   5.823289e+06   0.000000e+00    330s
#   162850    1.2277448e+03   9.312320e+05   0.000000e+00    335s
#   163602    1.2547948e+03   5.526753e+05   0.000000e+00    341s
#   164583    1.2645354e+03   2.714138e+05   0.000000e+00    347s
#   165523    1.2678456e+03   3.040934e+05   0.000000e+00    352s
#   166505    1.2947037e+03   2.178731e+06   0.000000e+00    357s
#   167257    1.5450961e+03   4.070519e+07   0.000000e+00    363s
#   168009    1.6119294e+03   1.085408e+07   0.000000e+00    367s
#   168866    1.7368779e+03   1.260333e+05   0.000000e+00    373s
#   169296    1.7423696e+03   2.188033e+06   0.000000e+00    376s
#   170048    1.8926688e+03   6.990429e+04   0.000000e+00    381s
#   170821    1.9068860e+03   1.212834e+05   0.000000e+00    387s
#   172827    1.9117875e+03   3.100876e+05   0.000000e+00    399s
#   173541    1.9351689e+03   1.727401e+07   0.000000e+00    403s
#   175297    1.9542193e+03   2.036936e+06   0.000000e+00    414s
#   177187    1.9735682e+03   1.206265e+08   0.000000e+00    424s
#   177599    1.9838048e+03   2.722565e+06   0.000000e+00    427s
#   178761    1.9880738e+03   1.336534e+06   0.000000e+00    436s
#   179921    1.9886082e+03   1.353750e+06   0.000000e+00    445s
#   180297    1.9907869e+03   1.329123e+07   0.000000e+00    448s
#   180673    1.9928907e+03   7.006185e+05   0.000000e+00    451s
#   181425    2.0107092e+03   2.883445e+06   0.000000e+00    456s
#   182177    2.0113186e+03   1.824953e+07   0.000000e+00    461s
#   182929    2.0114199e+03   1.300922e+07   0.000000e+00    466s
#   185194    2.0470582e+03   9.968375e+04   0.000000e+00    473s
#   185732    2.0480285e+03   7.546992e+05   0.000000e+00    477s
#   186108    2.0525178e+03   2.386886e+07   0.000000e+00    481s
#   186860    2.0618752e+03   9.610962e+04   0.000000e+00    487s
#   187236    2.0633827e+03   1.877564e+05   0.000000e+00    490s
#   187988    2.0693091e+03   2.091328e+06   0.000000e+00    496s
#   188740    2.0723627e+03   5.495283e+07   0.000000e+00    503s
#   189116    2.0891251e+03   6.452226e+05   0.000000e+00    506s
#   189868    2.0915262e+03   9.202005e+07   0.000000e+00    513s
#   190244    2.0919743e+03   1.205814e+05   0.000000e+00    516s
#   190996    2.0987620e+03   2.654654e+05   0.000000e+00    523s
# Warning: Markowitz tolerance tightened to 0.03125
#   191372    2.1052271e+03   1.740519e+07   0.000000e+00    527s
#   191748    2.1174812e+03   3.355645e+06   0.000000e+00    530s
#   192500    2.1364034e+03   3.297279e+05   0.000000e+00    539s
#   192876    2.1456098e+03   1.214219e+07   0.000000e+00    543s
#   193252    2.1537814e+03   2.750938e+07   0.000000e+00    546s
#   194042    2.1644495e+03   6.802820e+06   0.000000e+00    550s
#   194918    2.1681874e+03   2.400284e+05   0.000000e+00    557s
#   195294    2.1777863e+03   7.575613e+05   0.000000e+00    561s
#   196046    2.2080333e+03   2.125566e+06   0.000000e+00    568s
#   196422    2.2142003e+03   1.912508e+06   0.000000e+00    572s
#   197174    2.2477699e+03   2.028696e+05   0.000000e+00    579s
#   197550    2.2859916e+03   2.551559e+05   0.000000e+00    583s
#   197926    2.2926047e+03   7.004055e+06   0.000000e+00    587s
#   198302    2.3027152e+03   1.090428e+06   0.000000e+00    591s
#   199054    2.3062552e+03   1.460768e+05   0.000000e+00    599s
#   199430    2.3126372e+03   3.988326e+04   0.000000e+00    604s
#   199806    2.3174193e+03   3.455027e+06   0.000000e+00    609s
#   200182    2.3219684e+03   1.872837e+05   0.000000e+00    613s
#   200558    2.3241701e+03   1.125999e+07   0.000000e+00    617s
#   200934    2.3259090e+03   1.126341e+07   0.000000e+00    620s
#   201686    2.3399651e+03   5.811045e+04   0.000000e+00    629s
#   202062    2.3467864e+03   2.529169e+06   0.000000e+00    634s
#   202438    2.3517279e+03   1.488632e+05   0.000000e+00    639s
#   202814    2.3574298e+03   6.095498e+04   0.000000e+00    643s
#   203190    2.3617962e+03   2.449135e+06   0.000000e+00    647s
#   203566    2.3671953e+03   2.091701e+06   0.000000e+00    651s
#   203942    2.3706202e+03   2.377896e+04   0.000000e+00    656s
#   205133    2.3736450e+03   6.052068e+06   0.000000e+00    664s
#   206542    2.3736590e+03   6.051803e+06   0.000000e+00    673s
#   207420    2.3736606e+03   6.051637e+06   0.000000e+00    679s
#   208245    2.3736621e+03   6.051483e+06   0.000000e+00    685s
#   209468    2.3736641e+03   6.051255e+06   0.000000e+00    692s
#   211402    2.3750660e+03   2.819500e+05   0.000000e+00    700s
#   211778    2.3797603e+03   4.263841e+05   0.000000e+00    704s
#   212154    2.3827784e+03   4.387492e+05   0.000000e+00    708s
#   212530    2.3835908e+03   1.088146e+04   0.000000e+00    713s
#   212906    2.3860656e+03   5.584908e+05   0.000000e+00    717s
#   213282    2.3862937e+03   4.545920e+05   0.000000e+00    721s
#   214034    2.3970176e+03   2.616855e+06   0.000000e+00    728s
#   214410    2.4051378e+03   2.844881e+04   0.000000e+00    732s
#   214786    2.4075369e+03   1.655945e+07   0.000000e+00    736s
#   215162    2.4088787e+03   1.109188e+07   0.000000e+00    741s
#   215914    2.4102504e+03   1.713000e+07   0.000000e+00    748s
#   216290    2.4105615e+03   7.659234e+05   0.000000e+00    752s
#   216666    2.4144632e+03   3.472131e+05   0.000000e+00    756s
#   217042    2.4179628e+03   7.151206e+06   0.000000e+00    760s
#   217794    2.4252696e+03   2.407964e+06   0.000000e+00    768s
#   218170    2.4285020e+03   3.281059e+05   0.000000e+00    772s
#   218546    2.4290892e+03   4.560603e+05   0.000000e+00    775s
#   219298    2.4315572e+03   9.033354e+07   0.000000e+00    783s
#   219674    2.4321189e+03   3.894483e+06   0.000000e+00    787s
#   220050    2.4331944e+03   6.590556e+04   0.000000e+00    792s
#   220426    2.4345142e+03   6.671256e+05   0.000000e+00    797s
#   220802    2.4385577e+03   1.661075e+05   0.000000e+00    800s
#   221554    2.4431088e+03   7.600093e+05   0.000000e+00    808s
#   221930    2.4464222e+03   1.239483e+05   0.000000e+00    811s
#   222682    2.4500917e+03   5.700367e+05   0.000000e+00    819s
#   223058    2.4518293e+03   1.475899e+06   0.000000e+00    823s
#   223434    2.4532907e+03   3.928760e+06   0.000000e+00    826s
#   223810    2.4535313e+03   1.199861e+07   0.000000e+00    830s
#   224562    2.4541543e+03   1.381836e+07   0.000000e+00    838s
#   224938    2.4541595e+03   1.381805e+07   0.000000e+00    842s
#   225314    2.4557837e+03   2.796714e+05   0.000000e+00    847s
#   225690    2.4562165e+03   6.455184e+06   0.000000e+00    852s
#   226066    2.4562201e+03   6.455106e+06   0.000000e+00    857s
#   226442    2.4566324e+03   2.880943e+04   0.000000e+00    862s
#   226818    2.4572193e+03   2.379004e+04   0.000000e+00    867s
#   227194    2.4580184e+03   3.641788e+06   0.000000e+00    871s
#   227946    2.4589692e+03   7.214985e+03   0.000000e+00    879s
#   228322    2.4597215e+03   6.428220e+03   0.000000e+00    883s
#   228698    2.4601846e+03   3.797680e+03   0.000000e+00    886s
#   229520    2.4608013e+03   1.081018e+04   0.000000e+00    895s
#   229896    2.4615352e+03   9.846741e+04   0.000000e+00    899s
#   230272    2.4616280e+03   7.239870e+02   0.000000e+00    902s
#   234545    2.4616290e+03   4.662255e+02   0.000000e+00    931s
#   234921    2.4618189e+03   6.231451e+03   0.000000e+00    935s
#   235673    2.4621295e+03   9.570079e+05   0.000000e+00    943s
#   236049    2.4621824e+03   8.220889e+05   0.000000e+00    946s
#   236801    2.4625685e+03   8.493329e+06   0.000000e+00    955s
#   237177    2.4626757e+03   4.687527e+03   0.000000e+00    959s
#   237553    2.4629169e+03   3.303093e+07   0.000000e+00    963s
#   237929    2.4631118e+03   1.932491e+04   0.000000e+00    967s
#   238305    2.4632674e+03   3.666386e+04   0.000000e+00    972s
#   238681    2.4634113e+03   5.090311e+05   0.000000e+00    976s
#   239057    2.4635187e+03   4.292623e+03   0.000000e+00    980s
#   239433    2.4637128e+03   1.498932e+04   0.000000e+00    985s
#   240185    2.4640221e+03   2.629315e+02   0.000000e+00    994s
#   240561    2.4641077e+03   4.700831e+05   0.000000e+00    998s
#   240937    2.4641783e+03   1.691913e+02   0.000000e+00   1002s
#   241313    2.4642012e+03   1.676747e+02   0.000000e+00   1005s
#   242065    2.4643819e+03   1.477942e+06   0.000000e+00   1013s
#   242441    2.4645268e+03   1.988400e+05   0.000000e+00   1017s
#   243193    2.4647340e+03   7.888209e+03   0.000000e+00   1024s
#   243569    2.4648612e+03   1.657232e+05   0.000000e+00   1028s
#   243945    2.4649528e+03   2.135676e+05   0.000000e+00   1032s
#   244321    2.4650877e+03   2.725917e+06   0.000000e+00   1038s
#   244697    2.4651987e+03   4.434673e+03   0.000000e+00   1042s
#   245449    2.4652732e+03   4.438979e+03   0.000000e+00   1048s
#   245825    2.4653104e+03   4.440958e+03   0.000000e+00   1051s
#   246577    2.4653798e+03   4.567925e+05   0.000000e+00   1057s
#   246953    2.4654148e+03   4.447886e+03   0.000000e+00   1061s
#   247705    2.4654927e+03   4.452865e+03   0.000000e+00   1067s
#   248081    2.4655266e+03   4.454703e+03   0.000000e+00   1071s
#   248833    2.4655990e+03   4.458034e+03   0.000000e+00   1078s
#   249209    2.4656331e+03   4.460099e+03   0.000000e+00   1082s
#   249585    2.4656667e+03   4.461860e+03   0.000000e+00   1085s
#   250337    2.4657402e+03   4.453198e+03   0.000000e+00   1093s
#   250713    2.4657743e+03   4.455309e+03   0.000000e+00   1097s
#   251089    2.4658095e+03   4.457468e+03   0.000000e+00   1100s
#   251841    2.4658785e+03   4.461255e+03   0.000000e+00   1107s
#   252217    2.4659496e+03   1.260952e+03   0.000000e+00   1112s
#   252593    2.4660482e+03   2.029773e+02   0.000000e+00   1117s
#   252969    2.4661460e+03   2.732708e+00   0.000000e+00   1122s
#   253345    2.4662223e+03   2.689386e+03   0.000000e+00   1127s
#   253479    2.4658507e+03   0.000000e+00   0.000000e+00   1131s
#
# Root relaxation: objective 2.465851e+03, 253479 iterations, 1119.80 seconds (2982.86 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2465.85072    0    1          - 2465.85072      -     - 1130s
# H    0     0                    2466.7948515 2465.85072  0.04%     - 1171s
# H    0     0                    2465.8751445 2465.85072  0.00%     - 1175s
#
# Explored 1 nodes (253479 simplex iterations) in 1175.41 seconds (3146.39 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 2465.88 2466.79
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (3.3531e-06) exceeds tolerance
# Best objective 2.465875144491e+03, best bound 2.465850719114e+03, gap 0.0010%
# Warning : Unable to retrieve  Pi  information
# Warning : Unable to retrieve  CBasis  information
# Warning : Unable to retrieve  SARHSLow  information
# Warning : Unable to retrieve  SARHSUp  information
# Warning : Unable to retrieve  RC  information
# Warning : Unable to retrieve  VBasis  information
# Warning : Unable to retrieve  SAObjLow  information
# Warning : Unable to retrieve  SAObjUp  information
# Warning : Unable to retrieve  SALBLow  information
# Warning : Unable to retrieve  SALBUp  information
# Warning : Unable to retrieve  SAUBLow  information
# Warning : Unable to retrieve  SAUBUp  information
# Solved

# %%
import json

gathered_data = gboml_model.turn_solution_to_dictionary(solver_info, status, solution, obj, constr_info)
print("Json done")
with open(f'../../models/wave/results/RREH.json', "w") as fp:json.dump(gathered_data, fp, indent=4)
# Out:
# Json done

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
class MakeMeReadable:
    def __init__(self, d):
        self.d = d
    
    def __dir__(self):
        return self.d.keys()
    
    def __getattr__(self, v):
        try:
            out = self.d[v]
            if isinstance(out, dict):
                return MakeMeReadable(out)
            return out
        except:
            return getattr(self.d, v)
        
    def __str__(self):
        return str(self.d)
    
    def __repr__(self):
        return repr(self.d)

# %%
dico = {}
with open('../../models/wave/results/RREH.json', 'r') as f:
    dico = json.load(f)
            
d = MakeMeReadable(dico)
    
if isinstance(dico, dict):
    print('The data is a dictionary')
else:
    print('The data is not a dictionary')
# Out:
# The data is a dictionary

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(18, 15), constrained_layout=True)
ylim = (-0.1, 0.1)
axs = axs.flatten()
def plot_balance(ax, data, title):
    ax.plot(data)
    ax.set_ylim(ylim)
    ax.set_title(title)
    
# GR_CO2 Balance
co2_storage_gr_in = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.carbon_dioxide_in.values)
co2_storage_gr_out = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.carbon_dioxide_out.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.carbon_dioxide.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.carbon_dioxide.values)
co2_balance_gr = dac_gr + co2_storage_gr_out - co2_storage_gr_in - methanation_gr

plot_balance(axs[0], co2_balance_gr, 'GR_CO2 Balance')

# GR_LCH4 Balance
lch4_carriers_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_CARRIERS_GR.variables.liquefied_methane_in.values)
lch4_storage_gr_in = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_in.values)
lch4_storage_gr_out = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_out.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.liquefied_methane.values)
lch4_balance_gr = ch4_liquefaction_gr + lch4_storage_gr_out - lch4_storage_gr_in - lch4_carriers_gr

plot_balance(axs[1], lch4_balance_gr, 'GR_LCH4 Balance')

# Check BE_CH4 Balance
conversion_factor = d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.conversion_factor
demand_CH4 = np.array(d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.demand)
lch4_regasification_be = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.methane.values)
ch4_balance_be = conversion_factor * lch4_regasification_be - 10 * demand_CH4[:timehorizon]

plot_balance(axs[2], ch4_balance_be, 'BE_CH4 Balance')


# Check BE_LCH4 Balance
lch4_carriers_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_CARRIERS_GR.variables.liquefied_methane_out.values)
lch4_storage_dest_in = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_in.values)
lch4_storage_dest_out = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_out.values)
lch4_regasification_be = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.liquefied_methane.values)
lch4_balance_be = lch4_carriers_gr + lch4_storage_dest_out - lch4_storage_dest_in - lch4_regasification_be

plot_balance(axs[3], lch4_balance_be, 'BE_LCH4 Balance')


# Check GR_INLAND CH4 Balance
battery_storage_gr_out = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_out.values)
battery_storage_gr_in = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_in.values)
hvdc_gr_in = np.array(d.solution.elements.HVDC_GR.variables.electricity_in.values)
wave_gr = np.array(d.solution.elements.WAVE_PLANT_GR.variables.electricity.values)

power_balance_gr = wave_gr + battery_storage_gr_out - battery_storage_gr_in - hvdc_gr_in

plot_balance(axs[4], power_balance_gr, 'GR_Inland CH4 Balance')


# Check GR_Coastal Power Balance
hvdc_gr_out = np.array(d.solution.elements.HVDC_GR.variables.electricity_out.values)
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.electricity.values)
h2_storage_gr = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.electricity.values)
desalination_gr = np.array(d.solution.elements.DESALINATION_PLANTS_GR.variables.electricity.values)
h2o_storage_gr = np.array(d.solution.elements.WATER_STORAGE_GR.variables.electricity.values)
co2_storage_gr = np.array(d.solution.elements.CARBON_DIOXIDE_STORAGE_GR.variables.electricity.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.electricity.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.electricity.values)
power_balance_gr = hvdc_gr_out - electrolysis_gr - h2_storage_gr - desalination_gr - h2o_storage_gr - co2_storage_gr - ch4_liquefaction_gr - dac_gr 

plot_balance(axs[5], power_balance_gr, 'GR_Coastal Power Balance')


# Check GR_Coastal H2 Balance
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.hydrogen.values)
h2_storage_gr_out = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_out.values)
h2_storage_gr_in = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_in.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.hydrogen.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.hydrogen.values)
h2_balance_gr = electrolysis_gr + h2_storage_gr_out - h2_storage_gr_in - methanation_gr - dac_gr

plot_balance(axs[6], h2_balance_gr, 'GR_Coastal H2 Balance')


# Check GR_Coastal H2O Balance
desalination_gr = np.array(d.solution.elements.DESALINATION_PLANTS_GR.variables.water.values)
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.water.values)
h2o_storage_gr_out = np.array(d.solution.elements.WATER_STORAGE_GR.variables.water_out.values)
h2o_storage_gr_in = np.array(d.solution.elements.WATER_STORAGE_GR.variables.water_in.values)
electrolysis_gr = np.array(d.solution.elements.ELECTROLYSIS_PLANTS_GR.variables.water.values)
dac_gr = np.array(d.solution.elements.DIRECT_AIR_CAPTURE_PLANTS_GR.variables.water.values)
h20_balance_gr = desalination_gr + methanation_gr + h2o_storage_gr_out - h2o_storage_gr_in - electrolysis_gr - dac_gr

plot_balance(axs[7], h20_balance_gr, 'GR_Coastal H2O Balance')

# Check GR_Coastal CH4 Balance
methanation_gr = np.array(d.solution.elements.METHANATION_PLANTS_GR.variables.methane.values)
ch4_liquefaction_gr = np.array(d.solution.elements.METHANE_LIQUEFACTION_PLANTS_GR.variables.liquefied_methane.values)
ch4_balance_gr = methanation_gr - ch4_liquefaction_gr

plot_balance(axs[8], ch4_balance_gr, 'GR_Coastal CH4 Balance')

plt.show()

print()

# %%
ls_nodes = list(d.model.nodes.keys())

print(ls_nodes)
# Out:
# ['LIQUEFIED_METHANE_CARRIERS_GR', 'LIQUEFIED_METHANE_STORAGE_HUB_GR', 'METHANE_LIQUEFACTION_PLANTS_GR', 'METHANATION_PLANTS_GR', 'WATER_STORAGE_GR', 'CARBON_DIOXIDE_STORAGE_GR', 'HYDROGEN_STORAGE_GR', 'DIRECT_AIR_CAPTURE_PLANTS_GR', 'DESALINATION_PLANTS_GR', 'ELECTROLYSIS_PLANTS_GR', 'HVDC_GR', 'BATTERY_STORAGE_GR', 'WAVE_PLANT_GR', 'ENERGY_DEMAND_BE', 'LIQUEFIED_METHANE_STORAGE_DESTINATION', 'LIQUEFIED_METHANE_REGASIFICATION']

# %%
def cost_rreh(ls:list):
    if len(ls) == 0:
        return 0.0

    cost = 0

    for ele in ls:
        # print(f"{ele = }")
        # print(dico["solution"]["elements"][ele]["objectives"])
        try:
            cost += np.sum(dico["solution"]["elements"][ele]["objectives"]["unnamed"])
        except:
            for e in dico["solution"]["elements"][ele]["objectives"]["named"].values():
                # print(f"{e = }")
                cost += e
        # print(f"{cost = }")
    
    return cost

# %%
import re 

excluded_hydro_basins = [node for node in ls_nodes if re.match(r'HYDRO_BASIN_[\w]+_GR$', node)]

try:
    GR_nodes = [node for node in ls_nodes if node.endswith("_GR") and node not in excluded_hydro_basins]
except:
    GR_nodes = []
BE_nodes = list(map(lambda string: string if string[-3:] == "_BE" or string in ["PCCC_CCGT", "PCCC", "CO2_EXPORT", "LIQUEFIED_METHANE_STORAGE_DESTINATION","LIQUEFIED_METHANE_REGASIFICATION"] else None, ls_nodes))

try:
    GR_nodes = list(filter(lambda x: x not in [None, "PCCC", "PROD_CO2", "CO2_EXPORT"], GR_nodes))
except:
    GR_nodes = []
BE_nodes = list(filter(lambda x: x not in [None, "PROD_CO2"], BE_nodes))

cost_GR = cost_rreh(GR_nodes)
cost_BE = cost_rreh(BE_nodes)


print(f"GR {cost_GR = }")
print(f"BE {cost_BE = }")


obj_cost = d.solution.objective
tot_cost = np.sum([cost_GR, cost_BE])

abs_diff = np.abs(d.solution.objective - np.sum([cost_GR, cost_BE]))
print(f"{obj_cost = }")
print(f"{tot_cost = }")
print(abs_diff < 0.1)
# Out:
# GR cost_GR = 2447.8476221014766
# BE cost_BE = 18.027522389570443
# obj_cost = 2465.8751444930663
# tot_cost = 2465.875144491047
# True

# %%
# Initialize a dictionary to hold individual capacities
plant_capacities = {}

wave_n_units = d.solution.elements.WAVE_PLANT_GR.variables.num_units.values[0]
wave_RP = d.model.nodes.WAVE_PLANT_GR.parameters.unit_rated_power[0]
plant_capacities['wave_off_gr'] = wave_RP * wave_n_units

# Compute the total installed capacity by summing all individual capacities
total_installed_capacity = sum(plant_capacities.values())

# %%
# Doesn't install on/offshore wind turbines if 1,7GW of Hydro

import matplotlib.pyplot as plt
import numpy as np

# Print installed capacities
for plant, capacity in plant_capacities.items():
    plant_type = "hydro" if "HYDRO_PLANT" in plant else "onshore" if "onshore" in plant else "offshore" if "wind_off" in plant else "wave"
    print(f"Installed capacity of {plant_type} = {capacity:.3f} GW")

# Calculate the total installed capacity
total_installed_capacity = sum(plant_capacities.values())

print(f"\nTotal installed capacity = {total_installed_capacity:.3f} GW")

# Calculate total hydro capacity by summing all hydro plant capacities
total_hydro_capacity = sum(capacity for plant, capacity in plant_capacities.items() if "HYDRO_PLANT" in plant)

# Data for the first plot
categories = [ 'Wave']
capacities = [
    plant_capacities.get('wave_off_gr', 0),
]

### Plot 1: Combined Wind and Total Hydro Capacities
plt.figure(figsize=(10, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(categories)))
plt.bar(categories, capacities, color=colors)
plt.ylabel('Installed Capacity (GW)')
plt.title('On-Offshore Wind and Total Hydro Capacities')
# Annotate each bar with its capacity
for i, v in enumerate(capacities):
    plt.text(i, v, f"{v:.3f}", ha='center', va='bottom')
plt.tight_layout()
plt.show()
# Out:
# Installed capacity of wave = 3.457 GW
#
# Total installed capacity = 3.457 GW

# %%
gas_demand = d.model.hyperedges.DESTINATION_METHANE_BALANCE.parameters.demand
gas_demand = np.sum(gas_demand[:timehorizon])/1000
print("the gas demand is ", gas_demand, "TWh")
# Out:
# the gas demand is  1.2970272171668917 TWh

# %%
# LCH4 full production:
gas = np.array(d.solution.elements.LIQUEFIED_METHANE_REGASIFICATION.variables.methane.values) * 15.31 # kt/h * GWh/kt
gas_prod = np.sum(gas) # GWh
gas_prod/1000
# Out:
# 12.970272171668919

# %%
demand_in_mwh = gas_prod * 1e3  # Convert TWh to MWh
total_cost_in_euros = tot_cost * 1e6  # Convert million euros to euros

# Compute price per MWh in euros
price_per_mwh = total_cost_in_euros / demand_in_mwh

print(f"The price is {round(price_per_mwh, 3)} €/MWh \n")
print("In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh")  # Adjusted to €/MWh
print("This system is about", round((price_per_mwh / 45), 3), "times more expensive compared to a reference price of 45 €/MWh")
# Out:
# The price is 190.117 €/MWh
#
# In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh
# This system is about 4.225 times more expensive compared to a reference price of 45 €/MWh

# %%
def cost_rreh_detailed(ls):
    detailed_cost = {}
    if len(ls) == 0:
        return detailed_cost

    for ele in ls:
        node_cost = 0
        try:
            node_cost += np.sum(dico["solution"]["elements"][ele]["objectives"]["unnamed"])
        except:
            for e in dico["solution"]["elements"][ele]["objectives"]["named"].values():
                node_cost += e
        detailed_cost[ele] = node_cost
    
    return detailed_cost

# %%
import matplotlib.pyplot as plt
import numpy as np

cost_details_GR = cost_rreh_detailed(GR_nodes)

sorted_nodes_and_costs = sorted(cost_details_GR.items(), key=lambda item: item[1])
sorted_nodes = [item[0] for item in sorted_nodes_and_costs]
sorted_costs = [item[1] for item in sorted_nodes_and_costs]

# Convert costs to €/MWh
adjusted_costs = [cost *1e6 / demand_in_mwh for cost in sorted_costs]

# Generate colors - ensuring consistent colors across plots
colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_nodes)))

# Plot 1: Stacked Horizontal Bar Chart
plt.figure(figsize=(10, 2))
cumulative_cost = 0  # Start at 0 for the leftmost bar segment

for node, cost, color in zip(sorted_nodes, adjusted_costs, colors):
    plt.barh('GR Nodes', cost, left=cumulative_cost, color=color, label=node)
    cumulative_cost += cost

plt.xlabel('Cost (€/MWh)')
plt.title('Cost Breakdown per GR Node (€/MWh)')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Nodes')
plt.show()

# Plot 2: Vertical Bar Chart with Sorted Nodes
plt.figure(figsize=(10, 6))
bars = plt.bar(sorted_nodes, adjusted_costs, color=colors)

plt.xlabel('Nodes')
plt.ylabel('Cost (€/MWh)')
plt.title('Cost per GR Node (€/MWh)')
plt.xticks(rotation=45, ha="right")

# Adding the cost above each bar
for bar, cost in zip(bars, adjusted_costs):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f"{cost:.2f}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()  # Adjust layout to make room for the rotated x-axis labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_wave_production_dynamics(wave_prod_gr, start_date='2015-01-01'):
    # Create date range for the dataset
    date_range = pd.date_range(start=start_date, periods=len(wave_prod_gr), freq='H')

    # Create DataFrame for wave production
    wave_prod_df_gr = pd.DataFrame(wave_prod_gr, index=date_range, columns=['Elec'])
   
    # Smooth the data with a rolling mean
    wave_prod_df_gr['Smoothed'] = wave_prod_df_gr['Elec'].rolling(window=24).mean()
   
    # Plotting
    plt.figure(figsize=(12, 4))
    plt.fill_between(wave_prod_df_gr.index, wave_prod_df_gr['Smoothed'], color='dodgerblue', alpha=0.5)
    plt.title('Wave Energy Production Dynamics (Greenland)', fontsize=14, loc='left')
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%b'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())
    plt.ylabel('GWh')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()
    plt.show()

# %%
wave_prod_gr = np.array(d.solution.elements.WAVE_PLANT_GR.variables.electricity.values)

plot_wave_production_dynamics(wave_prod_gr)

# %%
import pandas as pd

# Example input data
# If the CSV has no header row, set header=None and provide column names
column_name = ['WaveEnergyDensity']
wave_energy_df = pd.read_csv('../../data/wave_series_goff.csv', header=None, names=column_name)

length_of_installation = d.solution.elements.WAVE_PLANT_GR.variables.length.values[0]
unit_width = d.model.nodes.WAVE_PLANT_GR.parameters.unit_width[0]  # meters
space_between = d.model.nodes.WAVE_PLANT_GR.parameters.space_between[0]  # meters

# Calculate total space required per unit (width + space)
total_space_per_unit = unit_width + space_between

# Calculate the number of units that can be installed
number_of_units = length_of_installation // total_space_per_unit

# Calculate the total energy potential for each wave energy density value
wave_energy_df['TotalEnergyPotentialGW'] = wave_energy_df['WaveEnergyDensity'] * wave_n_units * unit_width

# Calculate the total rated energy capacity based on the number of units
total_rated_capacity_gw = number_of_units * wave_RP

# Check when the total energy potential exceeds the total rated capacity
wave_energy_df['ExceedsRatedPower'] = wave_energy_df['TotalEnergyPotentialGW'] > total_rated_capacity_gw

print(wave_energy_df)
# Out:
#        WaveEnergyDensity  TotalEnergyPotentialGW  ExceedsRatedPower
# 0               0.000022                3.411002              False
# 1               0.000049                7.453907               True
# 2               0.000049                7.493494               True
# 3               0.000019                2.862862              False
# 4               0.000050                7.551501               True
# ...                  ...                     ...                ...
# 43817           0.000047                7.152744               True
# 43818           0.000027                4.101815               True
# 43819           0.000047                7.154899               True
# 43820           0.000047                7.154555               True
# 43821           0.000026                3.992724               True
#
# [43822 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Slice the DataFrame to only include the first x rows
wave_energy_df_subset = wave_energy_df.head(timehorizon)

# Convert wave_prod array/list to a pandas Series for easy plotting (match the length of the DataFrame subset)
wave_prod = pd.Series(wave_prod_gr[:timehorizon])

# For visualization, calculate the total rated capacity again for the plot
total_rated_capacity_gw = number_of_units * wave_RP

# Plotting
plt.figure(figsize=(10, 6))

# Plot Total Energy Potential GW for the subset as grey bars with 90% transparency
plt.bar(wave_energy_df_subset.index, wave_energy_df_subset['TotalEnergyPotentialGW'], color='grey', alpha=0.9, label='Total Energy Potential (GW)')

# Plot the electricity production output as a grey line with 90% transparency
plt.plot(wave_energy_df_subset.index, wave_prod, color='blue', markersize=3, label='Electricity Production Output (GW)', alpha=0.3, linewidth=2)

# Plot a line for the Total Rated Capacity GW Threshold
plt.axhline(y=total_rated_capacity_gw, color='green', linestyle='-', label='Rated Power * Number of Units (GW)')

# Set the y-axis limit to 10 times the total rated capacity
plt.ylim(0, 10 * total_rated_capacity_gw)

plt.xlabel('Index')
plt.ylabel('Energy (GW)')
plt.title('Wave Energy Potential vs. Rated Capacity Threshold (First {} Entries)'.format(timehorizon))
plt.legend()
plt.grid(True)

plt.show()

# %%
n=0
for t in range(len(wave_energy_df_subset)):
    calculated_prod = min(wave_energy_df_subset['WaveEnergyDensity'][t] * wave_n_units * unit_width, wave_RP * wave_n_units)
    if calculated_prod < wave_prod[t]:
        if 1.1*calculated_prod< wave_prod[t]:
            n+=1
        print(f"Overprod at time {t}: Calculated {round(calculated_prod,4)}, Existing {round(wave_prod[t],4)}")
    elif calculated_prod > wave_prod[t]: 
        print(f"Underprod at time {t}: Calculated {round(calculated_prod,4)}, Existing {round(wave_prod[t],4)}")
    elif calculated_prod == wave_prod[t]:
        print(f"Exactprod at time {t}: Calculated {round(calculated_prod,4)}, Existing {round(wave_prod[t],4)}")
# Out:
# Underprod at time 0: Calculated 3.411, Existing 2.0786
# Underprod at time 1: Calculated 3.4574, Existing 2.0786
# Underprod at time 2: Calculated 3.4574, Existing 2.0786
# Underprod at time 3: Calculated 2.8629, Existing 2.0786
# Underprod at time 4: Calculated 3.4574, Existing 2.0786
# Underprod at time 5: Calculated 3.4574, Existing 2.0786
# Underprod at time 6: Calculated 2.4492, Existing 2.0786
# Underprod at time 7: Calculated 3.4574, Existing 2.0895
# Underprod at time 8: Calculated 3.4574, Existing 2.2035
# Exactprod at time 9: Calculated 1.5281, Existing 1.5281
# Underprod at time 10: Calculated 3.4574, Existing 2.0786
# Underprod at time 11: Calculated 3.4574, Existing 2.0786
# Underprod at time 12: Calculated 3.4574, Existing 2.0786
# Underprod at time 13: Calculated 3.4574, Existing 2.0786
# Underprod at time 14: Calculated 3.4574, Existing 2.0786
# Underprod at time 15: Calculated 2.5578, Existing 2.0786
# Underprod at time 16: Calculated 3.4574, Existing 2.0786
# Underprod at time 17: Calculated 3.4574, Existing 2.0786
# Underprod at time 18: Calculated 3.4574, Existing 2.0786
# Underprod at time 19: Calculated 3.4574, Existing 2.0786
# Underprod at time 20: Calculated 3.4574, Existing 2.0786
# Underprod at time 21: Calculated 3.4574, Existing 2.0786
# Underprod at time 22: Calculated 3.4574, Existing 2.0786
# Underprod at time 23: Calculated 3.4574, Existing 2.0786
# Underprod at time 24: Calculated 2.2437, Existing 2.0786
# Underprod at time 25: Calculated 3.4574, Existing 2.0786
# Underprod at time 26: Calculated 3.4574, Existing 2.0786
# Underprod at time 27: Calculated 3.4574, Existing 2.0786
# Underprod at time 28: Calculated 3.4574, Existing 2.0786
# Underprod at time 29: Calculated 3.4574, Existing 2.0786
# Underprod at time 30: Calculated 2.3439, Existing 2.0786
# Underprod at time 31: Calculated 3.4574, Existing 2.0786
# Underprod at time 32: Calculated 3.4574, Existing 2.0786
# Underprod at time 33: Calculated 2.0844, Existing 2.0786
# Underprod at time 34: Calculated 3.4574, Existing 2.0786
# Underprod at time 35: Calculated 3.4574, Existing 2.0786
# Underprod at time 36: Calculated 3.4574, Existing 2.0786
# Underprod at time 37: Calculated 3.4574, Existing 2.0786
# Underprod at time 38: Calculated 3.4574, Existing 2.0786
# Underprod at time 39: Calculated 2.7959, Existing 2.0786
# Underprod at time 40: Calculated 3.4574, Existing 2.0786
# Underprod at time 41: Calculated 3.4574, Existing 2.0786
# Underprod at time 42: Calculated 3.4574, Existing 2.0786
# Underprod at time 43: Calculated 3.4574, Existing 2.0786
# Underprod at time 44: Calculated 3.4574, Existing 2.0786
# Underprod at time 45: Calculated 3.4574, Existing 2.0786
# Underprod at time 46: Calculated 3.4574, Existing 2.0786
# Underprod at time 47: Calculated 3.4574, Existing 2.0786
# Underprod at time 48: Calculated 3.4574, Existing 2.0786
# Underprod at time 49: Calculated 3.4574, Existing 2.0786
# Underprod at time 50: Calculated 3.4574, Existing 2.0786
# Underprod at time 51: Calculated 2.8867, Existing 2.0786
# Underprod at time 52: Calculated 3.4574, Existing 2.0786
# Underprod at time 53: Calculated 3.4574, Existing 2.0786
# Underprod at time 54: Calculated 2.2641, Existing 2.0786
# Underprod at time 55: Calculated 3.4574, Existing 2.0786
# Underprod at time 56: Calculated 3.4574, Existing 2.0786
# Underprod at time 57: Calculated 2.4545, Existing 2.0786
# Underprod at time 58: Calculated 3.4574, Existing 2.0786
# Underprod at time 59: Calculated 3.4574, Existing 2.0786
# Underprod at time 60: Calculated 2.5451, Existing 2.0786
# Underprod at time 61: Calculated 3.4574, Existing 2.0786
# Underprod at time 62: Calculated 3.4574, Existing 2.0786
# Underprod at time 63: Calculated 2.9203, Existing 2.0786
# Underprod at time 64: Calculated 3.4574, Existing 2.0786
# Underprod at time 65: Calculated 3.4574, Existing 2.0786
# Underprod at time 66: Calculated 3.1767, Existing 2.0786
# Underprod at time 67: Calculated 3.4574, Existing 2.0786
# Underprod at time 68: Calculated 3.4574, Existing 2.0786
# Underprod at time 69: Calculated 2.9107, Existing 2.0786
# Underprod at time 70: Calculated 3.4574, Existing 2.0786
# Underprod at time 71: Calculated 3.4574, Existing 2.0786
# Underprod at time 72: Calculated 2.2108, Existing 2.0786
# Underprod at time 73: Calculated 3.4574, Existing 2.0895
# Underprod at time 74: Calculated 3.4574, Existing 2.2035
# Exactprod at time 75: Calculated 1.4377, Existing 1.4377
# Underprod at time 76: Calculated 3.4574, Existing 2.0895
# Underprod at time 77: Calculated 3.4574, Existing 2.2035
# Exactprod at time 78: Calculated 0.9603, Existing 0.9603
# Underprod at time 79: Calculated 3.4574, Existing 2.0895
# Underprod at time 80: Calculated 3.4574, Existing 2.2035
# Exactprod at time 81: Calculated 1.4035, Existing 1.4035
# Underprod at time 82: Calculated 3.4574, Existing 2.0786
# Underprod at time 83: Calculated 3.4574, Existing 2.0786
# Underprod at time 84: Calculated 3.4574, Existing 2.0786
# Underprod at time 85: Calculated 3.4574, Existing 2.0786
# Underprod at time 86: Calculated 3.4574, Existing 2.0786
# Underprod at time 87: Calculated 3.4574, Existing 2.0786
# Underprod at time 88: Calculated 3.4574, Existing 2.0786
# Underprod at time 89: Calculated 3.4574, Existing 2.0786
# Underprod at time 90: Calculated 3.4574, Existing 2.0786
# Underprod at time 91: Calculated 3.4574, Existing 2.0786
# Underprod at time 92: Calculated 3.4574, Existing 2.0786
# Underprod at time 93: Calculated 3.4574, Existing 2.0786
# Underprod at time 94: Calculated 3.4574, Existing 2.0786
# Underprod at time 95: Calculated 3.4574, Existing 2.0786
# Underprod at time 96: Calculated 3.4574, Existing 2.0786
# Underprod at time 97: Calculated 3.4574, Existing 2.0786
# Underprod at time 98: Calculated 3.4574, Existing 2.0786
# Underprod at time 99: Calculated 3.4574, Existing 2.0786
# Underprod at time 100: Calculated 3.4574, Existing 2.0786
# Underprod at time 101: Calculated 3.4574, Existing 2.0786
# Underprod at time 102: Calculated 3.4574, Existing 2.0786
# Underprod at time 103: Calculated 3.4574, Existing 2.0786
# Underprod at time 104: Calculated 3.4574, Existing 2.0786
# Underprod at time 105: Calculated 3.4574, Existing 2.0786
# Underprod at time 106: Calculated 3.4574, Existing 2.0786
# Underprod at time 107: Calculated 3.4574, Existing 2.0786
# Underprod at time 108: Calculated 3.4574, Existing 2.0786
# Underprod at time 109: Calculated 3.4574, Existing 2.0786
# Underprod at time 110: Calculated 3.4574, Existing 2.0786
# Underprod at time 111: Calculated 3.4574, Existing 2.0786
# Underprod at time 112: Calculated 3.4574, Existing 2.0786
# Underprod at time 113: Calculated 3.4574, Existing 2.0786
# Underprod at time 114: Calculated 3.4574, Existing 2.0786
# Underprod at time 115: Calculated 3.4574, Existing 2.0786
# Underprod at time 116: Calculated 3.4574, Existing 2.0786
# Underprod at time 117: Calculated 2.9115, Existing 2.0786
# Underprod at time 118: Calculated 3.4574, Existing 2.0786
# Underprod at time 119: Calculated 3.4574, Existing 2.0786
# Underprod at time 120: Calculated 3.3748, Existing 2.0786
# Underprod at time 121: Calculated 3.4574, Existing 2.0786
# Underprod at time 122: Calculated 3.4574, Existing 2.0786
# Underprod at time 123: Calculated 3.4574, Existing 2.0786
# Underprod at time 124: Calculated 3.4574, Existing 2.0786
# Underprod at time 125: Calculated 3.4574, Existing 2.0786
# Underprod at time 126: Calculated 2.6878, Existing 2.0786
# Underprod at time 127: Calculated 3.4574, Existing 2.0895
# Underprod at time 128: Calculated 3.4574, Existing 2.2035
# Underprod at time 129: Calculated 1.6941, Existing 1.6941
# Underprod at time 130: Calculated 3.4574, Existing 2.0895
# Underprod at time 131: Calculated 3.4574, Existing 2.2035
# Exactprod at time 132: Calculated 0.9778, Existing 0.9778
# Underprod at time 133: Calculated 3.4574, Existing 2.0895
# Underprod at time 134: Calculated 3.4574, Existing 2.2035
# Overprod at time 135: Calculated 0.4214, Existing 0.4214
# Underprod at time 136: Calculated 3.4574, Existing 2.0786
# Underprod at time 137: Calculated 3.4574, Existing 2.0786
# Underprod at time 138: Calculated 3.4574, Existing 2.0786
# Underprod at time 139: Calculated 3.4574, Existing 2.0786
# Underprod at time 140: Calculated 3.4574, Existing 2.0786
# Underprod at time 141: Calculated 3.4574, Existing 2.0786
# Underprod at time 142: Calculated 3.4574, Existing 2.0786
# Underprod at time 143: Calculated 3.4574, Existing 2.0786
# Underprod at time 144: Calculated 3.4574, Existing 2.0786
# Underprod at time 145: Calculated 3.4574, Existing 2.0786
# Underprod at time 146: Calculated 3.4574, Existing 2.0786
# Underprod at time 147: Calculated 3.4574, Existing 2.0786
# Underprod at time 148: Calculated 3.4574, Existing 2.0786
# Underprod at time 149: Calculated 3.4574, Existing 2.0786
# Underprod at time 150: Calculated 3.4574, Existing 2.0786
# Underprod at time 151: Calculated 3.4574, Existing 2.0786
# Underprod at time 152: Calculated 3.4574, Existing 2.0786
# Underprod at time 153: Calculated 3.4574, Existing 2.0786
# Underprod at time 154: Calculated 3.4574, Existing 2.0786
# Underprod at time 155: Calculated 3.4574, Existing 2.0786
# Underprod at time 156: Calculated 3.4574, Existing 2.0786
# Underprod at time 157: Calculated 3.4574, Existing 2.0786
# Underprod at time 158: Calculated 3.4574, Existing 2.0786
# Underprod at time 159: Calculated 3.4574, Existing 2.0786
# Underprod at time 160: Calculated 3.4574, Existing 2.0786
# Underprod at time 161: Calculated 3.4574, Existing 2.0786
# Underprod at time 162: Calculated 3.4574, Existing 2.0786
# Underprod at time 163: Calculated 3.4574, Existing 2.0786
# Underprod at time 164: Calculated 3.4574, Existing 2.0786
# Underprod at time 165: Calculated 3.4574, Existing 2.0786
# Underprod at time 166: Calculated 3.4574, Existing 2.0786
# Underprod at time 167: Calculated 3.4574, Existing 2.0786
# Underprod at time 168: Calculated 3.4574, Existing 2.0786
# Underprod at time 169: Calculated 3.4574, Existing 2.0786
# Underprod at time 170: Calculated 3.4574, Existing 2.0786
# Underprod at time 171: Calculated 3.4574, Existing 2.0786
# Underprod at time 172: Calculated 3.4574, Existing 2.0786
# Underprod at time 173: Calculated 3.4574, Existing 2.0786
# Underprod at time 174: Calculated 3.4574, Existing 2.0786
# Underprod at time 175: Calculated 3.4574, Existing 2.0786
# Underprod at time 176: Calculated 3.4574, Existing 2.0786
# Underprod at time 177: Calculated 3.4574, Existing 2.0786
# Underprod at time 178: Calculated 3.4574, Existing 2.0786
# Underprod at time 179: Calculated 3.4574, Existing 2.0786
# Underprod at time 180: Calculated 3.4574, Existing 2.0786
# Underprod at time 181: Calculated 3.4574, Existing 2.0786
# Underprod at time 182: Calculated 3.4574, Existing 2.0786
# Underprod at time 183: Calculated 3.4574, Existing 2.0786
# Underprod at time 184: Calculated 3.4574, Existing 2.0786
# Underprod at time 185: Calculated 3.4574, Existing 2.0786
# Underprod at time 186: Calculated 3.4574, Existing 2.0786
# Underprod at time 187: Calculated 3.4574, Existing 2.0786
# Underprod at time 188: Calculated 3.4574, Existing 2.0786
# Underprod at time 189: Calculated 3.4574, Existing 2.0786
# Underprod at time 190: Calculated 3.4574, Existing 2.0786
# Underprod at time 191: Calculated 3.4574, Existing 2.0786
# Underprod at time 192: Calculated 3.4574, Existing 2.0786
# Underprod at time 193: Calculated 3.4574, Existing 2.0786
# Underprod at time 194: Calculated 3.4574, Existing 2.0786
# Underprod at time 195: Calculated 3.4574, Existing 2.0786
# Underprod at time 196: Calculated 3.4574, Existing 2.0786
# Underprod at time 197: Calculated 3.4574, Existing 2.0786
# Underprod at time 198: Calculated 3.4574, Existing 2.0786
# Underprod at time 199: Calculated 3.4574, Existing 2.0786
# Underprod at time 200: Calculated 3.4574, Existing 2.0786
# Underprod at time 201: Calculated 3.4574, Existing 2.0786
# Underprod at time 202: Calculated 3.4574, Existing 2.0786
# Underprod at time 203: Calculated 3.4574, Existing 2.0786
# Underprod at time 204: Calculated 3.1426, Existing 2.0786
# Underprod at time 205: Calculated 3.4574, Existing 2.0786
# Underprod at time 206: Calculated 3.4574, Existing 2.0786
# Underprod at time 207: Calculated 2.6841, Existing 2.0786
# Underprod at time 208: Calculated 3.4574, Existing 2.0786
# Underprod at time 209: Calculated 3.4574, Existing 2.0786
# Underprod at time 210: Calculated 3.4574, Existing 2.0786
# Underprod at time 211: Calculated 3.4574, Existing 2.0786
# Underprod at time 212: Calculated 3.4574, Existing 2.0786
# Underprod at time 213: Calculated 3.4574, Existing 2.0786
# Underprod at time 214: Calculated 3.4574, Existing 2.0786
# Underprod at time 215: Calculated 3.4574, Existing 2.0786
# Underprod at time 216: Calculated 3.4574, Existing 2.0786
# Underprod at time 217: Calculated 3.4574, Existing 2.0786
# Underprod at time 218: Calculated 3.4574, Existing 2.0786
# Underprod at time 219: Calculated 3.4574, Existing 2.0786
# Underprod at time 220: Calculated 3.4574, Existing 2.0786
# Underprod at time 221: Calculated 3.4574, Existing 2.0786
# Underprod at time 222: Calculated 3.4574, Existing 2.0786
# Underprod at time 223: Calculated 3.4574, Existing 2.0786
# Underprod at time 224: Calculated 3.4574, Existing 2.0786
# Underprod at time 225: Calculated 3.4574, Existing 2.0786
# Underprod at time 226: Calculated 3.4574, Existing 2.0786
# Underprod at time 227: Calculated 3.4574, Existing 2.0786
# Underprod at time 228: Calculated 3.4574, Existing 2.0786
# Underprod at time 229: Calculated 3.4574, Existing 2.0786
# Underprod at time 230: Calculated 3.4574, Existing 2.0786
# Underprod at time 231: Calculated 3.4574, Existing 2.0786
# Underprod at time 232: Calculated 3.4574, Existing 2.0786
# Underprod at time 233: Calculated 3.4574, Existing 2.0786
# Underprod at time 234: Calculated 3.4574, Existing 2.0786
# Underprod at time 235: Calculated 3.4574, Existing 2.0786
# Underprod at time 236: Calculated 3.4574, Existing 2.0786
# Underprod at time 237: Calculated 3.4574, Existing 2.0786
# Underprod at time 238: Calculated 3.4574, Existing 2.0786
# Underprod at time 239: Calculated 3.4574, Existing 2.0786
# Underprod at time 240: Calculated 3.4574, Existing 2.0786
# Underprod at time 241: Calculated 3.4574, Existing 2.0786
# Underprod at time 242: Calculated 3.4574, Existing 2.0786
# Underprod at time 243: Calculated 3.4574, Existing 2.0786
# Underprod at time 244: Calculated 3.4574, Existing 2.0786
# Underprod at time 245: Calculated 3.4574, Existing 2.0786
# Underprod at time 246: Calculated 3.4574, Existing 2.0786
# Underprod at time 247: Calculated 3.4574, Existing 2.0786
# Underprod at time 248: Calculated 3.4574, Existing 2.0786
# Underprod at time 249: Calculated 3.4574, Existing 2.0786
# Underprod at time 250: Calculated 3.4574, Existing 2.0786
# Underprod at time 251: Calculated 3.4574, Existing 2.0786
# Underprod at time 252: Calculated 3.4574, Existing 2.0786
# Underprod at time 253: Calculated 3.4574, Existing 2.0786
# Underprod at time 254: Calculated 3.4574, Existing 2.0786
# Underprod at time 255: Calculated 3.4574, Existing 2.0786
# Underprod at time 256: Calculated 3.4574, Existing 2.0786
# Underprod at time 257: Calculated 3.4574, Existing 2.0786
# Underprod at time 258: Calculated 3.4574, Existing 2.0786
# Underprod at time 259: Calculated 3.4574, Existing 2.0786
# Underprod at time 260: Calculated 3.4574, Existing 2.0786
# Underprod at time 261: Calculated 3.4574, Existing 2.0786
# Underprod at time 262: Calculated 3.4574, Existing 2.0786
# Underprod at time 263: Calculated 3.4574, Existing 2.0786
# Underprod at time 264: Calculated 3.4574, Existing 2.0786
# Underprod at time 265: Calculated 3.4574, Existing 2.0786
# Underprod at time 266: Calculated 3.4574, Existing 2.0786
# Underprod at time 267: Calculated 3.4574, Existing 2.0786
# Underprod at time 268: Calculated 3.4574, Existing 2.0786
# Underprod at time 269: Calculated 3.4574, Existing 2.0786
# Underprod at time 270: Calculated 3.4574, Existing 2.0786
# Underprod at time 271: Calculated 3.4574, Existing 2.0786
# Underprod at time 272: Calculated 3.4574, Existing 2.0786
# Underprod at time 273: Calculated 3.4574, Existing 2.0786
# Underprod at time 274: Calculated 3.4574, Existing 2.0786
# Underprod at time 275: Calculated 3.4574, Existing 2.0786
# Underprod at time 276: Calculated 3.4574, Existing 2.0786
# Underprod at time 277: Calculated 3.4574, Existing 2.0786
# Underprod at time 278: Calculated 3.4574, Existing 2.0786
# Underprod at time 279: Calculated 3.4574, Existing 2.0786
# Underprod at time 280: Calculated 3.4574, Existing 2.0786
# Underprod at time 281: Calculated 3.4574, Existing 2.0786
# Underprod at time 282: Calculated 3.4574, Existing 2.0786
# Underprod at time 283: Calculated 3.4574, Existing 2.0786
# Underprod at time 284: Calculated 3.4574, Existing 2.0786
# Underprod at time 285: Calculated 3.4574, Existing 2.0786
# Underprod at time 286: Calculated 3.4574, Existing 2.0786
# Underprod at time 287: Calculated 3.4574, Existing 2.0786
# Underprod at time 288: Calculated 3.4574, Existing 2.0786
# Underprod at time 289: Calculated 3.4574, Existing 2.0786
# Underprod at time 290: Calculated 3.4574, Existing 2.0786
# Underprod at time 291: Calculated 3.4574, Existing 2.0786
# Underprod at time 292: Calculated 3.4574, Existing 2.0786
# Underprod at time 293: Calculated 3.4574, Existing 2.0786
# Underprod at time 294: Calculated 3.4574, Existing 2.0786
# Underprod at time 295: Calculated 3.4574, Existing 2.0786
# Underprod at time 296: Calculated 3.4574, Existing 2.0786
# Underprod at time 297: Calculated 3.4574, Existing 2.0786
# Underprod at time 298: Calculated 3.4574, Existing 2.0786
# Underprod at time 299: Calculated 3.4574, Existing 2.0786
# Underprod at time 300: Calculated 3.4574, Existing 2.0786
# Underprod at time 301: Calculated 3.4574, Existing 2.0786
# Underprod at time 302: Calculated 3.4574, Existing 2.0786
# Underprod at time 303: Calculated 3.4574, Existing 2.0786
# Underprod at time 304: Calculated 3.4574, Existing 2.0786
# Underprod at time 305: Calculated 3.4574, Existing 2.0786
# Underprod at time 306: Calculated 3.4574, Existing 2.0786
# Underprod at time 307: Calculated 3.4574, Existing 2.0786
# Underprod at time 308: Calculated 3.4574, Existing 2.0786
# Underprod at time 309: Calculated 3.4574, Existing 2.0786
# Underprod at time 310: Calculated 3.4574, Existing 2.0786
# Underprod at time 311: Calculated 3.4574, Existing 2.0786
# Underprod at time 312: Calculated 3.4574, Existing 2.0786
# Underprod at time 313: Calculated 3.4574, Existing 2.0786
# Underprod at time 314: Calculated 3.4574, Existing 2.0786
# Underprod at time 315: Calculated 3.4574, Existing 2.0786
# Underprod at time 316: Calculated 3.4574, Existing 2.0786
# Underprod at time 317: Calculated 3.4574, Existing 2.0786
# Underprod at time 318: Calculated 3.4574, Existing 2.0786
# Underprod at time 319: Calculated 3.4574, Existing 2.0786
# Underprod at time 320: Calculated 3.4574, Existing 2.0786
# Underprod at time 321: Calculated 3.4574, Existing 2.0786
# Underprod at time 322: Calculated 3.4574, Existing 2.0786
# Underprod at time 323: Calculated 3.4574, Existing 2.0786
# Underprod at time 324: Calculated 2.7668, Existing 2.0786
# Underprod at time 325: Calculated 3.4574, Existing 2.0786
# Underprod at time 326: Calculated 3.4574, Existing 2.0786
# Underprod at time 327: Calculated 3.4574, Existing 2.0786
# Underprod at time 328: Calculated 3.4574, Existing 2.0786
# Underprod at time 329: Calculated 3.4574, Existing 2.0786
# Underprod at time 330: Calculated 3.4574, Existing 2.0786
# Underprod at time 331: Calculated 3.4574, Existing 2.0786
# Underprod at time 332: Calculated 3.4574, Existing 2.0786
# Underprod at time 333: Calculated 3.4574, Existing 2.0786
# Underprod at time 334: Calculated 3.4574, Existing 2.0786
# Underprod at time 335: Calculated 3.4574, Existing 2.0786
# Underprod at time 336: Calculated 3.4574, Existing 2.0786
# Underprod at time 337: Calculated 3.4574, Existing 2.0786
# Underprod at time 338: Calculated 3.4574, Existing 2.0786
# Underprod at time 339: Calculated 3.4574, Existing 2.0786
# Underprod at time 340: Calculated 3.4574, Existing 2.0786
# Underprod at time 341: Calculated 3.4574, Existing 2.0786
# Underprod at time 342: Calculated 3.4574, Existing 2.0786
# Underprod at time 343: Calculated 3.4574, Existing 2.0786
# Underprod at time 344: Calculated 3.4574, Existing 2.0786
# Underprod at time 345: Calculated 3.4574, Existing 2.0786
# Underprod at time 346: Calculated 3.4574, Existing 2.0786
# Underprod at time 347: Calculated 3.4574, Existing 2.0786
# Underprod at time 348: Calculated 3.4574, Existing 2.0786
# Underprod at time 349: Calculated 3.4574, Existing 2.0786
# Underprod at time 350: Calculated 3.4574, Existing 2.0786
# Underprod at time 351: Calculated 3.4574, Existing 2.0786
# Underprod at time 352: Calculated 3.4574, Existing 2.0786
# Underprod at time 353: Calculated 3.4574, Existing 2.0786
# Underprod at time 354: Calculated 3.4574, Existing 2.0786
# Underprod at time 355: Calculated 3.4574, Existing 2.0786
# Underprod at time 356: Calculated 3.4574, Existing 2.0786
# Underprod at time 357: Calculated 3.4574, Existing 2.0786
# Underprod at time 358: Calculated 3.4574, Existing 2.0786
# Underprod at time 359: Calculated 3.4574, Existing 2.0786
# Underprod at time 360: Calculated 3.0671, Existing 2.0786
# Underprod at time 361: Calculated 3.4574, Existing 2.0786
# Underprod at time 362: Calculated 3.4574, Existing 2.0786
# Underprod at time 363: Calculated 3.4574, Existing 2.0786
# Underprod at time 364: Calculated 3.4574, Existing 2.0786
# Underprod at time 365: Calculated 3.4574, Existing 2.0786
# Underprod at time 366: Calculated 3.4574, Existing 2.0786
# Underprod at time 367: Calculated 3.4574, Existing 2.0786
# Underprod at time 368: Calculated 3.4574, Existing 2.0786
# Underprod at time 369: Calculated 3.4574, Existing 2.0786
# Underprod at time 370: Calculated 3.4574, Existing 2.0786
# Underprod at time 371: Calculated 3.4574, Existing 2.0786
# Underprod at time 372: Calculated 3.4574, Existing 2.0786
# Underprod at time 373: Calculated 3.4574, Existing 2.0786
# Underprod at time 374: Calculated 3.4574, Existing 2.0786
# Underprod at time 375: Calculated 2.565, Existing 2.0786
# Underprod at time 376: Calculated 3.4574, Existing 2.0786
# Underprod at time 377: Calculated 3.4574, Existing 2.0786
# Underprod at time 378: Calculated 2.2792, Existing 2.0786
# Underprod at time 379: Calculated 3.4574, Existing 2.0786
# Underprod at time 380: Calculated 3.4574, Existing 2.0786
# Underprod at time 381: Calculated 2.2766, Existing 2.0786
# Underprod at time 382: Calculated 3.4574, Existing 2.0895
# Underprod at time 383: Calculated 3.4574, Existing 2.2035
# Overprod at time 384: Calculated 1.5146, Existing 1.5146
# Underprod at time 385: Calculated 3.4574, Existing 2.0786
# Underprod at time 386: Calculated 3.4574, Existing 2.0786
# Underprod at time 387: Calculated 2.3043, Existing 2.0786
# Underprod at time 388: Calculated 3.4574, Existing 2.0786
# Underprod at time 389: Calculated 3.4574, Existing 2.1999
# Underprod at time 390: Calculated 1.9671, Existing 1.9671
# Underprod at time 391: Calculated 3.4574, Existing 2.0895
# Underprod at time 392: Calculated 3.4574, Existing 2.2035
# Underprod at time 393: Calculated 1.4979, Existing 1.4979
# Underprod at time 394: Calculated 3.4574, Existing 2.0895
# Underprod at time 395: Calculated 3.4574, Existing 2.2035
# Overprod at time 396: Calculated 1.574, Existing 1.574
# Underprod at time 397: Calculated 3.4574, Existing 2.0895
# Underprod at time 398: Calculated 3.4574, Existing 2.2035
# Overprod at time 399: Calculated 1.8537, Existing 1.8537
# Underprod at time 400: Calculated 3.4574, Existing 2.0786
# Underprod at time 401: Calculated 3.4574, Existing 2.0786
# Underprod at time 402: Calculated 2.6827, Existing 2.0786
# Underprod at time 403: Calculated 3.4574, Existing 2.0786
# Underprod at time 404: Calculated 3.4574, Existing 2.0786
# Underprod at time 405: Calculated 3.0451, Existing 2.0786
# Underprod at time 406: Calculated 3.4574, Existing 2.0786
# Underprod at time 407: Calculated 3.4574, Existing 2.0786
# Underprod at time 408: Calculated 3.1166, Existing 2.0786
# Underprod at time 409: Calculated 3.4574, Existing 2.0786
# Underprod at time 410: Calculated 3.4574, Existing 2.0786
# Underprod at time 411: Calculated 3.4574, Existing 2.0786
# Underprod at time 412: Calculated 3.4574, Existing 2.0786
# Underprod at time 413: Calculated 3.4574, Existing 2.0786
# Underprod at time 414: Calculated 3.4574, Existing 2.0786
# Underprod at time 415: Calculated 3.4574, Existing 2.0786
# Underprod at time 416: Calculated 3.4574, Existing 2.0786
# Underprod at time 417: Calculated 3.4574, Existing 2.0786
# Underprod at time 418: Calculated 3.4574, Existing 2.0786
# Underprod at time 419: Calculated 3.4574, Existing 2.0786
# Underprod at time 420: Calculated 3.4574, Existing 2.0786
# Underprod at time 421: Calculated 3.4574, Existing 2.0786
# Underprod at time 422: Calculated 3.4574, Existing 2.0786
# Underprod at time 423: Calculated 3.4574, Existing 2.0786
# Underprod at time 424: Calculated 3.4574, Existing 2.0786
# Underprod at time 425: Calculated 3.4574, Existing 2.0786
# Underprod at time 426: Calculated 3.4574, Existing 2.0786
# Underprod at time 427: Calculated 3.4574, Existing 2.0786
# Underprod at time 428: Calculated 3.4574, Existing 2.0786
# Underprod at time 429: Calculated 3.4574, Existing 2.0786
# Underprod at time 430: Calculated 3.4574, Existing 2.0786
# Underprod at time 431: Calculated 3.4574, Existing 2.0786
# Underprod at time 432: Calculated 3.4574, Existing 2.0786
# Underprod at time 433: Calculated 3.4574, Existing 2.0786
# Underprod at time 434: Calculated 3.4574, Existing 2.0786
# Underprod at time 435: Calculated 3.4574, Existing 2.0786
# Underprod at time 436: Calculated 3.4574, Existing 2.0786
# Underprod at time 437: Calculated 3.4574, Existing 2.0786
# Underprod at time 438: Calculated 3.4574, Existing 2.0786
# Underprod at time 439: Calculated 3.4574, Existing 2.0786
# Underprod at time 440: Calculated 3.4574, Existing 2.0786
# Underprod at time 441: Calculated 3.4574, Existing 2.0786
# Underprod at time 442: Calculated 3.4574, Existing 2.0786
# Underprod at time 443: Calculated 3.4574, Existing 2.0786
# Underprod at time 444: Calculated 3.4574, Existing 2.0786
# Underprod at time 445: Calculated 3.4574, Existing 2.0786
# Underprod at time 446: Calculated 3.4574, Existing 2.0786
# Underprod at time 447: Calculated 3.4574, Existing 2.0786
# Underprod at time 448: Calculated 3.4574, Existing 2.0786
# Underprod at time 449: Calculated 3.4574, Existing 2.0786
# Underprod at time 450: Calculated 3.4574, Existing 2.0786
# Underprod at time 451: Calculated 3.4574, Existing 2.0786
# Underprod at time 452: Calculated 3.4574, Existing 2.0786
# Underprod at time 453: Calculated 3.4574, Existing 2.0786
# Underprod at time 454: Calculated 3.4574, Existing 2.0786
# Underprod at time 455: Calculated 3.4574, Existing 2.0786
# Underprod at time 456: Calculated 3.4574, Existing 2.0786
# Underprod at time 457: Calculated 3.4574, Existing 2.0786
# Underprod at time 458: Calculated 3.4574, Existing 2.0786
# Underprod at time 459: Calculated 3.4574, Existing 2.0786
# Underprod at time 460: Calculated 3.4574, Existing 2.0786
# Underprod at time 461: Calculated 3.4574, Existing 2.0786
# Underprod at time 462: Calculated 2.9748, Existing 2.0786
# Underprod at time 463: Calculated 3.4574, Existing 2.0786
# Underprod at time 464: Calculated 3.4574, Existing 2.0786
# Underprod at time 465: Calculated 2.4938, Existing 2.0786
# Underprod at time 466: Calculated 3.4574, Existing 2.0786
# Underprod at time 467: Calculated 3.4574, Existing 2.0786
# Underprod at time 468: Calculated 3.0328, Existing 2.0786
# Underprod at time 469: Calculated 3.4574, Existing 2.0895
# Underprod at time 470: Calculated 3.4574, Existing 2.2035
# Overprod at time 471: Calculated 1.7716, Existing 1.7716
# Underprod at time 472: Calculated 3.4574, Existing 2.0786
# Underprod at time 473: Calculated 3.4574, Existing 2.0786
# Underprod at time 474: Calculated 2.5972, Existing 2.0786
# Underprod at time 475: Calculated 3.4574, Existing 2.0786
# Underprod at time 476: Calculated 3.4574, Existing 2.0786
# Underprod at time 477: Calculated 2.1875, Existing 2.0786
# Underprod at time 478: Calculated 3.4574, Existing 2.0895
# Underprod at time 479: Calculated 3.4574, Existing 2.2035
# Exactprod at time 480: Calculated 1.7381, Existing 1.7381
# Underprod at time 481: Calculated 3.4574, Existing 2.0895
# Underprod at time 482: Calculated 3.4574, Existing 2.2035
# Overprod at time 483: Calculated 1.3822, Existing 1.3822
# Underprod at time 484: Calculated 3.4574, Existing 2.0895
# Underprod at time 485: Calculated 3.4574, Existing 2.2035
# Exactprod at time 486: Calculated 1.7401, Existing 1.7401
# Underprod at time 487: Calculated 3.4574, Existing 2.0786
# Underprod at time 488: Calculated 3.4574, Existing 2.0786
# Underprod at time 489: Calculated 2.1008, Existing 2.0786
# Underprod at time 490: Calculated 3.4574, Existing 2.0786
# Underprod at time 491: Calculated 3.4574, Existing 2.0786
# Underprod at time 492: Calculated 3.4574, Existing 2.0786
# Underprod at time 493: Calculated 3.4574, Existing 2.0786
# Underprod at time 494: Calculated 3.4574, Existing 2.0786
# Underprod at time 495: Calculated 3.4574, Existing 2.0786
# Underprod at time 496: Calculated 3.4574, Existing 2.0786
# Underprod at time 497: Calculated 3.4574, Existing 2.0786
# Underprod at time 498: Calculated 3.4574, Existing 2.0786
# Underprod at time 499: Calculated 3.4574, Existing 2.0786
# Underprod at time 500: Calculated 3.4574, Existing 2.0786
# Underprod at time 501: Calculated 3.4574, Existing 2.0786
# Underprod at time 502: Calculated 3.4574, Existing 2.0786
# Underprod at time 503: Calculated 3.4574, Existing 2.0786
# Underprod at time 504: Calculated 3.4574, Existing 2.0786
# Underprod at time 505: Calculated 3.4574, Existing 2.0786
# Underprod at time 506: Calculated 3.4574, Existing 2.0786
# Underprod at time 507: Calculated 3.4574, Existing 2.0786
# Underprod at time 508: Calculated 3.4574, Existing 2.0786
# Underprod at time 509: Calculated 3.4574, Existing 2.0786
# Underprod at time 510: Calculated 3.4574, Existing 2.0786
# Underprod at time 511: Calculated 3.4574, Existing 2.0786
# Underprod at time 512: Calculated 3.4574, Existing 2.0786
# Underprod at time 513: Calculated 3.4574, Existing 2.0786
# Underprod at time 514: Calculated 3.4574, Existing 2.0786
# Underprod at time 515: Calculated 3.4574, Existing 2.0786
# Underprod at time 516: Calculated 3.4574, Existing 2.0786
# Underprod at time 517: Calculated 3.4574, Existing 2.0786
# Underprod at time 518: Calculated 3.4574, Existing 2.0786
# Underprod at time 519: Calculated 3.4574, Existing 2.0786
# Underprod at time 520: Calculated 3.4574, Existing 2.0786
# Underprod at time 521: Calculated 3.4574, Existing 2.0786
# Underprod at time 522: Calculated 2.8326, Existing 2.0786
# Underprod at time 523: Calculated 3.4574, Existing 2.0786
# Underprod at time 524: Calculated 3.4574, Existing 2.0786
# Underprod at time 525: Calculated 2.1442, Existing 2.0786
# Underprod at time 526: Calculated 3.4574, Existing 2.0895
# Underprod at time 527: Calculated 3.4574, Existing 2.2035
# Exactprod at time 528: Calculated 1.5211, Existing 1.5211
# Underprod at time 529: Calculated 3.4574, Existing 2.0895
# Underprod at time 530: Calculated 3.4574, Existing 2.2035
# Underprod at time 531: Calculated 1.0543, Existing 1.0543
# Underprod at time 532: Calculated 3.4574, Existing 2.0895
# Underprod at time 533: Calculated 3.4574, Existing 2.2035
# Underprod at time 534: Calculated 0.7142, Existing 0.7142
# Underprod at time 535: Calculated 3.4574, Existing 2.0895
# Underprod at time 536: Calculated 3.4574, Existing 2.2035
# Overprod at time 537: Calculated 0.2664, Existing 0.2664
# Underprod at time 538: Calculated 3.4574, Existing 2.0895
# Underprod at time 539: Calculated 3.4574, Existing 2.2035
# Exactprod at time 540: Calculated 0.3848, Existing 0.3848
# Underprod at time 541: Calculated 3.4574, Existing 2.0786
# Underprod at time 542: Calculated 3.4574, Existing 2.0786
# Underprod at time 543: Calculated 2.3335, Existing 2.0786
# Underprod at time 544: Calculated 3.4574, Existing 2.0786
# Underprod at time 545: Calculated 3.4574, Existing 2.0786
# Underprod at time 546: Calculated 2.1483, Existing 2.0786
# Underprod at time 547: Calculated 3.4574, Existing 2.0895
# Underprod at time 548: Calculated 3.4574, Existing 2.2035
# Exactprod at time 549: Calculated 1.3556, Existing 1.3556
# Underprod at time 550: Calculated 3.4574, Existing 2.0895
# Underprod at time 551: Calculated 3.4574, Existing 2.2035
# Exactprod at time 552: Calculated 0.9472, Existing 0.9472
# Underprod at time 553: Calculated 3.4574, Existing 2.0895
# Underprod at time 554: Calculated 3.4574, Existing 2.2035
# Exactprod at time 555: Calculated 0.5895, Existing 0.5895
# Underprod at time 556: Calculated 3.4574, Existing 2.0895
# Underprod at time 557: Calculated 3.4574, Existing 2.2035
# Underprod at time 558: Calculated 0.7123, Existing 0.7123
# Underprod at time 559: Calculated 3.4574, Existing 2.0895
# Underprod at time 560: Calculated 3.4574, Existing 2.2035
# Exactprod at time 561: Calculated 0.5078, Existing 0.5078
# Underprod at time 562: Calculated 3.4574, Existing 2.0895
# Underprod at time 563: Calculated 3.4574, Existing 2.2035
# Exactprod at time 564: Calculated 1.0816, Existing 1.0816
# Underprod at time 565: Calculated 3.4574, Existing 2.0786
# Underprod at time 566: Calculated 3.4574, Existing 2.0786
# Underprod at time 567: Calculated 2.3249, Existing 2.0786
# Underprod at time 568: Calculated 3.4574, Existing 2.0786
# Underprod at time 569: Calculated 3.4574, Existing 2.0786
# Underprod at time 570: Calculated 3.4574, Existing 2.0786
# Underprod at time 571: Calculated 3.4574, Existing 2.0786
# Underprod at time 572: Calculated 3.4574, Existing 2.0786
# Underprod at time 573: Calculated 3.4574, Existing 2.0786
# Underprod at time 574: Calculated 3.4574, Existing 2.0786
# Underprod at time 575: Calculated 3.4574, Existing 2.0786
# Underprod at time 576: Calculated 3.4574, Existing 2.0786
# Underprod at time 577: Calculated 3.4574, Existing 2.0786
# Underprod at time 578: Calculated 3.4574, Existing 2.0786
# Underprod at time 579: Calculated 3.4574, Existing 2.0786
# Underprod at time 580: Calculated 3.4574, Existing 2.0786
# Underprod at time 581: Calculated 3.4574, Existing 2.0786
# Underprod at time 582: Calculated 3.4574, Existing 2.0786
# Underprod at time 583: Calculated 3.4574, Existing 2.0786
# Underprod at time 584: Calculated 3.4574, Existing 2.0786
# Underprod at time 585: Calculated 3.4574, Existing 2.0786
# Underprod at time 586: Calculated 3.4574, Existing 2.0786
# Underprod at time 587: Calculated 3.4574, Existing 2.0786
# Underprod at time 588: Calculated 3.0346, Existing 2.0786
# Underprod at time 589: Calculated 3.4574, Existing 2.0786
# Underprod at time 590: Calculated 3.4574, Existing 2.0786
# Underprod at time 591: Calculated 2.2572, Existing 2.0786
# Underprod at time 592: Calculated 3.4574, Existing 2.0786
# Underprod at time 593: Calculated 3.4574, Existing 2.0786
# Underprod at time 594: Calculated 3.4574, Existing 2.0786
# Underprod at time 595: Calculated 3.4574, Existing 2.0786
# Underprod at time 596: Calculated 3.4574, Existing 2.0786
# Underprod at time 597: Calculated 3.4574, Existing 2.0786
# Underprod at time 598: Calculated 3.4574, Existing 2.0786
# Underprod at time 599: Calculated 3.4574, Existing 2.0786
# Underprod at time 600: Calculated 3.0595, Existing 2.0786
# Underprod at time 601: Calculated 3.4574, Existing 2.0786
# Underprod at time 602: Calculated 3.4574, Existing 2.0786
# Underprod at time 603: Calculated 2.628, Existing 2.0786
# Underprod at time 604: Calculated 3.4574, Existing 2.0786
# Underprod at time 605: Calculated 3.4574, Existing 2.0786
# Underprod at time 606: Calculated 3.4574, Existing 2.0786
# Underprod at time 607: Calculated 3.4574, Existing 2.0786
# Underprod at time 608: Calculated 3.4574, Existing 2.0786
# Underprod at time 609: Calculated 3.4574, Existing 2.0786
# Underprod at time 610: Calculated 3.4574, Existing 2.0786
# Underprod at time 611: Calculated 3.4574, Existing 2.0786
# Underprod at time 612: Calculated 3.4574, Existing 2.0786
# Underprod at time 613: Calculated 3.4574, Existing 2.0786
# Underprod at time 614: Calculated 3.4574, Existing 2.0786
# Underprod at time 615: Calculated 3.4574, Existing 2.0786
# Underprod at time 616: Calculated 3.4574, Existing 2.0786
# Underprod at time 617: Calculated 3.4574, Existing 2.0786
# Underprod at time 618: Calculated 3.4574, Existing 2.0786
# Underprod at time 619: Calculated 3.4574, Existing 2.0786
# Underprod at time 620: Calculated 3.4574, Existing 2.0786
# Underprod at time 621: Calculated 3.4574, Existing 2.0786
# Underprod at time 622: Calculated 3.4574, Existing 2.0786
# Underprod at time 623: Calculated 3.4574, Existing 2.0786
# Underprod at time 624: Calculated 3.4574, Existing 2.0786
# Underprod at time 625: Calculated 3.4574, Existing 2.0786
# Underprod at time 626: Calculated 3.4574, Existing 2.0786
# Underprod at time 627: Calculated 3.4574, Existing 2.0786
# Underprod at time 628: Calculated 3.4574, Existing 2.0786
# Underprod at time 629: Calculated 3.4574, Existing 2.0786
# Underprod at time 630: Calculated 3.4574, Existing 2.0786
# Underprod at time 631: Calculated 3.4574, Existing 2.0786
# Underprod at time 632: Calculated 3.4574, Existing 2.0786
# Underprod at time 633: Calculated 3.4574, Existing 2.0786
# Underprod at time 634: Calculated 3.4574, Existing 2.0786
# Underprod at time 635: Calculated 3.4574, Existing 2.0786
# Underprod at time 636: Calculated 3.4574, Existing 2.0786
# Underprod at time 637: Calculated 3.4574, Existing 2.0786
# Underprod at time 638: Calculated 3.4574, Existing 2.0786
# Underprod at time 639: Calculated 3.4574, Existing 2.0786
# Underprod at time 640: Calculated 3.4574, Existing 2.0786
# Underprod at time 641: Calculated 3.4574, Existing 2.0786
# Underprod at time 642: Calculated 3.4574, Existing 2.0786
# Underprod at time 643: Calculated 3.4574, Existing 2.0786
# Underprod at time 644: Calculated 3.4574, Existing 2.0786
# Underprod at time 645: Calculated 3.4574, Existing 2.0786
# Underprod at time 646: Calculated 3.4574, Existing 2.0786
# Underprod at time 647: Calculated 3.4574, Existing 2.0786
# Underprod at time 648: Calculated 3.4574, Existing 2.0786
# Underprod at time 649: Calculated 3.4574, Existing 2.0786
# Underprod at time 650: Calculated 3.4574, Existing 2.0786
# Underprod at time 651: Calculated 3.4574, Existing 2.0786
# Underprod at time 652: Calculated 3.4574, Existing 2.0786
# Underprod at time 653: Calculated 3.4574, Existing 2.0786
# Underprod at time 654: Calculated 3.4574, Existing 2.0786
# Underprod at time 655: Calculated 3.4574, Existing 2.0786
# Underprod at time 656: Calculated 3.4574, Existing 2.0786
# Underprod at time 657: Calculated 3.4574, Existing 2.0786
# Underprod at time 658: Calculated 3.4574, Existing 2.0786
# Underprod at time 659: Calculated 3.4574, Existing 2.0786
# Underprod at time 660: Calculated 3.4574, Existing 2.0786
# Underprod at time 661: Calculated 3.4574, Existing 2.0786
# Underprod at time 662: Calculated 3.4574, Existing 2.0786
# Underprod at time 663: Calculated 2.8509, Existing 2.0786
# Underprod at time 664: Calculated 3.4574, Existing 2.0786
# Underprod at time 665: Calculated 3.4574, Existing 2.0786
# Underprod at time 666: Calculated 2.3232, Existing 2.0786
# Underprod at time 667: Calculated 3.4574, Existing 2.0786
# Underprod at time 668: Calculated 3.4574, Existing 2.0786
# Underprod at time 669: Calculated 3.4574, Existing 2.0786
# Underprod at time 670: Calculated 3.4574, Existing 2.0786
# Underprod at time 671: Calculated 3.4574, Existing 2.0786
# Underprod at time 672: Calculated 3.4574, Existing 2.0786
# Underprod at time 673: Calculated 3.4574, Existing 2.0786
# Underprod at time 674: Calculated 3.4574, Existing 2.0786
# Underprod at time 675: Calculated 3.1651, Existing 2.0786
# Underprod at time 676: Calculated 3.4574, Existing 2.0895
# Underprod at time 677: Calculated 3.4574, Existing 2.2035
# Exactprod at time 678: Calculated 1.806, Existing 1.806
# Underprod at time 679: Calculated 3.4574, Existing 2.0895
# Underprod at time 680: Calculated 3.4574, Existing 2.2035
# Exactprod at time 681: Calculated 1.2744, Existing 1.2744
# Underprod at time 682: Calculated 3.4574, Existing 2.0895
# Underprod at time 683: Calculated 3.4574, Existing 2.2035
# Overprod at time 684: Calculated 0.8423, Existing 0.8423
# Underprod at time 685: Calculated 3.4574, Existing 2.0786
# Underprod at time 686: Calculated 3.4574, Existing 2.0786
# Underprod at time 687: Calculated 2.3696, Existing 2.0786
# Underprod at time 688: Calculated 3.4574, Existing 2.0786
# Underprod at time 689: Calculated 3.4574, Existing 2.0786
# Underprod at time 690: Calculated 3.4574, Existing 2.0786
# Underprod at time 691: Calculated 3.4574, Existing 2.0786
# Underprod at time 692: Calculated 3.4574, Existing 2.0786
# Underprod at time 693: Calculated 3.4574, Existing 2.0786
# Underprod at time 694: Calculated 3.4574, Existing 2.0786
# Underprod at time 695: Calculated 3.4574, Existing 2.0786
# Underprod at time 696: Calculated 3.4574, Existing 2.0786
# Underprod at time 697: Calculated 3.4574, Existing 2.0786
# Underprod at time 698: Calculated 3.4574, Existing 2.0786
# Underprod at time 699: Calculated 3.4574, Existing 2.0786
# Underprod at time 700: Calculated 3.4574, Existing 2.0786
# Underprod at time 701: Calculated 3.4574, Existing 2.0786
# Underprod at time 702: Calculated 3.4574, Existing 2.0786
# Underprod at time 703: Calculated 3.4574, Existing 2.0786
# Underprod at time 704: Calculated 3.4574, Existing 2.0786
# Underprod at time 705: Calculated 3.4574, Existing 2.0786
# Underprod at time 706: Calculated 3.4574, Existing 2.0786
# Underprod at time 707: Calculated 3.4574, Existing 2.0786
# Underprod at time 708: Calculated 3.4574, Existing 2.0786
# Underprod at time 709: Calculated 3.4574, Existing 2.0786
# Underprod at time 710: Calculated 3.4574, Existing 2.0786
# Underprod at time 711: Calculated 3.4574, Existing 2.0786
# Underprod at time 712: Calculated 3.4574, Existing 2.0786
# Underprod at time 713: Calculated 3.4574, Existing 2.0786
# Underprod at time 714: Calculated 3.4574, Existing 2.0786
# Underprod at time 715: Calculated 3.4574, Existing 2.0786
# Underprod at time 716: Calculated 3.4574, Existing 2.0786
# Underprod at time 717: Calculated 2.9449, Existing 2.0786
# Underprod at time 718: Calculated 3.4574, Existing 2.0786
# Underprod at time 719: Calculated 3.4574, Existing 2.0786
# Underprod at time 720: Calculated 3.4574, Existing 2.0786
# Underprod at time 721: Calculated 3.4574, Existing 2.0786
# Underprod at time 722: Calculated 3.4574, Existing 2.0786
# Underprod at time 723: Calculated 3.4574, Existing 2.0786
# Underprod at time 724: Calculated 3.4574, Existing 2.0786
# Underprod at time 725: Calculated 3.4574, Existing 2.0786
# Underprod at time 726: Calculated 3.4574, Existing 2.0786
# Underprod at time 727: Calculated 3.4574, Existing 2.0786
# Underprod at time 728: Calculated 3.4574, Existing 2.0786
# Underprod at time 729: Calculated 3.4574, Existing 2.0786
# Underprod at time 730: Calculated 3.4574, Existing 2.0786
# Underprod at time 731: Calculated 3.4574, Existing 2.0786
# Underprod at time 732: Calculated 3.4574, Existing 2.0786
# Underprod at time 733: Calculated 3.4574, Existing 2.0786
# Underprod at time 734: Calculated 3.4574, Existing 2.0786
# Underprod at time 735: Calculated 2.7908, Existing 2.0786
# Underprod at time 736: Calculated 3.4574, Existing 2.0895
# Underprod at time 737: Calculated 3.4574, Existing 2.2035
# Exactprod at time 738: Calculated 1.9323, Existing 1.9323
# Underprod at time 739: Calculated 3.4574, Existing 2.0786
# Underprod at time 740: Calculated 3.4574, Existing 2.0786
# Underprod at time 741: Calculated 2.1056, Existing 2.0786
# Underprod at time 742: Calculated 3.4574, Existing 2.0786
# Underprod at time 743: Calculated 3.4574, Existing 2.0786
# Underprod at time 744: Calculated 2.9276, Existing 2.0786
# Underprod at time 745: Calculated 3.4574, Existing 2.0786
# Underprod at time 746: Calculated 3.4574, Existing 2.0786
# Underprod at time 747: Calculated 2.9492, Existing 2.0786
# Underprod at time 748: Calculated 3.4574, Existing 2.0786
# Underprod at time 749: Calculated 3.4574, Existing 2.0786
# Underprod at time 750: Calculated 2.8441, Existing 2.0786
# Underprod at time 751: Calculated 3.4574, Existing 2.0786
# Underprod at time 752: Calculated 3.4574, Existing 2.0786
# Underprod at time 753: Calculated 2.5826, Existing 2.0786
# Underprod at time 754: Calculated 3.4574, Existing 2.0786
# Underprod at time 755: Calculated 3.4574, Existing 2.0786
# Underprod at time 756: Calculated 2.8359, Existing 2.0786
# Underprod at time 757: Calculated 3.4574, Existing 2.0786
# Underprod at time 758: Calculated 3.4574, Existing 2.0786
# Underprod at time 759: Calculated 3.1435, Existing 2.0786
# Underprod at time 760: Calculated 3.4574, Existing 2.0786
# Underprod at time 761: Calculated 3.4574, Existing 2.0786
# Underprod at time 762: Calculated 3.2055, Existing 2.0786
# Underprod at time 763: Calculated 3.4574, Existing 2.0786
# Underprod at time 764: Calculated 3.4574, Existing 2.0786
# Underprod at time 765: Calculated 3.1044, Existing 2.0786
# Underprod at time 766: Calculated 3.4574, Existing 2.0786
# Underprod at time 767: Calculated 3.4574, Existing 2.0786
# Underprod at time 768: Calculated 2.6164, Existing 2.0786
# Underprod at time 769: Calculated 3.4574, Existing 2.0786
# Underprod at time 770: Calculated 3.4574, Existing 2.0786
# Underprod at time 771: Calculated 2.2572, Existing 2.0786
# Underprod at time 772: Calculated 3.4574, Existing 2.0786
# Underprod at time 773: Calculated 3.4574, Existing 2.0786
# Underprod at time 774: Calculated 3.1064, Existing 2.0786
# Underprod at time 775: Calculated 3.4574, Existing 2.0786
# Underprod at time 776: Calculated 3.4574, Existing 2.0786
# Underprod at time 777: Calculated 3.4574, Existing 2.0786
# Underprod at time 778: Calculated 3.4574, Existing 2.0786
# Underprod at time 779: Calculated 3.4574, Existing 2.0786
# Underprod at time 780: Calculated 3.4574, Existing 2.0786
# Underprod at time 781: Calculated 3.4574, Existing 2.0786
# Underprod at time 782: Calculated 3.4574, Existing 2.0786
# Underprod at time 783: Calculated 3.4574, Existing 2.0786
# Underprod at time 784: Calculated 3.4574, Existing 2.0786
# Underprod at time 785: Calculated 3.4574, Existing 2.0786
# Underprod at time 786: Calculated 3.4574, Existing 2.0786
# Underprod at time 787: Calculated 3.4574, Existing 2.0786
# Underprod at time 788: Calculated 3.4574, Existing 2.0786
# Underprod at time 789: Calculated 3.4574, Existing 2.0786
# Underprod at time 790: Calculated 3.4574, Existing 2.0786
# Underprod at time 791: Calculated 3.4574, Existing 2.0786
# Underprod at time 792: Calculated 3.4574, Existing 2.0786
# Underprod at time 793: Calculated 3.4574, Existing 2.0786
# Underprod at time 794: Calculated 3.4574, Existing 2.0786
# Underprod at time 795: Calculated 3.4574, Existing 2.0786
# Underprod at time 796: Calculated 3.4574, Existing 2.0786
# Underprod at time 797: Calculated 3.4574, Existing 2.0786
# Underprod at time 798: Calculated 3.4574, Existing 2.0786
# Underprod at time 799: Calculated 3.4574, Existing 2.0786
# Underprod at time 800: Calculated 3.4574, Existing 2.0786
# Underprod at time 801: Calculated 3.4574, Existing 2.0786
# Underprod at time 802: Calculated 3.4574, Existing 2.0786
# Underprod at time 803: Calculated 3.4574, Existing 2.0786
# Underprod at time 804: Calculated 3.4574, Existing 2.0786
# Underprod at time 805: Calculated 3.4574, Existing 2.0786
# Underprod at time 806: Calculated 3.4574, Existing 2.0786
# Underprod at time 807: Calculated 3.4574, Existing 2.0786
# Underprod at time 808: Calculated 3.4574, Existing 2.0786
# Underprod at time 809: Calculated 3.4574, Existing 2.0786
# Underprod at time 810: Calculated 3.4574, Existing 2.0786
# Underprod at time 811: Calculated 3.4574, Existing 2.0786
# Underprod at time 812: Calculated 3.4574, Existing 2.0786
# Underprod at time 813: Calculated 3.4574, Existing 2.0786
# Underprod at time 814: Calculated 3.4574, Existing 2.0786
# Underprod at time 815: Calculated 3.4574, Existing 2.0786
# Underprod at time 816: Calculated 3.4574, Existing 2.0786
# Underprod at time 817: Calculated 3.4574, Existing 2.0786
# Underprod at time 818: Calculated 3.4574, Existing 2.0786
# Underprod at time 819: Calculated 3.4574, Existing 2.0786
# Underprod at time 820: Calculated 3.4574, Existing 2.0895
# Underprod at time 821: Calculated 3.4574, Existing 2.2035
# Exactprod at time 822: Calculated 0.8858, Existing 0.8858
# Underprod at time 823: Calculated 3.4574, Existing 2.0895
# Underprod at time 824: Calculated 3.4574, Existing 2.2035
# Exactprod at time 825: Calculated 1.0522, Existing 1.0522
# Underprod at time 826: Calculated 3.4574, Existing 2.0786
# Underprod at time 827: Calculated 3.4574, Existing 2.0786
# Underprod at time 828: Calculated 3.4574, Existing 2.0786
# ...
# Underprod at time 17278: Calculated 3.4574, Existing 2.0786
# Underprod at time 17279: Calculated 3.4574, Existing 2.0786
# Underprod at time 17280: Calculated 3.4574, Existing 2.0786
# Underprod at time 17281: Calculated 3.4574, Existing 2.0786
# Underprod at time 17282: Calculated 3.4574, Existing 2.0786
# Underprod at time 17283: Calculated 3.4574, Existing 2.0786
# Underprod at time 17284: Calculated 3.4574, Existing 2.0786
# Underprod at time 17285: Calculated 3.4574, Existing 2.0786
# Underprod at time 17286: Calculated 3.4574, Existing 2.0786
# Underprod at time 17287: Calculated 3.4574, Existing 2.0786
# Underprod at time 17288: Calculated 3.4574, Existing 2.0786
# Underprod at time 17289: Calculated 3.4409, Existing 2.0786
# Underprod at time 17290: Calculated 3.4574, Existing 2.0786
# Underprod at time 17291: Calculated 3.4574, Existing 2.0786
# Underprod at time 17292: Calculated 2.3974, Existing 2.0786
# Underprod at time 17293: Calculated 3.4574, Existing 2.0895
# Underprod at time 17294: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17295: Calculated 1.3485, Existing 1.3485
# Underprod at time 17296: Calculated 3.4574, Existing 2.0895
# Underprod at time 17297: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17298: Calculated 1.3085, Existing 1.3085
# Underprod at time 17299: Calculated 3.4574, Existing 2.0786
# Underprod at time 17300: Calculated 3.4574, Existing 2.0786
# Underprod at time 17301: Calculated 3.2578, Existing 2.0786
# Underprod at time 17302: Calculated 3.4574, Existing 2.0786
# Underprod at time 17303: Calculated 3.4574, Existing 2.0786
# Underprod at time 17304: Calculated 2.8687, Existing 2.0786
# Underprod at time 17305: Calculated 3.4574, Existing 2.0786
# Underprod at time 17306: Calculated 3.4574, Existing 2.0786
# Underprod at time 17307: Calculated 2.7391, Existing 2.0786
# Underprod at time 17308: Calculated 3.4574, Existing 2.0786
# Underprod at time 17309: Calculated 3.4574, Existing 2.0786
# Underprod at time 17310: Calculated 3.4574, Existing 2.0786
# Underprod at time 17311: Calculated 3.4574, Existing 2.0786
# Underprod at time 17312: Calculated 3.4574, Existing 2.0786
# Underprod at time 17313: Calculated 3.4574, Existing 2.0786
# Underprod at time 17314: Calculated 3.4574, Existing 2.0786
# Underprod at time 17315: Calculated 3.4574, Existing 2.0786
# Underprod at time 17316: Calculated 3.0898, Existing 2.0786
# Underprod at time 17317: Calculated 3.4574, Existing 2.0895
# Underprod at time 17318: Calculated 3.4574, Existing 2.2035
# Underprod at time 17319: Calculated 1.3681, Existing 1.3681
# Underprod at time 17320: Calculated 3.4574, Existing 2.0895
# Underprod at time 17321: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17322: Calculated 1.9417, Existing 1.9417
# Underprod at time 17323: Calculated 3.4574, Existing 2.0786
# Underprod at time 17324: Calculated 3.4574, Existing 2.0786
# Underprod at time 17325: Calculated 2.1406, Existing 2.0786
# Underprod at time 17326: Calculated 3.4574, Existing 2.0895
# Underprod at time 17327: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17328: Calculated 1.9284, Existing 1.9284
# Underprod at time 17329: Calculated 3.4574, Existing 2.0895
# Underprod at time 17330: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17331: Calculated 1.5299, Existing 1.5299
# Underprod at time 17332: Calculated 3.4574, Existing 2.0895
# Underprod at time 17333: Calculated 3.4574, Existing 2.2035
# Overprod at time 17334: Calculated 1.2569, Existing 1.2569
# Underprod at time 17335: Calculated 3.4574, Existing 2.0895
# Underprod at time 17336: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17337: Calculated 1.189, Existing 1.189
# Underprod at time 17338: Calculated 3.4574, Existing 2.0895
# Underprod at time 17339: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17340: Calculated 1.3555, Existing 1.3555
# Underprod at time 17341: Calculated 3.4574, Existing 2.0895
# Underprod at time 17342: Calculated 3.4574, Existing 2.2035
# Overprod at time 17343: Calculated 0.9697, Existing 0.9697
# Underprod at time 17344: Calculated 3.4574, Existing 2.0786
# Underprod at time 17345: Calculated 3.4574, Existing 2.0786
# Underprod at time 17346: Calculated 2.85, Existing 2.0786
# Underprod at time 17347: Calculated 3.4574, Existing 2.0786
# Underprod at time 17348: Calculated 3.4574, Existing 2.0786
# Underprod at time 17349: Calculated 3.4574, Existing 2.0786
# Underprod at time 17350: Calculated 3.4574, Existing 2.0786
# Underprod at time 17351: Calculated 3.4574, Existing 2.0786
# Underprod at time 17352: Calculated 3.3897, Existing 2.0786
# Underprod at time 17353: Calculated 3.4574, Existing 2.0786
# Underprod at time 17354: Calculated 3.4574, Existing 2.0786
# Underprod at time 17355: Calculated 2.3494, Existing 2.0786
# Underprod at time 17356: Calculated 3.4574, Existing 2.0895
# Underprod at time 17357: Calculated 3.4574, Existing 2.2035
# Underprod at time 17358: Calculated 1.8448, Existing 1.8448
# Underprod at time 17359: Calculated 3.4574, Existing 2.0895
# Underprod at time 17360: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17361: Calculated 1.6895, Existing 1.6895
# Underprod at time 17362: Calculated 3.4574, Existing 2.0895
# Underprod at time 17363: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17364: Calculated 0.7648, Existing 0.7648
# Underprod at time 17365: Calculated 3.4574, Existing 2.0895
# Underprod at time 17366: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17367: Calculated 0.8893, Existing 0.8893
# Underprod at time 17368: Calculated 3.4574, Existing 2.0895
# Underprod at time 17369: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17370: Calculated 0.8224, Existing 0.8224
# Underprod at time 17371: Calculated 3.4574, Existing 2.0895
# Underprod at time 17372: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17373: Calculated 0.86, Existing 0.86
# Underprod at time 17374: Calculated 3.4574, Existing 2.0895
# Underprod at time 17375: Calculated 3.4574, Existing 2.2035
# Underprod at time 17376: Calculated 0.7026, Existing 0.7026
# Underprod at time 17377: Calculated 3.4574, Existing 2.0895
# Underprod at time 17378: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17379: Calculated 0.5665, Existing 0.5665
# Underprod at time 17380: Calculated 3.4574, Existing 2.0895
# Underprod at time 17381: Calculated 3.4574, Existing 2.2035
# Underprod at time 17382: Calculated 0.1995, Existing 0.1995
# Underprod at time 17383: Calculated 3.4574, Existing 2.0895
# Underprod at time 17384: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17385: Calculated 0.6557, Existing 0.6557
# Underprod at time 17386: Calculated 3.4574, Existing 2.0895
# Underprod at time 17387: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17388: Calculated 1.6357, Existing 1.6357
# Underprod at time 17389: Calculated 3.4574, Existing 2.0786
# Underprod at time 17390: Calculated 3.4574, Existing 2.0786
# Underprod at time 17391: Calculated 2.6832, Existing 2.0786
# Underprod at time 17392: Calculated 3.4574, Existing 2.0786
# Underprod at time 17393: Calculated 3.4574, Existing 2.0786
# Underprod at time 17394: Calculated 3.4574, Existing 2.0786
# Underprod at time 17395: Calculated 3.4574, Existing 2.0786
# Underprod at time 17396: Calculated 3.4574, Existing 2.0786
# Underprod at time 17397: Calculated 3.4574, Existing 2.0786
# Underprod at time 17398: Calculated 3.4574, Existing 2.0786
# Underprod at time 17399: Calculated 3.4574, Existing 2.0786
# Underprod at time 17400: Calculated 3.4574, Existing 2.0786
# Underprod at time 17401: Calculated 3.4574, Existing 2.0786
# Underprod at time 17402: Calculated 3.4574, Existing 2.0786
# Underprod at time 17403: Calculated 3.4574, Existing 2.0786
# Underprod at time 17404: Calculated 3.4574, Existing 2.0786
# Underprod at time 17405: Calculated 3.4574, Existing 2.0786
# Underprod at time 17406: Calculated 3.1339, Existing 2.0786
# Underprod at time 17407: Calculated 3.4574, Existing 2.0786
# Underprod at time 17408: Calculated 3.4574, Existing 2.0786
# Underprod at time 17409: Calculated 3.4574, Existing 2.0786
# Underprod at time 17410: Calculated 3.4574, Existing 2.0786
# Underprod at time 17411: Calculated 3.4574, Existing 2.0786
# Underprod at time 17412: Calculated 3.4574, Existing 2.0786
# Underprod at time 17413: Calculated 3.4574, Existing 2.0786
# Underprod at time 17414: Calculated 3.4574, Existing 2.0786
# Underprod at time 17415: Calculated 3.4574, Existing 2.0786
# Underprod at time 17416: Calculated 3.4574, Existing 2.0786
# Underprod at time 17417: Calculated 3.4574, Existing 2.0786
# Underprod at time 17418: Calculated 3.4574, Existing 2.0786
# Underprod at time 17419: Calculated 3.4574, Existing 2.0786
# Underprod at time 17420: Calculated 3.4574, Existing 2.0786
# Underprod at time 17421: Calculated 3.4574, Existing 2.0786
# Underprod at time 17422: Calculated 3.4574, Existing 2.0786
# Underprod at time 17423: Calculated 3.4574, Existing 2.0786
# Underprod at time 17424: Calculated 3.4574, Existing 2.0786
# Underprod at time 17425: Calculated 3.4574, Existing 2.0786
# Underprod at time 17426: Calculated 3.4574, Existing 2.0786
# Underprod at time 17427: Calculated 3.4574, Existing 2.0786
# Underprod at time 17428: Calculated 3.4574, Existing 2.0786
# Underprod at time 17429: Calculated 3.4574, Existing 2.0786
# Underprod at time 17430: Calculated 3.4574, Existing 2.0786
# Underprod at time 17431: Calculated 3.4574, Existing 2.0786
# Underprod at time 17432: Calculated 3.4574, Existing 2.0786
# Underprod at time 17433: Calculated 3.4574, Existing 2.0786
# Underprod at time 17434: Calculated 3.4574, Existing 2.0786
# Underprod at time 17435: Calculated 3.4574, Existing 2.0786
# Underprod at time 17436: Calculated 3.4574, Existing 2.0786
# Underprod at time 17437: Calculated 3.4574, Existing 2.0786
# Underprod at time 17438: Calculated 3.4574, Existing 2.0786
# Underprod at time 17439: Calculated 3.4574, Existing 2.0786
# Underprod at time 17440: Calculated 3.4574, Existing 2.0786
# Underprod at time 17441: Calculated 3.4574, Existing 2.0786
# Underprod at time 17442: Calculated 3.4574, Existing 2.0786
# Underprod at time 17443: Calculated 3.4574, Existing 2.0786
# Underprod at time 17444: Calculated 3.4574, Existing 2.0786
# Underprod at time 17445: Calculated 3.4574, Existing 2.0786
# Underprod at time 17446: Calculated 3.4574, Existing 2.0786
# Underprod at time 17447: Calculated 3.4574, Existing 2.0786
# Underprod at time 17448: Calculated 3.4574, Existing 2.0786
# Underprod at time 17449: Calculated 3.4574, Existing 2.0786
# Underprod at time 17450: Calculated 3.4574, Existing 2.0786
# Underprod at time 17451: Calculated 3.2875, Existing 2.0786
# Underprod at time 17452: Calculated 3.4574, Existing 2.0786
# Underprod at time 17453: Calculated 3.4574, Existing 2.0786
# Underprod at time 17454: Calculated 3.3276, Existing 2.0786
# Underprod at time 17455: Calculated 3.4574, Existing 2.0786
# Underprod at time 17456: Calculated 3.4574, Existing 2.0786
# Underprod at time 17457: Calculated 2.9736, Existing 2.0786
# Underprod at time 17458: Calculated 3.4574, Existing 2.0786
# Underprod at time 17459: Calculated 3.4574, Existing 2.0786
# Underprod at time 17460: Calculated 2.5973, Existing 2.0786
# Underprod at time 17461: Calculated 3.4574, Existing 2.0786
# Underprod at time 17462: Calculated 3.4574, Existing 2.0786
# Underprod at time 17463: Calculated 2.4532, Existing 2.0786
# Underprod at time 17464: Calculated 3.4574, Existing 2.0786
# Underprod at time 17465: Calculated 3.4574, Existing 2.0786
# Underprod at time 17466: Calculated 2.2951, Existing 2.0786
# Underprod at time 17467: Calculated 3.4574, Existing 2.0786
# Underprod at time 17468: Calculated 3.4574, Existing 2.0786
# Underprod at time 17469: Calculated 2.1757, Existing 2.0786
# Underprod at time 17470: Calculated 3.4574, Existing 2.0786
# Underprod at time 17471: Calculated 3.4574, Existing 2.0786
# Underprod at time 17472: Calculated 2.1059, Existing 2.0786
# Underprod at time 17473: Calculated 3.4574, Existing 2.0895
# Underprod at time 17474: Calculated 3.4574, Existing 2.2035
# Underprod at time 17475: Calculated 1.8789, Existing 1.8789
# Underprod at time 17476: Calculated 3.4574, Existing 2.0895
# Underprod at time 17477: Calculated 3.4574, Existing 2.2035
# Underprod at time 17478: Calculated 1.6896, Existing 1.6896
# Underprod at time 17479: Calculated 3.4574, Existing 2.0786
# Underprod at time 17480: Calculated 3.4574, Existing 2.0786
# Underprod at time 17481: Calculated 2.3793, Existing 2.0786
# Underprod at time 17482: Calculated 3.4574, Existing 2.0786
# Underprod at time 17483: Calculated 3.4574, Existing 2.0786
# Underprod at time 17484: Calculated 3.4574, Existing 2.0786
# Underprod at time 17485: Calculated 3.4574, Existing 2.0786
# Underprod at time 17486: Calculated 3.4574, Existing 2.0786
# Underprod at time 17487: Calculated 3.4574, Existing 2.0786
# Underprod at time 17488: Calculated 3.4574, Existing 2.0786
# Underprod at time 17489: Calculated 3.4574, Existing 2.0786
# Underprod at time 17490: Calculated 3.4574, Existing 2.0786
# Underprod at time 17491: Calculated 3.4574, Existing 2.0786
# Underprod at time 17492: Calculated 3.4574, Existing 2.0786
# Underprod at time 17493: Calculated 3.4574, Existing 2.0786
# Underprod at time 17494: Calculated 3.4574, Existing 2.0786
# Underprod at time 17495: Calculated 3.4574, Existing 2.0786
# Underprod at time 17496: Calculated 2.9697, Existing 2.0786
# Underprod at time 17497: Calculated 3.4574, Existing 2.0786
# Underprod at time 17498: Calculated 3.4574, Existing 2.0786
# Underprod at time 17499: Calculated 2.3289, Existing 2.0786
# Underprod at time 17500: Calculated 3.4574, Existing 2.0786
# Underprod at time 17501: Calculated 3.4574, Existing 2.0786
# Underprod at time 17502: Calculated 2.1084, Existing 2.0786
# Underprod at time 17503: Calculated 3.4574, Existing 2.0895
# Underprod at time 17504: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17505: Calculated 1.4867, Existing 1.4867
# Underprod at time 17506: Calculated 3.4574, Existing 2.0895
# Underprod at time 17507: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17508: Calculated 1.3047, Existing 1.3047
# Underprod at time 17509: Calculated 3.4574, Existing 2.0895
# Underprod at time 17510: Calculated 3.4574, Existing 2.2035
# Overprod at time 17511: Calculated 0.9087, Existing 0.9087
# Underprod at time 17512: Calculated 3.4574, Existing 2.0895
# Underprod at time 17513: Calculated 3.4574, Existing 2.2035
# Underprod at time 17514: Calculated 0.6064, Existing 0.6064
# Underprod at time 17515: Calculated 3.4574, Existing 2.0895
# Underprod at time 17516: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17517: Calculated 0.9471, Existing 0.9471
# Underprod at time 17518: Calculated 3.4574, Existing 2.0786
# Underprod at time 17519: Calculated 3.4574, Existing 2.0786
# Underprod at time 17520: Calculated 2.5736, Existing 2.0786
# Underprod at time 17521: Calculated 3.4574, Existing 2.0786
# Underprod at time 17522: Calculated 3.4574, Existing 2.0786
# Underprod at time 17523: Calculated 2.1637, Existing 2.0786
# Underprod at time 17524: Calculated 3.4535, Existing 2.0895
# Underprod at time 17525: Calculated 3.4486, Existing 2.2035
# Exactprod at time 17526: Calculated 1.4441, Existing 1.4441
# Underprod at time 17527: Calculated 3.4574, Existing 2.0895
# Underprod at time 17528: Calculated 3.4574, Existing 2.2035
# Exactprod at time 17529: Calculated 0.8076, Existing 0.8076
# Underprod at time 17530: Calculated 3.4574, Existing 2.0895
# Underprod at time 17531: Calculated 3.4574, Existing 2.2035
# Overprod at time 17532: Calculated 1.4943, Existing 1.4943
# Underprod at time 17533: Calculated 3.4574, Existing 2.0895
# Underprod at time 17534: Calculated 3.4574, Existing 2.2035
# Overprod at time 17535: Calculated 1.4632, Existing 1.4632
# Underprod at time 17536: Calculated 3.4574, Existing 2.0786
# Underprod at time 17537: Calculated 3.4574, Existing 2.0786
# Underprod at time 17538: Calculated 2.6092, Existing 2.0786
# Underprod at time 17539: Calculated 3.4574, Existing 2.0786
# Underprod at time 17540: Calculated 3.4574, Existing 2.0786
# Underprod at time 17541: Calculated 3.4574, Existing 2.0786
# Underprod at time 17542: Calculated 3.4574, Existing 2.0786
# Underprod at time 17543: Calculated 3.4574, Existing 0.0275

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_storage_dynamics(battery_data, hydrogen_data, methane_data_src, methane_data_dest, start_date='2015-01-01'):
    # Create date range for the datasets
    date_range = pd.date_range(start=start_date, periods=len(battery_data), freq='H')

    # Create DataFrames
    battery_df = pd.DataFrame(battery_data, index=date_range, columns=['Battery'])
    hydrogen_df = pd.DataFrame(hydrogen_data, index=date_range, columns=['Hydrogen'])
    methane_df_gr = pd.DataFrame(methane_data_src, index=date_range, columns=['Methane'])
    methane_df_be = pd.DataFrame(methane_data_dest, index=date_range, columns=['Methane'])


    # Smooth the data with a rolling mean
    battery_df['Smoothed'] = battery_df['Battery'].rolling(window=24).mean()
    hydrogen_df['Smoothed'] = hydrogen_df['Hydrogen'].rolling(window=24).mean()
    methane_df_gr['Smoothed'] = methane_df_gr['Methane'].rolling(window=24).mean()
    methane_df_be['Smoothed'] = methane_df_be['Methane'].rolling(window=24).mean()

    # Plotting
    fig, axs = plt.subplots(4, 1, figsize=(12, 8), sharex=True)

    colors = plt.cm.viridis(np.linspace(0, 1, 4))

    # Plot each storage type
    for ax, df, color, label in zip(axs,
                                    [battery_df, hydrogen_df, methane_df_gr, methane_df_be],
                                    colors,
                                    ['Battery Storage Dynamics', 'Hydrogen Storage Dynamics', 'Liquid Methane Storage Dynamics (Greenland)', 'Liquid Methane Storage Dynamics (Belgium)']):
        ax.fill_between(df.index, df['Smoothed'], color=color)
        ax.set_title(label, fontsize=10, loc='left')
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.set_ylabel('GWh')

    # Adjust layout and show plot
    fig.tight_layout()
    plt.show()

# %%
battery_flow = np.array(d.solution.elements.BATTERY_STORAGE_GR.variables.electricity_stored.values)
h2_flow = np.array(d.solution.elements.HYDROGEN_STORAGE_GR.variables.hydrogen_stored.values)
lch4_flow_gr = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_HUB_GR.variables.liquefied_methane_stored.values)
lch4_flow_be = np.array(d.solution.elements.LIQUEFIED_METHANE_STORAGE_DESTINATION.variables.liquefied_methane_stored.values)

plot_storage_dynamics(battery_flow, h2_flow, lch4_flow_gr, lch4_flow_be)

print(battery_flow[-1])
print(h2_flow[-1])
print(lch4_flow_gr[-1])
print(lch4_flow_be[-1])
# Out:
# 0.0
# 12.806041034925425
# 10.657891138972225
# 5.715802232037658

# %%
leftover_lch4 = (lch4_flow_be[-1] + lch4_flow_gr[-1]) * 0.98 * 15.31 *1e3

leftover_lch4 # MWh
# Out:
# 245667.62059995806

# %%
demand_in_mwh = gas_prod * 1e3  # Convert TWh to MWh
total_cost_in_euros = tot_cost * 1e6  # Convert million euros to euros

# Compute price per MWh in euros
price_per_mwh = total_cost_in_euros / (demand_in_mwh+leftover_lch4)

print(f"The price is {round(price_per_mwh, 3)} €/MWh \n")
print("In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh")  # Adjusted to €/MWh
print("This system is about", round((price_per_mwh / 45), 3), "times more expensive compared to a reference price of 45 €/MWh")
# Out:
# The price is 186.583 €/MWh
#
# In February 2024, the natural gas price is between 40.2 and 51.5 €/MWh
# This system is about 4.146 times more expensive compared to a reference price of 45 €/MWh

# %%
import calendar

def energy_demand():
    def daily_sum(ts):
        elec = np.array(ts[0])
        elec = elec.reshape((elec.shape[0]//24, 24))
        sum_elec = np.sum(elec, axis=1)
        
        return sum_elec

    df_elec = pd.read_csv("../../data/demand_el.csv", header=None)
    df_gas = pd.read_csv("../../data/demand_ng.csv", header=None)

    sum_elec = daily_sum(df_elec)
    sum_gas = daily_sum(df_gas)

    years = 2

    month_names = [calendar.month_name[i] for i in range(1, 13)]
    month_names = list(map(lambda x: x + " 2015", month_names)) + list(map(lambda x: x + " 2016", month_names)) + ['']

    # month_names = [calendar.month_name[i] for i in range(1, 13)] * years + [''] # add a placeholder string

    tmp = (sum_elec.shape[0] // 3) * years
    months= [x for x in range(0,tmp)]

    days = [x for x in range(tmp)]

    plt.figure(figsize=(10,8))

    color1, color2 = 'steelblue', 'lightcoral'

    linewidth = 2

    plt.plot([],[], color=color2, label='Gas', linewidth=linewidth)

    plt.stackplot(days, sum_gas[:tmp], colors=[color2], alpha=.7, linewidth=linewidth)

    plt.legend()
    plt.xlim(0, tmp)
    freq = 4
    plt.xticks(months[::30*freq], month_names[::freq], rotation=0)

    plt.ylabel('Energy demand [GWh/day]')

    plt.axhline(color='black', linewidth=1)

    plt.show()

# %%
energy_demand()
